# %% [markdown]
# # Algoritmo Genético Versão Ensamble
#
# Essa versão inclui:
# - Otimização da rota (V1)
# - Otimização da quantidade de waypoints (V2)
# - Risco Inflado: Inflação das áreas não-navegáveis (V3)
# - Alocação de risco (V3.5)

# %% [markdown]
# # 1. Utils
# Essa seção contém funções auxiliares para o algoritmo. Não é necessário mexer nessa parte
# (Feche essa aba)

# %% [markdown]
# ## utils.py

# %%
import itertools
from scipy.stats import norm

# Support Functions
# _________________________________________________________________________________________________
def pairwise_circle(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ... (s<last>,s0)"
    a, b = itertools.tee(iterable)
    first_value = next(b, None)
    return itertools.zip_longest(a, b,fillvalue=first_value)

def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = itertools.tee(iterable)
    next(b, None)
    return zip(a, b)

def boundary(val, val_min, val_max):
  if val<val_min:
    return val_min
  if val>val_max:
    return val_max
  return val

# Ray Casting Algorithm
# _________________________________________________________________________________________________
epsilon = 0.00001  # Used on the Ray-Tracing Algorithm

def point_in_polygon(point, polygon):
    # Using ray_casting algorithm
    # https://rosettacode.org/wiki/Ray-casting_algorithm

    count = 0
    
    for vertex1, vertex2 in pairwise_circle(polygon):

        if vertex1.y < vertex2.y:
            A = vertex1
            B = vertex2
        else:
            A = vertex2
            B = vertex1

        if ray_intersects_segment(point, A, B):
            count += 1

    if count % 2 == 0: # Odd
        return False 
    else:
        return True # Inside the polygon
    

def ray_intersects_segment(P, A, B):
    # P : the point from which the ray starts
    # A : the end-point of the segment with the smallest y coordinate
    #     (A must be "below" B)
    # B : the end-point of the segment with the greatest y coordinate
    #     (B must be "above" A)

    # To avoid the "ray on vertex" problem, the point is moved upward of a small quantity epsilon.
    if P.y == A.y or P.y == B.y:
        P.y += epsilon

    # Point higher or lower than polygon
    if P.y < A.y or P.y > B.y:
        return False

    # Point to the right of the polygon
    elif P.x >= max(A.x, B.x):
        return False 

    else:

        if P.x < min(A.x, B.x):
            return True

        else:

            if A.x != B.x:
                m_red = (B.y - A.y)/(B.x - A.x)
            else:
                m_red = 99999999 # Infinite


            if A.x != P.x:
                m_blue = (P.y - A.y)/(P.x - A.x)
            else:
                m_blue = 99999999 # Infinite


            if m_blue >= m_red:
                return True
            else:
                return False



# Segment Intersection
# _________________________________________________________________________________________________
def segment_in_polygon(wp1, wp2, polygon):
    # count = 0
    #print('Segment: {}-{}'.format(wp1,wp2))

    for vertex1, vertex2 in pairwise_circle(polygon):
        A = vertex1
        B = vertex2
        #if vertex1.y < vertex2.y:
        #    A = vertex1
        #    B = vertex2
        #else:
        #    A = vertex2
        #    B = vertex1
        #print('Polygon edge: {}-{}'.format(A, B))

        if segment_intersects_segment(wp1, wp2, A, B):
            return True
    return False
    # if count > 1:
    #     return True 
    # else:
    #     return False 
    

def segment_intersects_segment(p1, q1, p2, q2):
    # Returns true if line segment 'p1q1' and 'p2q2' intersect. 
    # Based on the algorithm from https://www.geeksforgeeks.org/check-if-two-given-line-segments-intersect/

    
    # Two segments (p1,q1) and (p2,q2) intersect if and only if one of the following two conditions is verified:
    #
    # 1. General Case:
    # – (p1, q1, p2) and (p1, q1, q2) have different orientations and
    # – (p2, q2, p1) and (p2, q2, q1) have different orientations.
    #
    # 2. Special Case
    # – (p1, q1, p2), (p1, q1, q2), (p2, q2, p1), and (p2, q2, q1) are all collinear and
    # – the x-projections of (p1, q1) and (p2, q2) intersect
    # – the y-projections of (p1, q1) and (p2, q2) intersect
    
    
    # Find the four orientations needed for general and 
    # special cases 
    o1 = orientation(p1, q1, p2) 
    o2 = orientation(p1, q1, q2) 
    o3 = orientation(p2, q2, p1) 
    #print(p2, q2, p1, o3)
    o4 = orientation(p2, q2, q1) 
    #print(o1,o2,o3,o4)
    
    # 1. General case 
    if o1 != o2 and o3 != o4:
        return True  


    # 2. Special Cases 
    # p1, q1 and p2 are colinear and p2 lies on segment p1q1 
    if o1 == 0 and on_segment(p1, p2, q1): 
        return True 
  
    # p1, q1 and q2 are colinear and q2 lies on segment p1q1 
    if o2 == 0 and on_segment(p1, q2, q1):
        return True 
  
    # p2, q2 and p1 are colinear and p1 lies on segment p2q2 
    if o3 == 0 and on_segment(p2, p1, q2):
        return True 
  
    # p2, q2 and q1 are colinear and q1 lies on segment p2q2 
    if o4 == 0 and on_segment(p2, q1, q2):
        return True 
  
    
    # Doesn't fall in any of the above cases 
    return False 
    
    
def on_segment(p, q, r):
    # Given three colinear points p, q, r, the function checks if 
    # point q lies on line segment 'pr' 
    if (q.x <= max(p.x, r.x) and q.x >= min(p.x, r.x) 
    and q.y <= max(p.y, r.y) and q.y >= min(p.y, r.y)):
        return True
    else:
        return False
    
    
def orientation(p, q, r):
    # To find orientation of ordered triplet (p, q, r). 
    # The function returns following values 
    # 0 --> p, q and r are colinear 
    # 1 --> Clockwise 
    # 2 --> Counterclockwise 
    
    # See https://www.geeksforgeeks.org/orientation-3-ordered-points/ 
    # for details of below formula. 
      
    val =( (q.y - p.y) * (r.x - q.x) 
         - ((q.x - p.x) * (r.y - q.y)))
    #print('\n---\ndebug')
    #print((q.y - p.y), (r.x - q.x), (q.x - p.x), (r.y - q.y))
    #print(val)
    if val == 0:
        return 0         # colinear

    return (1 if val > 0 else 2)  # clock or counterclock wise



# Chance Constraint
# _________________________________________________________________________________________________

def risk_total(wp, area, imprecision):   
    distance_total = math.inf

    maior = 0 #M1
    soma = 0 #M2

    if debug:
        print('maior, soma, wp_risk, distance_total')
    for A, B in pairwise(area):
        # segmento A-B

        # plano determinado pela equação ax + by + cz + d = 0, onde (a, b, c) é o vetor normal
        x = A.x - B.x
        y = A.y - B.y
        # direction_vector = (x, y) # vector in the same direction of the line that connects A and B
        # normal_vector = [-y, x] # rotate the direction vector by 90º. (x, y) -> (-y, x) 
        normal_vector = [-y/(sqrt((y**2)+(x**2))), x/(sqrt((y**2)+(x**2)))] # dividindo pela norma, normalizando o vetor

        b = (-y) * A.x + x * A.y # Coeficiente da reta

        distance = wp.x * normal_vector[0] + wp.y * normal_vector[1] - b
        #print(distance)
        distance_total = min(distance_total, distance)
        wp_risk  = risk(distance_total, imprecision)
        # maior = max(maior, wp_risk) #M1
        # soma += wp_risk #M2
        if debug:
            print(maior, soma, wp_risk, distance_total, '--', wp, A, B)
    
    

    return wp_risk
    #return maior #M1
    #return soma #M2


def risk(distance, imprecision):
    # Survival function (also defined as 1 - cdf, but sf is sometimes more accurate).
    # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

    # mi    : média         : location
    # sigma : desvio padrão : scale

    return norm.sf(distance, loc=0, scale=imprecision)

# %% [markdown]
# ## visualization.py

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path

import plotly.graph_objects as go

from sklearn import preprocessing


cor_area_nn    = '#25283d' # Yankees Blue
cor_area_p     = '#8f3985' # Plum
cor_area_b     = '#07beb8' # Tiffany Blue
cor_waypoints  = '#aa1155' # Jazzberry Jam
cor_ori_dest   = '#880044' # Pink Raspberry


def new_shape(vertices, color='navajowhite', lw=.25):

    assert len(vertices) >= 3, 'At least 3 vertices to form a shape'

    colors = {
        'n': cor_area_nn,
        'p': cor_area_p,
        'b': cor_area_b
    }
    
    color = colors[color] if color in colors else color
    
    codes = [Path.MOVETO]
    for _ in range(1, len(vertices)-1):
        codes.append(Path.LINETO)
    codes.append(Path.CLOSEPOLY)
    
    path = Path(vertices, codes)

    patch = patches.PathPatch(path, facecolor=color, lw=lw, alpha=0.6)

    return patch


def plot_map(wp_style='-x', **kwargs):
    # Optional arguments:
    # areas, labels, origem, destino, waypoints, texts

    fig, ax = plt.subplots(figsize=(8,8)) 
    
    # Plot areas
    if 'areas' in kwargs and 'labels' in kwargs:
        areas=kwargs['areas']
        labels=kwargs['labels']
        patches = [ new_shape(vertice, color=label) for vertice, label in zip(areas, labels) ]
        for patch in patches:
            ax.add_patch(patch)
        
    # Plot origin and destination
    if 'origem' in kwargs and 'destino' in kwargs:
        origem=kwargs['origem']
        destino=kwargs['destino']
        ax.plot([origem[0], destino[0]], [origem[1], destino[1]], 'o', color=cor_ori_dest)
    
    # Plot waypoints and route
    if 'waypoints' in kwargs:
        waypoints=kwargs['waypoints']
        waypoints = list(map(list, zip(*waypoints)))
        ax.plot(waypoints[0], waypoints[1], wp_style, color=cor_waypoints, linewidth=2) #marker='x', linestyle='solid'
        if 'texts' in kwargs:
            for i, text in enumerate(kwargs['texts']):
                ax.annotate(text, (waypoints[0][i], waypoints[1][i]))
    
    if 'stress' in kwargs:
        # Plot waypoints
        if 'points' in kwargs:
            for wp, text in zip(kwargs['points'], kwargs['texts']):
                if text=='T':
                    in_color=cor_area_b
                else:
                    in_color=cor_waypoints

                ax.plot(wp[0], wp[1], wp_style, color=in_color, linewidth=2)
                ax.annotate(text, (wp[0], wp[1]))

        # Plot segments
        if 'segments' in kwargs and 'texts' in kwargs:
            i=0
            for segment, text in zip(kwargs['segments'], kwargs['texts']):
                X = [segment[0].x, segment[1].x]
                Y = [segment[0].y, segment[1].y]

                if text=='T':
                    in_color=cor_area_b
                else:
                    in_color=cor_waypoints
                ax.plot(X, Y, wp_style, color=in_color, linewidth=2)
                ax.annotate(text+str(i), (X[0], Y[0]))
                i+=1
    
    # Set size
    automin, automax = ax.get_xlim()
    plt.xlim(automin-0.5, automax+0.5)
    automin, automax = ax.get_ylim()
    plt.ylim(automin-0.5, automax+0.5)
    plt.gca().set_aspect('equal', adjustable='box')
    
    if 'title' in kwargs:
        plt.title(kwargs['title'])
    
    plt.show()
    #plt.savefig('out.png')

def plot_stats(ag_trace, normalize=True):
    dft = pd.DataFrame.from_dict(ag_trace)
    
    if normalize:
        x = dft.values #returns a numpy array
        min_max_scaler = preprocessing.MinMaxScaler()
        x_scaled = min_max_scaler.fit_transform(x)
        dft = pd.DataFrame(x_scaled, columns=dft.columns)

    fig = go.Figure()

    for column in dft.columns:
        fig.add_trace(go.Scatter(x=dft.index, y=dft[column], name=column))
    fig.show()

# %%
def vis_mapa(mapa):
    areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
    tipos = [ 'n' for _ in range(len(areas))]
    plot_map(
        areas=areas,             # Mapa usado
        labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
        origem=mapa.origin,      # waypoint de origem
        destino=mapa.destination # waypoint de destino   
    )

# %% [markdown]
# ## data_definitions.py

# %%
import collections
import math

CartesianPoint = collections.namedtuple('CartesianPoint', 'x y')
GeoPoint = collections.namedtuple('GeoPoint', 'latitude, longitude, altitude')
Version = collections.namedtuple('Version', 'major, minor')

class Mapa():
    def __init__(self, origin, destination, areas_n, inflation_rate=0.1, mode='scalar'):
        self.origin = origin           # CartesianPoint : Define o ponto de partida da rota
        self.destination = destination # CartesianPoint : Define o ponto de destino da rota
        self.areas_n = areas_n         # [area, ...]
                                       # area = [CartesianPoint(),...]      
        self.areas_n_inf = [ self._inflate_area(area, inflation_rate=inflation_rate, mode=mode) for area in areas_n ]
        
        
    def _inflate_area(self, area, inflation_rate, mode):
        if mode == 'percentage':
            # Infla uma área retangular em uma porcentagem do tamanho, alterando os valores em x% de cada vértice
            x = area[2].x - area[0].x
            y = area[1].y - area[3].y

            inc = (inflation_rate)
            dec = -(inflation_rate)

            new_area = [
                CartesianPoint(area[0].x + dec * x, area[0].y + dec * y), # left,  bottom
                CartesianPoint(area[1].x + dec * x, area[1].y + inc * y), # left,  top
                CartesianPoint(area[2].x + inc * x, area[2].y + inc * y), # right, top
                CartesianPoint(area[3].x + inc * x, area[3].y + dec * y)  # right, bottom
            ]
            new_area.append(new_area[0]) # Repetir primeiro ponto, para o ignore do shape na hora de plotar
        
        elif mode == 'scalar':
            # Infla uma área retangular em uma quantidade fixa
            inc = (inflation_rate)
            dec = -(inflation_rate)

            new_area = [
                CartesianPoint(area[0].x + dec, area[0].y + dec), # left,  bottom
                CartesianPoint(area[1].x + dec, area[1].y + inc), # left,  top
                CartesianPoint(area[2].x + inc, area[2].y + inc), # right, top
                CartesianPoint(area[3].x + inc, area[3].y + dec)  # right, bottom
            ]
            new_area.append(new_area[0]) # Repetir primeiro ponto, para o ignore do shape na hora de plotar
        
        
        return new_area



class Conversor():

    def list_geo_to_cart( l, geo_home):
        for i in l:
            yield Conversor.geo_to_cart(i, geo_home)

    def list_cart_to_geo( l, geo_home):
        for i in l:
            yield Conversor.cart_to_geo(i, geo_home)


    def geo_to_cart( geo_point, geo_home):
        
        def calc_y(lat, lat_):
            return (lat - lat_) * (10000000.0 / 90)
        def calc_x(longi, longi_, lat_):
            return (longi - longi_) * (6400000.0 * (math.cos(lat_ * math.pi / 180) * 2 * math.pi / 360))

        x = calc_x(geo_point.longitude, geo_home.longitude, geo_home.latitude)
        y = calc_y(geo_point.latitude, geo_home.latitude)

        #return CartesianPoint(x, y, geo_point.altitude)
        return CartesianPoint(x, y)


    def cart_to_geo( cartesian_point, geo_home):

        def calc_latitude_y(lat_, y):
            return ((y * 90) / 10000000.0) + lat_
        def calc_longitude_x(lat_, longi_, x):
            return ((x * 90) / (10008000 * math.cos(lat_ * math.pi / 180))) + longi_


        longitude_x = calc_longitude_x(geo_home.latitude, geo_home.longitude, cartesian_point.x)
        latitude_y = calc_latitude_y(geo_home.latitude, cartesian_point.y)

        #return GeoPoint(longitude_x, latitude_y, cartesian_point.z)
        return GeoPoint(longitude_x, latitude_y, 10)

# %% [markdown]
# ## file_manipulation.py

# %%
def upload_mapa(mapa_file, mapa_id):
    mapa = mapa_file[mapa_id]

    geo_home = GeoPoint(mapa['geo_home'][1], mapa['geo_home'][0], mapa['geo_home'][2])

    areas_bonificadoras  = [ Conversor.list_geo_to_cart(area['geo_points'], geo_home) for area in mapa['areas_bonificadoras'] ]
    areas_penalizadoras  = [ Conversor.list_geo_to_cart(area['geo_points'], geo_home) for area in mapa['areas_penalizadoras'] ]
    
    areas_nao_navegaveis = []
    for area in mapa['areas_nao_navegaveis']:
        geo_points=[]
        for geo_point in area['geo_points']:
            geo_points.append(Conversor.geo_to_cart(
                GeoPoint(geo_point[1], geo_point[0], geo_point[2]) 
                , geo_home))
        geo_points.append(geo_points[0])
        areas_nao_navegaveis.append(geo_points)



    return geo_home, areas_bonificadoras, areas_penalizadoras, areas_nao_navegaveis

# %% [markdown]
# # 2. Algoritmo Genético
# Essa seção contém a implementação do algoritmo genético, contendo a definição da classe indivíduo (Subject) e da classe do genético (Genetic).
# Aqui está a implementação, não é necessário mexer, a menos que queira mudar alguma coisa na lógica da solução. **Caso somente queira mexer nos parâmetros, pule para a próxima etapa**

# %% [markdown]
# ### Utilitários

# %%
import collections
import random
import time
import copy

from math import cos, sin, sqrt, ceil

from itertools import tee
#from utils import pairwise, point_in_polygon, segment_in_polygon

Gene           = collections.namedtuple('Gene', 'a e')
GeneDecoded    = collections.namedtuple('GeneDecoded', 'x y v al')

# %% [markdown]
# ## 2.1. Definição do Indivíduo

# %%
class Subject():
    
    # codificação - u
    # dna = [Gene, ...]
    #     Gene = [a, e]
    #         a = float: aceleração
    #         e = float: variação angular


    # decodificação - x
    # dna_decoded = [GeneDecoded, ...]
    #     GeneDecoded = (x, y, v, al)
    #         x  = : Posição do VANT no eixo x (aka px)
    #         y  = : Posição do VANT no eixo y (aka py)
    #         v  = : Velocidade do VANT na horizontal
    #         al = : ângulo (direção) do VANT na horizontal
    def __init__(
        self,
        px0=10.,
        py0=10.,
        v0=0,
        al0=0,
        v_min=11.1,
        v_max=30.5,
        e_min=-3,        
        e_max=3,
        a_min=-2.0,
        a_max=2.0,
        T=10,
        T_min=1,
        T_max=7,
        delta_T=1,
        m=743.0,
        mutation_prob=0.7,
        start_time=None,
        spawn_mode='random',
        version=None,
        **kwargs
    ):
        # VANT
        # px0   int : Posição inicial no eixo x (m)
        # py0   int : Posição inicial no eixo y (m)
        # v0    int : Velocidade Inicial (m/s)
        # al0   int : Ângulo inicial (graus)
        self.gene_decoded_0 = GeneDecoded(px0, py0, v0, al0) # GeneDecoded : objeto contendo o gene decodificado de posição 0
        self.v_min = v_min # float : Velocidade máxima (m/s)
        self.v_max = v_max # float : Velocidade mínima (m/s)
        self.e_min = e_min # int   : Velocidade angular mínima (graus/s)
        self.e_max = e_max # int   : Velocidade angular máxima (graus/s)
        self.a_min = a_min # float : Aceleração mínima (m/s**2)
        self.a_max = a_max # float : Aceleração máxima (m/s**2)
        
        # TODO9:implementar os initialize
        
        # Modelo
        self.T_min   = T_min   # int : Valor mínimo para o horizonte de planejamento
        self.T_max   = T_max   # int : Valor máximo para o horizonte de planejamento
        self.delta_T = delta_T # int : Discretização do tempo (s) Tempo que leva de um waypoint até o outro
        self.m       = m       # float : Massa do VANT (!=0) (gramas)
    
        # Parametros do indivíduo
        self.mutation_prob = mutation_prob # float : Probabilidade de ocorrer uma mutação no dna (%)
        self.fitness       = None          # float : Fitness do indivíduo
        #self.birth_time    = None          # time  : Hora que o indivíduo é criado
        self.dna           = None          # list  : Conjunto de genes formando o DNA ([Gene, ...])
        self.dna_decoded   = None          # list  : DNA decodificado ([GeneDecoded, ...])
        self.spawn_mode    = spawn_mode    # str   : Tipo de incialização do DNA {'random'}
        self.start_time    = start_time    # time  : a hora em que o genético começou a rodar

        assert version, 'Algorithm version must be informed!\nEx: Version("alpha","RC")'
        if version.major == 'alpha': # Sem otimização em T
            self.T = T
            self.mutation_choices = [
                self._mutation_creep, 
                self._mutation_change
            ]
        elif version.major == 'beta': # Com otimização em T
            self.T = random.randint(T_min, T_max) # int : Horizonte de planejamento (quantidade de waypoints)
            self.mutation_choices = [
                self._mutation_remove, 
                self._mutation_insert, 
                self._mutation_creep, 
                self._mutation_change
            ]


        self.spawn(mode=spawn_mode)
        
    
    def set_fitness(self, fitness, fitness_trace, birth_time):
        self.fitness = fitness
        self.fitness_trace = fitness_trace
        #self.birth_time = birth_time
    
    
    # ---
    
    def spawn(self, mode):
        self.dna = [self._build_gene(mode) for _ in range(self.T) ]
        
    def _build_gene(self, mode='random'):
        # Inicialização aleatória gera valores com distribuição uniforme
        if mode == 'random':
            a = random.uniform(self.a_min, self.a_max)
            e = random.uniform(self.e_min, self.e_max)
            
        return Gene(a, e)
    
    # ---
    
    def decode(self):
        #self.dna_decoded = [self._decode_gene() for i in range(len(self.dna))]
        self.dna_decoded = self._decode_gene() # TODO: Organizar, voltar como era a linha de cima. Fazer função abaixo só computar o gene
        self.birth_time = time.time() - self.start_time

    def _decode_gene(self):
        dna = self.dna
        
        # parametros
        delta_T = self.delta_T
        m = self.m
        
        dna_decoded = []
        dna_decoded.append(self.gene_decoded_0)
        
        for i in range(0, len(dna)):
            # dna
            a  = dna[i].a
            e  = dna[i].e
            
            # dna decodificado
            px = dna_decoded[i].x
            py = dna_decoded[i].y
            v  = dna_decoded[i].v
            al = dna_decoded[i].al
            
            F = self.__F(v)
        
            # Equações descritas em (Arantes 2016)
            _px = px + ( v * cos(al) * delta_T ) + ( a * cos(al) * ((delta_T**2)/2) ) 
            _py = py + ( v * sin(al) * delta_T ) + ( a * sin(al) * ((delta_T**2)/2) ) 
            _v  = v  + ( a * delta_T ) - ( (F/m) * delta_T )
            _al = al + ( e * delta_T )

            dna_decoded.append(GeneDecoded(_px, _py, _v, _al))

        return dna_decoded
    
    
    def __F(self, v):
        # Equação do Arrasto
        # Disponível em https://pt.wikipedia.org/wiki/Equa%C3%A7%C3%A3o_do_arrasto
        # Versão utilizada ((Arantes, 2016) equação 3.5)
        
        Cd  = 0.8     # float : Coeficiente de arrasto, específico para cada aeronave
                      #         (considerado Angled Cube) obtido de https://pt.wikipedia.org/wiki/Coeficiente_de_resist%C3%AAncia_aerodin%C3%A2mica
        rho = 1.225   # float : Massa específica do fuído (aka densidade) (k/m**3)
                      #         (a 15 graus Celsius) Valor de rho obtido de https://pt.m.wikipedia.org/wiki/Densidade_do_ar
        A = 1.0       # float : Área de referência # TODO: o que é isso?
        # v = v       # float : Velocidade do Vant no instante t (fornecido como parâmetro da função)
        
        F = 0.5 * Cd * rho * A * (v**2)
        
        return F
        
    
    # ---
    
    def crossover(self, parent2):
        dna = random.choice([self._OX, self._BLX_Alpha])(self.dna, parent2.dna)
        dna = self._complete(dna, self.dna, parent2.dna)
        child = self.generate(dna)
        return child
    
    
    def _complete(self, dna, dna1, dna2):
        # Adiciona os genes restantes da diferença de tamanho entre os dois DNAs
               
        if len(dna1) > len(dna2):
            bigger  = dna1
            smaller = dna2
        else:
            bigger  = dna2
            smaller = dna1
    
        for i in range(len(smaller)-1, len(bigger)-1):
            if random.random() < 0.5:
                dna.append(bigger[i])
                
        return dna
        
    
    def _OX(self, dna1, dna2):
        dna = []
        for gene1, gene2 in zip(dna1, dna2):
            dna.append(random.choice([gene1, gene2]))
        return dna
        
        
    def _BLX_Alpha(self, dna1, dna2):
        dna = []
        for gene1, gene2 in zip(dna1, dna2):
            a = self.__BLX_ALpha_select_gene(gene1.a, gene2.a)
            e = self.__BLX_ALpha_select_gene(gene1.e, gene2.e)
            if a>self.a_max:
              a=self.a_max
            elif a < self.a_min:
              a=self.a_min

            if e>self.e_max:
              e=self.e_max
            elif e < self.e_min:
              e=self.e_min            
            
            gene = Gene(a, e)
            dna.append(gene)
            
        return dna
    
    
    def __BLX_ALpha_select_gene(self, x, y):
        # x - Gene : gene do pai 1
        # y - Gene : gene do pai 2
        alpha = random.uniform(0,1)
        d = abs(x-y)
        u = random.uniform(min(x,y)-alpha*d, max(x,y)+alpha*d)
        return u
    
    
    def generate(self, dna):
        # Cria um filho com os mesmos parametros do pai, mas com um dna fornecido
        child = copy.deepcopy(self)
        child.dna = dna
        child.decode()
        return child
    
        
    # ---
    
    def mutation(self, mutation_prob=None):
        mutation_prob = self.mutation_prob if not mutation_prob else mutation_prob # 0.7
        
        # Tem uma probabilidade mutation_prob de mutar o gene ou não
        if random.random() < mutation_prob:
            # Seleciona aleatoriamente uma das formas de mutação
            new_dna = random.choice(self.mutation_choices)(self.dna)
            # [
            #     self._mutation_remove, 
            #     self._mutation_insert, 
            #     self._mutation_creep, 
            #     self._mutation_change
            # ]
            
            if new_dna:
                self.dna = new_dna
                self.decode()
            
            return True
        return False
    
    def _mutation_change(self, dna):
        # Reinicia um gene aleatoriamente
        new_dna = []
        for gene in dna:
            if random.random() < 0.5:
                new_dna.append(self._build_gene('random'))
            else:
                new_dna.append(gene)
        
        return new_dna
    
    
    def _mutation_remove(self, dna):
        # Remove UM gene aleatório do DNA
        if len(dna) > self.T_min:
            i = random.randint(0, len(dna)-1)
            dna.pop(i)
            return dna
        return None
        
        
    def _mutation_insert(self, dna):
        # Insere UM gene aleatório no DNA em uma posição aleatória
        if len(dna) < self.T_max:
            i = random.randint(0, len(dna)-1)
            gene = self._build_gene()
            dna.insert(i, gene)
            return dna
        return None
    
    
    def _mutation_creep(self, dna):
        # Muta em um pequeno valor aleatorio todos os genes
        new_dna = []
        for gene in dna:
            a = self.__mute(gene.a, self.a_min, self.a_max)
            e = self.__mute(gene.e, self.e_min, self.e_max)

            # TODO2: otimizar
            new_gene = Gene(a, e)
            new_dna.append(new_gene)

        return new_dna
        
        
    def __mute(self, val, min_val, max_val):
        mutation_rate = random.uniform(0, max_val*0.5)
        s = random.choice([1, -1])
        val = val * (1 + (mutation_rate * s))

        # Checa se não estoura os limites
        if val>max_val:
          val=max_val
        elif val<min_val:
          val=min_val
        #val = max(val, min_val)
        #val = min(val, max_val)

        return val
    
    
    # ---
    
    def get_route(self):
        return [ [gene.x, gene.y] for gene in self.dna_decoded ]

# %% [markdown]
# ## 2.2. Definição do Genético

# %%
class Genetic():
    
    def __init__(
        self, 
        Specie, 
        mapa,
        taxa_cross=1.0,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=500,
        C_cur=100,
        C_t=10,
        max_exec_time=30,
        min_precision=1.0,
        k_tournament=2,
        gps_imprecision=1,
        big_delta=1,
        version=Version('alpha','RC'),
        **kwargs
    ):
        # Modelo
        self.Specie = Specie # objeto : Definição da classe (não a instância)
        self.mapa   = mapa   # Mapa   : Mapa com as características da missão

        # Parâmetros
        self.taxa_cross      = taxa_cross      # float : Taxa de ocorrencia do crossover [0,1]
        self.population_size = population_size # int   : Quantidade máxima de indivíduos na população 
        self.C_d             = C_d             # int   : Custo associado ao fitness de destino
        self.C_obs           = C_obs           # int   : Custo associado ao fitness de obstáculos
        self.C_con           = C_con           # int   : Custo associado ao fitness de consumo de combustível
        self.C_cur           = C_cur           # int   : Custo associado ao fitness de curvatura da rota
        self.C_t             = C_t             # int   : Custo associado ao fitness do tamanho do DNA (T ou horizonte de planejamento)
        self.max_exec_time   = max_exec_time   # float : Tempo máximo de execução - Stop criteria (segundos)
        self.min_precision   = min_precision   # float : Precisão mínima de acerto ao destino (metros)
        self.k_tournament    = k_tournament    # int   : Quantidade de indivíduos disputando o torneio
        self.gps_imprecision = gps_imprecision # float : Imprecisão do GPS (metros)
        self.big_delta       = big_delta
        
        # Versionamento
        self.version = version

        # Alguns dos valores do kwargs são passados para a instanciação dos indivíduos
        self.kwargs = kwargs
        
        # Inicialização
        self.population = None 
        self.fitnesses  = None
        self.best       = None
        self.ancestry   = []
        

#         if version.minor == "RC":
#             self.__fitness_obstacles = self.__fitness_obstacles_RC
#         elif version.minor == "CC":
#             self.__fitness_obstacles = self.__fitness_obstacles_CC

        
    def run(self, max_exec_time=None, verbose=False, info=False, debug=False):
        self.max_exec_time = max_exec_time if max_exec_time else self.max_exec_time
        
        # Acompanhamento do tempo (critério de parada)
        self.start_time = time.time()
        
        # Genesis
        self.population = self._genesis(self.Specie, self.population_size)
        
        # Inicializar
        self._decode(self.population)
        
        # Avaliar
        self.fitnesses = [self._fitness(subject, self.mapa) for subject in self.population]
    
        # Escolher melhor de todos
        self.best = self.population[self.fitnesses.index(max(self.fitnesses))]
        
        
        self.trace = []
        
        while not self.stop_criteria():
            self.flag_newborn = self.population_size
            count_while = 0
            
            while not self.converge():
                self.flag_newborn = 0
                count_while += 1
                
                for i in range(ceil(self.taxa_cross * self.population_size)):
                    # Seleção por torneio
                    parent1, parent2 = self._tournament(self.population, k=self.k_tournament)
            
                    # Crossover
                    child = parent1.crossover(parent2)
                    
                    # Mutação
                    child.mutation()
                    
                    # Fitness
                    self._fitness(child, self.mapa)
                    
                    # Adicionar filho na população
                    self._insert(child, parent1, parent2)
                    
                    # Print
                    if verbose and self.flag_newbest:
                        print('  Novo melhor de todos! fit: {}'.format(self.best.fitness))
                    if debug:
                        print('\nparent1.dna', parent1.dna)
                        print('\nparent2.dna', parent2.dna)
                        print('\nchild.dna.mutation', child.dna)
                        
                        
                aux_T_dna = [len(subject.dna) for subject in self.population]
                self.trace.append({
                    'medium_fitness': sum(self.fitnesses)/self.population_size,
                    'best_fitness': self.best.fitness,
                    'newborns': self.flag_newborn,
                    'newbest': self.flag_newbest,
                    'T_medio': sum(aux_T_dna)/self.population_size,
                    'T_maior': max(aux_T_dna),
                    'T_menor': min(aux_T_dna),
                    'T_melhor': len(self.best.dna)
                })
                
                # Print
                if verbose:
                    print('Fim da geração. {} novos indivíduos'.format(self.flag_newborn))
                    print('Melhor de todos: {}'.format(self.best.fitness))
                    print('-'*20)
                        
                        
            # Reiniciar rotas
            self.population = []
            self.population = self._genesis(self.Specie, self.population_size-1)
            # Nunca matar o melhor de todos
            self.population.append(self.best)
            
            # Inicializar
            self._decode(self.population)
            
            # Avaliar
            self.fitnesses = [self._fitness(subject, self.mapa) for subject in self.population]
            
            # Print
            if verbose:
                print('Meteoro! Reiniciando rotas')
            if info:
                print('Meteoro! Melhor de todos:{} - count:{}'.format(self.best.fitness, count_while))
                
                
        return self.best
                      
    # ---
    
    def _insert(self, child, parent1, parent2):
        # Verifica se um indivíduo é digno de entrar na população e tomar o lugar de um de seus pais

        self.flag_newbest = False
        
        if child.fitness < parent1.fitness:
            self.__substitute(child, parent1)

        elif child.fitness < parent2.fitness:
            self.__substitute(child, parent2)

        if child.fitness < self.best.fitness:
            self.best = child
            self.ancestry.append(child)
            self.flag_newbest = True
    
    
    def __substitute(self, child, parent):
        i_parent = self.population.index(parent)

        self.population.remove(parent)
        self.population.append(child)

        self.fitnesses.pop(i_parent)
        self.fitnesses.append(child.fitness)
        self.flag_newborn += 1
    
    
    # ---
    
    def stop_criteria(self):
        # Para a execução depois de uma quantidade de segundos
        if (time.time() - self.start_time) >= self.max_exec_time:
            return True
        return False
    
    def converge(self):
        # Converge caso nenhum novo indivíduo seja adicinado
        if self.flag_newborn == 0:
            return True
        return False
                         
    # ---
    
    def _genesis(self, Specie, population_size):
        population = [Specie(start_time=self.start_time, version=self.version,**self.kwargs) for i in range(population_size)]
        return population 
    
    # ---
    
    def _decode(self, population):
        for subject in population:
            subject.decode()
        return True
    
    # ---
    
    def _fitness(self, subject, mapa):
        
        fit_d   = self.__fitness_destination(subject, mapa)
        fit_obs = self.__fitness_obstacles(subject, mapa)
        fit_con = self.__fitness_consumption(subject, mapa)
        fit_cur = self.__fitness_curves(subject, mapa)
        fit_t   = self.__fitness_t(subject, mapa)
        
        fitness_trace = [self.C_d   * fit_d,
                         self.C_obs * fit_obs,
                         self.C_con * fit_con,
                         self.C_cur * fit_cur,
                         self.C_t   * fit_t]
        
        fitness = sum(fitness_trace)
        
        birth_time = time.time() - self.start_time
        
        subject.set_fitness(fitness, fitness_trace, birth_time)
        
        return fitness
    
    def __fitness_destination(self, subject, mapa):
        # Prioriza rotas que acertem o destino
        
        A = subject.dna_decoded[-1] # Último waypoint da rota
        B = mapa.destination        # Waypoint de destino
        
        # Distância euclidiana entre o último ponto da rota e o ponto de destino
        d = sqrt( (B.x - A.x)**2 + (B.y - A.y)**2 )
        
        # Determina uma precisão mínima aceita
        if d < self.min_precision: # min_precision default = 1.0
            return 0
        return d

    
    # def __fitness_obstacles is an abstraction of either one of those two following functions:
    # __fitness_obstacles_RC and __fitness_obstacles_CC

#     def __fitness_obstacles_RC(self, subject, mapa):
    def __fitness_obstacles(self, subject, mapa):
        # Prioriza rotas que não ultrapassem obstáculos
        count = 0
        
        for gene_decoded_t1, gene_decoded_t2  in pairwise(subject.dna_decoded):
            # Utiliza somente as áreas infladas para cálculo
            for area_n in mapa.areas_n_inf:
                wp1 = CartesianPoint(gene_decoded_t1.x, gene_decoded_t1.y)
                wp2 = CartesianPoint(gene_decoded_t2.x, gene_decoded_t2.y)
                
                # Calcula se algum waypoint está dentro de algum obstáculo
                if point_in_polygon(wp1, area_n):
                    count += 1

                # Calcula se alguma conexão entre os waypoints intersecciona algum obstáculo
                if segment_in_polygon(wp1, wp2, area_n):
                    count += 1
            
        return count


    def __fitness_obstacles_CC(self, subject, mapa):
        # Prioriza rotas que não ultrapassem obstáculos
        count       = 0
        
        #bigger_risk = 0 #M1
        sum_risk    = 0 #M2
    
        for gene_decoded_t1  in subject.dna_decoded:
            # Utiliza somente as áreas infladas para cálculo
            for area_n in mapa.areas_n_inf:
                wp1 = CartesianPoint(gene_decoded_t1.x, gene_decoded_t1.y)
    
                # Alocação de Risco    
                wp_risk = risk_total(wp1, area_n, self.gps_imprecision) #M1 #M2
            
                # Modo 1: Considerar o maior risco
                # bigger_risk = max(wp_risk, bigger_risk) #M1

                # Modo 2: Considerar a soma individual de cada risco
                sum_risk += wp_risk #M2

        #prob = min(bigger_risk, 1) #M1
        #prob = min(self.big_delta - sum_risk, 1) #M2
        if self.big_delta-sum_risk > 0:
            prob=0
        else:
            prob=sum_risk-self.big_delta
            
        #print(sum_risk)
            
        return prob
    
    
    def __fitness_consumption(self, subject, _):
        # Prioriza rotas com menor consumo de combustível (bateria)
        consumption = [gene.a**2 for gene in subject.dna]
        return sum(consumption)
    
        
    def __fitness_curves(self, subject, _):
        # Prioriza rotas que evitem fazer curvas desnecessárias
        curves = [abs(gene.e) for gene in subject.dna]
        return (1/subject.e_max) * sum(curves)
        
        
    def __fitness_t(self, subject, _):
        # Prioriza rotas com menor quantidade de waypoints
        return len(subject.dna)
    
        
    # ---
        
    def _tournament(self, population, k=2):
        parents = []
        for i in range(2):
            
            local_best = random.choice(population)
            for j in range(k-1):
                # Seleciona k individuos
                a = random.choice(population)
                if a.fitness < local_best.fitness:
                    local_best = a
                    
            parents.append(local_best)
            
        # Retorna o resultado de duas batalhas
        return parents[0], parents[1]

# %% [markdown]
# # 3. Execução
# Essa seção contém a execução do AG. Aqui contém as definições dos mapas, e execução do planejador de rotas. Pode alterar os parâmetros a vontade para testar novos resultados

# %% [markdown]
# ## 3.1. Mapas

# %% [markdown]
# ### Mapa 1

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (20.0, 5.0), # left, bottom
    (20.0, 15.5), # left, top
    (30.0, 15.5), # right, top
    (30.0, 5.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]


mapa_1 = Mapa(wp_ori, wp_des, [verts1], inflation_rate=1)

# %%
# Visualização desse mapa
vis_mapa(mapa_1)

# %% [markdown]
# ### Mapa 2

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (15.0,  8.0), # left, bottom
    (15.0, 20.0), # left, top
    (20.0, 20.0), # right, top
    (20.0,  8.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (30.0,  0.0), # left, bottom
    (30.0, 12.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  0.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_2 = Mapa(wp_ori, wp_des, [verts1, verts2], inflation_rate=1)

# %%
# Visualização desse mapa
vis_mapa(mapa_2)

# %% [markdown]
# ### Mapa 3

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (15.0, 11.0), # left, bottom
    (15.0, 25.0), # left, top
    (35.0, 23.0), # right, top
    (35.0, 16.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (15.0,  0.0), # left, bottom
    (15.0,  9.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  6.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_3 = Mapa(wp_ori, wp_des, [verts1, verts2], inflation_rate=0.5)

# %%
# Visualização desse mapa
vis_mapa(mapa_3)

# %% [markdown]
# ### Mapa 4

# %%
wp_ori = CartesianPoint(40.0, 25.0)
wp_des = CartesianPoint(36.0, -22.0)

verts1 = [
    (19.0,-12.0), # left, bottom
    (15.0,0.0), # left, top
    (87.0,15.0), # right, top
    (90.0,3.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

# verts1 = [
#     (38.0,-9.0), # left, bottom
#     (38.0,6.0), # left, top
#     (87.0,15.0), # right, top
#     (90.0,3.0), # right, bottom
# ]
# verts1.append(verts1[0])
# verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (15.0,  0.0), # left, bottom
    (15.0,  9.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  6.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_4 = Mapa(wp_ori, wp_des, [verts1], inflation_rate=0.5)

# %%
# Visualização desse mapa
vis_mapa(mapa_4)

# %% [markdown]
# ## 3.2. Planejamento de Rota

# %%
break
# Out:
#   File "<ipython-input-17-6aaf1f276005>", line 4
# SyntaxError: 'break' outside loop

# %%
# ===============================================================
# --------------   UTILIZE ESSE ESPAÇO --------------------------

debug = False

# Altere aqui o mapa que deseja utilizar
#mapa = mapa_1
mapa = mapa_2
#mapa = mapa_3
#mapa = mapa_4


# Inicialização do Algoritmo
ag = Genetic(Subject, mapa, 
        version = Version('beta', 'RC'),
        # Parâmetros da classe Genetic:
        taxa_cross=5,
        population_size=10,
        C_d=1000,
        C_obs=10000,
        C_con=500,
        C_cur=100,
        C_t=100,
        max_exec_time=30, # segundos
        # Parâmetros da classe Subject:
        px0=mapa.origin.x,
        py0=mapa.origin.y,
        T_min=1,
        T_max=25,
        mutation_prob=0.7
)

# ===============================================================

# Execução do AG, retorna o melhor indivíduo
best = ag.run(info=True)

# Print do DNA do melhor
print('-'*30)
for dna in best.dna:
    print(dna)
    
# Print do DNA DECODIFICADO do melhor
print('-'*30)
for dna_decoded in best.dna_decoded:
    print(dna_decoded)
    
best = ag.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)


# Visualização de alguns gráficos de fitness e quantidade de Ts
#plot_stats(ag.trace, normalize=True)
#plot_stats(ag.trace, normalize=False)

# %%
import pickle
pickle.dump(ag, open( "test_ag_save.p", "wb" ) )
ag_backup = pickle.load(open( "test_ag_save.p", "rb" ) )

# %%
ag.__module__

# %%
ag_backup.best.birth_time

# %%
ag_backup

# %%
debug = True
wp_teste = GeneDecoded(x=19, y=16.5, v=7.8730500357006825, al=0.23615218818588443)

risk_total(wp_teste, mapa.areas_n_inf[0], 5)

# %%
 mapa.areas_n_inf[0]

# %% [markdown]
# #### Visualizar Detalhes do fitness

# %%
best.fitness_trace
# Destino Obstáculo Consumo Curva QtdWP

# %% [markdown]
# #### Recuperação de Erros
# Caso o AG pare no meio da execução, é possível visualizar o melhor de todos gerado até o momento mesmo assim, basta rodar a célula abaixo

# %%
best = ag.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %% [markdown]
# # 4. Execução da Implementação em ROS

# %%
mapa_file = [
{
	"id": 0,
	"name": "Mapa C2",
	"geo_home": [-47.932949, -22.002467, 0],
	"areas_bonificadoras":[],
	"areas_penalizadoras":[],
	"areas_nao_navegaveis":[
		{
			"id": "NN1",
			"name": "Campo atras dos containers",
			"geo_points":[
				[-47.932749, -22.002332, 7], 
				[-47.932794, -22.002177, 13], 
				[-47.932664, -22.002147, 13], 
				[-47.932612, -22.002306, 7]
    			]
    		},
		{
			"id": "NN2",
			"name": "Bloco de aula",
			"geo_points":[
				[-47.932099, -22.002278, 20],
				[-47.932063, -22.002396, 20],
				[-47.932772, -22.002582, 20],
				[-47.932811, -22.002465, 20]
			]
		}
    ]
}
]

# %%
mapa_file = [
{
	"id": 0,
	"name": "Mapa C2",
	"geo_home": [-47.932949, -22.002467, 0],
	"areas_bonificadoras":[],
	"areas_penalizadoras":[],
	"areas_nao_navegaveis":[
		{
			"id": "NN1",
			"name": "Bloco de Aula",
			"geo_points":[
				[-47.932754, -22.002590, 7], 
				[-47.932804, -22.002485, 13], 
				[-47.932109, -22.002287, 13], 
				[-47.932072, -22.002401, 7]
    			]
    		},
		{
			"id": "NN2",
			"name": "Containers",
			"geo_points":[
				[-47.933286, -22.002630, 20],
				[-47.933370, -22.002350, 20],
				[-47.933047, -22.002259, 20],
				[-47.932956, -22.002532, 20]
			]
		}
    ]
}
]

# %%
import argparse

#from visualization import plot_map
#from genetic_v2_3 import Subject, Genetic 
#from data_definitions import Mapa, CartesianPoint, Conversor, GeoPoint

#from file_manipulation import read_mapa, write_mavros, upload_mapa

## ENTRADA

# Parâmetros recebidos (arquivo .srv)
origin_lat       = -22.002237
origin_long      = -47.932546
origin_alt       = 13
destination_lat  = -22.002674 
destination_long = -47.932608
destination_alt  = 15

# P0
# destination_lat  = -22.002278 
# destination_long = -47.932099
# destination_alt  = 20

# P1
# destination_lat  = -22.002396 
# destination_long = -47.932063
# destination_alt  = 20


mapa_id          = 0

# Leitura do arquvio em DATA
#PATH = '/home/gustavosouza/Documents/Per/path-planning/data/mapa.json' #Ubuntu
PATH = r'../../data' #Windows
#geo_home, _, _, areas_n = read_mapa(PATH, mapa_id)
geo_home, _, _, areas_n = upload_mapa(mapa_file, mapa_id)

cart_origin      = Conversor.geo_to_cart(GeoPoint(origin_lat, origin_long, origin_alt), geo_home)
cart_destination = Conversor.geo_to_cart(GeoPoint(destination_lat, destination_long, destination_alt), geo_home)


mapa = Mapa(cart_origin, cart_destination, areas_n, inflation_rate=3)



## EXECUÇÃO DO AG
ag_teste = Genetic(Subject, mapa,
        # Genetic
        taxa_cross=0.5,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=100,
        C_cur=500,
        C_t=100,
        max_exec_time=6000,
        #Subject,
        T_min=10,
        T_max=40,
        mutation_prob=0.7,
        px0=cart_origin.x,
        py0=cart_origin.y
)


best = ag_teste.run(info=True)

# Melhor rota encontrada : WPs em cartesiano
cart_points = best.get_route()

# Melhor rota encontrada : WPs em geográfico
geo_points = [ Conversor.cart_to_geo(CartesianPoint(cart_point[0], cart_point[1]), geo_home) for cart_point in cart_points ]


# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

## SAÍDA

#output_filename = '/mnt/c/Projetos/path-planning/algorithms/ros_genetic/path_from_ga_output.wp'
#write_mavros(output_filename, geo_points)

# %%
def print_mavros(geo_points): #throws FileNotFoundException
    print('Printing mavros file...\n\n\n')
    count = 1


    current_waypoint = 1

    print('QGC WPL 120\n') # Determines the file version

    i = 0

    for geo_point in geo_points:
        print(
            str(i) + '\t'
            + str(current_waypoint) + '\t' 
            + '3\t16\t3\t0\t0\t0\t'
            + '{:10.8f}'.format(geo_point.longitude) + '\t' 
            + '{:10.8f}'.format(geo_point.latitude) + '\t'
            + '{:10.8f}'.format(geo_point.altitude) + '\t'
            + '1'
            + '\n'
        )

        current_waypoint = 0
        i+=1

    print('\n\n\nOutput print generated.')

# %%
print_mavros(geo_points)

# %%
mapa.areas_n

# %%
areas = [ area for area in itertools.chain(mapa.areas_n) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %%
import argparse

#from visualization import plot_map
#from genetic_v2_3 import Subject, Genetic 
#from data_definitions import Mapa, CartesianPoint, Conversor, GeoPoint

#from file_manipulation import read_mapa, write_mavros, upload_mapa

## ENTRADA

# Parâmetros recebidos (arquivo .srv)
origin_lat       = -22.002237
origin_long      = -47.932546
origin_alt       = 13
destination_lat  = -22.002674 
destination_long = -47.932608
destination_alt  = 15

# P0
# destination_lat  = -22.002278 
# destination_long = -47.932099
# destination_alt  = 20

# P1
# destination_lat  = -22.002396 
# destination_long = -47.932063
# destination_alt  = 20


mapa_id          = 0

# Leitura do arquvio em DATA
#PATH = '/home/gustavosouza/Documents/Per/path-planning/data/mapa.json' #Ubuntu
PATH = r'../../data' #Windows
#geo_home, _, _, areas_n = read_mapa(PATH, mapa_id)
geo_home, _, _, areas_n = upload_mapa(mapa_file, mapa_id)

cart_origin      = Conversor.geo_to_cart(GeoPoint(origin_lat, origin_long, origin_alt), geo_home)
cart_destination = Conversor.geo_to_cart(GeoPoint(destination_lat, destination_long, destination_alt), geo_home)


mapa = Mapa(cart_origin, cart_destination, areas_n, inflation_rate=0.1)



## EXECUÇÃO DO AG
ag_teste = Genetic(Subject, mapa,
        # Genetic
        taxa_cross=0.5,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=100,
        C_cur=500,
        C_t=1,
        max_exec_time=600,
        #Subject,
        T_min=10,
        T_max=40,
        mutation_prob=0.7,
        px0=cart_origin.x,
        py0=cart_origin.y
)


best = ag_teste.run(info=True)

# Melhor rota encontrada : WPs em cartesiano
cart_points = best.get_route()

# Melhor rota encontrada : WPs em geográfico
geo_points = [ Conversor.cart_to_geo(CartesianPoint(cart_point[0], cart_point[1]), geo_home) for cart_point in cart_points ]


# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

## SAÍDA

#output_filename = '/mnt/c/Projetos/path-planning/algorithms/ros_genetic/path_from_ga_output.wp'
#write_mavros(output_filename, geo_points)

# %%
best.fitness_trace
# Destino Obstáculo Consumo Curva QtdWP

# %%
best = ag_teste.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %% [markdown]
# # 5. Ray Casting Stress Test
# Testes de estresse para verificar desempenho do algoritmo Ray Casting

# %% [markdown]
# ## 5.1. Point in Polygon

# %%
qty_points = 1000


verts1 = [
    (2.5, 2.5), # left, bottom
    (2.5, 4.5), # left, top
    (4.5, 4.5), # right, top
    (4.5, 2.5), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

texts = []
wps = []
for i in range(qty_points):
    x = random.uniform(1,6)
    y = random.uniform(1,6)
    
    wp = CartesianPoint(x,y)
    wps.append(wp)
    texts.append(str(point_in_polygon(wp, verts1))[0])
    
plot_map(
    areas=[verts1], 
    labels=['n'], 
    texts=texts,
    points=wps,
    wp_style='x',
    title='Ray Casting Algorithm Stress Test, wp={}'.format(qty_points),
    stress=True
)

# %% [markdown]
# ## 5.2. Segment intersects polygon

# %%
qty_segments = 15

verts1 = [
    (2.5, 2.5), # left, bottom
    (2.5, 4.5), # left, top
    (4.5, 4.5), # right, top
    (4.5, 2.5), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

texts = []
segments = []
for i in range(qty_segments):
    x = random.uniform(1,6)
    y = random.uniform(1,6)
    wp1 = CartesianPoint(x,y)

    x = random.uniform(1,6)
    y = random.uniform(1,6)
    wp2 = CartesianPoint(x,y)

    segment = [wp1, wp2]
    segments.append(segment)
    texts.append(str(segment_in_polygon(wp1, wp2, verts1))[0])
    
plot_map(
    areas=[verts1], 
    labels=['n'], 
    texts=texts,
    segments=segments,
    wp_style='-x',
    title='Ray Casting Algorithm Stress Test, wp={}'.format(qty_segments),
    stress=True
)

# %% [markdown]
# # 6. Automated Experiments

# %% [markdown]
# ## Def

# %%
debug = False

# Altere aqui o mapa que deseja utilizar
#mapa = mapa_1
#mapa = mapa_2
#mapa = mapa_3
#mapa = mapa_4

def run_ag(mapa):

    # Inicialização do Algoritmo
    ag = Genetic(Subject, mapa, 
            version = Version('beta', 'RC'),
            # Parâmetros da classe Genetic:
            taxa_cross=5,
            population_size=10,
            C_d=1000,
            C_obs=10000,
            C_con=500,
            C_cur=100,
            C_t=100,
            max_exec_time=600, # segundos
            # Parâmetros da classe Subject:
            px0=mapa.origin.x,
            py0=mapa.origin.y,
            T=10,
            T_min=1,
            T_max=25,
            mutation_prob=0.7
    )

    # Execução do AG, retorna o melhor indivíduo
    best = ag.run(info=True)

    # Print do DNA do melhor
    print('-'*30)
    for dna in best.dna:
        print(dna)
        
    # Print do DNA DECODIFICADO do melhor
    print('-'*30)
    for dna_decoded in best.dna_decoded:
        print(dna_decoded)
        
    best = ag.best

    # Visualização do Mapa usado, com a rota do melhor de todos
    areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
    tipos = [ 'n' for _ in range(len(areas))]
    plot_map(
        areas=areas,            # Mapa usado
        labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
        origem=mapa.origin,      # waypoint de origem
        destino=mapa.destination, # waypoint de destino
        waypoints=best.get_route(), # rota do melhor de todos
    )


    # Visualização de alguns gráficos de fitness e quantidade de Ts
    #plot_stats(ag.trace, normalize=True)
    #plot_stats(ag.trace, normalize=False)

    return ag

# %% [markdown]
# ## Run

# %%
import pickle

# %%
tests = {
    'mapa1':{
        'ags': [],
        'res': []
    },
    'mapa2':{
        'ags': [],
        'res': []
    },
    'mapa3':{
        'ags': [],
        'res': []
    },
    'mapa4':{
        'ags': [],
        'res': []
    }
}

# %%
import pickle

for i in range(5):
    for selected_map, mapa in zip(['mapa2'], [mapa_2]):
        ag = run_ag(mapa)
        tests[selected_map]['ags'].append(ag)
        
        l = [[subject.fitness, subject.birth_time] for subject in ag.ancestry]   
        tests[selected_map]['res'].append(l)
        
        pickle.dump(tests, open( 'backups/{}_{}.p'.format(selected_map, str(i)), 'wb' ) )

pickle.dump(tests, open('execution_10min_B.p', 'wb'))
# Out:
# Meteoro! Melhor de todos:18378.889222239948 - count:14
# Meteoro! Melhor de todos:17294.665372796895 - count:10
# Meteoro! Melhor de todos:15100.538513731868 - count:26
# Meteoro! Melhor de todos:15100.538513731868 - count:17
# Meteoro! Melhor de todos:14644.727959951802 - count:19
# Meteoro! Melhor de todos:14314.712234625502 - count:13
# Meteoro! Melhor de todos:14269.090178260989 - count:7
# Meteoro! Melhor de todos:14269.090178260989 - count:16
# Meteoro! Melhor de todos:14269.090178260989 - count:11
# Meteoro! Melhor de todos:14269.090178260989 - count:13
# Meteoro! Melhor de todos:14266.357119165206 - count:20
# Meteoro! Melhor de todos:13780.149983528674 - count:33
# Meteoro! Melhor de todos:3988.3082316193677 - count:66
# Meteoro! Melhor de todos:3988.3082316193677 - count:11
# Meteoro! Melhor de todos:3860.577834553923 - count:110
# Meteoro! Melhor de todos:3836.906798353756 - count:23
# Meteoro! Melhor de todos:3836.906798353756 - count:12
# Meteoro! Melhor de todos:3836.906798353756 - count:17
# Meteoro! Melhor de todos:3836.906798353756 - count:14
# Meteoro! Melhor de todos:3836.8968873281297 - count:20
# Meteoro! Melhor de todos:3836.8968873281297 - count:20
# Meteoro! Melhor de todos:3836.8968873281297 - count:8
# Meteoro! Melhor de todos:3836.8968873281297 - count:8
# Meteoro! Melhor de todos:3836.8968873281297 - count:16
# Meteoro! Melhor de todos:3830.5055059974934 - count:16
# Meteoro! Melhor de todos:3830.5055059974934 - count:15
# Meteoro! Melhor de todos:3830.5055059974934 - count:11
# Meteoro! Melhor de todos:3800.7667700445904 - count:70
# Meteoro! Melhor de todos:3800.7667700445904 - count:12
# Meteoro! Melhor de todos:3796.9381763932533 - count:20
# Meteoro! Melhor de todos:3796.9381763932533 - count:16
# Meteoro! Melhor de todos:3783.492202094679 - count:44
# Meteoro! Melhor de todos:3783.492202094679 - count:12
# Meteoro! Melhor de todos:3783.492202094679 - count:17
# Meteoro! Melhor de todos:3774.838264857827 - count:54
# Meteoro! Melhor de todos:3774.838264857827 - count:25
# Meteoro! Melhor de todos:3770.9359657235127 - count:21
# Meteoro! Melhor de todos:3655.2516947153026 - count:45
# Meteoro! Melhor de todos:3655.2516947153026 - count:16
# Meteoro! Melhor de todos:3655.2516947153026 - count:20
# Meteoro! Melhor de todos:3655.1174325795187 - count:21
# Meteoro! Melhor de todos:3650.199660600597 - count:16
# Meteoro! Melhor de todos:3624.3711958363024 - count:97
# Meteoro! Melhor de todos:3624.3449786829556 - count:10
# Meteoro! Melhor de todos:3623.661688757952 - count:21
# Meteoro! Melhor de todos:3619.8151837878904 - count:27
# Meteoro! Melhor de todos:3615.9448340853774 - count:31
# Meteoro! Melhor de todos:3595.5602981266647 - count:53
# Meteoro! Melhor de todos:3595.5602981266647 - count:25
# Meteoro! Melhor de todos:3595.5602981266647 - count:9
# Meteoro! Melhor de todos:3595.5602981266647 - count:21
# Meteoro! Melhor de todos:3595.528311156772 - count:26
# Meteoro! Melhor de todos:3595.528311156772 - count:24
# Meteoro! Melhor de todos:3564.3968188382237 - count:21
# Meteoro! Melhor de todos:3564.3968188382237 - count:10
# Meteoro! Melhor de todos:3564.3968188382237 - count:18
# Meteoro! Melhor de todos:3564.3968188382237 - count:25
# Meteoro! Melhor de todos:3564.3968188382237 - count:9
# Meteoro! Melhor de todos:3564.3373052824018 - count:22
# Meteoro! Melhor de todos:3563.7091693906436 - count:62
# Meteoro! Melhor de todos:3563.7091693906436 - count:11
# Meteoro! Melhor de todos:3563.7091693906436 - count:14
# Meteoro! Melhor de todos:3559.8565269102864 - count:101
# Meteoro! Melhor de todos:3559.8565269102864 - count:10
# Meteoro! Melhor de todos:3559.8565269102864 - count:8
# Meteoro! Melhor de todos:3559.8565269102864 - count:15
# Meteoro! Melhor de todos:3559.8565269102864 - count:16
# Meteoro! Melhor de todos:3559.8565269102864 - count:22
# Meteoro! Melhor de todos:3559.8565269102864 - count:16
# Meteoro! Melhor de todos:3559.842524785839 - count:28
# Meteoro! Melhor de todos:3559.842524785839 - count:15
# Meteoro! Melhor de todos:3559.842524785839 - count:18
# Meteoro! Melhor de todos:3559.789875551563 - count:31
# Meteoro! Melhor de todos:3559.789875551563 - count:8
# Meteoro! Melhor de todos:3559.789875551563 - count:17
# Meteoro! Melhor de todos:3559.789875551563 - count:9
# Meteoro! Melhor de todos:3559.789875551563 - count:19
# Meteoro! Melhor de todos:3559.789875551563 - count:14
# Meteoro! Melhor de todos:3559.789875551563 - count:5
# Meteoro! Melhor de todos:3559.789875551563 - count:15
# Meteoro! Melhor de todos:3559.789875551563 - count:16
# Meteoro! Melhor de todos:3555.8654643290056 - count:35
# Meteoro! Melhor de todos:3555.855846646354 - count:28
# Meteoro! Melhor de todos:3555.855846646354 - count:16
# Meteoro! Melhor de todos:3555.855846646354 - count:17
# Meteoro! Melhor de todos:3423.2367502959155 - count:179
# Meteoro! Melhor de todos:3423.2367502959155 - count:10
# Meteoro! Melhor de todos:3423.2367502959155 - count:25
# Meteoro! Melhor de todos:3423.2367502959155 - count:14
# Meteoro! Melhor de todos:3420.530212557215 - count:26
# Meteoro! Melhor de todos:3420.530212557215 - count:12
# Meteoro! Melhor de todos:3420.530212557215 - count:11
# Meteoro! Melhor de todos:3420.530212557215 - count:17
# Meteoro! Melhor de todos:3420.530212557215 - count:10
# Meteoro! Melhor de todos:3418.824266521771 - count:34
# Meteoro! Melhor de todos:3418.824266521771 - count:14
# Meteoro! Melhor de todos:3418.824266521771 - count:18
# Meteoro! Melhor de todos:3418.824266521771 - count:18
# Meteoro! Melhor de todos:3418.824266521771 - count:24
# Meteoro! Melhor de todos:3418.824266521771 - count:17
# Meteoro! Melhor de todos:3418.824266521771 - count:14
# Meteoro! Melhor de todos:3418.5804065139855 - count:30
# Meteoro! Melhor de todos:3418.432904018539 - count:18
# Meteoro! Melhor de todos:3418.432904018539 - count:11
# Meteoro! Melhor de todos:3418.432904018539 - count:24
# Meteoro! Melhor de todos:3418.432904018539 - count:12
# Meteoro! Melhor de todos:3418.432904018539 - count:31
# Meteoro! Melhor de todos:3418.432904018539 - count:10
# Meteoro! Melhor de todos:3412.1067205336185 - count:26
# Meteoro! Melhor de todos:3412.1067205336185 - count:12
# Meteoro! Melhor de todos:3412.1067205336185 - count:14
# Meteoro! Melhor de todos:3412.1067205336185 - count:9
# Meteoro! Melhor de todos:3412.1067205336185 - count:15
# Meteoro! Melhor de todos:3409.259819107941 - count:22
# Meteoro! Melhor de todos:3409.257199837953 - count:18
# Meteoro! Melhor de todos:3409.257199837953 - count:20
# Meteoro! Melhor de todos:3409.257199837953 - count:12
# Meteoro! Melhor de todos:3409.257199837953 - count:26
# Meteoro! Melhor de todos:3409.257199837953 - count:14
# Meteoro! Melhor de todos:3409.257199837953 - count:17
# Meteoro! Melhor de todos:3409.257199837953 - count:20
# Meteoro! Melhor de todos:3386.8749135362877 - count:44
# Meteoro! Melhor de todos:3384.7009749722683 - count:22
# Meteoro! Melhor de todos:3384.7009749722683 - count:22
# Meteoro! Melhor de todos:3384.7009749722683 - count:14
# Meteoro! Melhor de todos:3384.7009749722683 - count:12
# Meteoro! Melhor de todos:3384.692269637877 - count:18
# Meteoro! Melhor de todos:3384.692269637877 - count:16
# Meteoro! Melhor de todos:3384.692269637877 - count:12
# Meteoro! Melhor de todos:3384.6909049947917 - count:21
# Meteoro! Melhor de todos:3384.682731358933 - count:9
# Meteoro! Melhor de todos:3372.712746310864 - count:90
# Meteoro! Melhor de todos:3372.712746310864 - count:23
# Meteoro! Melhor de todos:3372.712746310864 - count:11
# Meteoro! Melhor de todos:3372.712746310864 - count:15
# Meteoro! Melhor de todos:3372.712746310864 - count:7
# Meteoro! Melhor de todos:3372.712746310864 - count:11
# Meteoro! Melhor de todos:3372.6616655903103 - count:38
# Meteoro! Melhor de todos:3372.6616655903103 - count:21
# Meteoro! Melhor de todos:3372.6616655903103 - count:7
# Meteoro! Melhor de todos:3372.6144047327766 - count:44
# Meteoro! Melhor de todos:3372.6144047327766 - count:21
# Meteoro! Melhor de todos:3372.6144047327766 - count:11
# Meteoro! Melhor de todos:3372.6144047327766 - count:16
# Meteoro! Melhor de todos:3367.1764701763423 - count:103
# Meteoro! Melhor de todos:3367.1322979564943 - count:30
# Meteoro! Melhor de todos:3367.1322979564943 - count:23
# Meteoro! Melhor de todos:3367.1322979564943 - count:20
# Meteoro! Melhor de todos:3367.1306478197353 - count:19
# Meteoro! Melhor de todos:3367.1306478197353 - count:8
# Meteoro! Melhor de todos:3367.1306478197353 - count:16
# Meteoro! Melhor de todos:3367.1306478197353 - count:22
# Meteoro! Melhor de todos:3330.855672755542 - count:49
# Meteoro! Melhor de todos:3167.989620733173 - count:151
# Meteoro! Melhor de todos:3137.0686651740257 - count:81
# Meteoro! Melhor de todos:3137.0686651740257 - count:13
# Meteoro! Melhor de todos:3040.2727391979943 - count:50
# Meteoro! Melhor de todos:2932.112529313316 - count:18
# Meteoro! Melhor de todos:2931.5431949769136 - count:59
# Meteoro! Melhor de todos:2931.5431949769136 - count:13
# Meteoro! Melhor de todos:2888.1206660998178 - count:41
# Meteoro! Melhor de todos:2880.09481870089 - count:23
# Meteoro! Melhor de todos:2880.09481870089 - count:22
# Meteoro! Melhor de todos:2874.284515443632 - count:76
# Meteoro! Melhor de todos:2874.284515443632 - count:31
# Meteoro! Melhor de todos:2873.0141414599993 - count:30
# Meteoro! Melhor de todos:2871.1145273314014 - count:15
# Meteoro! Melhor de todos:2871.1145273314014 - count:19
# Meteoro! Melhor de todos:2871.1145273314014 - count:16
# Meteoro! Melhor de todos:2871.1145273314014 - count:12
# Meteoro! Melhor de todos:2871.1145273314014 - count:17
# Meteoro! Melhor de todos:2870.0394070553466 - count:55
# Meteoro! Melhor de todos:2868.732470986006 - count:17
# Meteoro! Melhor de todos:2865.400792438677 - count:20
# Meteoro! Melhor de todos:2865.400792438677 - count:28
# Meteoro! Melhor de todos:2854.3253145701233 - count:54
# Meteoro! Melhor de todos:2854.103339652108 - count:26
# Meteoro! Melhor de todos:2854.103339652108 - count:24
# Meteoro! Melhor de todos:2854.103339652108 - count:12
# Meteoro! Melhor de todos:2854.103339652108 - count:14
# Meteoro! Melhor de todos:2854.065437537782 - count:33
# Meteoro! Melhor de todos:2854.065437537782 - count:19
# Meteoro! Melhor de todos:2854.065437537782 - count:11
# Meteoro! Melhor de todos:2854.01184511217 - count:24
# Meteoro! Melhor de todos:2854.01184511217 - count:19
# Meteoro! Melhor de todos:2853.147912592256 - count:13
# Meteoro! Melhor de todos:2853.147912592256 - count:9
# Meteoro! Melhor de todos:2853.147912592256 - count:16
# Meteoro! Melhor de todos:2849.7492285033945 - count:16
# Meteoro! Melhor de todos:2849.7492285033945 - count:22
# Meteoro! Melhor de todos:2849.701693902035 - count:16
# Meteoro! Melhor de todos:2849.701693902035 - count:19
# Meteoro! Melhor de todos:2849.452782813979 - count:22
# Meteoro! Melhor de todos:2849.452782813979 - count:16
# Meteoro! Melhor de todos:2849.452782813979 - count:24
# Meteoro! Melhor de todos:2849.452782813979 - count:10
# Meteoro! Melhor de todos:2849.452782813979 - count:17
# Meteoro! Melhor de todos:2849.275219508123 - count:99
# Meteoro! Melhor de todos:2849.2708031340326 - count:57
# Meteoro! Melhor de todos:2849.2708031340326 - count:14
# Meteoro! Melhor de todos:2849.2708031340326 - count:15
# Meteoro! Melhor de todos:2849.2708031340326 - count:5
# Meteoro! Melhor de todos:2849.2708031340326 - count:9
# Meteoro! Melhor de todos:2849.2708031340326 - count:17
# Meteoro! Melhor de todos:2849.2708031340326 - count:8
# Meteoro! Melhor de todos:2849.250085039361 - count:27
# Meteoro! Melhor de todos:2849.250085039361 - count:10
# Meteoro! Melhor de todos:2849.250085039361 - count:12
# Meteoro! Melhor de todos:2849.250085039361 - count:18
# Meteoro! Melhor de todos:2843.231903353505 - count:48
# Meteoro! Melhor de todos:2843.0450327704357 - count:41
# Meteoro! Melhor de todos:2843.0450327704357 - count:18
# Meteoro! Melhor de todos:2843.0450327704357 - count:14
# Meteoro! Melhor de todos:2843.0450327704357 - count:15
# Meteoro! Melhor de todos:2843.0450327704357 - count:13
# Meteoro! Melhor de todos:2843.0450327704357 - count:8
# Meteoro! Melhor de todos:2843.041642139834 - count:19
# Meteoro! Melhor de todos:2843.041642139834 - count:19
# Meteoro! Melhor de todos:2843.041642139834 - count:13
# Meteoro! Melhor de todos:2843.041642139834 - count:17
# Meteoro! Melhor de todos:2843.041642139834 - count:19
# Meteoro! Melhor de todos:2843.041642139834 - count:14
# Meteoro! Melhor de todos:2843.041642139834 - count:14
# Meteoro! Melhor de todos:2843.041642139834 - count:19
# Meteoro! Melhor de todos:2843.041642139834 - count:11
# Meteoro! Melhor de todos:2843.041642139834 - count:14
# Meteoro! Melhor de todos:2843.041642139834 - count:11
# Meteoro! Melhor de todos:2843.041642139834 - count:10
# Meteoro! Melhor de todos:2843.041642139834 - count:12
# Meteoro! Melhor de todos:2842.9800204539524 - count:35
# Meteoro! Melhor de todos:2842.9800204539524 - count:11
# Meteoro! Melhor de todos:2842.9800204539524 - count:19
# Meteoro! Melhor de todos:2842.9798578272803 - count:35
# Meteoro! Melhor de todos:2842.8043421969064 - count:13
# Meteoro! Melhor de todos:2842.8043421969064 - count:18
# Meteoro! Melhor de todos:2842.8043421969064 - count:14
# Meteoro! Melhor de todos:2842.8043421969064 - count:24
# Meteoro! Melhor de todos:2842.8043421969064 - count:18
# Meteoro! Melhor de todos:2842.8043421969064 - count:14
# Meteoro! Melhor de todos:2842.8043421969064 - count:11
# Meteoro! Melhor de todos:2842.8043421969064 - count:13
# Meteoro! Melhor de todos:2842.8043421969064 - count:11
# Meteoro! Melhor de todos:2842.8043421969064 - count:15
# Meteoro! Melhor de todos:2842.8043421969064 - count:6
# Meteoro! Melhor de todos:2842.8043421969064 - count:36
# Meteoro! Melhor de todos:2842.6918831159755 - count:21
# Meteoro! Melhor de todos:2842.6918831159755 - count:9
# Meteoro! Melhor de todos:2842.673996992158 - count:71
# Meteoro! Melhor de todos:2842.673996992158 - count:24
# Meteoro! Melhor de todos:2842.673996992158 - count:23
# Meteoro! Melhor de todos:2842.673996992158 - count:18
# Meteoro! Melhor de todos:2842.673996992158 - count:13
# Meteoro! Melhor de todos:2842.673996992158 - count:11
# Meteoro! Melhor de todos:2842.673996992158 - count:16
# Meteoro! Melhor de todos:2842.673996992158 - count:13
# Meteoro! Melhor de todos:2842.673996992158 - count:13
# Meteoro! Melhor de todos:2842.673996992158 - count:32
# Meteoro! Melhor de todos:2842.673996992158 - count:14
# Meteoro! Melhor de todos:2842.673996992158 - count:24
# Meteoro! Melhor de todos:2842.673996992158 - count:6
# Meteoro! Melhor de todos:2842.673996992158 - count:4
# Meteoro! Melhor de todos:2842.473253547865 - count:119
# Meteoro! Melhor de todos:2842.473253547865 - count:11
# Meteoro! Melhor de todos:2842.473253547865 - count:10
# Meteoro! Melhor de todos:2842.473253547865 - count:9
# Meteoro! Melhor de todos:2842.473253547865 - count:20
# Meteoro! Melhor de todos:2842.473253547865 - count:12
# Meteoro! Melhor de todos:2842.473253547865 - count:7
# Meteoro! Melhor de todos:2842.473253547865 - count:20
# Meteoro! Melhor de todos:2842.473253547865 - count:7
# Meteoro! Melhor de todos:2842.473253547865 - count:13
# Meteoro! Melhor de todos:2842.473253547865 - count:16
# Meteoro! Melhor de todos:2842.473253547865 - count:23
# Meteoro! Melhor de todos:2842.4605918046636 - count:71
# Meteoro! Melhor de todos:2842.4605918046636 - count:23
# Meteoro! Melhor de todos:2842.4605918046636 - count:13
# Meteoro! Melhor de todos:2842.4605918046636 - count:29
# Meteoro! Melhor de todos:2842.4605918046636 - count:14
# Meteoro! Melhor de todos:2842.4605918046636 - count:28
# Meteoro! Melhor de todos:2842.4605918046636 - count:11
# Meteoro! Melhor de todos:2842.4605918046636 - count:26
# Meteoro! Melhor de todos:2842.441524737995 - count:54
# Meteoro! Melhor de todos:2842.441524737995 - count:21
# Meteoro! Melhor de todos:2842.441524737995 - count:11
# Meteoro! Melhor de todos:2842.441524737995 - count:15
# Meteoro! Melhor de todos:2842.441524737995 - count:9
# Meteoro! Melhor de todos:2842.441524737995 - count:30
# Meteoro! Melhor de todos:2842.441524737995 - count:7
# Meteoro! Melhor de todos:2842.441524737995 - count:15
# Meteoro! Melhor de todos:2842.427651529175 - count:38
# Meteoro! Melhor de todos:2842.427651529175 - count:21
# Meteoro! Melhor de todos:2842.427651529175 - count:22
# Meteoro! Melhor de todos:2842.427651529175 - count:17
# Meteoro! Melhor de todos:2842.427651529175 - count:21
# Meteoro! Melhor de todos:2842.427651529175 - count:15
# Meteoro! Melhor de todos:2842.427651529175 - count:21
# Meteoro! Melhor de todos:2842.427651529175 - count:9
# Meteoro! Melhor de todos:2842.427651529175 - count:23
# Meteoro! Melhor de todos:2842.427651529175 - count:12
# Meteoro! Melhor de todos:2842.427651529175 - count:25
# Meteoro! Melhor de todos:2842.427651529175 - count:19
# Meteoro! Melhor de todos:2842.427651529175 - count:10
# Meteoro! Melhor de todos:2842.427651529175 - count:19
# Meteoro! Melhor de todos:2842.427651529175 - count:23
# Meteoro! Melhor de todos:2842.427651529175 - count:24
# Meteoro! Melhor de todos:2842.427651529175 - count:7
# Meteoro! Melhor de todos:2842.427651529175 - count:20
# Meteoro! Melhor de todos:2841.9744567904327 - count:62
# Meteoro! Melhor de todos:2841.957896349146 - count:19
# Meteoro! Melhor de todos:2841.957896349146 - count:18
# Meteoro! Melhor de todos:2841.957896349146 - count:17
# Meteoro! Melhor de todos:2841.957896349146 - count:24
# Meteoro! Melhor de todos:2841.957896349146 - count:13
# Meteoro! Melhor de todos:2841.893214086459 - count:21
# Meteoro! Melhor de todos:2841.893214086459 - count:8
# Meteoro! Melhor de todos:2841.893214086459 - count:7
# Meteoro! Melhor de todos:2841.8424753996032 - count:32
# Meteoro! Melhor de todos:2841.8424753996032 - count:13
# Meteoro! Melhor de todos:2841.8424753996032 - count:26
# Meteoro! Melhor de todos:2841.8424753996032 - count:23
# Meteoro! Melhor de todos:2841.8424753996032 - count:20
# Meteoro! Melhor de todos:2841.8424753996032 - count:15
# Meteoro! Melhor de todos:2841.8424753996032 - count:11
# Meteoro! Melhor de todos:2841.8424753996032 - count:25
# Meteoro! Melhor de todos:2841.8424753996032 - count:13
# Meteoro! Melhor de todos:2841.8424753996032 - count:16
# Meteoro! Melhor de todos:2841.8424753996032 - count:8
# Meteoro! Melhor de todos:2841.8317783810207 - count:25
# Meteoro! Melhor de todos:2841.8267325409515 - count:31
# Meteoro! Melhor de todos:2841.8267325409515 - count:11
# Meteoro! Melhor de todos:2841.616952787801 - count:23
# Meteoro! Melhor de todos:2841.616952787801 - count:9
# Meteoro! Melhor de todos:2841.616952787801 - count:11
# Meteoro! Melhor de todos:2841.616952787801 - count:15
# Meteoro! Melhor de todos:2841.616952787801 - count:12
# Meteoro! Melhor de todos:2841.616952787801 - count:9
# Meteoro! Melhor de todos:2841.616952787801 - count:12
# Meteoro! Melhor de todos:2841.616952787801 - count:10
# Meteoro! Melhor de todos:2841.616952787801 - count:10
# Meteoro! Melhor de todos:2841.616952787801 - count:6
# Meteoro! Melhor de todos:2841.616952787801 - count:9
# Meteoro! Melhor de todos:2841.616952787801 - count:18
# Meteoro! Melhor de todos:2841.616952787801 - count:9
# Meteoro! Melhor de todos:2841.616952787801 - count:27
# Meteoro! Melhor de todos:2841.616952787801 - count:24
# Meteoro! Melhor de todos:2841.616952787801 - count:13
# Meteoro! Melhor de todos:2841.616952787801 - count:13
# Meteoro! Melhor de todos:2841.616952787801 - count:29
# Meteoro! Melhor de todos:2841.616952787801 - count:12
# Meteoro! Melhor de todos:2841.616952787801 - count:26
# Meteoro! Melhor de todos:2841.616952787801 - count:22
# Meteoro! Melhor de todos:2841.616952787801 - count:12
# Meteoro! Melhor de todos:2841.616952787801 - count:26
# Meteoro! Melhor de todos:2841.4561006235863 - count:59
# Meteoro! Melhor de todos:2841.4561006235863 - count:14
# Meteoro! Melhor de todos:2841.4561006235863 - count:15
# Meteoro! Melhor de todos:2841.4561006235863 - count:14
# Meteoro! Melhor de todos:2841.4561006235863 - count:17
# Meteoro! Melhor de todos:2841.4561006235863 - count:20
# Meteoro! Melhor de todos:2841.3104043568987 - count:22
# Meteoro! Melhor de todos:2841.3104043568987 - count:16
# Meteoro! Melhor de todos:2841.3104043568987 - count:10
# Meteoro! Melhor de todos:2841.3104043568987 - count:22
# Meteoro! Melhor de todos:2841.3104043568987 - count:11
# Meteoro! Melhor de todos:2841.3104043568987 - count:5
# Meteoro! Melhor de todos:2841.3104043568987 - count:14
# Meteoro! Melhor de todos:2841.310393778778 - count:55
# Meteoro! Melhor de todos:2841.30748621606 - count:29
# Meteoro! Melhor de todos:2841.30748621606 - count:13
# Meteoro! Melhor de todos:2841.30748621606 - count:24
# Meteoro! Melhor de todos:2841.30748621606 - count:17
# Meteoro! Melhor de todos:2841.30748621606 - count:10
# Meteoro! Melhor de todos:2841.30748621606 - count:13
# Meteoro! Melhor de todos:2841.30748621606 - count:13
# Meteoro! Melhor de todos:2841.30748621606 - count:9
# Meteoro! Melhor de todos:2841.30748621606 - count:9
# Meteoro! Melhor de todos:2841.30748621606 - count:12
# Meteoro! Melhor de todos:2841.30748621606 - count:14
# Meteoro! Melhor de todos:2841.30748621606 - count:16
# Meteoro! Melhor de todos:2841.30748621606 - count:9
# Meteoro! Melhor de todos:2841.306835896815 - count:34
# Meteoro! Melhor de todos:2841.306835896815 - count:11
# Meteoro! Melhor de todos:2841.306835896815 - count:26
# Meteoro! Melhor de todos:2841.306835896815 - count:20
# Meteoro! Melhor de todos:2841.306835896815 - count:21
# Meteoro! Melhor de todos:2841.306835896815 - count:22
# Meteoro! Melhor de todos:2841.306835896815 - count:18
# Meteoro! Melhor de todos:2841.306835896815 - count:21
# Meteoro! Melhor de todos:2841.306835896815 - count:16
# Meteoro! Melhor de todos:2841.306835896815 - count:13
# Meteoro! Melhor de todos:2841.306835896815 - count:12
# Meteoro! Melhor de todos:2841.306835896815 - count:6
# Meteoro! Melhor de todos:2841.306835896815 - count:12
# Meteoro! Melhor de todos:2841.306835896815 - count:19
# Meteoro! Melhor de todos:2841.306835896815 - count:24
# Meteoro! Melhor de todos:2841.306835896815 - count:5
# Meteoro! Melhor de todos:2841.306835896815 - count:13
# Meteoro! Melhor de todos:2841.2668621771263 - count:18
# Meteoro! Melhor de todos:2841.2668621771263 - count:15
# Meteoro! Melhor de todos:2841.266300325771 - count:13
# Meteoro! Melhor de todos:2841.266300325771 - count:32
# Meteoro! Melhor de todos:2841.215144759744 - count:37
# Meteoro! Melhor de todos:2841.215144759744 - count:16
# Meteoro! Melhor de todos:2841.215144759744 - count:8
# Meteoro! Melhor de todos:2841.215144759744 - count:15
# Meteoro! Melhor de todos:2841.215144759744 - count:17
# Meteoro! Melhor de todos:2841.2086475040505 - count:20
# Meteoro! Melhor de todos:2841.2086475040505 - count:8
# Meteoro! Melhor de todos:2841.2086475040505 - count:18
# Meteoro! Melhor de todos:2841.2086475040505 - count:16
# Meteoro! Melhor de todos:2841.2025824675575 - count:69
# Meteoro! Melhor de todos:2841.2025824675575 - count:30
# Meteoro! Melhor de todos:2841.2025824675575 - count:18
# Meteoro! Melhor de todos:2841.2025824675575 - count:19
# Meteoro! Melhor de todos:2841.2025824675575 - count:12
# Meteoro! Melhor de todos:2841.2025824675575 - count:24
# Meteoro! Melhor de todos:2841.2025824675575 - count:24
# Meteoro! Melhor de todos:2841.2025824675575 - count:9
# Meteoro! Melhor de todos:2841.2025824675575 - count:16
# Meteoro! Melhor de todos:2841.2025824675575 - count:30
# Meteoro! Melhor de todos:2841.1884108575955 - count:70
# Meteoro! Melhor de todos:2841.1884108575955 - count:13
# Meteoro! Melhor de todos:2841.1884108575955 - count:15
# Meteoro! Melhor de todos:2841.1884108575955 - count:20
# Meteoro! Melhor de todos:2841.1884108575955 - count:25
# Meteoro! Melhor de todos:2841.1884108575955 - count:25
# Meteoro! Melhor de todos:2841.1884108575955 - count:14
# Meteoro! Melhor de todos:2841.1884108575955 - count:23
# Meteoro! Melhor de todos:2841.1884108575955 - count:21
# Meteoro! Melhor de todos:2841.1884108575955 - count:14
# Meteoro! Melhor de todos:2841.1884108575955 - count:18
# Meteoro! Melhor de todos:2841.1884108575955 - count:21
# Meteoro! Melhor de todos:2841.1884108575955 - count:21
# Meteoro! Melhor de todos:2841.1884108575955 - count:42
# Meteoro! Melhor de todos:2841.1884108575955 - count:23
# Meteoro! Melhor de todos:2841.1884108575955 - count:5
# Meteoro! Melhor de todos:2841.1884108575955 - count:19
# Meteoro! Melhor de todos:2841.1884108575955 - count:12
# Meteoro! Melhor de todos:2841.1884108575955 - count:6
# Meteoro! Melhor de todos:2841.1884108575955 - count:20
# Meteoro! Melhor de todos:2841.1884108575955 - count:19
# Meteoro! Melhor de todos:2841.1884108575955 - count:19
# Meteoro! Melhor de todos:2841.1884108575955 - count:19
# Meteoro! Melhor de todos:2841.1884108575955 - count:20
# Meteoro! Melhor de todos:2841.1884108575955 - count:23
# Meteoro! Melhor de todos:2841.1884108575955 - count:5
# Meteoro! Melhor de todos:2841.1884108575955 - count:15
# Meteoro! Melhor de todos:2841.1884108575955 - count:34
# Meteoro! Melhor de todos:2841.1884108575955 - count:16
# Meteoro! Melhor de todos:2841.1884108575955 - count:17
# Meteoro! Melhor de todos:2841.1884108575955 - count:26
# Meteoro! Melhor de todos:2841.1884108575955 - count:15
# Meteoro! Melhor de todos:2841.1884108575955 - count:12
# Meteoro! Melhor de todos:2841.1884108575955 - count:10
# Meteoro! Melhor de todos:2841.1884108575955 - count:22
# Meteoro! Melhor de todos:2841.1884108575955 - count:7
# Meteoro! Melhor de todos:2841.1884108575955 - count:19
# Meteoro! Melhor de todos:2841.1884108575955 - count:13
# Meteoro! Melhor de todos:2841.1884108575955 - count:20
# Meteoro! Melhor de todos:2841.1884108575955 - count:16
# Meteoro! Melhor de todos:2841.1884108575955 - count:11
# Meteoro! Melhor de todos:2841.1884108575955 - count:15
# Meteoro! Melhor de todos:2841.1169408560304 - count:19
# Meteoro! Melhor de todos:2841.1169408560304 - count:16
# Meteoro! Melhor de todos:2841.1169408560304 - count:20
# Meteoro! Melhor de todos:2841.1169408560304 - count:22
# Meteoro! Melhor de todos:2841.1169408560304 - count:26
# Meteoro! Melhor de todos:2841.1169408560304 - count:13
# Meteoro! Melhor de todos:2841.1169408560304 - count:32
# Meteoro! Melhor de todos:2841.1169408560304 - count:17
# Meteoro! Melhor de todos:2841.1097715332908 - count:34
# Meteoro! Melhor de todos:2841.1097715332908 - count:14
# Meteoro! Melhor de todos:2841.1097715332908 - count:16
# Meteoro! Melhor de todos:2841.1097715332908 - count:16
# Meteoro! Melhor de todos:2841.1097715332908 - count:26
# Meteoro! Melhor de todos:2841.1097715332908 - count:17
# Meteoro! Melhor de todos:2841.1054915515374 - count:24
# Meteoro! Melhor de todos:2841.1054915515374 - count:13
# Meteoro! Melhor de todos:2841.1054915515374 - count:13
# Meteoro! Melhor de todos:2841.0960644326456 - count:22
# Meteoro! Melhor de todos:2841.0960644326456 - count:25
# Meteoro! Melhor de todos:2841.0960644326456 - count:31
# Meteoro! Melhor de todos:2841.091332385614 - count:23
# Meteoro! Melhor de todos:2841.091332385614 - count:26
# Meteoro! Melhor de todos:2841.091332385614 - count:26
# Meteoro! Melhor de todos:2841.0499189238053 - count:73
# Meteoro! Melhor de todos:2840.991639201529 - count:34
# Meteoro! Melhor de todos:2840.991639201529 - count:32
# Meteoro! Melhor de todos:2840.991639201529 - count:16
# Meteoro! Melhor de todos:2840.991639201529 - count:16
# Meteoro! Melhor de todos:2840.991639201529 - count:31
# Meteoro! Melhor de todos:2840.991639201529 - count:18
# Meteoro! Melhor de todos:2840.991639201529 - count:18
# Meteoro! Melhor de todos:2840.991639201529 - count:11
# Meteoro! Melhor de todos:2840.991639201529 - count:18
# Meteoro! Melhor de todos:2840.991639201529 - count:9
# Meteoro! Melhor de todos:2840.991639201529 - count:9
# Meteoro! Melhor de todos:2840.991639201529 - count:17
# Meteoro! Melhor de todos:2840.991639201529 - count:12
# Meteoro! Melhor de todos:2840.198819997108 - count:59
# Meteoro! Melhor de todos:2840.198819997108 - count:17
# Meteoro! Melhor de todos:2840.1870170082575 - count:30
# Meteoro! Melhor de todos:2840.1870170082575 - count:20
# Meteoro! Melhor de todos:2840.1870170082575 - count:10
# Meteoro! Melhor de todos:2840.1870170082575 - count:15
# Meteoro! Melhor de todos:2840.1870170082575 - count:9
# Meteoro! Melhor de todos:2840.1870170082575 - count:11
# Meteoro! Melhor de todos:2840.1870170082575 - count:8
# Meteoro! Melhor de todos:2840.1870170082575 - count:19
# Meteoro! Melhor de todos:2840.1870170082575 - count:22
# Meteoro! Melhor de todos:2840.1870170082575 - count:4
# Meteoro! Melhor de todos:2840.1870170082575 - count:20
# Meteoro! Melhor de todos:2840.1870170082575 - count:27
# Meteoro! Melhor de todos:2840.1870170082575 - count:19
# Meteoro! Melhor de todos:2840.1870170082575 - count:16
# Meteoro! Melhor de todos:2840.1870170082575 - count:31
# Meteoro! Melhor de todos:2840.1870170082575 - count:28
# Meteoro! Melhor de todos:2840.1870170082575 - count:8
# Meteoro! Melhor de todos:2840.1870170082575 - count:12
# Meteoro! Melhor de todos:2840.1870170082575 - count:18
# Meteoro! Melhor de todos:2840.1870170082575 - count:17
# Meteoro! Melhor de todos:2840.1870170082575 - count:21
# Meteoro! Melhor de todos:2840.1870170082575 - count:24
# Meteoro! Melhor de todos:2840.1870170082575 - count:22
# Meteoro! Melhor de todos:2840.1870170082575 - count:18
# Meteoro! Melhor de todos:2840.1870170082575 - count:31
# Meteoro! Melhor de todos:2840.185291702358 - count:35
# Meteoro! Melhor de todos:2840.185291702358 - count:20
# Meteoro! Melhor de todos:2840.185291702358 - count:17
# Meteoro! Melhor de todos:2840.185291702358 - count:26
# Meteoro! Melhor de todos:2840.185291702358 - count:11
# Meteoro! Melhor de todos:2840.185291702358 - count:20
# Meteoro! Melhor de todos:2840.185291702358 - count:21
# Meteoro! Melhor de todos:2840.185291702358 - count:17
# Meteoro! Melhor de todos:2840.185291702358 - count:18
# Meteoro! Melhor de todos:2840.185291702358 - count:14
# Meteoro! Melhor de todos:2840.185291702358 - count:13
# Meteoro! Melhor de todos:2840.185291702358 - count:16
# Meteoro! Melhor de todos:2840.185291702358 - count:21
# Meteoro! Melhor de todos:2840.185291702358 - count:17
# Meteoro! Melhor de todos:2840.185291702358 - count:18
# Meteoro! Melhor de todos:2840.185291702358 - count:25
# Meteoro! Melhor de todos:2840.185291702358 - count:12
# Meteoro! Melhor de todos:2840.185291702358 - count:4
# Meteoro! Melhor de todos:2840.185291702358 - count:24
# Meteoro! Melhor de todos:2840.185291702358 - count:14
# Meteoro! Melhor de todos:2840.185291702358 - count:12
# Meteoro! Melhor de todos:2840.185291702358 - count:13
# Meteoro! Melhor de todos:2840.185291702358 - count:26
# Meteoro! Melhor de todos:2840.185291702358 - count:20
# Meteoro! Melhor de todos:2840.185291702358 - count:25
# Meteoro! Melhor de todos:2840.185291702358 - count:17
# Meteoro! Melhor de todos:2840.185291702358 - count:15
# Meteoro! Melhor de todos:2840.185291702358 - count:8
# Meteoro! Melhor de todos:2840.185291702358 - count:13
# Meteoro! Melhor de todos:2840.185291702358 - count:29
# Meteoro! Melhor de todos:2840.185291702358 - count:28
# Meteoro! Melhor de todos:2840.185291702358 - count:15
# Meteoro! Melhor de todos:2840.185291702358 - count:17
# Meteoro! Melhor de todos:2840.185291702358 - count:21
# Meteoro! Melhor de todos:2840.185291702358 - count:14
# Meteoro! Melhor de todos:2840.185291702358 - count:10
# Meteoro! Melhor de todos:2840.185291702358 - count:21
# Meteoro! Melhor de todos:2840.185291702358 - count:14
# Meteoro! Melhor de todos:2840.185291702358 - count:13
# Meteoro! Melhor de todos:2840.16148716583 - count:23
# Meteoro! Melhor de todos:2840.16148716583 - count:26
# Meteoro! Melhor de todos:2840.1579166881775 - count:23
# Meteoro! Melhor de todos:2840.1579166881775 - count:19
# Meteoro! Melhor de todos:2840.1579166881775 - count:20
# Meteoro! Melhor de todos:2840.1579166881775 - count:17
# Meteoro! Melhor de todos:2840.1579166881775 - count:17
# Meteoro! Melhor de todos:2840.1579166881775 - count:9
# Meteoro! Melhor de todos:2840.1565891729656 - count:20
# Meteoro! Melhor de todos:2840.1565891729656 - count:22
# Meteoro! Melhor de todos:2840.1565891729656 - count:11
# Meteoro! Melhor de todos:2840.1565891729656 - count:17
# Meteoro! Melhor de todos:2840.1565891729656 - count:10
# Meteoro! Melhor de todos:2840.134588709665 - count:35
# Meteoro! Melhor de todos:2840.134588709665 - count:12
# Meteoro! Melhor de todos:2840.134588709665 - count:5
# Meteoro! Melhor de todos:2840.134588709665 - count:20
# Meteoro! Melhor de todos:2840.134588709665 - count:7
# Meteoro! Melhor de todos:2836.08096041538 - count:37
# Meteoro! Melhor de todos:2836.08096041538 - count:10
# Meteoro! Melhor de todos:2834.8947743503795 - count:28
# Meteoro! Melhor de todos:2834.8650074373927 - count:38
# Meteoro! Melhor de todos:2834.465493023119 - count:34
# Meteoro! Melhor de todos:2834.4235428102293 - count:28
# Meteoro! Melhor de todos:2834.4235428102293 - count:15
# Meteoro! Melhor de todos:2834.4235428102293 - count:9
# Meteoro! Melhor de todos:2834.4235428102293 - count:18
# Meteoro! Melhor de todos:2833.999484799478 - count:23
# Meteoro! Melhor de todos:2833.999484799478 - count:22
# Meteoro! Melhor de todos:2833.999484799478 - count:8
# Meteoro! Melhor de todos:2833.9649747628205 - count:19
# Meteoro! Melhor de todos:2833.949711365754 - count:34
# Meteoro! Melhor de todos:2833.949711365754 - count:11
# Meteoro! Melhor de todos:2833.767130625597 - count:88
# Meteoro! Melhor de todos:2833.767130625597 - count:7
# Meteoro! Melhor de todos:2833.767130625597 - count:12
# Meteoro! Melhor de todos:2833.5708833944423 - count:23
# Meteoro! Melhor de todos:2833.563638483091 - count:16
# Meteoro! Melhor de todos:2833.563638483091 - count:15
# Meteoro! Melhor de todos:2833.563638483091 - count:15
# Meteoro! Melhor de todos:2833.562590007351 - count:29
# Meteoro! Melhor de todos:2833.562590007351 - count:14
# Meteoro! Melhor de todos:2833.562590007351 - count:15
# Meteoro! Melhor de todos:2833.562590007351 - count:16
# Meteoro! Melhor de todos:2833.562590007351 - count:24
# Meteoro! Melhor de todos:2833.325969599605 - count:35
# Meteoro! Melhor de todos:2833.325969599605 - count:15
# Meteoro! Melhor de todos:2833.3251153629894 - count:30
# Meteoro! Melhor de todos:2833.3251153629894 - count:9
# Meteoro! Melhor de todos:2832.8253958327778 - count:95
# Meteoro! Melhor de todos:2827.7568261244733 - count:59
# Meteoro! Melhor de todos:2827.7568261244733 - count:22
# Meteoro! Melhor de todos:2827.7568261244733 - count:18
# Meteoro! Melhor de todos:2827.7568261244733 - count:24
# Meteoro! Melhor de todos:2827.7568261244733 - count:15
# Meteoro! Melhor de todos:2827.7568261244733 - count:27
# Meteoro! Melhor de todos:2827.7568261244733 - count:9
# Meteoro! Melhor de todos:2827.7568261244733 - count:6
# Meteoro! Melhor de todos:2827.7568261244733 - count:20
# Meteoro! Melhor de todos:2827.7568261244733 - count:20
# Meteoro! Melhor de todos:2827.7568261244733 - count:11
# Meteoro! Melhor de todos:2827.7568261244733 - count:14
# Meteoro! Melhor de todos:2827.7568261244733 - count:15
# Meteoro! Melhor de todos:2827.7568261244733 - count:12
# Meteoro! Melhor de todos:2827.7568261244733 - count:15
# Meteoro! Melhor de todos:2827.7568261244733 - count:7
# Meteoro! Melhor de todos:2827.7568261244733 - count:13
# Meteoro! Melhor de todos:2827.7568261244733 - count:19
# Meteoro! Melhor de todos:2827.7327192522685 - count:24
# Meteoro! Melhor de todos:2827.7327192522685 - count:26
# Meteoro! Melhor de todos:2827.7327192522685 - count:13
# Meteoro! Melhor de todos:2827.7327192522685 - count:16
# Meteoro! Melhor de todos:2827.7327192522685 - count:16
# Meteoro! Melhor de todos:2827.7327192522685 - count:13
# Meteoro! Melhor de todos:2827.7327192522685 - count:14
# Meteoro! Melhor de todos:2827.7327192522685 - count:9
# Meteoro! Melhor de todos:2827.7327192522685 - count:24
# Meteoro! Melhor de todos:2827.7327192522685 - count:19
# Meteoro! Melhor de todos:2827.7327192522685 - count:13
# Meteoro! Melhor de todos:2827.7327192522685 - count:15
# Meteoro! Melhor de todos:2827.7327192522685 - count:30
# Meteoro! Melhor de todos:2827.7327192522685 - count:20
# Meteoro! Melhor de todos:2827.7327192522685 - count:21
# Meteoro! Melhor de todos:2827.7327192522685 - count:11
# Meteoro! Melhor de todos:2827.7327192522685 - count:9
# Meteoro! Melhor de todos:2827.625267301587 - count:21
# Meteoro! Melhor de todos:2827.6206295272777 - count:22
# Meteoro! Melhor de todos:2827.6206295272777 - count:9
# Meteoro! Melhor de todos:2827.6206295272777 - count:8
# Meteoro! Melhor de todos:2827.6162725741096 - count:42
# Meteoro! Melhor de todos:2827.6162725741096 - count:19
# Meteoro! Melhor de todos:2827.6162725741096 - count:16
# Meteoro! Melhor de todos:2827.6162725741096 - count:14
# Meteoro! Melhor de todos:2827.6162725741096 - count:13
# Meteoro! Melhor de todos:2827.6162725741096 - count:19
# Meteoro! Melhor de todos:2827.6162725741096 - count:11
# Meteoro! Melhor de todos:2827.6162725741096 - count:5
# Meteoro! Melhor de todos:2827.6162725741096 - count:28
# Meteoro! Melhor de todos:2827.6162725741096 - count:12
# Meteoro! Melhor de todos:2827.6141884933986 - count:28
# Meteoro! Melhor de todos:2827.6141884933986 - count:41
# Meteoro! Melhor de todos:2827.6141884933986 - count:15
# Meteoro! Melhor de todos:2827.6141884933986 - count:10
# Meteoro! Melhor de todos:2827.603097409883 - count:45
# Meteoro! Melhor de todos:2827.603097409883 - count:9
# Meteoro! Melhor de todos:2827.603097409883 - count:14
# Meteoro! Melhor de todos:2827.603097409883 - count:24
# Meteoro! Melhor de todos:2827.603097409883 - count:25
# Meteoro! Melhor de todos:2827.603097409883 - count:15
# Meteoro! Melhor de todos:2827.603097409883 - count:20
# Meteoro! Melhor de todos:2827.603097409883 - count:11
# Meteoro! Melhor de todos:2827.603097409883 - count:24
# Meteoro! Melhor de todos:2827.603097409883 - count:9
# Meteoro! Melhor de todos:2827.603097409883 - count:21
# Meteoro! Melhor de todos:2827.603097409883 - count:23
# Meteoro! Melhor de todos:2827.603097409883 - count:18
# Meteoro! Melhor de todos:2827.603097409883 - count:11
# Meteoro! Melhor de todos:2827.603097409883 - count:21
# Meteoro! Melhor de todos:2827.603097409883 - count:18
# Meteoro! Melhor de todos:2827.603097409883 - count:24
# Meteoro! Melhor de todos:2827.603097409883 - count:23
# Meteoro! Melhor de todos:2827.603097409883 - count:13
# Meteoro! Melhor de todos:2827.603097409883 - count:24
# Meteoro! Melhor de todos:2827.603097409883 - count:9
# ------------------------------
# Gene(a=0.9735775778376147, e=-0.9279035228525664)
# Gene(a=0.7800048229343253, e=-0.20361368943643415)
# Gene(a=0.6921158908927246, e=0.056814649829366945)
# Gene(a=0.5744352074673292, e=1.2782903069300633)
# Gene(a=0.7525989826041211, e=0.002917003227179859)
# Gene(a=0.3219612706524782, e=0.6553768892976861)
# Gene(a=0.27284381602757046, e=-0.16057847963852226)
# Gene(a=0.14709337345745316, e=-0.302626291011219)
# Gene(a=0.12536017854210774, e=-0.5220972156970783)
# Gene(a=0.041204348512718696, e=-0.46266479969221846)
# Gene(a=0.039043667865771604, e=6.634292508734132e-05)
# ------------------------------
# GeneDecoded(x=10.0, y=10.0, v=0, al=0)
# GeneDecoded(x=10.486788788918807, y=10.0, v=0.9735775778376147, al=-0.9279035228525664)
# GeneDecoded(x=11.304273053313265, y=8.908638527022385, v=1.7529573023640888, al=-1.1315172122890005)
# GeneDecoded(x=12.196957228283447, y=7.008906973802674, v=2.443046677699725, al=-1.0747025624596336)
# GeneDecoded(x=13.496546222356443, y=4.607779844108097, v=3.0135457428197925, al=0.2035877444704297)
# GeneDecoded(x=16.81638266733835, y=5.293153238593573, v=3.7601556078026577, al=0.20650474769760957)
# GeneDecoded(x=20.654208720597456, y=6.097143675168926, v=4.07279252126066, al=0.8618816369952957)
# GeneDecoded(x=23.39445079274253, y=9.292227320029928, v=4.33469697918405, al=0.7013031573567735)
# GeneDecoded(x=26.76235786286408, y=12.136487185985462, v=4.469398827780588, al=0.3986768663455545)
# GeneDecoded(x=30.93901048552387, y=13.895837117071675, v=4.5815853755258376, al=-0.12342034935152385)
# GeneDecoded(x=35.50619090551308, y=13.329274450954824, v=4.608946449434137, al=-0.5860851490437423)
# GeneDecoded(x=39.36222511664612, y=10.769251245453347, v=4.633981005842118, al=-0.586018806118655)
# Meteoro! Melhor de todos:27292.16013011893 - count:17
# Meteoro! Melhor de todos:27275.99740020763 - count:28
# Meteoro! Melhor de todos:14310.125141634622 - count:58
# Meteoro! Melhor de todos:14310.125141634622 - count:14
# Meteoro! Melhor de todos:14310.037236992874 - count:24
# Meteoro! Melhor de todos:14227.29924573618 - count:27
# Meteoro! Melhor de todos:14219.888422101909 - count:69
# Meteoro! Melhor de todos:14100.748045706274 - count:11
# Meteoro! Melhor de todos:14100.748045706274 - count:7
# Meteoro! Melhor de todos:14100.748045706274 - count:16
# Meteoro! Melhor de todos:13933.642064416113 - count:91
# Meteoro! Melhor de todos:3641.4078350534464 - count:62
# Meteoro! Melhor de todos:3641.4078350534464 - count:9
# Meteoro! Melhor de todos:3641.380022121782 - count:13
# Meteoro! Melhor de todos:3641.380022121782 - count:11
# Meteoro! Melhor de todos:3625.070071487923 - count:59
# Meteoro! Melhor de todos:3618.8494741508152 - count:19
# Meteoro! Melhor de todos:3618.8494741508152 - count:14
# Meteoro! Melhor de todos:3616.0628150375314 - count:18
# Meteoro! Melhor de todos:3616.0628150375314 - count:6
# Meteoro! Melhor de todos:3551.0895562351425 - count:161
# Meteoro! Melhor de todos:3551.0895562351425 - count:10
# Meteoro! Melhor de todos:3551.0895562351425 - count:8
# Meteoro! Melhor de todos:3551.0895562351425 - count:13
# Meteoro! Melhor de todos:3400.8869589804376 - count:18
# Meteoro! Melhor de todos:3384.236367444158 - count:20
# Meteoro! Melhor de todos:3348.442992896048 - count:34
# Meteoro! Melhor de todos:3230.043022605361 - count:91
# Meteoro! Melhor de todos:3228.38353274002 - count:42
# Meteoro! Melhor de todos:3221.8799213726506 - count:50
# Meteoro! Melhor de todos:3220.3554690120377 - count:64
# Meteoro! Melhor de todos:3220.3554690120377 - count:7
# Meteoro! Melhor de todos:3213.47440602606 - count:57
# Meteoro! Melhor de todos:3213.47440602606 - count:20
# Meteoro! Melhor de todos:3213.47440602606 - count:9
# Meteoro! Melhor de todos:3213.47440602606 - count:14
# Meteoro! Melhor de todos:3212.7109480265563 - count:65
# Meteoro! Melhor de todos:3212.7109480265563 - count:5
# Meteoro! Melhor de todos:3212.7109480265563 - count:13
# Meteoro! Melhor de todos:3198.265088309439 - count:13
# Meteoro! Melhor de todos:3198.265088309439 - count:16
# Meteoro! Melhor de todos:3198.265088309439 - count:29
# Meteoro! Melhor de todos:3198.265088309439 - count:18
# Meteoro! Melhor de todos:3198.102345075787 - count:43
# Meteoro! Melhor de todos:3198.0994728649293 - count:56
# Meteoro! Melhor de todos:3198.0994728649293 - count:17
# Meteoro! Melhor de todos:3198.0994728649293 - count:16
# Meteoro! Melhor de todos:3198.0994728649293 - count:20
# Meteoro! Melhor de todos:3142.9546036304696 - count:136
# Meteoro! Melhor de todos:3142.9546036304696 - count:12
# Meteoro! Melhor de todos:3142.9546036304696 - count:28
# Meteoro! Melhor de todos:3142.9546036304696 - count:10
# Meteoro! Melhor de todos:3142.9546036304696 - count:14
# Meteoro! Melhor de todos:3142.9546036304696 - count:18
# Meteoro! Melhor de todos:3142.9546036304696 - count:9
# Meteoro! Melhor de todos:3142.9546036304696 - count:5
# Meteoro! Melhor de todos:3142.9546036304696 - count:12
# Meteoro! Melhor de todos:3142.9546036304696 - count:18
# Meteoro! Melhor de todos:3142.9546036304696 - count:28
# Meteoro! Melhor de todos:3142.9546036304696 - count:24
# Meteoro! Melhor de todos:3142.9546036304696 - count:20
# Meteoro! Melhor de todos:3142.9515311746054 - count:34
# Meteoro! Melhor de todos:3142.9515311746054 - count:16
# Meteoro! Melhor de todos:3142.9515311746054 - count:12
# Meteoro! Melhor de todos:3142.9515311746054 - count:14
# Meteoro! Melhor de todos:3142.9515311746054 - count:14
# Meteoro! Melhor de todos:3142.9515311746054 - count:10
# Meteoro! Melhor de todos:3142.2406856860425 - count:27
# Meteoro! Melhor de todos:3141.99726007434 - count:19
# Meteoro! Melhor de todos:3141.979085619366 - count:27
# Meteoro! Melhor de todos:3141.979085619366 - count:13
# Meteoro! Melhor de todos:3141.979085619366 - count:14
# Meteoro! Melhor de todos:3141.979085619366 - count:16
# Meteoro! Melhor de todos:3141.3051612333775 - count:21
# Meteoro! Melhor de todos:3141.3051612333775 - count:21
# Meteoro! Melhor de todos:3141.0276501318926 - count:15
# Meteoro! Melhor de todos:3119.7862660173296 - count:76
# Meteoro! Melhor de todos:3118.4470860687493 - count:60
# Meteoro! Melhor de todos:3118.4470860687493 - count:13
# Meteoro! Melhor de todos:3118.4470860687493 - count:17
# Meteoro! Melhor de todos:3118.4470860687493 - count:15
# Meteoro! Melhor de todos:3118.4470860687493 - count:6
# Meteoro! Melhor de todos:3118.4470860687493 - count:23
# Meteoro! Melhor de todos:3118.045785082734 - count:113
# Meteoro! Melhor de todos:3118.000160964098 - count:26
# Meteoro! Melhor de todos:3118.000160964098 - count:19
# Meteoro! Melhor de todos:3118.000160964098 - count:19
# Meteoro! Melhor de todos:3118.000160964098 - count:16
# Meteoro! Melhor de todos:3082.419951066775 - count:70
# Meteoro! Melhor de todos:3080.369066978754 - count:63
# Meteoro! Melhor de todos:3074.7566971626875 - count:46
# Meteoro! Melhor de todos:3074.7566971626875 - count:5
# Meteoro! Melhor de todos:3074.2621223663755 - count:22
# Meteoro! Melhor de todos:3070.0909957372724 - count:29
# Meteoro! Melhor de todos:3070.0909957372724 - count:9
# Meteoro! Melhor de todos:3070.0909957372724 - count:15
# Meteoro! Melhor de todos:2998.5495982816396 - count:144
# Meteoro! Melhor de todos:2998.5495982816396 - count:5
# Meteoro! Melhor de todos:2998.2674882865695 - count:23
# Meteoro! Melhor de todos:2998.0515343650973 - count:10
# Meteoro! Melhor de todos:2996.0284345268983 - count:16
# Meteoro! Melhor de todos:2993.6177048790933 - count:106
# Meteoro! Melhor de todos:2993.6177048790933 - count:12
# Meteoro! Melhor de todos:2993.6177048790933 - count:18
# Meteoro! Melhor de todos:2993.6145082737803 - count:21
# Meteoro! Melhor de todos:2993.6145082737803 - count:13
# Meteoro! Melhor de todos:2993.1336774805986 - count:52
# Meteoro! Melhor de todos:2993.1336774805986 - count:9
# Meteoro! Melhor de todos:2993.104491949346 - count:24
# Meteoro! Melhor de todos:2992.3868778732603 - count:46
# Meteoro! Melhor de todos:2992.260560954489 - count:27
# Meteoro! Melhor de todos:2992.260560954489 - count:56
# Meteoro! Melhor de todos:2992.251847721004 - count:22
# Meteoro! Melhor de todos:2992.251847721004 - count:12
# Meteoro! Melhor de todos:2992.251847721004 - count:23
# Meteoro! Melhor de todos:2992.251847721004 - count:11
# Meteoro! Melhor de todos:2992.251847721004 - count:11
# Meteoro! Melhor de todos:2992.251847721004 - count:13
# Meteoro! Melhor de todos:2992.251847721004 - count:18
# Meteoro! Melhor de todos:2992.251847721004 - count:20
# Meteoro! Melhor de todos:2992.251847721004 - count:17
# Meteoro! Melhor de todos:2992.251847721004 - count:20
# Meteoro! Melhor de todos:2992.111686929017 - count:76
# Meteoro! Melhor de todos:2992.111686929017 - count:10
# Meteoro! Melhor de todos:2992.111686929017 - count:8
# Meteoro! Melhor de todos:2992.099352667231 - count:39
# Meteoro! Melhor de todos:2990.8698775641997 - count:33
# Meteoro! Melhor de todos:2990.7793105750775 - count:24
# Meteoro! Melhor de todos:2975.161633385295 - count:28
# Meteoro! Melhor de todos:2973.99832292042 - count:19
# Meteoro! Melhor de todos:2973.9320247369624 - count:37
# Meteoro! Melhor de todos:2970.149551176614 - count:132
# Meteoro! Melhor de todos:2969.2569010118395 - count:24
# Meteoro! Melhor de todos:2969.2569010118395 - count:10
# Meteoro! Melhor de todos:2969.018047407724 - count:18
# Meteoro! Melhor de todos:2952.9143896885234 - count:18
# Meteoro! Melhor de todos:2952.1696558540125 - count:14
# Meteoro! Melhor de todos:2950.630321448293 - count:40
# Meteoro! Melhor de todos:2950.630321448293 - count:12
# Meteoro! Melhor de todos:2950.630321448293 - count:16
# Meteoro! Melhor de todos:2950.630321448293 - count:12
# Meteoro! Melhor de todos:2950.630321448293 - count:22
# Meteoro! Melhor de todos:2950.630321448293 - count:23
# Meteoro! Melhor de todos:2950.630321448293 - count:15
# Meteoro! Melhor de todos:2950.630321448293 - count:20
# Meteoro! Melhor de todos:2950.630321448293 - count:15
# Meteoro! Melhor de todos:2950.630321448293 - count:16
# Meteoro! Melhor de todos:2950.630321448293 - count:9
# Meteoro! Melhor de todos:2948.4179859375818 - count:41
# Meteoro! Melhor de todos:2948.4179859375818 - count:9
# Meteoro! Melhor de todos:2938.671030052565 - count:31
# Meteoro! Melhor de todos:2938.671030052565 - count:14
# Meteoro! Melhor de todos:2938.671030052565 - count:24
# Meteoro! Melhor de todos:2938.671030052565 - count:12
# Meteoro! Melhor de todos:2938.5655086581646 - count:21
# Meteoro! Melhor de todos:2938.1639766533062 - count:111
# Meteoro! Melhor de todos:2938.1638281170717 - count:55
# Meteoro! Melhor de todos:2938.0138064489515 - count:45
# Meteoro! Melhor de todos:2938.0138064489515 - count:17
# Meteoro! Melhor de todos:2937.9773602864598 - count:43
# Meteoro! Melhor de todos:2937.9773602864598 - count:12
# ...
# Meteoro! Melhor de todos:2960.2816925420975 - count:19
# Meteoro! Melhor de todos:2960.2816925420975 - count:8
# Meteoro! Melhor de todos:2960.2816925420975 - count:11
# Meteoro! Melhor de todos:2960.2816925420975 - count:15
# Meteoro! Melhor de todos:2960.2816925420975 - count:16
# Meteoro! Melhor de todos:2960.218675696987 - count:49
# Meteoro! Melhor de todos:2960.218675696987 - count:6
# Meteoro! Melhor de todos:2960.218675696987 - count:18
# Meteoro! Melhor de todos:2960.218675696987 - count:18
# Meteoro! Melhor de todos:2960.218675696987 - count:14
# Meteoro! Melhor de todos:2960.218675696987 - count:18
# Meteoro! Melhor de todos:2960.218675696987 - count:24
# Meteoro! Melhor de todos:2960.218675696987 - count:18
# Meteoro! Melhor de todos:2960.218675696987 - count:11
# Meteoro! Melhor de todos:2960.218675696987 - count:13
# Meteoro! Melhor de todos:2960.218675696987 - count:22
# Meteoro! Melhor de todos:2960.218675696987 - count:24
# Meteoro! Melhor de todos:2960.218675696987 - count:18
# Meteoro! Melhor de todos:2960.218675696987 - count:19
# Meteoro! Melhor de todos:2960.218675696987 - count:20
# Meteoro! Melhor de todos:2960.1904368971313 - count:64
# Meteoro! Melhor de todos:2960.1904368971313 - count:22
# Meteoro! Melhor de todos:2960.1904368971313 - count:15
# Meteoro! Melhor de todos:2960.1904368971313 - count:9
# Meteoro! Melhor de todos:2960.1904368971313 - count:24
# Meteoro! Melhor de todos:2960.1904368971313 - count:26
# Meteoro! Melhor de todos:2960.1904368971313 - count:23
# Meteoro! Melhor de todos:2960.1904368971313 - count:20
# Meteoro! Melhor de todos:2960.1904368971313 - count:11
# Meteoro! Melhor de todos:2960.1904368971313 - count:11
# Meteoro! Melhor de todos:2960.1904368971313 - count:12
# Meteoro! Melhor de todos:2960.1904368971313 - count:27
# Meteoro! Melhor de todos:2960.1904368971313 - count:16
# Meteoro! Melhor de todos:2959.7979628484272 - count:120
# Meteoro! Melhor de todos:2959.7979628484272 - count:8
# Meteoro! Melhor de todos:2959.67008638341 - count:56
# Meteoro! Melhor de todos:2959.67008638341 - count:8
# Meteoro! Melhor de todos:2959.646005603633 - count:68
# Meteoro! Melhor de todos:2959.646005603633 - count:20
# Meteoro! Melhor de todos:2959.646005603633 - count:15
# Meteoro! Melhor de todos:2959.646005603633 - count:22
# Meteoro! Melhor de todos:2959.646005603633 - count:16
# Meteoro! Melhor de todos:2959.646005603633 - count:20
# Meteoro! Melhor de todos:2959.646005603633 - count:15
# Meteoro! Melhor de todos:2959.6449083254074 - count:39
# Meteoro! Melhor de todos:2959.6449083254074 - count:11
# Meteoro! Melhor de todos:2959.6449083254074 - count:21
# Meteoro! Melhor de todos:2959.6449083254074 - count:11
# Meteoro! Melhor de todos:2959.6449083254074 - count:6
# Meteoro! Melhor de todos:2959.6449083254074 - count:10
# Meteoro! Melhor de todos:2959.6449083254074 - count:15
# Meteoro! Melhor de todos:2959.6449083254074 - count:26
# Meteoro! Melhor de todos:2959.6449083254074 - count:11
# Meteoro! Melhor de todos:2959.6449083254074 - count:12
# Meteoro! Melhor de todos:2959.6449083254074 - count:18
# Meteoro! Melhor de todos:2959.6449083254074 - count:14
# Meteoro! Melhor de todos:2959.6449083254074 - count:23
# Meteoro! Melhor de todos:2959.6449083254074 - count:10
# Meteoro! Melhor de todos:2959.6449083254074 - count:19
# Meteoro! Melhor de todos:2959.6449083254074 - count:5
# Meteoro! Melhor de todos:2959.6420637237325 - count:73
# Meteoro! Melhor de todos:2959.6420637237325 - count:17
# Meteoro! Melhor de todos:2959.6420637237325 - count:10
# Meteoro! Melhor de todos:2959.6336752126417 - count:31
# Meteoro! Melhor de todos:2959.6336752126417 - count:8
# Meteoro! Melhor de todos:2959.6336752126417 - count:14
# Meteoro! Melhor de todos:2959.6328990846205 - count:37
# Meteoro! Melhor de todos:2959.6328990846205 - count:20
# Meteoro! Melhor de todos:2959.6328990846205 - count:8
# Meteoro! Melhor de todos:2959.6328990846205 - count:16
# Meteoro! Melhor de todos:2959.6328990846205 - count:11
# Meteoro! Melhor de todos:2959.6328990846205 - count:18
# Meteoro! Melhor de todos:2959.6328990846205 - count:9
# Meteoro! Melhor de todos:2959.6328990846205 - count:12
# Meteoro! Melhor de todos:2959.6328990846205 - count:7
# Meteoro! Melhor de todos:2959.6328990846205 - count:15
# Meteoro! Melhor de todos:2959.6328990846205 - count:13
# Meteoro! Melhor de todos:2959.6328990846205 - count:11
# Meteoro! Melhor de todos:2959.6328990846205 - count:21
# Meteoro! Melhor de todos:2959.6328990846205 - count:11
# Meteoro! Melhor de todos:2959.6328990846205 - count:14
# Meteoro! Melhor de todos:2959.6328990846205 - count:8
# Meteoro! Melhor de todos:2959.6328990846205 - count:23
# Meteoro! Melhor de todos:2959.6328990846205 - count:9
# Meteoro! Melhor de todos:2959.6328990846205 - count:8
# Meteoro! Melhor de todos:2959.6328990846205 - count:11
# Meteoro! Melhor de todos:2959.6328990846205 - count:12
# Meteoro! Melhor de todos:2959.6328990846205 - count:12
# Meteoro! Melhor de todos:2959.6328990846205 - count:16
# Meteoro! Melhor de todos:2959.6328990846205 - count:10
# Meteoro! Melhor de todos:2959.6328990846205 - count:17
# Meteoro! Melhor de todos:2959.6328990846205 - count:16
# Meteoro! Melhor de todos:2959.6328990846205 - count:26
# Meteoro! Melhor de todos:2959.6328990846205 - count:11
# Meteoro! Melhor de todos:2959.6328990846205 - count:25
# Meteoro! Melhor de todos:2959.6328990846205 - count:15
# Meteoro! Melhor de todos:2959.6328990846205 - count:20
# Meteoro! Melhor de todos:2959.6328990846205 - count:32
# Meteoro! Melhor de todos:2959.6328990846205 - count:22
# Meteoro! Melhor de todos:2959.6328990846205 - count:16
# Meteoro! Melhor de todos:2959.52177826983 - count:57
# Meteoro! Melhor de todos:2959.52177826983 - count:4
# Meteoro! Melhor de todos:2959.52177826983 - count:6
# Meteoro! Melhor de todos:2959.52177826983 - count:17
# Meteoro! Melhor de todos:2959.252896384234 - count:90
# Meteoro! Melhor de todos:2959.252896384234 - count:7
# Meteoro! Melhor de todos:2959.2150203412775 - count:27
# Meteoro! Melhor de todos:2952.945324278553 - count:75
# Meteoro! Melhor de todos:2952.945324278553 - count:10
# Meteoro! Melhor de todos:2952.943487462642 - count:48
# Meteoro! Melhor de todos:2952.943487462642 - count:21
# Meteoro! Melhor de todos:2952.943487462642 - count:14
# Meteoro! Melhor de todos:2952.943487462642 - count:4
# Meteoro! Melhor de todos:2952.943487462642 - count:48
# Meteoro! Melhor de todos:2952.943487462642 - count:19
# Meteoro! Melhor de todos:2952.943487462642 - count:16
# Meteoro! Melhor de todos:2952.8856069502394 - count:29
# Meteoro! Melhor de todos:2952.8856069502394 - count:8
# Meteoro! Melhor de todos:2952.8856069502394 - count:17
# Meteoro! Melhor de todos:2952.88543153511 - count:25
# Meteoro! Melhor de todos:2952.88543153511 - count:7
# Meteoro! Melhor de todos:2952.88543153511 - count:4
# Meteoro! Melhor de todos:2952.88543153511 - count:23
# Meteoro! Melhor de todos:2952.88543153511 - count:15
# Meteoro! Melhor de todos:2952.88543153511 - count:5
# Meteoro! Melhor de todos:2952.88543153511 - count:24
# Meteoro! Melhor de todos:2952.88543153511 - count:9
# Meteoro! Melhor de todos:2952.882730171752 - count:22
# Meteoro! Melhor de todos:2952.882730171752 - count:12
# Meteoro! Melhor de todos:2952.882730171752 - count:14
# Meteoro! Melhor de todos:2952.882730171752 - count:11
# Meteoro! Melhor de todos:2952.882730171752 - count:8
# Meteoro! Melhor de todos:2952.882730171752 - count:15
# Meteoro! Melhor de todos:2952.882730171752 - count:17
# Meteoro! Melhor de todos:2951.6646672095803 - count:110
# Meteoro! Melhor de todos:2951.6646672095803 - count:12
# Meteoro! Melhor de todos:2951.6294784369557 - count:11
# Meteoro! Melhor de todos:2951.6294784369557 - count:17
# Meteoro! Melhor de todos:2951.6294784369557 - count:22
# Meteoro! Melhor de todos:2951.6294784369557 - count:14
# Meteoro! Melhor de todos:2951.5067866911704 - count:71
# Meteoro! Melhor de todos:2951.5067866911704 - count:20
# Meteoro! Melhor de todos:2951.5067866911704 - count:11
# Meteoro! Melhor de todos:2951.5067866911704 - count:19
# Meteoro! Melhor de todos:2951.5067866911704 - count:9
# Meteoro! Melhor de todos:2951.5067866911704 - count:9
# Meteoro! Melhor de todos:2951.5067866911704 - count:18
# Meteoro! Melhor de todos:2951.5067866911704 - count:19
# Meteoro! Melhor de todos:2951.5067866911704 - count:6
# Meteoro! Melhor de todos:2951.5067866911704 - count:11
# Meteoro! Melhor de todos:2951.5067866911704 - count:29
# Meteoro! Melhor de todos:2951.5067866911704 - count:13
# Meteoro! Melhor de todos:2951.5067866911704 - count:9
# Meteoro! Melhor de todos:2951.5067866911704 - count:10
# Meteoro! Melhor de todos:2951.5067866911704 - count:16
# Meteoro! Melhor de todos:2951.5067866911704 - count:13
# Meteoro! Melhor de todos:2951.5067866911704 - count:25
# Meteoro! Melhor de todos:2951.5067866911704 - count:18
# Meteoro! Melhor de todos:2951.5067866911704 - count:16
# Meteoro! Melhor de todos:2951.5067866911704 - count:8
# Meteoro! Melhor de todos:2951.5067866911704 - count:17
# Meteoro! Melhor de todos:2951.5067866911704 - count:25
# Meteoro! Melhor de todos:2951.5067866911704 - count:15
# Meteoro! Melhor de todos:2951.5067866911704 - count:11
# Meteoro! Melhor de todos:2951.5067866911704 - count:8
# Meteoro! Melhor de todos:2951.5067866911704 - count:22
# Meteoro! Melhor de todos:2951.5067866911704 - count:25
# Meteoro! Melhor de todos:2951.5067866911704 - count:31
# Meteoro! Melhor de todos:2951.5067866911704 - count:17
# Meteoro! Melhor de todos:2951.5067866911704 - count:26
# Meteoro! Melhor de todos:2951.5067866911704 - count:10
# Meteoro! Melhor de todos:2951.5067866911704 - count:24
# Meteoro! Melhor de todos:2951.5067866911704 - count:10
# Meteoro! Melhor de todos:2951.5067866911704 - count:5
# Meteoro! Melhor de todos:2951.5067866911704 - count:11
# Meteoro! Melhor de todos:2951.5067866911704 - count:13
# Meteoro! Melhor de todos:2951.5067866911704 - count:22
# Meteoro! Melhor de todos:2951.5067866911704 - count:14
# Meteoro! Melhor de todos:2951.5067866911704 - count:20
# Meteoro! Melhor de todos:2951.5067866911704 - count:28
# Meteoro! Melhor de todos:2951.5067866911704 - count:23
# Meteoro! Melhor de todos:2951.5067866911704 - count:20
# Meteoro! Melhor de todos:2951.5067866911704 - count:29
# Meteoro! Melhor de todos:2951.5067866911704 - count:15
# Meteoro! Melhor de todos:2951.5067866911704 - count:8
# Meteoro! Melhor de todos:2951.5067866911704 - count:10
# Meteoro! Melhor de todos:2951.5067866911704 - count:11
# Meteoro! Melhor de todos:2951.5067866911704 - count:16
# Meteoro! Melhor de todos:2951.5067866911704 - count:10
# Meteoro! Melhor de todos:2951.5067866911704 - count:15
# Meteoro! Melhor de todos:2951.5067866911704 - count:17
# Meteoro! Melhor de todos:2951.5067866911704 - count:12
# Meteoro! Melhor de todos:2951.5067866911704 - count:19
# Meteoro! Melhor de todos:2951.5067866911704 - count:19
# Meteoro! Melhor de todos:2951.5067866911704 - count:17
# Meteoro! Melhor de todos:2951.5067866911704 - count:9
# Meteoro! Melhor de todos:2951.5067866911704 - count:18
# Meteoro! Melhor de todos:2951.5067866911704 - count:23
# Meteoro! Melhor de todos:2951.5067866911704 - count:17
# Meteoro! Melhor de todos:2950.744402951028 - count:31
# Meteoro! Melhor de todos:2950.744402951028 - count:13
# Meteoro! Melhor de todos:2950.744402951028 - count:15
# Meteoro! Melhor de todos:2950.744402951028 - count:21
# Meteoro! Melhor de todos:2950.321637380611 - count:27
# Meteoro! Melhor de todos:2950.321637380611 - count:20
# Meteoro! Melhor de todos:2950.321637380611 - count:31
# Meteoro! Melhor de todos:2936.997401026001 - count:94
# Meteoro! Melhor de todos:2936.997401026001 - count:14
# Meteoro! Melhor de todos:2936.997401026001 - count:22
# Meteoro! Melhor de todos:2931.618472266892 - count:30
# Meteoro! Melhor de todos:2931.618472266892 - count:16
# Meteoro! Melhor de todos:2931.618472266892 - count:19
# Meteoro! Melhor de todos:2931.618472266892 - count:16
# Meteoro! Melhor de todos:2931.6013593850057 - count:23
# Meteoro! Melhor de todos:2905.0845330431666 - count:58
# Meteoro! Melhor de todos:2905.0845330431666 - count:11
# Meteoro! Melhor de todos:2905.0845330431666 - count:12
# Meteoro! Melhor de todos:2905.0845330431666 - count:7
# Meteoro! Melhor de todos:2905.0845330431666 - count:27
# Meteoro! Melhor de todos:2905.0845330431666 - count:12
# Meteoro! Melhor de todos:2905.0845330431666 - count:20
# Meteoro! Melhor de todos:2904.681014708737 - count:18
# Meteoro! Melhor de todos:2904.681014708737 - count:37
# Meteoro! Melhor de todos:2904.681014708737 - count:15
# Meteoro! Melhor de todos:2904.681014708737 - count:17
# Meteoro! Melhor de todos:2904.681014708737 - count:10
# Meteoro! Melhor de todos:2904.681014708737 - count:8
# Meteoro! Melhor de todos:2904.681014708737 - count:14
# Meteoro! Melhor de todos:2904.681014708737 - count:7
# Meteoro! Melhor de todos:2904.681014708737 - count:35
# Meteoro! Melhor de todos:2904.2055666299466 - count:22
# Meteoro! Melhor de todos:2904.2055666299466 - count:16
# Meteoro! Melhor de todos:2904.1342032320194 - count:70
# Meteoro! Melhor de todos:2904.1342032320194 - count:8
# Meteoro! Melhor de todos:2904.1342032320194 - count:15
# Meteoro! Melhor de todos:2904.1342032320194 - count:8
# Meteoro! Melhor de todos:2904.1342032320194 - count:13
# Meteoro! Melhor de todos:2904.1342032320194 - count:10
# Meteoro! Melhor de todos:2904.1342032320194 - count:28
# Meteoro! Melhor de todos:2904.1342032320194 - count:12
# Meteoro! Melhor de todos:2904.1284035499475 - count:18
# Meteoro! Melhor de todos:2904.1284035499475 - count:11
# Meteoro! Melhor de todos:2904.1284035499475 - count:15
# Meteoro! Melhor de todos:2904.1284035499475 - count:10
# Meteoro! Melhor de todos:2904.1284035499475 - count:10
# Meteoro! Melhor de todos:2904.1284035499475 - count:6
# Meteoro! Melhor de todos:2903.7396669288178 - count:24
# Meteoro! Melhor de todos:2903.7396669288178 - count:4
# Meteoro! Melhor de todos:2903.7396669288178 - count:4
# Meteoro! Melhor de todos:2903.7396669288178 - count:16
# Meteoro! Melhor de todos:2903.7396669288178 - count:13
# Meteoro! Melhor de todos:2903.7396669288178 - count:21
# Meteoro! Melhor de todos:2903.7396669288178 - count:11
# Meteoro! Melhor de todos:2903.7396669288178 - count:15
# Meteoro! Melhor de todos:2903.7396669288178 - count:11
# Meteoro! Melhor de todos:2903.7396669288178 - count:28
# ------------------------------
# Gene(a=0.5287306338187228, e=0.4886096908597759)
# Gene(a=0.9778126970358045, e=-3.0)
# Gene(a=0.95438254448946, e=1.7421765238055962)
# Gene(a=0.1320986145257849, e=0.1670846292042677)
# Gene(a=0.5305762728610423, e=0.5514202299971788)
# Gene(a=0.26723208028311235, e=-0.11918591860973266)
# Gene(a=0.26882684175819344, e=1.1493386143400237)
# Gene(a=0.0920521425766497, e=-0.21933285459154733)
# Gene(a=0.10888636301182733, e=-0.155962350870299)
# Gene(a=0.057623496354729305, e=-0.4198304986163995)
# Gene(a=0.09284479617063579, e=-0.3743804374314386)
# Gene(a=0.03518528012236763, e=-0.3771781115562198)
# Gene(a=0.00745612934435865, e=0.006801137578171847)
# ------------------------------
# GeneDecoded(x=10.0, y=10.0, v=0, al=0)
# GeneDecoded(x=10.26436531690936, y=10.0, v=0.5287306338187228, al=0.4886096908597759)
# GeneDecoded(x=11.162924852174948, y=10.477677495181094, v=1.5063589668158492, al=-2.511390309140224)
# GeneDecoded(x=9.560398187069126, y=9.308754983419902, v=2.459245054380566, al=-0.7692137853346279)
# GeneDecoded(x=11.374715515975947, y=7.552234490235533, v=2.5873551571211926, al=-0.6021291561303602)
# GeneDecoded(x=13.725668806837218, y=5.936501720117243, v=3.113516545342329, al=-0.05070892613318145)
# GeneDecoded(x=16.968627456284242, y=5.77191367168114, v=3.374355553234756, al=-0.1698948447429141)
# GeneDecoded(x=20.42687911110655, y=5.178655544368311, v=3.6356732766270996, al=0.9794437695971097)
# GeneDecoded(x=22.479369094207318, y=8.235155987311494, v=3.7190082201654637, al=0.7601109150055623)
# GeneDecoded(x=25.21421420216181, y=10.83507093135737, v=3.81877318230325, al=0.6041485641352633)
# GeneDecoded(x=28.380722979505634, y=13.020736038427993, v=3.866779338115906, al=0.18431806551886382)
# GeneDecoded(x=32.227640797654054, y=13.737932753855802, v=3.9497634729132667, al=-0.1900623719125748)
# GeneDecoded(x=36.123554561801654, y=12.988419265330744, v=3.974660315039591, al=-0.5672404834687945)
# GeneDecoded(x=39.47887516984829, y=10.850804305371113, v=3.971697893827051, al=-0.5604393458906227)

# %%
pickle.dump(tests, open( "aasave_alpha.p", "wb" ) )

# %%
import pickle
tests = pickle.load(open( "save_alpha.p", "rb" ) )

# %% [markdown]
# ## Import

# %%
test_backup = pickle.load(open( "execution_1.p", "rb" ) )

# %% [markdown]
# ## Visualization

# %%
for i in range(5):
    np_ar = np.array(tests['mapa2']['res'][i])
    plt.plot(np_ar[:,1], np_ar[:,0])

# %%
for i in range(1):
    np_ar = np.array(test_backup['mapa2']['res'][i])
    plt.plot(np_ar[:,1], np_ar[:,0])

# %% [markdown]
# # TODO

# %%
# TODO1: Setar a semente do random para controlar o experimento
# TODO1: Printar o tempo que encontra cada melhor
# TODO1: Ter certeza na conversão de latitutde e longitude <- confiavel   (Veronica)

# %%
Monografia
- até domingo - sobrar somente resultados
- ler os abstracts dos principais artigos
- achar ref pro Ray casting (google scholar: ray casting / ray casting GA / RC path planning) 
      foco pra imagens (citar) 
    rc com ga, mesmo que em outra area
    só ler abstract (os mais novos)
    ate onde nos pudermos pesquisar nessa monografia, nos nao encontramos trabalhos

- durante a semana so sobra os resultados


- retornar no domingo (a noite) ou segunda (noite): apresentar a monografia
    a medida que concluir uma seção, enviar
