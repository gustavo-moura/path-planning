# %% [markdown]
# # Algoritmo Genético Versão Ensamble
#
# Essa versão inclui:
# - Otimização da rota (V1)
# - Otimização da quantidade de waypoints (V2)
# - Risco Inflado: Inflação das áreas não-navegáveis (V3)
# - Alocação de risco (V3.5)

# %% [markdown]
# # 1. Utils
# Essa seção contém funções auxiliares para o algoritmo. Não é necessário mexer nessa parte
# (Feche essa aba)

# %% [markdown]
# ## utils.py

# %%
import itertools
from scipy.stats import norm

# Support Functions
# _________________________________________________________________________________________________
def pairwise_circle(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ... (s<last>,s0)"
    a, b = itertools.tee(iterable)
    first_value = next(b, None)
    return itertools.zip_longest(a, b,fillvalue=first_value)

def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = itertools.tee(iterable)
    next(b, None)
    return zip(a, b)

def boundary(val, val_min, val_max):
  if val<val_min:
    return val_min
  if val>val_max:
    return val_max
  return val

# Ray Casting Algorithm
# _________________________________________________________________________________________________
epsilon = 0.00001  # Used on the Ray-Tracing Algorithm

def point_in_polygon(point, polygon):
    # Using ray_casting algorithm
    # https://rosettacode.org/wiki/Ray-casting_algorithm

    count = 0
    
    for vertex1, vertex2 in pairwise_circle(polygon):

        if vertex1.y < vertex2.y:
            A = vertex1
            B = vertex2
        else:
            A = vertex2
            B = vertex1

        if ray_intersects_segment(point, A, B):
            count += 1

    if count % 2 == 0: # Odd
        return False 
    else:
        return True # Inside the polygon
    

def ray_intersects_segment(P, A, B):
    # P : the point from which the ray starts
    # A : the end-point of the segment with the smallest y coordinate
    #     (A must be "below" B)
    # B : the end-point of the segment with the greatest y coordinate
    #     (B must be "above" A)

    # To avoid the "ray on vertex" problem, the point is moved upward of a small quantity epsilon.
    if P.y == A.y or P.y == B.y:
        P.y += epsilon

    # Point higher or lower than polygon
    if P.y < A.y or P.y > B.y:
        return False

    # Point to the right of the polygon
    elif P.x >= max(A.x, B.x):
        return False 

    else:

        if P.x < min(A.x, B.x):
            return True

        else:

            if A.x != B.x:
                m_red = (B.y - A.y)/(B.x - A.x)
            else:
                m_red = 99999999 # Infinite


            if A.x != P.x:
                m_blue = (P.y - A.y)/(P.x - A.x)
            else:
                m_blue = 99999999 # Infinite


            if m_blue >= m_red:
                return True
            else:
                return False



# Segment Intersection
# _________________________________________________________________________________________________
def segment_in_polygon(wp1, wp2, polygon):
    # count = 0
    #print('Segment: {}-{}'.format(wp1,wp2))

    for vertex1, vertex2 in pairwise_circle(polygon):
        A = vertex1
        B = vertex2
        #if vertex1.y < vertex2.y:
        #    A = vertex1
        #    B = vertex2
        #else:
        #    A = vertex2
        #    B = vertex1
        #print('Polygon edge: {}-{}'.format(A, B))

        if segment_intersects_segment(wp1, wp2, A, B):
            return True
    return False
    # if count > 1:
    #     return True 
    # else:
    #     return False 
    

def segment_intersects_segment(p1, q1, p2, q2):
    # Returns true if line segment 'p1q1' and 'p2q2' intersect. 
    # Based on the algorithm from https://www.geeksforgeeks.org/check-if-two-given-line-segments-intersect/

    
    # Two segments (p1,q1) and (p2,q2) intersect if and only if one of the following two conditions is verified:
    #
    # 1. General Case:
    # – (p1, q1, p2) and (p1, q1, q2) have different orientations and
    # – (p2, q2, p1) and (p2, q2, q1) have different orientations.
    #
    # 2. Special Case
    # – (p1, q1, p2), (p1, q1, q2), (p2, q2, p1), and (p2, q2, q1) are all collinear and
    # – the x-projections of (p1, q1) and (p2, q2) intersect
    # – the y-projections of (p1, q1) and (p2, q2) intersect
    
    
    # Find the four orientations needed for general and 
    # special cases 
    o1 = orientation(p1, q1, p2) 
    o2 = orientation(p1, q1, q2) 
    o3 = orientation(p2, q2, p1) 
    #print(p2, q2, p1, o3)
    o4 = orientation(p2, q2, q1) 
    #print(o1,o2,o3,o4)
    
    # 1. General case 
    if o1 != o2 and o3 != o4:
        return True  


    # 2. Special Cases 
    # p1, q1 and p2 are colinear and p2 lies on segment p1q1 
    if o1 == 0 and on_segment(p1, p2, q1): 
        return True 
  
    # p1, q1 and q2 are colinear and q2 lies on segment p1q1 
    if o2 == 0 and on_segment(p1, q2, q1):
        return True 
  
    # p2, q2 and p1 are colinear and p1 lies on segment p2q2 
    if o3 == 0 and on_segment(p2, p1, q2):
        return True 
  
    # p2, q2 and q1 are colinear and q1 lies on segment p2q2 
    if o4 == 0 and on_segment(p2, q1, q2):
        return True 
  
    
    # Doesn't fall in any of the above cases 
    return False 
    
    
def on_segment(p, q, r):
    # Given three colinear points p, q, r, the function checks if 
    # point q lies on line segment 'pr' 
    if (q.x <= max(p.x, r.x) and q.x >= min(p.x, r.x) 
    and q.y <= max(p.y, r.y) and q.y >= min(p.y, r.y)):
        return True
    else:
        return False
    
    
def orientation(p, q, r):
    # To find orientation of ordered triplet (p, q, r). 
    # The function returns following values 
    # 0 --> p, q and r are colinear 
    # 1 --> Clockwise 
    # 2 --> Counterclockwise 
    
    # See https://www.geeksforgeeks.org/orientation-3-ordered-points/ 
    # for details of below formula. 
      
    val =( (q.y - p.y) * (r.x - q.x) 
         - ((q.x - p.x) * (r.y - q.y)))
    #print('\n---\ndebug')
    #print((q.y - p.y), (r.x - q.x), (q.x - p.x), (r.y - q.y))
    #print(val)
    if val == 0:
        return 0         # colinear

    return (1 if val > 0 else 2)  # clock or counterclock wise



# Chance Constraint
# _________________________________________________________________________________________________

def risk_total(wp, area, imprecision):   
    distance_total = math.inf

    maior = 0 #M1
    soma = 0 #M2

    if debug:
        print('maior, soma, wp_risk, distance_total')
    for A, B in pairwise(area):
        # segmento A-B

        # plano determinado pela equação ax + by + cz + d = 0, onde (a, b, c) é o vetor normal
        x = A.x - B.x
        y = A.y - B.y
        # direction_vector = (x, y) # vector in the same direction of the line that connects A and B
        # normal_vector = [-y, x] # rotate the direction vector by 90º. (x, y) -> (-y, x) 
        normal_vector = [-y/(sqrt((y**2)+(x**2))), x/(sqrt((y**2)+(x**2)))] # dividindo pela norma, normalizando o vetor

        b = (-y) * A.x + x * A.y # Coeficiente da reta

        distance = wp.x * normal_vector[0] + wp.y * normal_vector[1] - b
        #print(distance)
        distance_total = min(distance_total, distance)
        wp_risk  = risk(distance_total, imprecision)
        # maior = max(maior, wp_risk) #M1
        # soma += wp_risk #M2
        if debug:
            print(maior, soma, wp_risk, distance_total, '--', wp, A, B)
    
    

    return wp_risk
    #return maior #M1
    #return soma #M2


def risk(distance, imprecision):
    # Survival function (also defined as 1 - cdf, but sf is sometimes more accurate).
    # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

    # mi    : média         : location
    # sigma : desvio padrão : scale

    return norm.sf(distance, loc=0, scale=imprecision)

# %% [markdown]
# ## visualization.py

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path

import plotly.graph_objects as go

from sklearn import preprocessing


cor_area_nn    = '#25283d' # Yankees Blue
cor_area_p     = '#8f3985' # Plum
cor_area_b     = '#07beb8' # Tiffany Blue
cor_waypoints  = '#aa1155' # Jazzberry Jam
cor_ori_dest   = '#880044' # Pink Raspberry


def new_shape(vertices, color='navajowhite', lw=.25):

    assert len(vertices) >= 3, 'At least 3 vertices to form a shape'

    colors = {
        'n': cor_area_nn,
        'p': cor_area_p,
        'b': cor_area_b
    }
    
    color = colors[color] if color in colors else color
    
    codes = [Path.MOVETO]
    for _ in range(1, len(vertices)-1):
        codes.append(Path.LINETO)
    codes.append(Path.CLOSEPOLY)
    
    path = Path(vertices, codes)

    patch = patches.PathPatch(path, facecolor=color, lw=lw, alpha=0.6)

    return patch


def plot_map(wp_style='-x', **kwargs):
    # Optional arguments:
    # areas, labels, origem, destino, waypoints, texts

    fig, ax = plt.subplots(figsize=(8,8)) 
    
    # Plot areas
    if 'areas' in kwargs and 'labels' in kwargs:
        areas=kwargs['areas']
        labels=kwargs['labels']
        patches = [ new_shape(vertice, color=label) for vertice, label in zip(areas, labels) ]
        for patch in patches:
            ax.add_patch(patch)
        
    # Plot origin and destination
    if 'origem' in kwargs and 'destino' in kwargs:
        origem=kwargs['origem']
        destino=kwargs['destino']
        ax.plot([origem[0], destino[0]], [origem[1], destino[1]], 'o', color=cor_ori_dest)
    
    # Plot waypoints and route
    if 'waypoints' in kwargs:
        waypoints=kwargs['waypoints']
        waypoints = list(map(list, zip(*waypoints)))
        ax.plot(waypoints[0], waypoints[1], wp_style, color=cor_waypoints, linewidth=2) #marker='x', linestyle='solid'
        if 'texts' in kwargs:
            for i, text in enumerate(kwargs['texts']):
                ax.annotate(text, (waypoints[0][i], waypoints[1][i]))
    
    if 'stress' in kwargs:
        # Plot waypoints
        if 'points' in kwargs:
            for wp, text in zip(kwargs['points'], kwargs['texts']):
                if text=='T':
                    in_color=cor_area_b
                else:
                    in_color=cor_waypoints

                ax.plot(wp[0], wp[1], wp_style, color=in_color, linewidth=2)
                ax.annotate(text, (wp[0], wp[1]))

        # Plot segments
        if 'segments' in kwargs and 'texts' in kwargs:
            i=0
            for segment, text in zip(kwargs['segments'], kwargs['texts']):
                X = [segment[0].x, segment[1].x]
                Y = [segment[0].y, segment[1].y]

                if text=='T':
                    in_color=cor_area_b
                else:
                    in_color=cor_waypoints
                ax.plot(X, Y, wp_style, color=in_color, linewidth=2)
                ax.annotate(text+str(i), (X[0], Y[0]))
                i+=1
    
    # Set size
    automin, automax = ax.get_xlim()
    plt.xlim(automin-0.5, automax+0.5)
    automin, automax = ax.get_ylim()
    plt.ylim(automin-0.5, automax+0.5)
    plt.gca().set_aspect('equal', adjustable='box')
    
    if 'title' in kwargs:
        plt.title(kwargs['title'])
    
    plt.show()
    #plt.savefig('out.png')

def plot_stats(ag_trace, normalize=True):
    dft = pd.DataFrame.from_dict(ag_trace)
    
    if normalize:
        x = dft.values #returns a numpy array
        min_max_scaler = preprocessing.MinMaxScaler()
        x_scaled = min_max_scaler.fit_transform(x)
        dft = pd.DataFrame(x_scaled, columns=dft.columns)

    fig = go.Figure()

    for column in dft.columns:
        fig.add_trace(go.Scatter(x=dft.index, y=dft[column], name=column))
    fig.show()

# %%
def vis_mapa(mapa):
    areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
    tipos = [ 'n' for _ in range(len(areas))]
    plot_map(
        areas=areas,             # Mapa usado
        labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
        origem=mapa.origin,      # waypoint de origem
        destino=mapa.destination # waypoint de destino   
    )

# %% [markdown]
# ## data_definitions.py

# %%
import collections
import math

CartesianPoint = collections.namedtuple('CartesianPoint', 'x y')
GeoPoint = collections.namedtuple('GeoPoint', 'latitude, longitude, altitude')
Version = collections.namedtuple('Version', 'major, minor')

class Mapa():
    def __init__(self, origin, destination, areas_n, inflation_rate=0.1, mode='scalar'):
        self.origin = origin           # CartesianPoint : Define o ponto de partida da rota
        self.destination = destination # CartesianPoint : Define o ponto de destino da rota
        self.areas_n = areas_n         # [area, ...]
                                       # area = [CartesianPoint(),...]      
        self.areas_n_inf = [ self._inflate_area(area, inflation_rate=inflation_rate, mode=mode) for area in areas_n ]
        
        
    def _inflate_area(self, area, inflation_rate, mode):
        if mode == 'percentage':
            # Infla uma área retangular em uma porcentagem do tamanho, alterando os valores em x% de cada vértice
            x = area[2].x - area[0].x
            y = area[1].y - area[3].y

            inc = (inflation_rate)
            dec = -(inflation_rate)

            new_area = [
                CartesianPoint(area[0].x + dec * x, area[0].y + dec * y), # left,  bottom
                CartesianPoint(area[1].x + dec * x, area[1].y + inc * y), # left,  top
                CartesianPoint(area[2].x + inc * x, area[2].y + inc * y), # right, top
                CartesianPoint(area[3].x + inc * x, area[3].y + dec * y)  # right, bottom
            ]
            new_area.append(new_area[0]) # Repetir primeiro ponto, para o ignore do shape na hora de plotar
        
        elif mode == 'scalar':
            # Infla uma área retangular em uma quantidade fixa
            inc = (inflation_rate)
            dec = -(inflation_rate)

            new_area = [
                CartesianPoint(area[0].x + dec, area[0].y + dec), # left,  bottom
                CartesianPoint(area[1].x + dec, area[1].y + inc), # left,  top
                CartesianPoint(area[2].x + inc, area[2].y + inc), # right, top
                CartesianPoint(area[3].x + inc, area[3].y + dec)  # right, bottom
            ]
            new_area.append(new_area[0]) # Repetir primeiro ponto, para o ignore do shape na hora de plotar
        
        
        return new_area



class Conversor():

    def list_geo_to_cart( l, geo_home):
        for i in l:
            yield Conversor.geo_to_cart(i, geo_home)

    def list_cart_to_geo( l, geo_home):
        for i in l:
            yield Conversor.cart_to_geo(i, geo_home)


    def geo_to_cart( geo_point, geo_home):
        
        def calc_y(lat, lat_):
            return (lat - lat_) * (10000000.0 / 90)
        def calc_x(longi, longi_, lat_):
            return (longi - longi_) * (6400000.0 * (math.cos(lat_ * math.pi / 180) * 2 * math.pi / 360))

        x = calc_x(geo_point.longitude, geo_home.longitude, geo_home.latitude)
        y = calc_y(geo_point.latitude, geo_home.latitude)

        #return CartesianPoint(x, y, geo_point.altitude)
        return CartesianPoint(x, y)


    def cart_to_geo( cartesian_point, geo_home):

        def calc_latitude_y(lat_, y):
            return ((y * 90) / 10000000.0) + lat_
        def calc_longitude_x(lat_, longi_, x):
            return ((x * 90) / (10008000 * math.cos(lat_ * math.pi / 180))) + longi_


        longitude_x = calc_longitude_x(geo_home.latitude, geo_home.longitude, cartesian_point.x)
        latitude_y = calc_latitude_y(geo_home.latitude, cartesian_point.y)

        #return GeoPoint(longitude_x, latitude_y, cartesian_point.z)
        return GeoPoint(longitude_x, latitude_y, 10)

# %% [markdown]
# ## file_manipulation.py

# %%
def upload_mapa(mapa_file, mapa_id):
    mapa = mapa_file[mapa_id]

    geo_home = GeoPoint(mapa['geo_home'][1], mapa['geo_home'][0], mapa['geo_home'][2])

    areas_bonificadoras  = [ Conversor.list_geo_to_cart(area['geo_points'], geo_home) for area in mapa['areas_bonificadoras'] ]
    areas_penalizadoras  = [ Conversor.list_geo_to_cart(area['geo_points'], geo_home) for area in mapa['areas_penalizadoras'] ]
    
    areas_nao_navegaveis = []
    for area in mapa['areas_nao_navegaveis']:
        geo_points=[]
        for geo_point in area['geo_points']:
            geo_points.append(Conversor.geo_to_cart(
                GeoPoint(geo_point[1], geo_point[0], geo_point[2]) 
                , geo_home))
        geo_points.append(geo_points[0])
        areas_nao_navegaveis.append(geo_points)



    return geo_home, areas_bonificadoras, areas_penalizadoras, areas_nao_navegaveis

# %% [markdown]
# # 2. Algoritmo Genético
# Essa seção contém a implementação do algoritmo genético, contendo a definição da classe indivíduo (Subject) e da classe do genético (Genetic).
# Aqui está a implementação, não é necessário mexer, a menos que queira mudar alguma coisa na lógica da solução. **Caso somente queira mexer nos parâmetros, pule para a próxima etapa**

# %% [markdown]
# ### Utilitários

# %%
import collections
import random
import time
import copy

from math import cos, sin, sqrt, ceil

from itertools import tee
#from utils import pairwise, point_in_polygon, segment_in_polygon

Gene           = collections.namedtuple('Gene', 'a e')
GeneDecoded    = collections.namedtuple('GeneDecoded', 'x y v al')

# %% [markdown]
# ## 2.1. Definição do Indivíduo

# %%
class Subject():
    
    # codificação - u
    # dna = [Gene, ...]
    #     Gene = [a, e]
    #         a = float: aceleração
    #         e = float: variação angular


    # decodificação - x
    # dna_decoded = [GeneDecoded, ...]
    #     GeneDecoded = (x, y, v, al)
    #         x  = : Posição do VANT no eixo x (aka px)
    #         y  = : Posição do VANT no eixo y (aka py)
    #         v  = : Velocidade do VANT na horizontal
    #         al = : ângulo (direção) do VANT na horizontal
    def __init__(
        self,
        px0=10.,
        py0=10.,
        v0=0,
        al0=0,
        v_min=11.1,
        v_max=30.5,
        e_min=-3,        
        e_max=3,
        a_min=-2.0,
        a_max=2.0,
        T=10,
        T_min=1,
        T_max=7,
        delta_T=1,
        m=743.0,
        mutation_prob=0.7,
        start_time=None,
        spawn_mode='random',
        version=None,
        **kwargs
    ):
        # VANT
        # px0   int : Posição inicial no eixo x (m)
        # py0   int : Posição inicial no eixo y (m)
        # v0    int : Velocidade Inicial (m/s)
        # al0   int : Ângulo inicial (graus)
        self.gene_decoded_0 = GeneDecoded(px0, py0, v0, al0) # GeneDecoded : objeto contendo o gene decodificado de posição 0
        self.v_min = v_min # float : Velocidade máxima (m/s)
        self.v_max = v_max # float : Velocidade mínima (m/s)
        self.e_min = e_min # int   : Velocidade angular mínima (graus/s)
        self.e_max = e_max # int   : Velocidade angular máxima (graus/s)
        self.a_min = a_min # float : Aceleração mínima (m/s**2)
        self.a_max = a_max # float : Aceleração máxima (m/s**2)
        
        # TODO9:implementar os initialize
        
        # Modelo
        self.T_min   = T_min   # int : Valor mínimo para o horizonte de planejamento
        self.T_max   = T_max   # int : Valor máximo para o horizonte de planejamento
        self.delta_T = delta_T # int : Discretização do tempo (s) Tempo que leva de um waypoint até o outro
        self.m       = m       # float : Massa do VANT (!=0) (gramas)
    
        # Parametros do indivíduo
        self.mutation_prob = mutation_prob # float : Probabilidade de ocorrer uma mutação no dna (%)
        self.fitness       = None          # float : Fitness do indivíduo
        #self.birth_time    = None          # time  : Hora que o indivíduo é criado
        self.dna           = None          # list  : Conjunto de genes formando o DNA ([Gene, ...])
        self.dna_decoded   = None          # list  : DNA decodificado ([GeneDecoded, ...])
        self.spawn_mode    = spawn_mode    # str   : Tipo de incialização do DNA {'random'}
        self.start_time    = start_time    # time  : a hora em que o genético começou a rodar

        assert version, 'Algorithm version must be informed!\nEx: Version("alpha","RC")'
        if version.major == 'alpha': # Sem otimização em T
            self.T = T
            self.mutation_choices = [
                self._mutation_creep, 
                self._mutation_change
            ]
        elif version.major == 'beta': # Com otimização em T
            self.T = random.randint(T_min, T_max) # int : Horizonte de planejamento (quantidade de waypoints)
            self.mutation_choices = [
                self._mutation_remove, 
                self._mutation_insert, 
                self._mutation_creep, 
                self._mutation_change
            ]


        self.spawn(mode=spawn_mode)
        
    
    def set_fitness(self, fitness, fitness_trace, birth_time):
        self.fitness = fitness
        self.fitness_trace = fitness_trace
        #self.birth_time = birth_time
    
    
    # ---
    
    def spawn(self, mode):
        self.dna = [self._build_gene(mode) for _ in range(self.T) ]
        
    def _build_gene(self, mode='random'):
        # Inicialização aleatória gera valores com distribuição uniforme
        if mode == 'random':
            a = random.uniform(self.a_min, self.a_max)
            e = random.uniform(self.e_min, self.e_max)
            
        return Gene(a, e)
    
    # ---
    
    def decode(self):
        #self.dna_decoded = [self._decode_gene() for i in range(len(self.dna))]
        self.dna_decoded = self._decode_gene() # TODO: Organizar, voltar como era a linha de cima. Fazer função abaixo só computar o gene
        self.birth_time = time.time() - self.start_time

    def _decode_gene(self):
        dna = self.dna
        
        # parametros
        delta_T = self.delta_T
        m = self.m
        
        dna_decoded = []
        dna_decoded.append(self.gene_decoded_0)
        
        for i in range(0, len(dna)):
            # dna
            a  = dna[i].a
            e  = dna[i].e
            
            # dna decodificado
            px = dna_decoded[i].x
            py = dna_decoded[i].y
            v  = dna_decoded[i].v
            al = dna_decoded[i].al
            
            F = self.__F(v)
        
            # Equações descritas em (Arantes 2016)
            _px = px + ( v * cos(al) * delta_T ) + ( a * cos(al) * ((delta_T**2)/2) ) 
            _py = py + ( v * sin(al) * delta_T ) + ( a * sin(al) * ((delta_T**2)/2) ) 
            _v  = v  + ( a * delta_T ) - ( (F/m) * delta_T )
            _al = al + ( e * delta_T )

            dna_decoded.append(GeneDecoded(_px, _py, _v, _al))

        return dna_decoded
    
    
    def __F(self, v):
        # Equação do Arrasto
        # Disponível em https://pt.wikipedia.org/wiki/Equa%C3%A7%C3%A3o_do_arrasto
        # Versão utilizada ((Arantes, 2016) equação 3.5)
        
        Cd  = 0.8     # float : Coeficiente de arrasto, específico para cada aeronave
                      #         (considerado Angled Cube) obtido de https://pt.wikipedia.org/wiki/Coeficiente_de_resist%C3%AAncia_aerodin%C3%A2mica
        rho = 1.225   # float : Massa específica do fuído (aka densidade) (k/m**3)
                      #         (a 15 graus Celsius) Valor de rho obtido de https://pt.m.wikipedia.org/wiki/Densidade_do_ar
        A = 1.0       # float : Área de referência # TODO: o que é isso?
        # v = v       # float : Velocidade do Vant no instante t (fornecido como parâmetro da função)
        
        F = 0.5 * Cd * rho * A * (v**2)
        
        return F
        
    
    # ---
    
    def crossover(self, parent2):
        dna = random.choice([self._OX, self._BLX_Alpha])(self.dna, parent2.dna)
        dna = self._complete(dna, self.dna, parent2.dna)
        child = self.generate(dna)
        return child
    
    
    def _complete(self, dna, dna1, dna2):
        # Adiciona os genes restantes da diferença de tamanho entre os dois DNAs
               
        if len(dna1) > len(dna2):
            bigger  = dna1
            smaller = dna2
        else:
            bigger  = dna2
            smaller = dna1
    
        for i in range(len(smaller)-1, len(bigger)-1):
            if random.random() < 0.5:
                dna.append(bigger[i])
                
        return dna
        
    
    def _OX(self, dna1, dna2):
        dna = []
        for gene1, gene2 in zip(dna1, dna2):
            dna.append(random.choice([gene1, gene2]))
        return dna
        
        
    def _BLX_Alpha(self, dna1, dna2):
        dna = []
        for gene1, gene2 in zip(dna1, dna2):
            a = self.__BLX_ALpha_select_gene(gene1.a, gene2.a)
            e = self.__BLX_ALpha_select_gene(gene1.e, gene2.e)
            if a>self.a_max:
              a=self.a_max
            elif a < self.a_min:
              a=self.a_min

            if e>self.e_max:
              e=self.e_max
            elif e < self.e_min:
              e=self.e_min            
            
            gene = Gene(a, e)
            dna.append(gene)
            
        return dna
    
    
    def __BLX_ALpha_select_gene(self, x, y):
        # x - Gene : gene do pai 1
        # y - Gene : gene do pai 2
        alpha = random.uniform(0,1)
        d = abs(x-y)
        u = random.uniform(min(x,y)-alpha*d, max(x,y)+alpha*d)
        return u
    
    
    def generate(self, dna):
        # Cria um filho com os mesmos parametros do pai, mas com um dna fornecido
        child = copy.deepcopy(self)
        child.dna = dna
        child.decode()
        return child
    
        
    # ---
    
    def mutation(self, mutation_prob=None):
        mutation_prob = self.mutation_prob if not mutation_prob else mutation_prob # 0.7
        
        # Tem uma probabilidade mutation_prob de mutar o gene ou não
        if random.random() < mutation_prob:
            # Seleciona aleatoriamente uma das formas de mutação
            new_dna = random.choice(self.mutation_choices)(self.dna)
            # [
            #     self._mutation_remove, 
            #     self._mutation_insert, 
            #     self._mutation_creep, 
            #     self._mutation_change
            # ]
            
            if new_dna:
                self.dna = new_dna
                self.decode()
            
            return True
        return False
    
    def _mutation_change(self, dna):
        # Reinicia um gene aleatoriamente
        new_dna = []
        for gene in dna:
            if random.random() < 0.5:
                new_dna.append(self._build_gene('random'))
            else:
                new_dna.append(gene)
        
        return new_dna
    
    
    def _mutation_remove(self, dna):
        # Remove UM gene aleatório do DNA
        if len(dna) > self.T_min:
            i = random.randint(0, len(dna)-1)
            dna.pop(i)
            return dna
        return None
        
        
    def _mutation_insert(self, dna):
        # Insere UM gene aleatório no DNA em uma posição aleatória
        if len(dna) < self.T_max:
            i = random.randint(0, len(dna)-1)
            gene = self._build_gene()
            dna.insert(i, gene)
            return dna
        return None
    
    
    def _mutation_creep(self, dna):
        # Muta em um pequeno valor aleatorio todos os genes
        new_dna = []
        for gene in dna:
            a = self.__mute(gene.a, self.a_min, self.a_max)
            e = self.__mute(gene.e, self.e_min, self.e_max)

            # TODO2: otimizar
            new_gene = Gene(a, e)
            new_dna.append(new_gene)

        return new_dna
        
        
    def __mute(self, val, min_val, max_val):
        mutation_rate = random.uniform(0, max_val*0.5)
        s = random.choice([1, -1])
        val = val * (1 + (mutation_rate * s))

        # Checa se não estoura os limites
        if val>max_val:
          val=max_val
        elif val<min_val:
          val=min_val
        #val = max(val, min_val)
        #val = min(val, max_val)

        return val
    
    
    # ---
    
    def get_route(self):
        return [ [gene.x, gene.y] for gene in self.dna_decoded ]

# %% [markdown]
# ## 2.2. Definição do Genético

# %%
class Genetic():
    
    def __init__(
        self, 
        Specie, 
        mapa,
        taxa_cross=1.0,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=500,
        C_cur=100,
        C_t=10,
        max_exec_time=30,
        min_precision=1.0,
        k_tournament=2,
        gps_imprecision=1,
        big_delta=1,
        version=Version('alpha','RC'),
        **kwargs
    ):
        # Modelo
        self.Specie = Specie # objeto : Definição da classe (não a instância)
        self.mapa   = mapa   # Mapa   : Mapa com as características da missão

        # Parâmetros
        self.taxa_cross      = taxa_cross      # float : Taxa de ocorrencia do crossover [0,1]
        self.population_size = population_size # int   : Quantidade máxima de indivíduos na população 
        self.C_d             = C_d             # int   : Custo associado ao fitness de destino
        self.C_obs           = C_obs           # int   : Custo associado ao fitness de obstáculos
        self.C_con           = C_con           # int   : Custo associado ao fitness de consumo de combustível
        self.C_cur           = C_cur           # int   : Custo associado ao fitness de curvatura da rota
        self.C_t             = C_t             # int   : Custo associado ao fitness do tamanho do DNA (T ou horizonte de planejamento)
        self.max_exec_time   = max_exec_time   # float : Tempo máximo de execução - Stop criteria (segundos)
        self.min_precision   = min_precision   # float : Precisão mínima de acerto ao destino (metros)
        self.k_tournament    = k_tournament    # int   : Quantidade de indivíduos disputando o torneio
        self.gps_imprecision = gps_imprecision # float : Imprecisão do GPS (metros)
        self.big_delta       = big_delta
        
        # Versionamento
        self.version = version

        # Alguns dos valores do kwargs são passados para a instanciação dos indivíduos
        self.kwargs = kwargs
        
        # Inicialização
        self.population = None 
        self.fitnesses  = None
        self.best       = None
        self.ancestry   = []
        

#         if version.minor == "RC":
#             self.__fitness_obstacles = self.__fitness_obstacles_RC
#         elif version.minor == "CC":
#             self.__fitness_obstacles = self.__fitness_obstacles_CC

        
    def run(self, max_exec_time=None, verbose=False, info=False, debug=False):
        self.max_exec_time = max_exec_time if max_exec_time else self.max_exec_time
        
        # Acompanhamento do tempo (critério de parada)
        self.start_time = time.time()
        
        # Genesis
        self.population = self._genesis(self.Specie, self.population_size)
        
        # Inicializar
        self._decode(self.population)
        
        # Avaliar
        self.fitnesses = [self._fitness(subject, self.mapa) for subject in self.population]
    
        # Escolher melhor de todos
        self.best = self.population[self.fitnesses.index(max(self.fitnesses))]
        
        
        self.trace = []
        
        while not self.stop_criteria():
            self.flag_newborn = self.population_size
            count_while = 0
            
            while not self.converge():
                self.flag_newborn = 0
                count_while += 1
                
                for i in range(ceil(self.taxa_cross * self.population_size)):
                    # Seleção por torneio
                    parent1, parent2 = self._tournament(self.population, k=self.k_tournament)
            
                    # Crossover
                    child = parent1.crossover(parent2)
                    
                    # Mutação
                    child.mutation()
                    
                    # Fitness
                    self._fitness(child, self.mapa)
                    
                    # Adicionar filho na população
                    self._insert(child, parent1, parent2)
                    
                    # Print
                    if verbose and self.flag_newbest:
                        print('  Novo melhor de todos! fit: {}'.format(self.best.fitness))
                    if debug:
                        print('\nparent1.dna', parent1.dna)
                        print('\nparent2.dna', parent2.dna)
                        print('\nchild.dna.mutation', child.dna)
                        
                        
                aux_T_dna = [len(subject.dna) for subject in self.population]
                self.trace.append({
                    'medium_fitness': sum(self.fitnesses)/self.population_size,
                    'best_fitness': self.best.fitness,
                    'newborns': self.flag_newborn,
                    'newbest': self.flag_newbest,
                    'T_medio': sum(aux_T_dna)/self.population_size,
                    'T_maior': max(aux_T_dna),
                    'T_menor': min(aux_T_dna),
                    'T_melhor': len(self.best.dna)
                })
                
                # Print
                if verbose:
                    print('Fim da geração. {} novos indivíduos'.format(self.flag_newborn))
                    print('Melhor de todos: {}'.format(self.best.fitness))
                    print('-'*20)
                        
                        
            # Reiniciar rotas
            self.population = []
            self.population = self._genesis(self.Specie, self.population_size-1)
            # Nunca matar o melhor de todos
            self.population.append(self.best)
            
            # Inicializar
            self._decode(self.population)
            
            # Avaliar
            self.fitnesses = [self._fitness(subject, self.mapa) for subject in self.population]
            
            # Print
            if verbose:
                print('Meteoro! Reiniciando rotas')
            if info:
                print('Meteoro! Melhor de todos:{} - count:{}'.format(self.best.fitness, count_while))
                
                
        return self.best
                      
    # ---
    
    def _insert(self, child, parent1, parent2):
        # Verifica se um indivíduo é digno de entrar na população e tomar o lugar de um de seus pais

        self.flag_newbest = False
        
        if child.fitness < parent1.fitness:
            self.__substitute(child, parent1)

        elif child.fitness < parent2.fitness:
            self.__substitute(child, parent2)

        if child.fitness < self.best.fitness:
            self.best = child
            self.ancestry.append(child)
            self.flag_newbest = True
    
    
    def __substitute(self, child, parent):
        i_parent = self.population.index(parent)

        self.population.remove(parent)
        self.population.append(child)

        self.fitnesses.pop(i_parent)
        self.fitnesses.append(child.fitness)
        self.flag_newborn += 1
    
    
    # ---
    
    def stop_criteria(self):
        # Para a execução depois de uma quantidade de segundos
        if (time.time() - self.start_time) >= self.max_exec_time:
            return True
        return False
    
    def converge(self):
        # Converge caso nenhum novo indivíduo seja adicinado
        if self.flag_newborn == 0:
            return True
        return False
                         
    # ---
    
    def _genesis(self, Specie, population_size):
        population = [Specie(start_time=self.start_time, version=self.version,**self.kwargs) for i in range(population_size)]
        return population 
    
    # ---
    
    def _decode(self, population):
        for subject in population:
            subject.decode()
        return True
    
    # ---
    
    def _fitness(self, subject, mapa):
        
        fit_d   = self.__fitness_destination(subject, mapa)
        fit_obs = self.__fitness_obstacles(subject, mapa)
        fit_con = self.__fitness_consumption(subject, mapa)
        fit_cur = self.__fitness_curves(subject, mapa)
        fit_t   = self.__fitness_t(subject, mapa)
        
        fitness_trace = [self.C_d   * fit_d,
                         self.C_obs * fit_obs,
                         self.C_con * fit_con,
                         self.C_cur * fit_cur,
                         self.C_t   * fit_t]
        
        fitness = sum(fitness_trace)
        
        birth_time = time.time() - self.start_time
        
        subject.set_fitness(fitness, fitness_trace, birth_time)
        
        return fitness
    
    def __fitness_destination(self, subject, mapa):
        # Prioriza rotas que acertem o destino
        
        A = subject.dna_decoded[-1] # Último waypoint da rota
        B = mapa.destination        # Waypoint de destino
        
        # Distância euclidiana entre o último ponto da rota e o ponto de destino
        d = sqrt( (B.x - A.x)**2 + (B.y - A.y)**2 )
        
        # Determina uma precisão mínima aceita
        if d < self.min_precision: # min_precision default = 1.0
            return 0
        return d

    
    # def __fitness_obstacles is an abstraction of either one of those two following functions:
    # __fitness_obstacles_RC and __fitness_obstacles_CC

#     def __fitness_obstacles_RC(self, subject, mapa):
    def __fitness_obstacles(self, subject, mapa):
        # Prioriza rotas que não ultrapassem obstáculos
        count = 0
        
        for gene_decoded_t1, gene_decoded_t2  in pairwise(subject.dna_decoded):
            # Utiliza somente as áreas infladas para cálculo
            for area_n in mapa.areas_n_inf:
                wp1 = CartesianPoint(gene_decoded_t1.x, gene_decoded_t1.y)
                wp2 = CartesianPoint(gene_decoded_t2.x, gene_decoded_t2.y)
                
                # Calcula se algum waypoint está dentro de algum obstáculo
                if point_in_polygon(wp1, area_n):
                    count += 1

                # Calcula se alguma conexão entre os waypoints intersecciona algum obstáculo
                if segment_in_polygon(wp1, wp2, area_n):
                    count += 1
            
        return count


    def __fitness_obstacles_CC(self, subject, mapa):
        # Prioriza rotas que não ultrapassem obstáculos
        count       = 0
        
        #bigger_risk = 0 #M1
        sum_risk    = 0 #M2
    
        for gene_decoded_t1  in subject.dna_decoded:
            # Utiliza somente as áreas infladas para cálculo
            for area_n in mapa.areas_n_inf:
                wp1 = CartesianPoint(gene_decoded_t1.x, gene_decoded_t1.y)
    
                # Alocação de Risco    
                wp_risk = risk_total(wp1, area_n, self.gps_imprecision) #M1 #M2
            
                # Modo 1: Considerar o maior risco
                # bigger_risk = max(wp_risk, bigger_risk) #M1

                # Modo 2: Considerar a soma individual de cada risco
                sum_risk += wp_risk #M2

        #prob = min(bigger_risk, 1) #M1
        #prob = min(self.big_delta - sum_risk, 1) #M2
        if self.big_delta-sum_risk > 0:
            prob=0
        else:
            prob=sum_risk-self.big_delta
            
        #print(sum_risk)
            
        return prob
    
    
    def __fitness_consumption(self, subject, _):
        # Prioriza rotas com menor consumo de combustível (bateria)
        consumption = [gene.a**2 for gene in subject.dna]
        return sum(consumption)
    
        
    def __fitness_curves(self, subject, _):
        # Prioriza rotas que evitem fazer curvas desnecessárias
        curves = [abs(gene.e) for gene in subject.dna]
        return (1/subject.e_max) * sum(curves)
        
        
    def __fitness_t(self, subject, _):
        # Prioriza rotas com menor quantidade de waypoints
        return len(subject.dna)
    
        
    # ---
        
    def _tournament(self, population, k=2):
        parents = []
        for i in range(2):
            
            local_best = random.choice(population)
            for j in range(k-1):
                # Seleciona k individuos
                a = random.choice(population)
                if a.fitness < local_best.fitness:
                    local_best = a
                    
            parents.append(local_best)
            
        # Retorna o resultado de duas batalhas
        return parents[0], parents[1]

# %% [markdown]
# # 3. Execução
# Essa seção contém a execução do AG. Aqui contém as definições dos mapas, e execução do planejador de rotas. Pode alterar os parâmetros a vontade para testar novos resultados

# %% [markdown]
# ## 3.1. Mapas

# %% [markdown]
# ### Mapa 1

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (20.0, 5.0), # left, bottom
    (20.0, 15.5), # left, top
    (30.0, 15.5), # right, top
    (30.0, 5.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]


mapa_1 = Mapa(wp_ori, wp_des, [verts1], inflation_rate=1)

# %%
# Visualização desse mapa
vis_mapa(mapa_1)

# %% [markdown]
# ### Mapa 2

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (15.0,  8.0), # left, bottom
    (15.0, 20.0), # left, top
    (20.0, 20.0), # right, top
    (20.0,  8.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (30.0,  0.0), # left, bottom
    (30.0, 12.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  0.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_2 = Mapa(wp_ori, wp_des, [verts1, verts2], inflation_rate=1)

# %%
# Visualização desse mapa
vis_mapa(mapa_2)

# %% [markdown]
# ### Mapa 3

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (15.0, 11.0), # left, bottom
    (15.0, 25.0), # left, top
    (35.0, 23.0), # right, top
    (35.0, 16.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (15.0,  0.0), # left, bottom
    (15.0,  9.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  6.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_3 = Mapa(wp_ori, wp_des, [verts1, verts2], inflation_rate=0.5)

# %%
# Visualização desse mapa
vis_mapa(mapa_3)

# %% [markdown]
# ### Mapa 4

# %%
wp_ori = CartesianPoint(40.0, 25.0)
wp_des = CartesianPoint(36.0, -22.0)

verts1 = [
    (19.0,-12.0), # left, bottom
    (15.0,0.0), # left, top
    (87.0,15.0), # right, top
    (90.0,3.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

# verts1 = [
#     (38.0,-9.0), # left, bottom
#     (38.0,6.0), # left, top
#     (87.0,15.0), # right, top
#     (90.0,3.0), # right, bottom
# ]
# verts1.append(verts1[0])
# verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (15.0,  0.0), # left, bottom
    (15.0,  9.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  6.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_4 = Mapa(wp_ori, wp_des, [verts1], inflation_rate=0.5)

# %%
# Visualização desse mapa
vis_mapa(mapa_4)

# %% [markdown]
# ## 3.2. Planejamento de Rota

# %%
break
# Out:
#   File "<ipython-input-17-6aaf1f276005>", line 4
# SyntaxError: 'break' outside loop

# %%
# ===============================================================
# --------------   UTILIZE ESSE ESPAÇO --------------------------

debug = False

# Altere aqui o mapa que deseja utilizar
#mapa = mapa_1
mapa = mapa_2
#mapa = mapa_3
#mapa = mapa_4


# Inicialização do Algoritmo
ag = Genetic(Subject, mapa, 
        version = Version('beta', 'RC'),
        # Parâmetros da classe Genetic:
        taxa_cross=5,
        population_size=10,
        C_d=1000,
        C_obs=10000,
        C_con=500,
        C_cur=100,
        C_t=100,
        max_exec_time=30, # segundos
        # Parâmetros da classe Subject:
        px0=mapa.origin.x,
        py0=mapa.origin.y,
        T_min=1,
        T_max=25,
        mutation_prob=0.7
)

# ===============================================================

# Execução do AG, retorna o melhor indivíduo
best = ag.run(info=True)

# Print do DNA do melhor
print('-'*30)
for dna in best.dna:
    print(dna)
    
# Print do DNA DECODIFICADO do melhor
print('-'*30)
for dna_decoded in best.dna_decoded:
    print(dna_decoded)
    
best = ag.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)


# Visualização de alguns gráficos de fitness e quantidade de Ts
#plot_stats(ag.trace, normalize=True)
#plot_stats(ag.trace, normalize=False)

# %%
import pickle
pickle.dump(ag, open( "test_ag_save.p", "wb" ) )
ag_backup = pickle.load(open( "test_ag_save.p", "rb" ) )

# %%
ag.__module__

# %%
ag_backup.best.birth_time

# %%
ag_backup

# %%
debug = True
wp_teste = GeneDecoded(x=19, y=16.5, v=7.8730500357006825, al=0.23615218818588443)

risk_total(wp_teste, mapa.areas_n_inf[0], 5)

# %%
 mapa.areas_n_inf[0]

# %% [markdown]
# #### Visualizar Detalhes do fitness

# %%
best.fitness_trace
# Destino Obstáculo Consumo Curva QtdWP

# %% [markdown]
# #### Recuperação de Erros
# Caso o AG pare no meio da execução, é possível visualizar o melhor de todos gerado até o momento mesmo assim, basta rodar a célula abaixo

# %%
best = ag.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %% [markdown]
# # 4. Execução da Implementação em ROS

# %%
mapa_file = [
{
	"id": 0,
	"name": "Mapa C2",
	"geo_home": [-47.932949, -22.002467, 0],
	"areas_bonificadoras":[],
	"areas_penalizadoras":[],
	"areas_nao_navegaveis":[
		{
			"id": "NN1",
			"name": "Campo atras dos containers",
			"geo_points":[
				[-47.932749, -22.002332, 7], 
				[-47.932794, -22.002177, 13], 
				[-47.932664, -22.002147, 13], 
				[-47.932612, -22.002306, 7]
    			]
    		},
		{
			"id": "NN2",
			"name": "Bloco de aula",
			"geo_points":[
				[-47.932099, -22.002278, 20],
				[-47.932063, -22.002396, 20],
				[-47.932772, -22.002582, 20],
				[-47.932811, -22.002465, 20]
			]
		}
    ]
}
]

# %%
mapa_file = [
{
	"id": 0,
	"name": "Mapa C2",
	"geo_home": [-47.932949, -22.002467, 0],
	"areas_bonificadoras":[],
	"areas_penalizadoras":[],
	"areas_nao_navegaveis":[
		{
			"id": "NN1",
			"name": "Bloco de Aula",
			"geo_points":[
				[-47.932754, -22.002590, 7], 
				[-47.932804, -22.002485, 13], 
				[-47.932109, -22.002287, 13], 
				[-47.932072, -22.002401, 7]
    			]
    		},
		{
			"id": "NN2",
			"name": "Containers",
			"geo_points":[
				[-47.933286, -22.002630, 20],
				[-47.933370, -22.002350, 20],
				[-47.933047, -22.002259, 20],
				[-47.932956, -22.002532, 20]
			]
		}
    ]
}
]

# %%
import argparse

#from visualization import plot_map
#from genetic_v2_3 import Subject, Genetic 
#from data_definitions import Mapa, CartesianPoint, Conversor, GeoPoint

#from file_manipulation import read_mapa, write_mavros, upload_mapa

## ENTRADA

# Parâmetros recebidos (arquivo .srv)
origin_lat       = -22.002237
origin_long      = -47.932546
origin_alt       = 13
destination_lat  = -22.002674 
destination_long = -47.932608
destination_alt  = 15

# P0
# destination_lat  = -22.002278 
# destination_long = -47.932099
# destination_alt  = 20

# P1
# destination_lat  = -22.002396 
# destination_long = -47.932063
# destination_alt  = 20


mapa_id          = 0

# Leitura do arquvio em DATA
#PATH = '/home/gustavosouza/Documents/Per/path-planning/data/mapa.json' #Ubuntu
PATH = r'../../data' #Windows
#geo_home, _, _, areas_n = read_mapa(PATH, mapa_id)
geo_home, _, _, areas_n = upload_mapa(mapa_file, mapa_id)

cart_origin      = Conversor.geo_to_cart(GeoPoint(origin_lat, origin_long, origin_alt), geo_home)
cart_destination = Conversor.geo_to_cart(GeoPoint(destination_lat, destination_long, destination_alt), geo_home)


mapa = Mapa(cart_origin, cart_destination, areas_n, inflation_rate=3)



## EXECUÇÃO DO AG
ag_teste = Genetic(Subject, mapa,
        # Genetic
        taxa_cross=0.5,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=100,
        C_cur=500,
        C_t=100,
        max_exec_time=6000,
        #Subject,
        T_min=10,
        T_max=40,
        mutation_prob=0.7,
        px0=cart_origin.x,
        py0=cart_origin.y
)


best = ag_teste.run(info=True)

# Melhor rota encontrada : WPs em cartesiano
cart_points = best.get_route()

# Melhor rota encontrada : WPs em geográfico
geo_points = [ Conversor.cart_to_geo(CartesianPoint(cart_point[0], cart_point[1]), geo_home) for cart_point in cart_points ]


# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

## SAÍDA

#output_filename = '/mnt/c/Projetos/path-planning/algorithms/ros_genetic/path_from_ga_output.wp'
#write_mavros(output_filename, geo_points)

# %%
def print_mavros(geo_points): #throws FileNotFoundException
    print('Printing mavros file...\n\n\n')
    count = 1


    current_waypoint = 1

    print('QGC WPL 120\n') # Determines the file version

    i = 0

    for geo_point in geo_points:
        print(
            str(i) + '\t'
            + str(current_waypoint) + '\t' 
            + '3\t16\t3\t0\t0\t0\t'
            + '{:10.8f}'.format(geo_point.longitude) + '\t' 
            + '{:10.8f}'.format(geo_point.latitude) + '\t'
            + '{:10.8f}'.format(geo_point.altitude) + '\t'
            + '1'
            + '\n'
        )

        current_waypoint = 0
        i+=1

    print('\n\n\nOutput print generated.')

# %%
print_mavros(geo_points)

# %%
mapa.areas_n

# %%
areas = [ area for area in itertools.chain(mapa.areas_n) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %%
import argparse

#from visualization import plot_map
#from genetic_v2_3 import Subject, Genetic 
#from data_definitions import Mapa, CartesianPoint, Conversor, GeoPoint

#from file_manipulation import read_mapa, write_mavros, upload_mapa

## ENTRADA

# Parâmetros recebidos (arquivo .srv)
origin_lat       = -22.002237
origin_long      = -47.932546
origin_alt       = 13
destination_lat  = -22.002674 
destination_long = -47.932608
destination_alt  = 15

# P0
# destination_lat  = -22.002278 
# destination_long = -47.932099
# destination_alt  = 20

# P1
# destination_lat  = -22.002396 
# destination_long = -47.932063
# destination_alt  = 20


mapa_id          = 0

# Leitura do arquvio em DATA
#PATH = '/home/gustavosouza/Documents/Per/path-planning/data/mapa.json' #Ubuntu
PATH = r'../../data' #Windows
#geo_home, _, _, areas_n = read_mapa(PATH, mapa_id)
geo_home, _, _, areas_n = upload_mapa(mapa_file, mapa_id)

cart_origin      = Conversor.geo_to_cart(GeoPoint(origin_lat, origin_long, origin_alt), geo_home)
cart_destination = Conversor.geo_to_cart(GeoPoint(destination_lat, destination_long, destination_alt), geo_home)


mapa = Mapa(cart_origin, cart_destination, areas_n, inflation_rate=0.1)



## EXECUÇÃO DO AG
ag_teste = Genetic(Subject, mapa,
        # Genetic
        taxa_cross=0.5,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=100,
        C_cur=500,
        C_t=1,
        max_exec_time=600,
        #Subject,
        T_min=10,
        T_max=40,
        mutation_prob=0.7,
        px0=cart_origin.x,
        py0=cart_origin.y
)


best = ag_teste.run(info=True)

# Melhor rota encontrada : WPs em cartesiano
cart_points = best.get_route()

# Melhor rota encontrada : WPs em geográfico
geo_points = [ Conversor.cart_to_geo(CartesianPoint(cart_point[0], cart_point[1]), geo_home) for cart_point in cart_points ]


# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

## SAÍDA

#output_filename = '/mnt/c/Projetos/path-planning/algorithms/ros_genetic/path_from_ga_output.wp'
#write_mavros(output_filename, geo_points)

# %%
best.fitness_trace
# Destino Obstáculo Consumo Curva QtdWP

# %%
best = ag_teste.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %% [markdown]
# # 5. Ray Casting Stress Test
# Testes de estresse para verificar desempenho do algoritmo Ray Casting

# %% [markdown]
# ## 5.1. Point in Polygon

# %%
qty_points = 1000


verts1 = [
    (2.5, 2.5), # left, bottom
    (2.5, 4.5), # left, top
    (4.5, 4.5), # right, top
    (4.5, 2.5), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

texts = []
wps = []
for i in range(qty_points):
    x = random.uniform(1,6)
    y = random.uniform(1,6)
    
    wp = CartesianPoint(x,y)
    wps.append(wp)
    texts.append(str(point_in_polygon(wp, verts1))[0])
    
plot_map(
    areas=[verts1], 
    labels=['n'], 
    texts=texts,
    points=wps,
    wp_style='x',
    title='Ray Casting Algorithm Stress Test, wp={}'.format(qty_points),
    stress=True
)

# %% [markdown]
# ## 5.2. Segment intersects polygon

# %%
qty_segments = 15

verts1 = [
    (2.5, 2.5), # left, bottom
    (2.5, 4.5), # left, top
    (4.5, 4.5), # right, top
    (4.5, 2.5), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

texts = []
segments = []
for i in range(qty_segments):
    x = random.uniform(1,6)
    y = random.uniform(1,6)
    wp1 = CartesianPoint(x,y)

    x = random.uniform(1,6)
    y = random.uniform(1,6)
    wp2 = CartesianPoint(x,y)

    segment = [wp1, wp2]
    segments.append(segment)
    texts.append(str(segment_in_polygon(wp1, wp2, verts1))[0])
    
plot_map(
    areas=[verts1], 
    labels=['n'], 
    texts=texts,
    segments=segments,
    wp_style='-x',
    title='Ray Casting Algorithm Stress Test, wp={}'.format(qty_segments),
    stress=True
)

# %% [markdown]
# # 6. Automated Experiments

# %% [markdown]
# ## Def

# %%
debug = False

# Altere aqui o mapa que deseja utilizar
#mapa = mapa_1
#mapa = mapa_2
#mapa = mapa_3
#mapa = mapa_4

def run_ag(mapa):

    # Inicialização do Algoritmo
    ag = Genetic(Subject, mapa, 
            version = Version('beta', 'RC'),
            # Parâmetros da classe Genetic:
            taxa_cross=5,
            population_size=10,
            C_d=1000,
            C_obs=10000,
            C_con=500,
            C_cur=100,
            C_t=100,
            max_exec_time=600, # segundos
            # Parâmetros da classe Subject:
            px0=mapa.origin.x,
            py0=mapa.origin.y,
            T=10,
            T_min=1,
            T_max=25,
            mutation_prob=0.7
    )

    # Execução do AG, retorna o melhor indivíduo
    best = ag.run(info=True)

    # Print do DNA do melhor
    print('-'*30)
    for dna in best.dna:
        print(dna)
        
    # Print do DNA DECODIFICADO do melhor
    print('-'*30)
    for dna_decoded in best.dna_decoded:
        print(dna_decoded)
        
    best = ag.best

    # Visualização do Mapa usado, com a rota do melhor de todos
    areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
    tipos = [ 'n' for _ in range(len(areas))]
    plot_map(
        areas=areas,            # Mapa usado
        labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
        origem=mapa.origin,      # waypoint de origem
        destino=mapa.destination, # waypoint de destino
        waypoints=best.get_route(), # rota do melhor de todos
    )


    # Visualização de alguns gráficos de fitness e quantidade de Ts
    #plot_stats(ag.trace, normalize=True)
    #plot_stats(ag.trace, normalize=False)

    return ag

# %% [markdown]
# ## Run

# %%
import pickle

# %%
tests = {
    'mapa1':{
        'ags': [],
        'res': []
    },
    'mapa2':{
        'ags': [],
        'res': []
    },
    'mapa3':{
        'ags': [],
        'res': []
    },
    'mapa4':{
        'ags': [],
        'res': []
    }
}

# %%
import pickle

for i in range(5):
    for selected_map, mapa in zip(['mapa1'], [mapa_1]):
        ag = run_ag(mapa)
        tests[selected_map]['ags'].append(ag)
        
        l = [[subject.fitness, subject.birth_time] for subject in ag.ancestry]   
        tests[selected_map]['res'].append(l)
        
        pickle.dump(tests, open( 'backups/{}_{}.p'.format(selected_map, str(i)), 'wb' ) )

pickle.dump(tests, open('execution_10min_A.p', 'wb'))
# Out:
# Meteoro! Melhor de todos:8773.39888003125 - count:51
# Meteoro! Melhor de todos:5856.569100906684 - count:59
# Meteoro! Melhor de todos:5856.569100906684 - count:11
# Meteoro! Melhor de todos:5681.650772328643 - count:61
# Meteoro! Melhor de todos:5337.802259333786 - count:63
# Meteoro! Melhor de todos:5277.423675277199 - count:51
# Meteoro! Melhor de todos:5269.381019754333 - count:80
# Meteoro! Melhor de todos:5265.344634195336 - count:15
# Meteoro! Melhor de todos:5265.344634195336 - count:13
# Meteoro! Melhor de todos:5263.852007673691 - count:45
# Meteoro! Melhor de todos:5263.852007673691 - count:9
# Meteoro! Melhor de todos:5263.852007673691 - count:7
# Meteoro! Melhor de todos:5263.852007673691 - count:14
# Meteoro! Melhor de todos:4783.405702202287 - count:118
# Meteoro! Melhor de todos:4783.405702202287 - count:9
# Meteoro! Melhor de todos:4783.405702202287 - count:17
# Meteoro! Melhor de todos:4782.0798392785155 - count:25
# Meteoro! Melhor de todos:4782.0798392785155 - count:18
# Meteoro! Melhor de todos:4782.0798392785155 - count:21
# Meteoro! Melhor de todos:4773.206287211951 - count:227
# Meteoro! Melhor de todos:4673.909714506952 - count:13
# Meteoro! Melhor de todos:4673.909714506952 - count:17
# Meteoro! Melhor de todos:4628.9086434802475 - count:21
# Meteoro! Melhor de todos:4628.9086434802475 - count:8
# Meteoro! Melhor de todos:4628.9086434802475 - count:24
# Meteoro! Melhor de todos:4620.013011359913 - count:105
# Meteoro! Melhor de todos:4620.013011359913 - count:16
# Meteoro! Melhor de todos:4620.013011359913 - count:21
# Meteoro! Melhor de todos:4619.68491793979 - count:20
# Meteoro! Melhor de todos:4619.68491793979 - count:14
# Meteoro! Melhor de todos:4533.427604518229 - count:66
# Meteoro! Melhor de todos:4533.427604518229 - count:16
# Meteoro! Melhor de todos:4474.850927891486 - count:22
# Meteoro! Melhor de todos:4300.950127507347 - count:57
# Meteoro! Melhor de todos:4300.950127507347 - count:5
# Meteoro! Melhor de todos:4300.871978518911 - count:25
# Meteoro! Melhor de todos:4300.871978518911 - count:21
# Meteoro! Melhor de todos:4300.871978518911 - count:13
# Meteoro! Melhor de todos:4300.871978518911 - count:17
# Meteoro! Melhor de todos:4300.871978518911 - count:16
# Meteoro! Melhor de todos:4300.871978518911 - count:8
# Meteoro! Melhor de todos:4300.871978518911 - count:10
# Meteoro! Melhor de todos:4300.656883873996 - count:46
# Meteoro! Melhor de todos:4294.861227762549 - count:130
# Meteoro! Melhor de todos:4285.930683573578 - count:43
# Meteoro! Melhor de todos:4267.136319189313 - count:47
# Meteoro! Melhor de todos:4239.049592457497 - count:31
# Meteoro! Melhor de todos:4237.0999463407825 - count:19
# Meteoro! Melhor de todos:4237.0999463407825 - count:10
# Meteoro! Melhor de todos:4237.0999463407825 - count:20
# Meteoro! Melhor de todos:4226.8976731202165 - count:24
# Meteoro! Melhor de todos:4208.597231803615 - count:69
# Meteoro! Melhor de todos:4190.075494659639 - count:70
# Meteoro! Melhor de todos:4185.875016369225 - count:47
# Meteoro! Melhor de todos:4185.870365551169 - count:22
# Meteoro! Melhor de todos:4183.825353533758 - count:19
# Meteoro! Melhor de todos:4183.711678376316 - count:29
# Meteoro! Melhor de todos:4183.711678376316 - count:8
# Meteoro! Melhor de todos:4172.591759302371 - count:15
# Meteoro! Melhor de todos:4172.496423922659 - count:34
# Meteoro! Melhor de todos:4168.319167023556 - count:62
# Meteoro! Melhor de todos:3683.256845610925 - count:22
# Meteoro! Melhor de todos:3646.3730903713868 - count:22
# Meteoro! Melhor de todos:3646.3730903713868 - count:13
# Meteoro! Melhor de todos:3502.6486979426268 - count:171
# Meteoro! Melhor de todos:3459.8337730445774 - count:105
# Meteoro! Melhor de todos:3457.632929708021 - count:53
# Meteoro! Melhor de todos:3457.471067934613 - count:40
# Meteoro! Melhor de todos:3449.9527028126895 - count:31
# Meteoro! Melhor de todos:3449.9527028126895 - count:11
# Meteoro! Melhor de todos:3449.9527028126895 - count:21
# Meteoro! Melhor de todos:3449.9510700101364 - count:14
# Meteoro! Melhor de todos:3449.9510700101364 - count:20
# Meteoro! Melhor de todos:3449.9510700101364 - count:12
# Meteoro! Melhor de todos:3449.9510700101364 - count:10
# Meteoro! Melhor de todos:3438.4813449033654 - count:42
# Meteoro! Melhor de todos:3433.629009355061 - count:138
# Meteoro! Melhor de todos:3433.629009355061 - count:12
# Meteoro! Melhor de todos:3433.6235881347925 - count:22
# Meteoro! Melhor de todos:3433.6235881347925 - count:7
# Meteoro! Melhor de todos:3431.5228809890555 - count:43
# Meteoro! Melhor de todos:3431.5228809890555 - count:14
# Meteoro! Melhor de todos:3431.5228809890555 - count:12
# Meteoro! Melhor de todos:3431.1706175158665 - count:100
# Meteoro! Melhor de todos:3431.1706175158665 - count:26
# Meteoro! Melhor de todos:3429.776785490309 - count:67
# Meteoro! Melhor de todos:3429.776785490309 - count:25
# Meteoro! Melhor de todos:3429.776785490309 - count:10
# Meteoro! Melhor de todos:3429.776785490309 - count:21
# Meteoro! Melhor de todos:3429.776785490309 - count:17
# Meteoro! Melhor de todos:3427.1473242548004 - count:64
# Meteoro! Melhor de todos:3427.1473242548004 - count:13
# Meteoro! Melhor de todos:3426.5661391673843 - count:23
# Meteoro! Melhor de todos:3426.359374820859 - count:49
# Meteoro! Melhor de todos:3426.0522647068265 - count:28
# Meteoro! Melhor de todos:3426.0522647068265 - count:17
# Meteoro! Melhor de todos:3426.0522647068265 - count:13
# Meteoro! Melhor de todos:3424.2922063157766 - count:22
# Meteoro! Melhor de todos:3421.578020057849 - count:21
# Meteoro! Melhor de todos:3421.578020057849 - count:10
# Meteoro! Melhor de todos:3415.313697841562 - count:36
# Meteoro! Melhor de todos:3142.8554499117317 - count:20
# Meteoro! Melhor de todos:3142.8554499117317 - count:4
# Meteoro! Melhor de todos:3113.615850359188 - count:21
# Meteoro! Melhor de todos:3113.615850359188 - count:18
# Meteoro! Melhor de todos:3113.615850359188 - count:7
# Meteoro! Melhor de todos:3112.054549322922 - count:41
# Meteoro! Melhor de todos:3109.3174034973326 - count:29
# Meteoro! Melhor de todos:3107.4602877621337 - count:21
# Meteoro! Melhor de todos:3107.4018271649984 - count:20
# Meteoro! Melhor de todos:3107.4018271649984 - count:18
# Meteoro! Melhor de todos:3107.4018271649984 - count:7
# Meteoro! Melhor de todos:3107.4018271649984 - count:14
# Meteoro! Melhor de todos:3107.4018271649984 - count:12
# Meteoro! Melhor de todos:3107.4018271649984 - count:12
# Meteoro! Melhor de todos:3107.4018271649984 - count:9
# Meteoro! Melhor de todos:3107.4018271649984 - count:10
# Meteoro! Melhor de todos:3107.4018271649984 - count:18
# Meteoro! Melhor de todos:3107.4018271649984 - count:21
# Meteoro! Melhor de todos:3107.4018271649984 - count:19
# Meteoro! Melhor de todos:3107.40181698745 - count:28
# Meteoro! Melhor de todos:3107.40181698745 - count:16
# Meteoro! Melhor de todos:3107.362374322157 - count:70
# Meteoro! Melhor de todos:3107.362374322157 - count:18
# Meteoro! Melhor de todos:3107.362374322157 - count:10
# Meteoro! Melhor de todos:3107.362374322157 - count:14
# Meteoro! Melhor de todos:3107.362374322157 - count:8
# Meteoro! Melhor de todos:3107.362374322157 - count:17
# Meteoro! Melhor de todos:3057.7090547452367 - count:21
# Meteoro! Melhor de todos:3008.6681475676505 - count:145
# Meteoro! Melhor de todos:3004.2159145320334 - count:14
# Meteoro! Melhor de todos:3004.2159145320334 - count:16
# Meteoro! Melhor de todos:2994.6358515937454 - count:74
# Meteoro! Melhor de todos:2992.914901609646 - count:72
# Meteoro! Melhor de todos:2992.9090241817407 - count:21
# Meteoro! Melhor de todos:2992.9090241817407 - count:13
# Meteoro! Melhor de todos:2990.1947628769976 - count:103
# Meteoro! Melhor de todos:2990.1947628769976 - count:15
# Meteoro! Melhor de todos:2990.1947628769976 - count:21
# Meteoro! Melhor de todos:2990.1947628769976 - count:20
# Meteoro! Melhor de todos:2990.1947628769976 - count:13
# Meteoro! Melhor de todos:2990.1947628769976 - count:20
# Meteoro! Melhor de todos:2990.043043056746 - count:64
# Meteoro! Melhor de todos:2989.8144007389965 - count:16
# Meteoro! Melhor de todos:2989.8144007389965 - count:9
# Meteoro! Melhor de todos:2989.8144007389965 - count:6
# Meteoro! Melhor de todos:2989.8144007389965 - count:17
# Meteoro! Melhor de todos:2986.830688213725 - count:20
# Meteoro! Melhor de todos:2986.6643264790673 - count:16
# Meteoro! Melhor de todos:2986.4367068671686 - count:36
# Meteoro! Melhor de todos:2961.5679812920243 - count:91
# Meteoro! Melhor de todos:2908.5731526175955 - count:60
# Meteoro! Melhor de todos:2899.97810985883 - count:47
# Meteoro! Melhor de todos:2899.5317336172175 - count:48
# Meteoro! Melhor de todos:2899.5128532891663 - count:24
# Meteoro! Melhor de todos:2899.5128532891663 - count:28
# Meteoro! Melhor de todos:2899.5128532891663 - count:10
# Meteoro! Melhor de todos:2898.9590427587855 - count:11
# Meteoro! Melhor de todos:2898.9590427587855 - count:8
# Meteoro! Melhor de todos:2898.959023461408 - count:48
# Meteoro! Melhor de todos:2898.959023461408 - count:10
# Meteoro! Melhor de todos:2898.9217946674885 - count:20
# Meteoro! Melhor de todos:2898.9217946674885 - count:16
# Meteoro! Melhor de todos:2882.4385588695527 - count:20
# Meteoro! Melhor de todos:2872.3804154311206 - count:96
# Meteoro! Melhor de todos:2872.3804154311206 - count:23
# Meteoro! Melhor de todos:2872.3804154311206 - count:8
# Meteoro! Melhor de todos:2871.4509341694275 - count:28
# Meteoro! Melhor de todos:2866.4900331914578 - count:39
# Meteoro! Melhor de todos:2866.398322419477 - count:27
# Meteoro! Melhor de todos:2866.398322419477 - count:21
# Meteoro! Melhor de todos:2866.353033408087 - count:25
# Meteoro! Melhor de todos:2866.353033408087 - count:8
# Meteoro! Melhor de todos:2861.644045770754 - count:75
# Meteoro! Melhor de todos:2861.644045770754 - count:12
# Meteoro! Melhor de todos:2861.6425059178946 - count:22
# Meteoro! Melhor de todos:2861.6425059178946 - count:21
# Meteoro! Melhor de todos:2861.6425059178946 - count:22
# Meteoro! Melhor de todos:2861.6425059178946 - count:12
# Meteoro! Melhor de todos:2861.6425059178946 - count:19
# Meteoro! Melhor de todos:2861.6425059178946 - count:22
# Meteoro! Melhor de todos:2861.6393454929885 - count:11
# Meteoro! Melhor de todos:2861.6393454929885 - count:17
# Meteoro! Melhor de todos:2861.6393454929885 - count:23
# Meteoro! Melhor de todos:2861.6393454929885 - count:18
# Meteoro! Melhor de todos:2861.6393454929885 - count:29
# Meteoro! Melhor de todos:2861.6393454929885 - count:16
# Meteoro! Melhor de todos:2823.764180046285 - count:79
# Meteoro! Melhor de todos:2823.764180046285 - count:13
# Meteoro! Melhor de todos:2806.5147192526306 - count:67
# Meteoro! Melhor de todos:2802.5787548618637 - count:62
# Meteoro! Melhor de todos:2802.5787548618637 - count:19
# Meteoro! Melhor de todos:2802.5787548618637 - count:20
# Meteoro! Melhor de todos:2801.930296571951 - count:14
# Meteoro! Melhor de todos:2786.636885129632 - count:105
# Meteoro! Melhor de todos:2786.636885129632 - count:22
# Meteoro! Melhor de todos:2765.6134280936653 - count:143
# Meteoro! Melhor de todos:2765.0446254683457 - count:45
# Meteoro! Melhor de todos:2759.4602134096244 - count:127
# Meteoro! Melhor de todos:2759.4602134096244 - count:16
# Meteoro! Melhor de todos:2759.4602134096244 - count:12
# Meteoro! Melhor de todos:2759.016822653549 - count:28
# Meteoro! Melhor de todos:2757.5714783421936 - count:38
# Meteoro! Melhor de todos:2757.5714783421936 - count:17
# Meteoro! Melhor de todos:2757.5714783421936 - count:21
# Meteoro! Melhor de todos:2757.4985975528143 - count:26
# Meteoro! Melhor de todos:2757.4985975528143 - count:20
# Meteoro! Melhor de todos:2757.4985975528143 - count:15
# Meteoro! Melhor de todos:2757.4985975528143 - count:7
# Meteoro! Melhor de todos:2757.4985975528143 - count:17
# Meteoro! Melhor de todos:2757.4985975528143 - count:11
# Meteoro! Melhor de todos:2757.2832606776046 - count:29
# Meteoro! Melhor de todos:2757.2529426133015 - count:40
# Meteoro! Melhor de todos:2757.2529426133015 - count:12
# Meteoro! Melhor de todos:2757.154326472014 - count:51
# Meteoro! Melhor de todos:2757.102285722638 - count:33
# Meteoro! Melhor de todos:2757.102285722638 - count:18
# Meteoro! Melhor de todos:2757.102285722638 - count:19
# Meteoro! Melhor de todos:2757.102285722638 - count:19
# Meteoro! Melhor de todos:2757.0340120314563 - count:28
# Meteoro! Melhor de todos:2757.03094660788 - count:15
# Meteoro! Melhor de todos:2757.03094660788 - count:12
# Meteoro! Melhor de todos:2756.6082404012072 - count:66
# Meteoro! Melhor de todos:2756.6082404012072 - count:20
# Meteoro! Melhor de todos:2756.572063077837 - count:40
# Meteoro! Melhor de todos:2756.572063077837 - count:10
# Meteoro! Melhor de todos:2756.572063077837 - count:22
# Meteoro! Melhor de todos:2756.572063077837 - count:21
# Meteoro! Melhor de todos:2756.572063077837 - count:29
# Meteoro! Melhor de todos:2756.572063077837 - count:16
# Meteoro! Melhor de todos:2756.572063077837 - count:11
# Meteoro! Melhor de todos:2756.572063077837 - count:24
# Meteoro! Melhor de todos:2756.4108854392134 - count:97
# Meteoro! Melhor de todos:2756.4108854392134 - count:23
# Meteoro! Melhor de todos:2756.3367286575485 - count:91
# Meteoro! Melhor de todos:2756.336606575158 - count:18
# Meteoro! Melhor de todos:2756.336606575158 - count:42
# Meteoro! Melhor de todos:2756.336606575158 - count:13
# Meteoro! Melhor de todos:2756.336606575158 - count:5
# Meteoro! Melhor de todos:2756.336606575158 - count:30
# Meteoro! Melhor de todos:2756.336606575158 - count:17
# Meteoro! Melhor de todos:2756.336606575158 - count:13
# Meteoro! Melhor de todos:2753.4347822528894 - count:30
# Meteoro! Melhor de todos:2753.4347822528894 - count:12
# Meteoro! Melhor de todos:2752.6512195133027 - count:83
# Meteoro! Melhor de todos:2752.6512195133027 - count:14
# Meteoro! Melhor de todos:2752.6512195133027 - count:17
# Meteoro! Melhor de todos:2752.6512195133027 - count:13
# Meteoro! Melhor de todos:2752.6512195133027 - count:14
# Meteoro! Melhor de todos:2658.8210436232566 - count:20
# Meteoro! Melhor de todos:2633.9439534345393 - count:128
# Meteoro! Melhor de todos:2632.2204077134347 - count:14
# Meteoro! Melhor de todos:2631.963724176645 - count:16
# Meteoro! Melhor de todos:2631.654276583337 - count:45
# Meteoro! Melhor de todos:2626.0864924786283 - count:108
# Meteoro! Melhor de todos:2626.0864924786283 - count:6
# Meteoro! Melhor de todos:2610.2652956115435 - count:166
# Meteoro! Melhor de todos:2610.2652956115435 - count:9
# Meteoro! Melhor de todos:2610.2652956115435 - count:13
# Meteoro! Melhor de todos:2605.903631393513 - count:23
# Meteoro! Melhor de todos:2605.903631393513 - count:20
# Meteoro! Melhor de todos:2605.903631393513 - count:17
# Meteoro! Melhor de todos:2605.903631393513 - count:8
# Meteoro! Melhor de todos:2605.903631393513 - count:32
# Meteoro! Melhor de todos:2605.903631393513 - count:11
# Meteoro! Melhor de todos:2605.776052078166 - count:18
# Meteoro! Melhor de todos:2605.3472454157245 - count:14
# Meteoro! Melhor de todos:2603.464492560381 - count:75
# Meteoro! Melhor de todos:2603.464492560381 - count:12
# Meteoro! Melhor de todos:2603.464492560381 - count:19
# Meteoro! Melhor de todos:2603.464492560381 - count:30
# Meteoro! Melhor de todos:2603.464492560381 - count:24
# Meteoro! Melhor de todos:2603.464492560381 - count:17
# Meteoro! Melhor de todos:2603.4087586040255 - count:14
# Meteoro! Melhor de todos:2603.4087586040255 - count:15
# Meteoro! Melhor de todos:2602.9403249311645 - count:22
# Meteoro! Melhor de todos:2602.9403249311645 - count:6
# Meteoro! Melhor de todos:2601.738411466765 - count:90
# Meteoro! Melhor de todos:2592.3641997874984 - count:60
# Meteoro! Melhor de todos:2591.873492479215 - count:28
# Meteoro! Melhor de todos:2591.873492479215 - count:19
# Meteoro! Melhor de todos:2567.3489055939226 - count:25
# Meteoro! Melhor de todos:2555.739393592885 - count:150
# Meteoro! Melhor de todos:2555.739393592885 - count:8
# Meteoro! Melhor de todos:2555.571616113997 - count:21
# Meteoro! Melhor de todos:2555.571616113997 - count:10
# Meteoro! Melhor de todos:2555.571616113997 - count:11
# Meteoro! Melhor de todos:2553.8764739046333 - count:98
# Meteoro! Melhor de todos:2553.8764739046333 - count:10
# Meteoro! Melhor de todos:2553.5708451794635 - count:24
# Meteoro! Melhor de todos:2553.528129093216 - count:22
# Meteoro! Melhor de todos:2553.528129093216 - count:23
# Meteoro! Melhor de todos:2553.528129093216 - count:6
# Meteoro! Melhor de todos:2553.4657662382797 - count:23
# Meteoro! Melhor de todos:2548.9714985903984 - count:15
# Meteoro! Melhor de todos:2548.5909816019735 - count:31
# Meteoro! Melhor de todos:2548.5909816019735 - count:11
# Meteoro! Melhor de todos:2548.476231632184 - count:26
# Meteoro! Melhor de todos:2548.449034765792 - count:46
# Meteoro! Melhor de todos:2548.088709016808 - count:84
# Meteoro! Melhor de todos:2548.088709016808 - count:16
# Meteoro! Melhor de todos:2547.8992096091615 - count:38
# Meteoro! Melhor de todos:2547.8991139714544 - count:22
# Meteoro! Melhor de todos:2547.8991139714544 - count:15
# Meteoro! Melhor de todos:2547.8644684322317 - count:22
# Meteoro! Melhor de todos:2547.864168313573 - count:20
# Meteoro! Melhor de todos:2547.864168313573 - count:15
# Meteoro! Melhor de todos:2547.864168313573 - count:22
# Meteoro! Melhor de todos:2547.864168313573 - count:15
# Meteoro! Melhor de todos:2547.864168313573 - count:7
# Meteoro! Melhor de todos:2547.3004075245117 - count:39
# Meteoro! Melhor de todos:2547.3004075245117 - count:25
# Meteoro! Melhor de todos:2546.084795778718 - count:57
# Meteoro! Melhor de todos:2546.084795778718 - count:16
# Meteoro! Melhor de todos:2546.084795778718 - count:22
# Meteoro! Melhor de todos:2546.0803147342754 - count:37
# Meteoro! Melhor de todos:2546.0803147342754 - count:7
# Meteoro! Melhor de todos:2546.0803147342754 - count:19
# Meteoro! Melhor de todos:2546.0803147342754 - count:15
# Meteoro! Melhor de todos:2546.0803147342754 - count:28
# Meteoro! Melhor de todos:2546.0803147342754 - count:22
# Meteoro! Melhor de todos:2546.0803147342754 - count:11
# Meteoro! Melhor de todos:2546.0803147342754 - count:14
# Meteoro! Melhor de todos:2546.0523668583605 - count:16
# Meteoro! Melhor de todos:2546.020074052255 - count:40
# Meteoro! Melhor de todos:2546.020074052255 - count:24
# Meteoro! Melhor de todos:2546.020074052255 - count:19
# Meteoro! Melhor de todos:2545.9145532748453 - count:45
# Meteoro! Melhor de todos:2545.8089980378154 - count:29
# Meteoro! Melhor de todos:2545.8089980378154 - count:15
# Meteoro! Melhor de todos:2545.8049233170477 - count:35
# Meteoro! Melhor de todos:2545.8049233170477 - count:19
# Meteoro! Melhor de todos:2545.8049233170477 - count:21
# Meteoro! Melhor de todos:2545.7880563033896 - count:75
# Meteoro! Melhor de todos:2545.7880563033896 - count:22
# Meteoro! Melhor de todos:2545.7880563033896 - count:7
# Meteoro! Melhor de todos:2545.7880563033896 - count:20
# Meteoro! Melhor de todos:2518.110817313837 - count:33
# Meteoro! Melhor de todos:2518.110817313837 - count:13
# Meteoro! Melhor de todos:2517.7361002618345 - count:19
# Meteoro! Melhor de todos:2517.7361002618345 - count:24
# Meteoro! Melhor de todos:2517.7361002618345 - count:12
# Meteoro! Melhor de todos:2517.7361002618345 - count:14
# Meteoro! Melhor de todos:2517.7320297764045 - count:18
# Meteoro! Melhor de todos:2517.7320297764045 - count:26
# Meteoro! Melhor de todos:2517.7320297764045 - count:9
# Meteoro! Melhor de todos:2517.7320297764045 - count:19
# Meteoro! Melhor de todos:2517.5324484985167 - count:124
# Meteoro! Melhor de todos:2517.5324484985167 - count:14
# Meteoro! Melhor de todos:2517.5324484985167 - count:13
# Meteoro! Melhor de todos:2517.5324484985167 - count:13
# Meteoro! Melhor de todos:2517.5324484985167 - count:14
# Meteoro! Melhor de todos:2517.5324484985167 - count:11
# Meteoro! Melhor de todos:2517.5324484985167 - count:14
# Meteoro! Melhor de todos:2517.5195356354698 - count:17
# Meteoro! Melhor de todos:2517.5195356354698 - count:17
# Meteoro! Melhor de todos:2517.5195356354698 - count:15
# Meteoro! Melhor de todos:2517.4501916936842 - count:37
# Meteoro! Melhor de todos:2517.4346086238534 - count:10
# Meteoro! Melhor de todos:2517.429852694495 - count:17
# Meteoro! Melhor de todos:2517.429852694495 - count:15
# Meteoro! Melhor de todos:2517.4210285586923 - count:19
# Meteoro! Melhor de todos:2517.3927206101316 - count:21
# Meteoro! Melhor de todos:2517.3927206101316 - count:12
# Meteoro! Melhor de todos:2517.3629964148104 - count:24
# Meteoro! Melhor de todos:2517.3629964148104 - count:25
# Meteoro! Melhor de todos:2517.362528790336 - count:25
# Meteoro! Melhor de todos:2517.362528790336 - count:14
# Meteoro! Melhor de todos:2517.362528790336 - count:9
# Meteoro! Melhor de todos:2517.362151904872 - count:21
# Meteoro! Melhor de todos:2517.355175324019 - count:26
# Meteoro! Melhor de todos:2517.355175324019 - count:15
# Meteoro! Melhor de todos:2517.355157523876 - count:30
# Meteoro! Melhor de todos:2517.355157523876 - count:19
# Meteoro! Melhor de todos:2517.355157523876 - count:6
# Meteoro! Melhor de todos:2517.355157523876 - count:27
# Meteoro! Melhor de todos:2517.355157523876 - count:17
# Meteoro! Melhor de todos:2517.355157523876 - count:15
# Meteoro! Melhor de todos:2517.355157523876 - count:22
# Meteoro! Melhor de todos:2517.355157523876 - count:15
# Meteoro! Melhor de todos:2517.355157523876 - count:24
# Meteoro! Melhor de todos:2517.355157523876 - count:21
# Meteoro! Melhor de todos:2517.3430379319043 - count:83
# Meteoro! Melhor de todos:2517.3430379319043 - count:15
# Meteoro! Melhor de todos:2420.752902867668 - count:21
# Meteoro! Melhor de todos:2395.3179181780315 - count:105
# Meteoro! Melhor de todos:2395.3179181780315 - count:9
# Meteoro! Melhor de todos:2381.7912088191665 - count:105
# Meteoro! Melhor de todos:2381.7912088191665 - count:11
# Meteoro! Melhor de todos:2381.7912088191665 - count:13
# Meteoro! Melhor de todos:2361.6723736411386 - count:119
# Meteoro! Melhor de todos:2360.579561829729 - count:19
# Meteoro! Melhor de todos:2360.579561829729 - count:23
# Meteoro! Melhor de todos:2359.3020086078764 - count:30
# Meteoro! Melhor de todos:2355.2526356383073 - count:19
# Meteoro! Melhor de todos:2355.2526356383073 - count:9
# Meteoro! Melhor de todos:2339.3035516333794 - count:34
# Meteoro! Melhor de todos:2339.3035516333794 - count:11
# Meteoro! Melhor de todos:2331.4541603218586 - count:48
# Meteoro! Melhor de todos:2331.4541603218586 - count:16
# Meteoro! Melhor de todos:2331.4541603218586 - count:10
# Meteoro! Melhor de todos:2330.389325706805 - count:20
# Meteoro! Melhor de todos:2328.6424312837908 - count:33
# Meteoro! Melhor de todos:2326.874772104586 - count:41
# Meteoro! Melhor de todos:2321.2328148519373 - count:76
# Meteoro! Melhor de todos:2321.2328148519373 - count:14
# Meteoro! Melhor de todos:2319.5044678497816 - count:15
# Meteoro! Melhor de todos:2319.4937187582987 - count:22
# Meteoro! Melhor de todos:2319.4937187582987 - count:17
# Meteoro! Melhor de todos:2319.4937187582987 - count:14
# Meteoro! Melhor de todos:2319.4937187582987 - count:14
# Meteoro! Melhor de todos:2311.9540867911637 - count:99
# Meteoro! Melhor de todos:2311.9450754092372 - count:38
# Meteoro! Melhor de todos:2311.5646946194834 - count:25
# Meteoro! Melhor de todos:2311.5646946194834 - count:60
# Meteoro! Melhor de todos:2311.5646946194834 - count:10
# Meteoro! Melhor de todos:2310.718913934696 - count:22
# Meteoro! Melhor de todos:2310.718913934696 - count:19
# Meteoro! Melhor de todos:2310.0771676226186 - count:80
# Meteoro! Melhor de todos:2310.0771676226186 - count:15
# Meteoro! Melhor de todos:2310.0771676226186 - count:14
# Meteoro! Melhor de todos:2310.0771676226186 - count:23
# Meteoro! Melhor de todos:2310.0771676226186 - count:10
# Meteoro! Melhor de todos:2310.0771676226186 - count:17
# Meteoro! Melhor de todos:2308.3830438003442 - count:137
# Meteoro! Melhor de todos:2308.3830438003442 - count:11
# Meteoro! Melhor de todos:2308.3830438003442 - count:21
# Meteoro! Melhor de todos:2308.3830438003442 - count:13
# Meteoro! Melhor de todos:2308.1582448760764 - count:47
# Meteoro! Melhor de todos:2308.1582448760764 - count:22
# Meteoro! Melhor de todos:2302.5760538130144 - count:179
# Meteoro! Melhor de todos:2302.5750518286645 - count:23
# Meteoro! Melhor de todos:2302.5750518286645 - count:8
# Meteoro! Melhor de todos:2302.0020751786824 - count:37
# Meteoro! Melhor de todos:2301.8438185928344 - count:127
# Meteoro! Melhor de todos:2301.8438185928344 - count:10
# Meteoro! Melhor de todos:2301.8416979016774 - count:24
# Meteoro! Melhor de todos:2296.362903948437 - count:80
# Meteoro! Melhor de todos:2296.362903948437 - count:12
# Meteoro! Melhor de todos:2296.362903948437 - count:9
# Meteoro! Melhor de todos:2295.9831211366927 - count:146
# Meteoro! Melhor de todos:2295.9831211366927 - count:18
# Meteoro! Melhor de todos:2295.9831211366927 - count:15
# Meteoro! Melhor de todos:2290.632370529892 - count:113
# Meteoro! Melhor de todos:2290.632370529892 - count:18
# Meteoro! Melhor de todos:2290.632370529892 - count:14
# Meteoro! Melhor de todos:2290.632370529892 - count:17
# Meteoro! Melhor de todos:2290.632370529892 - count:3
# Meteoro! Melhor de todos:2290.5752873637975 - count:29
# Meteoro! Melhor de todos:2290.0590056245946 - count:101
# Meteoro! Melhor de todos:2289.8089552682422 - count:22
# Meteoro! Melhor de todos:2289.8089552682422 - count:13
# Meteoro! Melhor de todos:2289.779226569265 - count:33
# Meteoro! Melhor de todos:2289.7703355603326 - count:31
# Meteoro! Melhor de todos:2285.763233888632 - count:125
# Meteoro! Melhor de todos:2276.209209981832 - count:25
# Meteoro! Melhor de todos:2275.469473818651 - count:104
# Meteoro! Melhor de todos:2275.469473818651 - count:22
# Meteoro! Melhor de todos:2275.469473818651 - count:15
# Meteoro! Melhor de todos:2275.469473818651 - count:46
# Meteoro! Melhor de todos:2275.469473818651 - count:17
# Meteoro! Melhor de todos:2274.7632299517672 - count:125
# Meteoro! Melhor de todos:2274.7632299517672 - count:16
# Meteoro! Melhor de todos:2274.67519333877 - count:32
# Meteoro! Melhor de todos:2274.67519333877 - count:22
# Meteoro! Melhor de todos:2274.67519333877 - count:18
# Meteoro! Melhor de todos:2274.67519333877 - count:10
# Meteoro! Melhor de todos:2274.67519333877 - count:8
# Meteoro! Melhor de todos:2274.67519333877 - count:15
# Meteoro! Melhor de todos:2274.6733389084006 - count:26
# Meteoro! Melhor de todos:2274.644343847842 - count:42
# Meteoro! Melhor de todos:2274.6328718922205 - count:24
# Meteoro! Melhor de todos:2274.6328718922205 - count:9
# Meteoro! Melhor de todos:2274.6328718922205 - count:4
# Meteoro! Melhor de todos:2274.6328718922205 - count:14
# Meteoro! Melhor de todos:2274.6328718922205 - count:16
# Meteoro! Melhor de todos:2274.6328718922205 - count:20
# Meteoro! Melhor de todos:2274.6328718922205 - count:12
# Meteoro! Melhor de todos:2274.6328718922205 - count:9
# Meteoro! Melhor de todos:2274.6328718922205 - count:15
# Meteoro! Melhor de todos:2274.611080492517 - count:19
# Meteoro! Melhor de todos:2274.611080492517 - count:13
# Meteoro! Melhor de todos:2274.611080492517 - count:15
# Meteoro! Melhor de todos:2274.601011137914 - count:19
# Meteoro! Melhor de todos:2274.541004125898 - count:60
# Meteoro! Melhor de todos:2274.4933308654713 - count:13
# Meteoro! Melhor de todos:2274.3988441850715 - count:44
# Meteoro! Melhor de todos:2274.2780503332338 - count:23
# Meteoro! Melhor de todos:2274.241777532042 - count:23
# Meteoro! Melhor de todos:2274.241777532042 - count:18
# Meteoro! Melhor de todos:2274.241777532042 - count:15
# Meteoro! Melhor de todos:2274.241777532042 - count:16
# Meteoro! Melhor de todos:2274.1868833712206 - count:28
# Meteoro! Melhor de todos:2274.1868833712206 - count:15
# Meteoro! Melhor de todos:2274.1868833712206 - count:16
# Meteoro! Melhor de todos:2274.1868833712206 - count:18
# Meteoro! Melhor de todos:2274.1868833712206 - count:3
# Meteoro! Melhor de todos:2274.1868833712206 - count:22
# Meteoro! Melhor de todos:2274.1868833712206 - count:14
# Meteoro! Melhor de todos:2274.1446333955146 - count:84
# Meteoro! Melhor de todos:2274.1446333955146 - count:14
# Meteoro! Melhor de todos:2274.1446333955146 - count:22
# Meteoro! Melhor de todos:2274.1446333955146 - count:12
# Meteoro! Melhor de todos:2274.1446333955146 - count:18
# Meteoro! Melhor de todos:2274.1143099876244 - count:29
# Meteoro! Melhor de todos:2274.1143099876244 - count:6
# Meteoro! Melhor de todos:2274.1143099876244 - count:14
# Meteoro! Melhor de todos:2274.1109961223247 - count:28
# Meteoro! Melhor de todos:2274.1109961223247 - count:18
# Meteoro! Melhor de todos:2274.088018918007 - count:39
# Meteoro! Melhor de todos:2274.088018918007 - count:17
# Meteoro! Melhor de todos:2274.088018918007 - count:18
# Meteoro! Melhor de todos:2274.088018918007 - count:9
# Meteoro! Melhor de todos:2274.088018918007 - count:22
# Meteoro! Melhor de todos:2274.088018918007 - count:22
# Meteoro! Melhor de todos:2274.087400800691 - count:29
# Meteoro! Melhor de todos:2274.0561052764197 - count:79
# Meteoro! Melhor de todos:2274.0561052764197 - count:7
# Meteoro! Melhor de todos:2274.0561052764197 - count:22
# Meteoro! Melhor de todos:2274.0561052764197 - count:25
# Meteoro! Melhor de todos:2274.0561052764197 - count:17
# Meteoro! Melhor de todos:2274.0561052764197 - count:18
# Meteoro! Melhor de todos:2274.0561052764197 - count:17
# Meteoro! Melhor de todos:2274.046249025558 - count:27
# Meteoro! Melhor de todos:2274.046249025558 - count:28
# Meteoro! Melhor de todos:2274.046249025558 - count:15
# Meteoro! Melhor de todos:2272.355206606986 - count:32
# Meteoro! Melhor de todos:2272.355206606986 - count:3
# Meteoro! Melhor de todos:2272.355206606986 - count:14
# Meteoro! Melhor de todos:2272.355206606986 - count:17
# Meteoro! Melhor de todos:2272.3547601707555 - count:29
# Meteoro! Melhor de todos:2272.354748071528 - count:32
# Meteoro! Melhor de todos:2272.354748071528 - count:11
# Meteoro! Melhor de todos:2272.354748071528 - count:19
# Meteoro! Melhor de todos:2272.354748071528 - count:9
# Meteoro! Melhor de todos:2272.35267677383 - count:23
# Meteoro! Melhor de todos:2272.2903492176865 - count:81
# Meteoro! Melhor de todos:2272.2903492176865 - count:10
# Meteoro! Melhor de todos:2272.2903492176865 - count:13
# Meteoro! Melhor de todos:2272.2903492176865 - count:15
# Meteoro! Melhor de todos:2272.2903492176865 - count:22
# Meteoro! Melhor de todos:2272.289733225747 - count:27
# Meteoro! Melhor de todos:2272.286431766527 - count:15
# Meteoro! Melhor de todos:2272.2738111035887 - count:24
# Meteoro! Melhor de todos:2272.2737314204173 - count:25
# Meteoro! Melhor de todos:2272.2737314204173 - count:27
# Meteoro! Melhor de todos:2272.2737314204173 - count:12
# Meteoro! Melhor de todos:2272.2737314204173 - count:21
# Meteoro! Melhor de todos:2272.2737314204173 - count:10
# Meteoro! Melhor de todos:2272.2737314204173 - count:11
# Meteoro! Melhor de todos:2272.2737314204173 - count:14
# Meteoro! Melhor de todos:2272.2737314204173 - count:11
# Meteoro! Melhor de todos:2272.2737314204173 - count:13
# Meteoro! Melhor de todos:2272.2737314204173 - count:7
# Meteoro! Melhor de todos:2272.2737314204173 - count:13
# Meteoro! Melhor de todos:2272.166908702797 - count:92
# Meteoro! Melhor de todos:2272.166908702797 - count:14
# Meteoro! Melhor de todos:2272.166908702797 - count:38
# Meteoro! Melhor de todos:2272.166908702797 - count:13
# Meteoro! Melhor de todos:2272.166908702797 - count:10
# Meteoro! Melhor de todos:2272.166908702797 - count:18
# Meteoro! Melhor de todos:2272.166908702797 - count:7
# Meteoro! Melhor de todos:2272.166908702797 - count:20
# Meteoro! Melhor de todos:2272.166908702797 - count:16
# Meteoro! Melhor de todos:2272.166908702797 - count:17
# Meteoro! Melhor de todos:2272.166908702797 - count:19
# Meteoro! Melhor de todos:2271.9800084129524 - count:39
# Meteoro! Melhor de todos:2271.9800084129524 - count:20
# Meteoro! Melhor de todos:2271.9059195423883 - count:49
# Meteoro! Melhor de todos:2271.756276049897 - count:53
# Meteoro! Melhor de todos:2271.756276049897 - count:23
# Meteoro! Melhor de todos:2271.756276049897 - count:22
# Meteoro! Melhor de todos:2271.756276049897 - count:15
# Meteoro! Melhor de todos:2271.544611280669 - count:65
# Meteoro! Melhor de todos:2271.544611280669 - count:74
# Meteoro! Melhor de todos:2271.040534263876 - count:30
# Meteoro! Melhor de todos:2271.040534263876 - count:23
# Meteoro! Melhor de todos:2270.9409105724644 - count:93
# Meteoro! Melhor de todos:2270.8719003552746 - count:11
# Meteoro! Melhor de todos:2270.8719003552746 - count:14
# Meteoro! Melhor de todos:2270.682047673127 - count:51
# Meteoro! Melhor de todos:2270.682047673127 - count:22
# Meteoro! Melhor de todos:2270.678308212725 - count:18
# Meteoro! Melhor de todos:2270.629742332923 - count:30
# Meteoro! Melhor de todos:2270.629742332923 - count:33
# Meteoro! Melhor de todos:2270.6282382480927 - count:54
# Meteoro! Melhor de todos:2270.6282382480927 - count:12
# Meteoro! Melhor de todos:2270.6282382480927 - count:11
# Meteoro! Melhor de todos:2270.6282382480927 - count:13
# Meteoro! Melhor de todos:2270.6282382480927 - count:15
# Meteoro! Melhor de todos:2270.6282382480927 - count:23
# Meteoro! Melhor de todos:2270.6282382480927 - count:21
# Meteoro! Melhor de todos:2270.6282382480927 - count:30
# Meteoro! Melhor de todos:2270.6282382480927 - count:19
# Meteoro! Melhor de todos:2270.6282382480927 - count:18
# Meteoro! Melhor de todos:2270.6282382480927 - count:11
# Meteoro! Melhor de todos:2270.6282382480927 - count:5
# Meteoro! Melhor de todos:2270.6282382480927 - count:27
# Meteoro! Melhor de todos:2270.6282382480927 - count:4
# Meteoro! Melhor de todos:2258.9079901304603 - count:116
# Meteoro! Melhor de todos:2258.9079901304603 - count:11
# Meteoro! Melhor de todos:2258.8718358782025 - count:42
# Meteoro! Melhor de todos:2258.8718358782025 - count:11
# Meteoro! Melhor de todos:2258.8599684777355 - count:39
# ------------------------------
# Gene(a=0.876462583715396, e=0.8475571661685714)
# Gene(a=0.6430719361884799, e=-0.14843696102630216)
# Gene(a=0.3819044989064276, e=-0.025721196589362505)
# Gene(a=0.1997529611102056, e=-3.3414781428408367e-06)
# Gene(a=0.2479787462769215, e=-0.0892139724845023)
# Gene(a=0.2553681404743201, e=-0.13879128704212773)
# Gene(a=0.17001806857812035, e=-0.19335727602639655)
# Gene(a=0.10839147206123363, e=-0.22134020918303676)
# Gene(a=0.0951566066959831, e=-0.16680673393950576)
# Gene(a=0.10770295884047107, e=-0.2411063209832391)
# Gene(a=0.07493211707062648, e=-0.24315040931925305)
# Gene(a=0.043517068218271615, e=0.0003757905981937924)
# Gene(a=0.017924419005104213, e=-2.1406558676943298e-05)
# Gene(a=0.0003454704744571042, e=-2.1930350369300706e-05)
# ------------------------------
# GeneDecoded(x=10.0, y=10.0, v=0, al=0)
# GeneDecoded(x=10.438231291857697, y=10.0, v=0.876462583715396, al=0.8475571661685714)
# GeneDecoded(x=11.231086414222155, y=10.898098705643443, v=1.5190279095893133, al=0.6991202051422691)
# GeneDecoded(x=12.539920054526155, y=11.998547089861297, v=1.8994106743945907, al=0.6733990085529067)
# GeneDecoded(x=14.102775629826127, y=13.245395748961766, v=2.0967843584578216, al=0.6733956670747638)
# GeneDecoded(x=15.838773308669555, y=14.630367960234722, v=2.341863660217276, al=0.5841816945902616)
# GeneDecoded(x=17.89878031771467, y=15.992365432948105, v=2.59361495082956, al=0.44539040754813386)
# GeneDecoded(x=20.316084557535085, y=17.146344057446413, v=2.7591967463640037, al=0.25203313152173734)
# GeneDecoded(x=23.040594697975394, y=17.847929230203434, v=2.8625674220918307, al=0.03069292233870058)
# GeneDecoded(x=25.9493697716562, y=17.93723608340563, v=2.952319986795148, al=-0.13611381160080518)
# GeneDecoded(x=28.927736581822263, y=17.529316938980188, v=3.0542747158655374, al=-0.3772201325840443)
# GeneDecoded(x=31.802103727469486, y=16.3905129487709, v=3.12305473188692, al=-0.6203705419032973)
# GeneDecoded(x=34.360922247583524, y=14.562317592933299, v=3.160139497654859, al=-0.6199947513051035)
# GeneDecoded(x=36.94019551871018, y=12.720971611549137, v=3.1714779462617497, al=-0.6200161578637805)
# GeneDecoded(x=39.5215039037375, y=10.8780893399863, v=3.165190101180115, al=-0.6200380882141499)
# Meteoro! Melhor de todos:10009.549579746752 - count:46
# Meteoro! Melhor de todos:10009.549579746752 - count:13
# Meteoro! Melhor de todos:5188.535720129478 - count:176
# Meteoro! Melhor de todos:5149.365563648857 - count:139
# Meteoro! Melhor de todos:4678.364458676391 - count:53
# Meteoro! Melhor de todos:4678.364458676391 - count:11
# Meteoro! Melhor de todos:4678.364458676391 - count:8
# Meteoro! Melhor de todos:4676.856237068151 - count:43
# Meteoro! Melhor de todos:4676.856237068151 - count:5
# Meteoro! Melhor de todos:4487.4029181626975 - count:101
# Meteoro! Melhor de todos:4487.4029181626975 - count:21
# Meteoro! Melhor de todos:4487.396900723035 - count:45
# Meteoro! Melhor de todos:4487.396900723035 - count:15
# Meteoro! Melhor de todos:4487.396900723035 - count:23
# Meteoro! Melhor de todos:4487.396900723035 - count:11
# Meteoro! Melhor de todos:4487.383039649889 - count:27
# Meteoro! Melhor de todos:4487.383039649889 - count:18
# Meteoro! Melhor de todos:4487.383039649889 - count:6
# Meteoro! Melhor de todos:4266.587698364334 - count:62
# Meteoro! Melhor de todos:4266.587698364334 - count:13
# Meteoro! Melhor de todos:4266.578664038386 - count:27
# Meteoro! Melhor de todos:4266.578664038386 - count:17
# Meteoro! Melhor de todos:4266.578664038386 - count:20
# Meteoro! Melhor de todos:4266.578664038386 - count:6
# Meteoro! Melhor de todos:3817.473368367778 - count:76
# Meteoro! Melhor de todos:3608.175008310077 - count:194
# Meteoro! Melhor de todos:3604.683421264538 - count:92
# Meteoro! Melhor de todos:3604.683421264538 - count:9
# Meteoro! Melhor de todos:3581.207556739516 - count:90
# Meteoro! Melhor de todos:3581.207556739516 - count:13
# Meteoro! Melhor de todos:3571.7631805064125 - count:120
# Meteoro! Melhor de todos:3561.3202602857696 - count:138
# Meteoro! Melhor de todos:3541.54801775969 - count:141
# Meteoro! Melhor de todos:3541.2245649776796 - count:39
# Meteoro! Melhor de todos:3541.2245649776796 - count:16
# Meteoro! Melhor de todos:3488.7393318944205 - count:117
# Meteoro! Melhor de todos:3485.8226429596484 - count:96
# Meteoro! Melhor de todos:3485.8226429596484 - count:14
# Meteoro! Melhor de todos:3485.8226429596484 - count:12
# Meteoro! Melhor de todos:3485.8226429596484 - count:12
# Meteoro! Melhor de todos:3485.8226429596484 - count:18
# Meteoro! Melhor de todos:3485.79096803884 - count:37
# Meteoro! Melhor de todos:3400.4507757723513 - count:28
# Meteoro! Melhor de todos:3400.058229339287 - count:27
# Meteoro! Melhor de todos:3400.058229339287 - count:11
# Meteoro! Melhor de todos:3400.0347417877 - count:26
# Meteoro! Melhor de todos:3400.0347417877 - count:15
# Meteoro! Melhor de todos:3399.347907544263 - count:101
# Meteoro! Melhor de todos:3399.347907544263 - count:18
# Meteoro! Melhor de todos:3399.2962525205235 - count:22
# Meteoro! Melhor de todos:3399.2962525205235 - count:19
# Meteoro! Melhor de todos:3399.2962525205235 - count:23
# Meteoro! Melhor de todos:3399.2962525205235 - count:14
# Meteoro! Melhor de todos:3399.2962525205235 - count:16
# Meteoro! Melhor de todos:3398.976860778276 - count:49
# Meteoro! Melhor de todos:3398.976860778276 - count:9
# Meteoro! Melhor de todos:3398.976860778276 - count:30
# Meteoro! Melhor de todos:3398.0123318510146 - count:43
# Meteoro! Melhor de todos:3398.0123318510146 - count:12
# Meteoro! Melhor de todos:3398.0123318510146 - count:29
# Meteoro! Melhor de todos:3398.012264492707 - count:14
# Meteoro! Melhor de todos:3397.9811310935193 - count:58
# Meteoro! Melhor de todos:3397.9811310935193 - count:12
# Meteoro! Melhor de todos:3397.981110391206 - count:20
# Meteoro! Melhor de todos:3397.8564892665026 - count:25
# Meteoro! Melhor de todos:3397.341302795923 - count:17
# Meteoro! Melhor de todos:3303.3515220056465 - count:116
# Meteoro! Melhor de todos:3302.055328397792 - count:67
# Meteoro! Melhor de todos:3301.9922533862864 - count:18
# Meteoro! Melhor de todos:3301.9922533862864 - count:16
# Meteoro! Melhor de todos:3301.9922533862864 - count:13
# Meteoro! Melhor de todos:3301.9922533862864 - count:5
# Meteoro! Melhor de todos:3301.9922533862864 - count:16
# Meteoro! Melhor de todos:3301.9922533862864 - count:24
# Meteoro! Melhor de todos:3301.9922533862864 - count:10
# Meteoro! Melhor de todos:3301.9818248189204 - count:28
# Meteoro! Melhor de todos:3301.9818248189204 - count:23
# Meteoro! Melhor de todos:3301.9818248189204 - count:6
# Meteoro! Melhor de todos:3301.9818248189204 - count:9
# Meteoro! Melhor de todos:3301.977875697659 - count:28
# Meteoro! Melhor de todos:3296.82908108024 - count:86
# Meteoro! Melhor de todos:3290.209927202654 - count:108
# Meteoro! Melhor de todos:3290.209927202654 - count:15
# Meteoro! Melhor de todos:3290.209917918826 - count:26
# Meteoro! Melhor de todos:3290.209917918826 - count:27
# Meteoro! Melhor de todos:3290.209917918826 - count:12
# Meteoro! Melhor de todos:3290.209917918826 - count:10
# Meteoro! Melhor de todos:3290.1642801377884 - count:118
# Meteoro! Melhor de todos:3290.0773943933063 - count:21
# Meteoro! Melhor de todos:3290.0773943933063 - count:14
# Meteoro! Melhor de todos:3290.0773901352236 - count:21
# Meteoro! Melhor de todos:3290.0773901352236 - count:12
# Meteoro! Melhor de todos:3270.300296420657 - count:101
# Meteoro! Melhor de todos:3261.793280700122 - count:154
# Meteoro! Melhor de todos:3261.793280700122 - count:8
# Meteoro! Melhor de todos:3260.9532521592278 - count:87
# Meteoro! Melhor de todos:3260.9532521592278 - count:22
# Meteoro! Melhor de todos:3260.9532521592278 - count:18
# Meteoro! Melhor de todos:3260.9532521592278 - count:11
# Meteoro! Melhor de todos:3260.9532521592278 - count:13
# Meteoro! Melhor de todos:3260.9532521592278 - count:23
# Meteoro! Melhor de todos:3259.4965846601785 - count:45
# Meteoro! Melhor de todos:3259.4965846601785 - count:27
# Meteoro! Melhor de todos:3259.4965846601785 - count:22
# Meteoro! Melhor de todos:3259.4965846601785 - count:15
# Meteoro! Melhor de todos:3259.3613223560187 - count:34
# Meteoro! Melhor de todos:3259.3613223560187 - count:23
# Meteoro! Melhor de todos:3259.3609133188284 - count:21
# Meteoro! Melhor de todos:3232.9619454297313 - count:120
# Meteoro! Melhor de todos:3232.9619454297313 - count:14
# Meteoro! Melhor de todos:3232.9619454297313 - count:11
# Meteoro! Melhor de todos:3232.9619454297313 - count:13
# Meteoro! Melhor de todos:3232.9619454297313 - count:18
# Meteoro! Melhor de todos:3232.9619454297313 - count:14
# Meteoro! Melhor de todos:3232.9619454297313 - count:20
# Meteoro! Melhor de todos:3232.9619454297313 - count:8
# Meteoro! Melhor de todos:3232.9619454297313 - count:24
# Meteoro! Melhor de todos:3232.784558297692 - count:29
# Meteoro! Melhor de todos:3231.9575530600055 - count:97
# Meteoro! Melhor de todos:3231.9567327417167 - count:21
# Meteoro! Melhor de todos:3231.9567327417167 - count:13
# Meteoro! Melhor de todos:3231.9567327417167 - count:20
# Meteoro! Melhor de todos:3231.9567327417167 - count:14
# Meteoro! Melhor de todos:3219.236332675626 - count:101
# Meteoro! Melhor de todos:3219.236332675626 - count:13
# Meteoro! Melhor de todos:3219.236332675626 - count:6
# Meteoro! Melhor de todos:3219.137974645989 - count:13
# Meteoro! Melhor de todos:3219.1379131791227 - count:25
# Meteoro! Melhor de todos:3219.1379131791227 - count:5
# Meteoro! Melhor de todos:3219.1379131791227 - count:17
# Meteoro! Melhor de todos:3219.1379131791227 - count:12
# Meteoro! Melhor de todos:3219.1379131791227 - count:10
# Meteoro! Melhor de todos:3219.1379131791227 - count:16
# Meteoro! Melhor de todos:3219.1379131791227 - count:8
# Meteoro! Melhor de todos:3219.1379105057854 - count:33
# Meteoro! Melhor de todos:3219.1379105057854 - count:76
# Meteoro! Melhor de todos:3219.1379105057854 - count:12
# Meteoro! Melhor de todos:3218.67283363319 - count:48
# Meteoro! Melhor de todos:3218.616793275346 - count:28
# Meteoro! Melhor de todos:3152.8549920715664 - count:21
# Meteoro! Melhor de todos:3152.8549920715664 - count:24
# Meteoro! Melhor de todos:3152.8549920715664 - count:32
# Meteoro! Melhor de todos:3152.8549920715664 - count:23
# Meteoro! Melhor de todos:3152.6620569120405 - count:58
# Meteoro! Melhor de todos:3114.852340814299 - count:110
# Meteoro! Melhor de todos:3114.5260688292383 - count:79
# Meteoro! Melhor de todos:3114.5260688292383 - count:18
# Meteoro! Melhor de todos:3114.5260688292383 - count:29
# Meteoro! Melhor de todos:3114.5260688292383 - count:17
# Meteoro! Melhor de todos:3114.5260688292383 - count:15
# Meteoro! Melhor de todos:3114.5260688292383 - count:17
# Meteoro! Melhor de todos:3114.5260688292383 - count:19
# Meteoro! Melhor de todos:3114.5260688292383 - count:21
# Meteoro! Melhor de todos:3114.5260688292383 - count:11
# Meteoro! Melhor de todos:3114.5260688292383 - count:7
# Meteoro! Melhor de todos:3114.317648692967 - count:95
# Meteoro! Melhor de todos:3114.3096549054544 - count:32
# Meteoro! Melhor de todos:3114.3096549054544 - count:11
# Meteoro! Melhor de todos:3114.3096549054544 - count:12
# Meteoro! Melhor de todos:3114.307717683474 - count:46
# Meteoro! Melhor de todos:3114.307717683474 - count:10
# Meteoro! Melhor de todos:3114.307717683474 - count:5
# Meteoro! Melhor de todos:3114.307717683474 - count:22
# Meteoro! Melhor de todos:3114.307717683474 - count:6
# Meteoro! Melhor de todos:3114.307717683474 - count:15
# Meteoro! Melhor de todos:3114.307717683474 - count:14
# Meteoro! Melhor de todos:3105.9324160355527 - count:123
# Meteoro! Melhor de todos:3105.9324160355527 - count:13
# Meteoro! Melhor de todos:3105.9324160355527 - count:4
# Meteoro! Melhor de todos:3105.9324160355527 - count:59
# Meteoro! Melhor de todos:3105.9324160355527 - count:15
# Meteoro! Melhor de todos:3091.116042453787 - count:104
# Meteoro! Melhor de todos:3090.8036334840476 - count:33
# Meteoro! Melhor de todos:3090.7342845784488 - count:85
# Meteoro! Melhor de todos:3090.72277533736 - count:29
# Meteoro! Melhor de todos:3090.72277533736 - count:10
# Meteoro! Melhor de todos:3090.72277533736 - count:20
# Meteoro! Melhor de todos:3090.72277533736 - count:14
# Meteoro! Melhor de todos:3090.72277533736 - count:20
# Meteoro! Melhor de todos:3090.72277533736 - count:20
# Meteoro! Melhor de todos:3090.6475299318076 - count:15
# Meteoro! Melhor de todos:3090.3460894666587 - count:58
# Meteoro! Melhor de todos:3084.525325787574 - count:52
# Meteoro! Melhor de todos:3084.525325787574 - count:16
# Meteoro! Melhor de todos:3084.525325787574 - count:16
# Meteoro! Melhor de todos:3084.525325787574 - count:22
# Meteoro! Melhor de todos:3084.49700920712 - count:24
# Meteoro! Melhor de todos:3084.49700920712 - count:9
# Meteoro! Melhor de todos:3084.49700920712 - count:7
# Meteoro! Melhor de todos:3084.315624290691 - count:26
# Meteoro! Melhor de todos:3084.315624290691 - count:11
# Meteoro! Melhor de todos:3084.287640395505 - count:73
# Meteoro! Melhor de todos:3084.287640395505 - count:14
# Meteoro! Melhor de todos:3083.2429307924667 - count:118
# Meteoro! Melhor de todos:3080.488825499159 - count:22
# Meteoro! Melhor de todos:3080.488825499159 - count:32
# Meteoro! Melhor de todos:3080.4832991476615 - count:24
# Meteoro! Melhor de todos:3080.4832991476615 - count:27
# Meteoro! Melhor de todos:3080.4832991476615 - count:11
# Meteoro! Melhor de todos:3080.4546595936145 - count:11
# Meteoro! Melhor de todos:3080.4546595936145 - count:15
# Meteoro! Melhor de todos:3079.0800132392133 - count:79
# Meteoro! Melhor de todos:3079.0072471669637 - count:36
# Meteoro! Melhor de todos:3079.0072471669637 - count:19
# Meteoro! Melhor de todos:3078.9464211051404 - count:22
# Meteoro! Melhor de todos:3078.9464211051404 - count:24
# Meteoro! Melhor de todos:3078.9464211051404 - count:18
# Meteoro! Melhor de todos:3078.9464211051404 - count:19
# Meteoro! Melhor de todos:3078.86662062534 - count:92
# Meteoro! Melhor de todos:3078.2425956199295 - count:98
# Meteoro! Melhor de todos:3078.2425956199295 - count:22
# Meteoro! Melhor de todos:3078.2425956199295 - count:21
# Meteoro! Melhor de todos:3078.2425956199295 - count:13
# Meteoro! Melhor de todos:3078.2425956199295 - count:17
# Meteoro! Melhor de todos:3078.2425956199295 - count:14
# Meteoro! Melhor de todos:3078.2425956199295 - count:17
# Meteoro! Melhor de todos:3078.2425956199295 - count:6
# Meteoro! Melhor de todos:3078.2425956199295 - count:16
# Meteoro! Melhor de todos:3078.2424090949235 - count:42
# Meteoro! Melhor de todos:3078.2424090949235 - count:14
# Meteoro! Melhor de todos:3078.2424090949235 - count:22
# Meteoro! Melhor de todos:3078.2424090949235 - count:12
# Meteoro! Melhor de todos:3078.2424090949235 - count:19
# Meteoro! Melhor de todos:3078.2424090949235 - count:21
# Meteoro! Melhor de todos:3078.2424090949235 - count:23
# Meteoro! Melhor de todos:3078.2424090949235 - count:17
# Meteoro! Melhor de todos:3078.1212711469957 - count:99
# Meteoro! Melhor de todos:3078.1212711469957 - count:22
# Meteoro! Melhor de todos:3060.098044704285 - count:61
# Meteoro! Melhor de todos:3060.085620326151 - count:32
# Meteoro! Melhor de todos:3060.085620326151 - count:17
# Meteoro! Melhor de todos:3060.085620326151 - count:8
# Meteoro! Melhor de todos:3060.085620326151 - count:32
# Meteoro! Melhor de todos:3059.2513179181383 - count:26
# Meteoro! Melhor de todos:3059.1464346871417 - count:28
# ...
# Meteoro! Melhor de todos:2760.810635157631 - count:18
# Meteoro! Melhor de todos:2760.810635157631 - count:15
# Meteoro! Melhor de todos:2760.810635157631 - count:13
# Meteoro! Melhor de todos:2760.810635157631 - count:20
# Meteoro! Melhor de todos:2760.810635157631 - count:26
# Meteoro! Melhor de todos:2760.810635157631 - count:11
# Meteoro! Melhor de todos:2760.810635157631 - count:21
# Meteoro! Melhor de todos:2760.794451217641 - count:31
# Meteoro! Melhor de todos:2760.794451217641 - count:11
# Meteoro! Melhor de todos:2760.794451217641 - count:14
# Meteoro! Melhor de todos:2760.794451217641 - count:20
# Meteoro! Melhor de todos:2760.786285463715 - count:50
# Meteoro! Melhor de todos:2760.786285463715 - count:13
# Meteoro! Melhor de todos:2760.786285463715 - count:10
# Meteoro! Melhor de todos:2760.786285463715 - count:15
# Meteoro! Melhor de todos:2760.786285463715 - count:6
# Meteoro! Melhor de todos:2759.1371810852206 - count:56
# Meteoro! Melhor de todos:2759.1365035840786 - count:21
# Meteoro! Melhor de todos:2759.098134716995 - count:57
# Meteoro! Melhor de todos:2759.0738736401026 - count:56
# Meteoro! Melhor de todos:2759.0738736401026 - count:11
# Meteoro! Melhor de todos:2756.441952216262 - count:54
# Meteoro! Melhor de todos:2756.441952216262 - count:29
# Meteoro! Melhor de todos:2756.441952216262 - count:11
# Meteoro! Melhor de todos:2756.441952216262 - count:19
# Meteoro! Melhor de todos:2756.441952216262 - count:20
# Meteoro! Melhor de todos:2756.441952216262 - count:17
# Meteoro! Melhor de todos:2756.441952216262 - count:17
# Meteoro! Melhor de todos:2756.441952216262 - count:12
# Meteoro! Melhor de todos:2756.441952216262 - count:7
# Meteoro! Melhor de todos:2756.441952216262 - count:17
# Meteoro! Melhor de todos:2756.441952216262 - count:13
# Meteoro! Melhor de todos:2756.441952216262 - count:9
# Meteoro! Melhor de todos:2753.986101659233 - count:30
# Meteoro! Melhor de todos:2753.9518475299196 - count:18
# Meteoro! Melhor de todos:2753.9494880255215 - count:82
# Meteoro! Melhor de todos:2753.9494880255215 - count:19
# Meteoro! Melhor de todos:2753.9494880255215 - count:18
# Meteoro! Melhor de todos:2753.9494880255215 - count:20
# Meteoro! Melhor de todos:2753.9494880255215 - count:15
# Meteoro! Melhor de todos:2753.9494880255215 - count:7
# Meteoro! Melhor de todos:2753.9494880255215 - count:25
# Meteoro! Melhor de todos:2753.9494880255215 - count:23
# Meteoro! Melhor de todos:2753.9494674243515 - count:33
# Meteoro! Melhor de todos:2753.9494674243515 - count:17
# Meteoro! Melhor de todos:2753.9494674243515 - count:23
# Meteoro! Melhor de todos:2753.9494674243515 - count:17
# Meteoro! Melhor de todos:2753.9494674243515 - count:15
# Meteoro! Melhor de todos:2753.9494414267056 - count:67
# Meteoro! Melhor de todos:2753.5131700811085 - count:79
# Meteoro! Melhor de todos:2753.5131700811085 - count:25
# Meteoro! Melhor de todos:2753.5131700811085 - count:24
# Meteoro! Melhor de todos:2753.5131700811085 - count:11
# Meteoro! Melhor de todos:2753.5131700811085 - count:19
# Meteoro! Melhor de todos:2753.5131700811085 - count:21
# Meteoro! Melhor de todos:2753.5131700811085 - count:12
# Meteoro! Melhor de todos:2752.4869635034147 - count:24
# Meteoro! Melhor de todos:2752.431408154068 - count:29
# Meteoro! Melhor de todos:2752.431408154068 - count:18
# Meteoro! Melhor de todos:2752.431408154068 - count:6
# Meteoro! Melhor de todos:2752.431408154068 - count:11
# Meteoro! Melhor de todos:2752.431408154068 - count:16
# Meteoro! Melhor de todos:2752.431408154068 - count:13
# Meteoro! Melhor de todos:2752.431408154068 - count:22
# Meteoro! Melhor de todos:2752.431408154068 - count:11
# Meteoro! Melhor de todos:2752.431408154068 - count:14
# Meteoro! Melhor de todos:2752.431408154068 - count:5
# Meteoro! Melhor de todos:2752.431408154068 - count:9
# Meteoro! Melhor de todos:2752.4246004087645 - count:53
# Meteoro! Melhor de todos:2752.3751416083287 - count:31
# Meteoro! Melhor de todos:2752.3751416083287 - count:16
# Meteoro! Melhor de todos:2752.3751416083287 - count:15
# Meteoro! Melhor de todos:2752.084424990505 - count:24
# Meteoro! Melhor de todos:2752.072869686674 - count:45
# Meteoro! Melhor de todos:2739.215032896492 - count:31
# Meteoro! Melhor de todos:2739.1757428149704 - count:25
# Meteoro! Melhor de todos:2738.358649008535 - count:39
# Meteoro! Melhor de todos:2738.358649008535 - count:22
# Meteoro! Melhor de todos:2738.358649008535 - count:7
# Meteoro! Melhor de todos:2737.8457673938683 - count:132
# Meteoro! Melhor de todos:2737.8457673938683 - count:17
# Meteoro! Melhor de todos:2737.8457673938683 - count:11
# Meteoro! Melhor de todos:2737.8457673938683 - count:21
# Meteoro! Melhor de todos:2737.8457673938683 - count:10
# Meteoro! Melhor de todos:2737.8457673938683 - count:16
# Meteoro! Melhor de todos:2737.8029153648054 - count:57
# Meteoro! Melhor de todos:2737.8029153648054 - count:8
# Meteoro! Melhor de todos:2737.8029153648054 - count:8
# Meteoro! Melhor de todos:2737.8029153648054 - count:14
# Meteoro! Melhor de todos:2737.7979952450214 - count:62
# Meteoro! Melhor de todos:2737.7979952450214 - count:16
# Meteoro! Melhor de todos:2737.7979952450214 - count:16
# Meteoro! Melhor de todos:2737.7804359770334 - count:35
# Meteoro! Melhor de todos:2737.7804359770334 - count:12
# Meteoro! Melhor de todos:2737.7804359770334 - count:25
# Meteoro! Melhor de todos:2736.8693903138437 - count:57
# Meteoro! Melhor de todos:2736.8693903138437 - count:15
# Meteoro! Melhor de todos:2736.8693903138437 - count:15
# Meteoro! Melhor de todos:2736.842374130388 - count:24
# Meteoro! Melhor de todos:2736.842374130388 - count:17
# Meteoro! Melhor de todos:2736.723993346192 - count:120
# Meteoro! Melhor de todos:2736.723993346192 - count:12
# Meteoro! Melhor de todos:2736.723993346192 - count:7
# Meteoro! Melhor de todos:2736.6580726098514 - count:70
# Meteoro! Melhor de todos:2736.6580726098514 - count:13
# Meteoro! Melhor de todos:2736.644937834476 - count:34
# Meteoro! Melhor de todos:2736.644937834476 - count:18
# Meteoro! Melhor de todos:2736.6251787143133 - count:27
# Meteoro! Melhor de todos:2736.6251787143133 - count:25
# Meteoro! Melhor de todos:2736.1443173571984 - count:153
# Meteoro! Melhor de todos:2736.1443173571984 - count:27
# Meteoro! Melhor de todos:2735.998770707448 - count:67
# Meteoro! Melhor de todos:2735.998770707448 - count:16
# Meteoro! Melhor de todos:2735.998770707448 - count:12
# Meteoro! Melhor de todos:2735.998770707448 - count:14
# Meteoro! Melhor de todos:2735.998770707448 - count:16
# Meteoro! Melhor de todos:2735.998770707448 - count:20
# Meteoro! Melhor de todos:2735.998770707448 - count:94
# Meteoro! Melhor de todos:2735.998770707448 - count:16
# Meteoro! Melhor de todos:2735.998770707448 - count:13
# Meteoro! Melhor de todos:2735.998770707448 - count:21
# Meteoro! Melhor de todos:2735.998770707448 - count:24
# Meteoro! Melhor de todos:2735.998770707448 - count:18
# Meteoro! Melhor de todos:2735.998770707448 - count:18
# Meteoro! Melhor de todos:2735.998770707448 - count:7
# Meteoro! Melhor de todos:2735.998770707448 - count:16
# Meteoro! Melhor de todos:2735.998770707448 - count:20
# Meteoro! Melhor de todos:2735.998770707448 - count:17
# Meteoro! Melhor de todos:2735.998770707448 - count:19
# Meteoro! Melhor de todos:2735.998770707448 - count:9
# Meteoro! Melhor de todos:2735.998770707448 - count:18
# Meteoro! Melhor de todos:2735.998770707448 - count:19
# Meteoro! Melhor de todos:2735.998770707448 - count:5
# Meteoro! Melhor de todos:2732.5583518287694 - count:25
# Meteoro! Melhor de todos:2729.567620177125 - count:173
# Meteoro! Melhor de todos:2724.1392585973463 - count:124
# Meteoro! Melhor de todos:2724.1392585973463 - count:26
# Meteoro! Melhor de todos:2722.068917543598 - count:63
# Meteoro! Melhor de todos:2722.068917543598 - count:10
# Meteoro! Melhor de todos:2722.068917543598 - count:17
# Meteoro! Melhor de todos:2722.068917543598 - count:10
# Meteoro! Melhor de todos:2721.773040676997 - count:16
# Meteoro! Melhor de todos:2720.604877953045 - count:30
# Meteoro! Melhor de todos:2719.523628688207 - count:37
# Meteoro! Melhor de todos:2719.523628688207 - count:13
# Meteoro! Melhor de todos:2718.908652688529 - count:23
# Meteoro! Melhor de todos:2718.908652688529 - count:13
# Meteoro! Melhor de todos:2718.900658302962 - count:38
# Meteoro! Melhor de todos:2718.773952244904 - count:88
# Meteoro! Melhor de todos:2718.773952244904 - count:12
# Meteoro! Melhor de todos:2718.773952244904 - count:22
# Meteoro! Melhor de todos:2718.773952244904 - count:21
# Meteoro! Melhor de todos:2718.773952244904 - count:12
# Meteoro! Melhor de todos:2718.773952244904 - count:12
# Meteoro! Melhor de todos:2718.773952244904 - count:16
# Meteoro! Melhor de todos:2718.773952244904 - count:11
# Meteoro! Melhor de todos:2718.773952244904 - count:19
# Meteoro! Melhor de todos:2717.4215045102796 - count:29
# Meteoro! Melhor de todos:2717.4076924465007 - count:37
# Meteoro! Melhor de todos:2717.212025630861 - count:88
# Meteoro! Melhor de todos:2717.212025630861 - count:27
# Meteoro! Melhor de todos:2717.212025630861 - count:12
# Meteoro! Melhor de todos:2717.212025630861 - count:22
# Meteoro! Melhor de todos:2717.212025630861 - count:20
# Meteoro! Melhor de todos:2717.212025630861 - count:8
# Meteoro! Melhor de todos:2673.279263066128 - count:26
# Meteoro! Melhor de todos:2673.279263066128 - count:7
# Meteoro! Melhor de todos:2672.6860566078335 - count:15
# Meteoro! Melhor de todos:2667.563261009544 - count:40
# Meteoro! Melhor de todos:2667.563261009544 - count:21
# Meteoro! Melhor de todos:2650.3286252935513 - count:129
# Meteoro! Melhor de todos:2650.3286252935513 - count:22
# Meteoro! Melhor de todos:2650.3286252935513 - count:14
# Meteoro! Melhor de todos:2649.686475186166 - count:53
# Meteoro! Melhor de todos:2649.6274107382915 - count:55
# Meteoro! Melhor de todos:2649.6274107382915 - count:25
# Meteoro! Melhor de todos:2649.6274107382915 - count:12
# Meteoro! Melhor de todos:2649.6274107382915 - count:16
# Meteoro! Melhor de todos:2649.6274107382915 - count:8
# Meteoro! Melhor de todos:2649.6274107382915 - count:25
# Meteoro! Melhor de todos:2649.6274107382915 - count:14
# Meteoro! Melhor de todos:2649.6274107382915 - count:9
# Meteoro! Melhor de todos:2649.6274107382915 - count:25
# Meteoro! Melhor de todos:2649.6274107382915 - count:7
# Meteoro! Melhor de todos:2649.6274107382915 - count:22
# Meteoro! Melhor de todos:2649.6274107382915 - count:8
# Meteoro! Melhor de todos:2649.6274107382915 - count:18
# Meteoro! Melhor de todos:2649.6274107382915 - count:17
# Meteoro! Melhor de todos:2649.6274107382915 - count:18
# Meteoro! Melhor de todos:2649.6274107382915 - count:17
# Meteoro! Melhor de todos:2649.6274107382915 - count:17
# Meteoro! Melhor de todos:2649.6274107382915 - count:19
# Meteoro! Melhor de todos:2649.625339424966 - count:44
# Meteoro! Melhor de todos:2649.625339424966 - count:9
# Meteoro! Melhor de todos:2649.625339424966 - count:7
# Meteoro! Melhor de todos:2649.625339424966 - count:31
# Meteoro! Melhor de todos:2649.625339424966 - count:15
# Meteoro! Melhor de todos:2646.7428133735757 - count:15
# Meteoro! Melhor de todos:2646.7428133735757 - count:22
# Meteoro! Melhor de todos:2645.603994337829 - count:21
# Meteoro! Melhor de todos:2645.2749701113526 - count:18
# Meteoro! Melhor de todos:2645.2749701113526 - count:21
# Meteoro! Melhor de todos:2645.2749701113526 - count:16
# Meteoro! Melhor de todos:2645.2749701113526 - count:12
# Meteoro! Melhor de todos:2645.2297746700897 - count:14
# Meteoro! Melhor de todos:2645.2297746700897 - count:8
# Meteoro! Melhor de todos:2645.2297746700897 - count:9
# Meteoro! Melhor de todos:2645.2297746700897 - count:12
# Meteoro! Melhor de todos:2645.0691094659933 - count:46
# Meteoro! Melhor de todos:2645.004571260905 - count:30
# Meteoro! Melhor de todos:2645.004571260905 - count:20
# Meteoro! Melhor de todos:2645.002811053322 - count:43
# Meteoro! Melhor de todos:2645.002811053322 - count:17
# Meteoro! Melhor de todos:2644.9944455447826 - count:19
# Meteoro! Melhor de todos:2644.9659111126857 - count:26
# Meteoro! Melhor de todos:2644.9599050293764 - count:32
# Meteoro! Melhor de todos:2644.9599050293764 - count:7
# Meteoro! Melhor de todos:2644.9599050293764 - count:18
# Meteoro! Melhor de todos:2644.9599050293764 - count:16
# Meteoro! Melhor de todos:2644.9599050293764 - count:16
# Meteoro! Melhor de todos:2644.9599050293764 - count:8
# Meteoro! Melhor de todos:2644.9599050293764 - count:12
# Meteoro! Melhor de todos:2644.9599050293764 - count:12
# Meteoro! Melhor de todos:2644.9599050293764 - count:18
# Meteoro! Melhor de todos:2644.9599050293764 - count:19
# Meteoro! Melhor de todos:2644.9599050293764 - count:19
# Meteoro! Melhor de todos:2644.9599050293764 - count:34
# Meteoro! Melhor de todos:2644.956743550034 - count:59
# Meteoro! Melhor de todos:2644.8908557748346 - count:29
# Meteoro! Melhor de todos:2639.797986066522 - count:76
# Meteoro! Melhor de todos:2639.7942211547997 - count:25
# Meteoro! Melhor de todos:2639.7827454275402 - count:19
# Meteoro! Melhor de todos:2639.7680112135076 - count:41
# Meteoro! Melhor de todos:2639.7160448641207 - count:58
# Meteoro! Melhor de todos:2639.689575879924 - count:16
# Meteoro! Melhor de todos:2639.689575879924 - count:23
# Meteoro! Melhor de todos:2639.689575879924 - count:28
# Meteoro! Melhor de todos:2639.6857750217237 - count:37
# Meteoro! Melhor de todos:2639.6778861965277 - count:24
# Meteoro! Melhor de todos:2639.6778861965277 - count:11
# Meteoro! Melhor de todos:2637.253529425352 - count:10
# Meteoro! Melhor de todos:2637.253529425352 - count:14
# Meteoro! Melhor de todos:2636.104407454468 - count:21
# Meteoro! Melhor de todos:2636.104407454468 - count:14
# Meteoro! Melhor de todos:2636.0883746850773 - count:18
# Meteoro! Melhor de todos:2636.0883746850773 - count:8
# Meteoro! Melhor de todos:2635.114800399739 - count:26
# Meteoro! Melhor de todos:2634.498503798878 - count:34
# Meteoro! Melhor de todos:2634.4837599890852 - count:20
# Meteoro! Melhor de todos:2634.4837599890852 - count:12
# Meteoro! Melhor de todos:2634.4837599890852 - count:21
# Meteoro! Melhor de todos:2634.4837599890852 - count:7
# Meteoro! Melhor de todos:2634.4837599890852 - count:17
# Meteoro! Melhor de todos:2634.4837599890852 - count:15
# Meteoro! Melhor de todos:2634.452195253366 - count:41
# Meteoro! Melhor de todos:2634.452195253366 - count:8
# Meteoro! Melhor de todos:2634.447331020245 - count:23
# Meteoro! Melhor de todos:2634.447331020245 - count:14
# Meteoro! Melhor de todos:2634.447331020245 - count:16
# Meteoro! Melhor de todos:2634.433847513312 - count:43
# Meteoro! Melhor de todos:2634.433847513312 - count:34
# Meteoro! Melhor de todos:2634.3489321826646 - count:63
# ------------------------------
# Gene(a=0.939718815603195, e=0.002491820249540988)
# Gene(a=1.052758539833048, e=-1.0171768845669154)
# Gene(a=0.5032524962118772, e=0.023707087131579468)
# Gene(a=0.5263841652057775, e=0.6006504911945131)
# Gene(a=0.40397954845418643, e=-0.07679491763229344)
# Gene(a=0.3475620177680264, e=0.3285580551071961)
# Gene(a=0.2427182048187195, e=0.27096840225660357)
# Gene(a=0.10762319470632926, e=0.2863426796466473)
# Gene(a=0.058110806005762655, e=0.16642519347518403)
# Gene(a=0.043975160447256294, e=0.0034787254032831207)
# Gene(a=0.04496978884437119, e=0.0007432125245471852)
# ------------------------------
# GeneDecoded(x=10.0, y=10.0, v=0, al=0)
# GeneDecoded(x=10.469859407801598, y=10.0, v=0.939718815603195, al=0.002491820249540988)
# GeneDecoded(x=11.9359529416989, y=10.003653249116702, v=1.9918949799158185, al=-1.0146850643173744)
# GeneDecoded(x=13.120279612873698, y=8.098198490659216, v=2.492530859237525, al=-0.990977977185795)
# GeneDecoded(x=14.630063008329602, y=5.792864885518471, v=3.0148178132168106, al=-0.39032748599128186)
# GeneDecoded(x=17.604916817169833, y=4.568897618527466, v=3.412803186759859, al=-0.4671224036235753)
# GeneDecoded(x=20.807262425559422, y=2.9537911833751767, v=3.7526839924957676, al=-0.13856434851637922)
# GeneDecoded(x=24.64417402206788, y=2.418703058146237, v=3.9861148592225737, al=0.13240405374022435)
# GeneDecoded(x=28.648740542460487, y=2.9520441856539823, v=4.083259366555083, al=0.41874673338687163)
# GeneDecoded(x=32.40574825495431, y=4.624176301303489, v=4.130374515149359, al=0.5851719268620557)
# GeneDecoded(x=35.86722845111685, y=6.91770324090217, v=4.163098804962236, al=0.5886506522653387)
# GeneDecoded(x=39.34833926569192, y=9.24170375751164, v=4.196638739279905, al=0.589393864789886)

# %%
pickle.dump(tests, open( "aasave_alpha.p", "wb" ) )

# %%
import pickle
tests = pickle.load(open( "save_alpha.p", "rb" ) )

# %% [markdown]
# ## Import

# %%
test_backup = pickle.load(open( "execution_1.p", "rb" ) )

# %% [markdown]
# ## Visualization

# %%
for i in range(5):
    np_ar = np.array(tests['mapa1']['res'][i])
    plt.plot(np_ar[:,1], np_ar[:,0])

# %%
for i in range(1):
    np_ar = np.array(test_backup['mapa2']['res'][i])
    plt.plot(np_ar[:,1], np_ar[:,0])

# %% [markdown]
# # TODO

# %%
# TODO1: Setar a semente do random para controlar o experimento
# TODO1: Printar o tempo que encontra cada melhor
# TODO1: Ter certeza na conversão de latitutde e longitude <- confiavel   (Veronica)

# %%
Monografia
- até domingo - sobrar somente resultados
- ler os abstracts dos principais artigos
- achar ref pro Ray casting (google scholar: ray casting / ray casting GA / RC path planning) 
      foco pra imagens (citar) 
    rc com ga, mesmo que em outra area
    só ler abstract (os mais novos)
    ate onde nos pudermos pesquisar nessa monografia, nos nao encontramos trabalhos

- durante a semana so sobra os resultados


- retornar no domingo (a noite) ou segunda (noite): apresentar a monografia
    a medida que concluir uma seção, enviar
