# %% [markdown]
# # Algoritmo Genético Versão Ensamble
#
# Essa versão inclui:
# - Otimização da rota (V1)
# - Otimização da quantidade de waypoints (V2)
# - Risco Inflado: Inflação das áreas não-navegáveis (V3)
# - Alocação de risco (V3.5)

# %% [markdown]
# # 1. Utils
# Essa seção contém funções auxiliares para o algoritmo. Não é necessário mexer nessa parte
# (Feche essa aba)

# %% [markdown]
# ## utils.py

# %%
import itertools
from scipy.stats import norm

# Support Functions
# _________________________________________________________________________________________________
def pairwise_circle(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ... (s<last>,s0)"
    a, b = itertools.tee(iterable)
    first_value = next(b, None)
    return itertools.zip_longest(a, b,fillvalue=first_value)

def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = itertools.tee(iterable)
    next(b, None)
    return zip(a, b)

def boundary(val, val_min, val_max):
  if val<val_min:
    return val_min
  if val>val_max:
    return val_max
  return val

# Ray Casting Algorithm
# _________________________________________________________________________________________________
epsilon = 0.00001  # Used on the Ray-Tracing Algorithm

def point_in_polygon(point, polygon):
    # Using ray_casting algorithm
    # https://rosettacode.org/wiki/Ray-casting_algorithm

    count = 0
    
    for vertex1, vertex2 in pairwise_circle(polygon):

        if vertex1.y < vertex2.y:
            A = vertex1
            B = vertex2
        else:
            A = vertex2
            B = vertex1

        if ray_intersects_segment(point, A, B):
            count += 1

    if count % 2 == 0: # Odd
        return False 
    else:
        return True # Inside the polygon
    

def ray_intersects_segment(P, A, B):
    # P : the point from which the ray starts
    # A : the end-point of the segment with the smallest y coordinate
    #     (A must be "below" B)
    # B : the end-point of the segment with the greatest y coordinate
    #     (B must be "above" A)

    # To avoid the "ray on vertex" problem, the point is moved upward of a small quantity epsilon.
    if P.y == A.y or P.y == B.y:
        P.y += epsilon

    # Point higher or lower than polygon
    if P.y < A.y or P.y > B.y:
        return False

    # Point to the right of the polygon
    elif P.x >= max(A.x, B.x):
        return False 

    else:

        if P.x < min(A.x, B.x):
            return True

        else:

            if A.x != B.x:
                m_red = (B.y - A.y)/(B.x - A.x)
            else:
                m_red = 99999999 # Infinite


            if A.x != P.x:
                m_blue = (P.y - A.y)/(P.x - A.x)
            else:
                m_blue = 99999999 # Infinite


            if m_blue >= m_red:
                return True
            else:
                return False



# Segment Intersection
# _________________________________________________________________________________________________
def segment_in_polygon(wp1, wp2, polygon):
    # count = 0
    #print('Segment: {}-{}'.format(wp1,wp2))

    for vertex1, vertex2 in pairwise_circle(polygon):
        A = vertex1
        B = vertex2
        #if vertex1.y < vertex2.y:
        #    A = vertex1
        #    B = vertex2
        #else:
        #    A = vertex2
        #    B = vertex1
        #print('Polygon edge: {}-{}'.format(A, B))

        if segment_intersects_segment(wp1, wp2, A, B):
            return True
    return False
    # if count > 1:
    #     return True 
    # else:
    #     return False 
    

def segment_intersects_segment(p1, q1, p2, q2):
    # Returns true if line segment 'p1q1' and 'p2q2' intersect. 
    # Based on the algorithm from https://www.geeksforgeeks.org/check-if-two-given-line-segments-intersect/

    
    # Two segments (p1,q1) and (p2,q2) intersect if and only if one of the following two conditions is verified:
    #
    # 1. General Case:
    # – (p1, q1, p2) and (p1, q1, q2) have different orientations and
    # – (p2, q2, p1) and (p2, q2, q1) have different orientations.
    #
    # 2. Special Case
    # – (p1, q1, p2), (p1, q1, q2), (p2, q2, p1), and (p2, q2, q1) are all collinear and
    # – the x-projections of (p1, q1) and (p2, q2) intersect
    # – the y-projections of (p1, q1) and (p2, q2) intersect
    
    
    # Find the four orientations needed for general and 
    # special cases 
    o1 = orientation(p1, q1, p2) 
    o2 = orientation(p1, q1, q2) 
    o3 = orientation(p2, q2, p1) 
    #print(p2, q2, p1, o3)
    o4 = orientation(p2, q2, q1) 
    #print(o1,o2,o3,o4)
    
    # 1. General case 
    if o1 != o2 and o3 != o4:
        return True  


    # 2. Special Cases 
    # p1, q1 and p2 are colinear and p2 lies on segment p1q1 
    if o1 == 0 and on_segment(p1, p2, q1): 
        return True 
  
    # p1, q1 and q2 are colinear and q2 lies on segment p1q1 
    if o2 == 0 and on_segment(p1, q2, q1):
        return True 
  
    # p2, q2 and p1 are colinear and p1 lies on segment p2q2 
    if o3 == 0 and on_segment(p2, p1, q2):
        return True 
  
    # p2, q2 and q1 are colinear and q1 lies on segment p2q2 
    if o4 == 0 and on_segment(p2, q1, q2):
        return True 
  
    
    # Doesn't fall in any of the above cases 
    return False 
    
    
def on_segment(p, q, r):
    # Given three colinear points p, q, r, the function checks if 
    # point q lies on line segment 'pr' 
    if (q.x <= max(p.x, r.x) and q.x >= min(p.x, r.x) 
    and q.y <= max(p.y, r.y) and q.y >= min(p.y, r.y)):
        return True
    else:
        return False
    
    
def orientation(p, q, r):
    # To find orientation of ordered triplet (p, q, r). 
    # The function returns following values 
    # 0 --> p, q and r are colinear 
    # 1 --> Clockwise 
    # 2 --> Counterclockwise 
    
    # See https://www.geeksforgeeks.org/orientation-3-ordered-points/ 
    # for details of below formula. 
      
    val =( (q.y - p.y) * (r.x - q.x) 
         - ((q.x - p.x) * (r.y - q.y)))
    #print('\n---\ndebug')
    #print((q.y - p.y), (r.x - q.x), (q.x - p.x), (r.y - q.y))
    #print(val)
    if val == 0:
        return 0         # colinear

    return (1 if val > 0 else 2)  # clock or counterclock wise



# Chance Constraint
# _________________________________________________________________________________________________

def risk_total(wp, area, imprecision):   
    distance_total = math.inf

    maior = 0 #M1
    soma = 0 #M2

    if debug:
        print('maior, soma, wp_risk, distance_total')
    for A, B in pairwise(area):
        # segmento A-B

        # plano determinado pela equação ax + by + cz + d = 0, onde (a, b, c) é o vetor normal
        x = A.x - B.x
        y = A.y - B.y
        # direction_vector = (x, y) # vector in the same direction of the line that connects A and B
        # normal_vector = [-y, x] # rotate the direction vector by 90º. (x, y) -> (-y, x) 
        normal_vector = [-y/(sqrt((y**2)+(x**2))), x/(sqrt((y**2)+(x**2)))] # dividindo pela norma, normalizando o vetor

        b = (-y) * A.x + x * A.y # Coeficiente da reta

        distance = wp.x * normal_vector[0] + wp.y * normal_vector[1] - b
        #print(distance)
        distance_total = min(distance_total, distance)
        wp_risk  = risk(distance_total, imprecision)
        # maior = max(maior, wp_risk) #M1
        # soma += wp_risk #M2
        if debug:
            print(maior, soma, wp_risk, distance_total, '--', wp, A, B)
    
    

    return wp_risk
    #return maior #M1
    #return soma #M2


def risk(distance, imprecision):
    # Survival function (also defined as 1 - cdf, but sf is sometimes more accurate).
    # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

    # mi    : média         : location
    # sigma : desvio padrão : scale

    return norm.sf(distance, loc=0, scale=imprecision)

# %% [markdown]
# ## visualization.py

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path

import plotly.graph_objects as go

from sklearn import preprocessing


cor_area_nn    = '#25283d' # Yankees Blue
cor_area_p     = '#8f3985' # Plum
cor_area_b     = '#07beb8' # Tiffany Blue
cor_waypoints  = '#aa1155' # Jazzberry Jam
cor_ori_dest   = '#880044' # Pink Raspberry


def new_shape(vertices, color='navajowhite', lw=.25):

    assert len(vertices) >= 3, 'At least 3 vertices to form a shape'

    colors = {
        'n': cor_area_nn,
        'p': cor_area_p,
        'b': cor_area_b
    }
    
    color = colors[color] if color in colors else color
    
    codes = [Path.MOVETO]
    for _ in range(1, len(vertices)-1):
        codes.append(Path.LINETO)
    codes.append(Path.CLOSEPOLY)
    
    path = Path(vertices, codes)

    patch = patches.PathPatch(path, facecolor=color, lw=lw, alpha=0.6)

    return patch


def plot_map(wp_style='-x', **kwargs):
    # Optional arguments:
    # areas, labels, origem, destino, waypoints, texts

    fig, ax = plt.subplots(figsize=(8,8)) 
    
    # Plot areas
    if 'areas' in kwargs and 'labels' in kwargs:
        areas=kwargs['areas']
        labels=kwargs['labels']
        patches = [ new_shape(vertice, color=label) for vertice, label in zip(areas, labels) ]
        for patch in patches:
            ax.add_patch(patch)
        
    # Plot origin and destination
    if 'origem' in kwargs and 'destino' in kwargs:
        origem=kwargs['origem']
        destino=kwargs['destino']
        ax.plot([origem[0], destino[0]], [origem[1], destino[1]], 'o', color=cor_ori_dest)
    
    # Plot waypoints and route
    if 'waypoints' in kwargs:
        waypoints=kwargs['waypoints']
        waypoints = list(map(list, zip(*waypoints)))
        ax.plot(waypoints[0], waypoints[1], wp_style, color=cor_waypoints, linewidth=2) #marker='x', linestyle='solid'
        if 'texts' in kwargs:
            for i, text in enumerate(kwargs['texts']):
                ax.annotate(text, (waypoints[0][i], waypoints[1][i]))
    
    if 'stress' in kwargs:
        # Plot waypoints
        if 'points' in kwargs:
            for wp, text in zip(kwargs['points'], kwargs['texts']):
                if text=='T':
                    in_color=cor_area_b
                else:
                    in_color=cor_waypoints

                ax.plot(wp[0], wp[1], wp_style, color=in_color, linewidth=2)
                ax.annotate(text, (wp[0], wp[1]))

        # Plot segments
        if 'segments' in kwargs and 'texts' in kwargs:
            i=0
            for segment, text in zip(kwargs['segments'], kwargs['texts']):
                X = [segment[0].x, segment[1].x]
                Y = [segment[0].y, segment[1].y]

                if text=='T':
                    in_color=cor_area_b
                else:
                    in_color=cor_waypoints
                ax.plot(X, Y, wp_style, color=in_color, linewidth=2)
                ax.annotate(text+str(i), (X[0], Y[0]))
                i+=1
    
    # Set size
    automin, automax = ax.get_xlim()
    plt.xlim(automin-0.5, automax+0.5)
    automin, automax = ax.get_ylim()
    plt.ylim(automin-0.5, automax+0.5)
    plt.gca().set_aspect('equal', adjustable='box')
    
    if 'title' in kwargs:
        plt.title(kwargs['title'])
    
    plt.show()
    #plt.savefig('out.png')

def plot_stats(ag_trace, normalize=True):
    dft = pd.DataFrame.from_dict(ag_trace)
    
    if normalize:
        x = dft.values #returns a numpy array
        min_max_scaler = preprocessing.MinMaxScaler()
        x_scaled = min_max_scaler.fit_transform(x)
        dft = pd.DataFrame(x_scaled, columns=dft.columns)

    fig = go.Figure()

    for column in dft.columns:
        fig.add_trace(go.Scatter(x=dft.index, y=dft[column], name=column))
    fig.show()

# %%
def vis_mapa(mapa):
    areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
    tipos = [ 'n' for _ in range(len(areas))]
    plot_map(
        areas=areas,             # Mapa usado
        labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
        origem=mapa.origin,      # waypoint de origem
        destino=mapa.destination # waypoint de destino   
    )

# %% [markdown]
# ## data_definitions.py

# %%
import collections
import math

CartesianPoint = collections.namedtuple('CartesianPoint', 'x y')
GeoPoint = collections.namedtuple('GeoPoint', 'latitude, longitude, altitude')
Version = collections.namedtuple('Version', 'major, minor')

class Mapa():
    def __init__(self, origin, destination, areas_n, inflation_rate=0.1, mode='scalar'):
        self.origin = origin           # CartesianPoint : Define o ponto de partida da rota
        self.destination = destination # CartesianPoint : Define o ponto de destino da rota
        self.areas_n = areas_n         # [area, ...]
                                       # area = [CartesianPoint(),...]      
        self.areas_n_inf = [ self._inflate_area(area, inflation_rate=inflation_rate, mode=mode) for area in areas_n ]
        
        
    def _inflate_area(self, area, inflation_rate, mode):
        if mode == 'percentage':
            # Infla uma área retangular em uma porcentagem do tamanho, alterando os valores em x% de cada vértice
            x = area[2].x - area[0].x
            y = area[1].y - area[3].y

            inc = (inflation_rate)
            dec = -(inflation_rate)

            new_area = [
                CartesianPoint(area[0].x + dec * x, area[0].y + dec * y), # left,  bottom
                CartesianPoint(area[1].x + dec * x, area[1].y + inc * y), # left,  top
                CartesianPoint(area[2].x + inc * x, area[2].y + inc * y), # right, top
                CartesianPoint(area[3].x + inc * x, area[3].y + dec * y)  # right, bottom
            ]
            new_area.append(new_area[0]) # Repetir primeiro ponto, para o ignore do shape na hora de plotar
        
        elif mode == 'scalar':
            # Infla uma área retangular em uma quantidade fixa
            inc = (inflation_rate)
            dec = -(inflation_rate)

            new_area = [
                CartesianPoint(area[0].x + dec, area[0].y + dec), # left,  bottom
                CartesianPoint(area[1].x + dec, area[1].y + inc), # left,  top
                CartesianPoint(area[2].x + inc, area[2].y + inc), # right, top
                CartesianPoint(area[3].x + inc, area[3].y + dec)  # right, bottom
            ]
            new_area.append(new_area[0]) # Repetir primeiro ponto, para o ignore do shape na hora de plotar
        
        
        return new_area



class Conversor():

    def list_geo_to_cart( l, geo_home):
        for i in l:
            yield Conversor.geo_to_cart(i, geo_home)

    def list_cart_to_geo( l, geo_home):
        for i in l:
            yield Conversor.cart_to_geo(i, geo_home)


    def geo_to_cart( geo_point, geo_home):
        
        def calc_y(lat, lat_):
            return (lat - lat_) * (10000000.0 / 90)
        def calc_x(longi, longi_, lat_):
            return (longi - longi_) * (6400000.0 * (math.cos(lat_ * math.pi / 180) * 2 * math.pi / 360))

        x = calc_x(geo_point.longitude, geo_home.longitude, geo_home.latitude)
        y = calc_y(geo_point.latitude, geo_home.latitude)

        #return CartesianPoint(x, y, geo_point.altitude)
        return CartesianPoint(x, y)


    def cart_to_geo( cartesian_point, geo_home):

        def calc_latitude_y(lat_, y):
            return ((y * 90) / 10000000.0) + lat_
        def calc_longitude_x(lat_, longi_, x):
            return ((x * 90) / (10008000 * math.cos(lat_ * math.pi / 180))) + longi_


        longitude_x = calc_longitude_x(geo_home.latitude, geo_home.longitude, cartesian_point.x)
        latitude_y = calc_latitude_y(geo_home.latitude, cartesian_point.y)

        #return GeoPoint(longitude_x, latitude_y, cartesian_point.z)
        return GeoPoint(longitude_x, latitude_y, 10)

# %% [markdown]
# ## file_manipulation.py

# %%
def upload_mapa(mapa_file, mapa_id):
    mapa = mapa_file[mapa_id]

    geo_home = GeoPoint(mapa['geo_home'][1], mapa['geo_home'][0], mapa['geo_home'][2])

    areas_bonificadoras  = [ Conversor.list_geo_to_cart(area['geo_points'], geo_home) for area in mapa['areas_bonificadoras'] ]
    areas_penalizadoras  = [ Conversor.list_geo_to_cart(area['geo_points'], geo_home) for area in mapa['areas_penalizadoras'] ]
    
    areas_nao_navegaveis = []
    for area in mapa['areas_nao_navegaveis']:
        geo_points=[]
        for geo_point in area['geo_points']:
            geo_points.append(Conversor.geo_to_cart(
                GeoPoint(geo_point[1], geo_point[0], geo_point[2]) 
                , geo_home))
        geo_points.append(geo_points[0])
        areas_nao_navegaveis.append(geo_points)



    return geo_home, areas_bonificadoras, areas_penalizadoras, areas_nao_navegaveis

# %% [markdown]
# # 2. Algoritmo Genético
# Essa seção contém a implementação do algoritmo genético, contendo a definição da classe indivíduo (Subject) e da classe do genético (Genetic).
# Aqui está a implementação, não é necessário mexer, a menos que queira mudar alguma coisa na lógica da solução. **Caso somente queira mexer nos parâmetros, pule para a próxima etapa**

# %% [markdown]
# ### Utilitários

# %%
import collections
import random
import time
import copy

from math import cos, sin, sqrt, ceil

from itertools import tee
#from utils import pairwise, point_in_polygon, segment_in_polygon

Gene           = collections.namedtuple('Gene', 'a e')
GeneDecoded    = collections.namedtuple('GeneDecoded', 'x y v al')

# %% [markdown]
# ## 2.1. Definição do Indivíduo

# %%
class Subject():
    
    # codificação - u
    # dna = [Gene, ...]
    #     Gene = [a, e]
    #         a = float: aceleração
    #         e = float: variação angular


    # decodificação - x
    # dna_decoded = [GeneDecoded, ...]
    #     GeneDecoded = (x, y, v, al)
    #         x  = : Posição do VANT no eixo x (aka px)
    #         y  = : Posição do VANT no eixo y (aka py)
    #         v  = : Velocidade do VANT na horizontal
    #         al = : ângulo (direção) do VANT na horizontal
    def __init__(
        self,
        px0=10.,
        py0=10.,
        v0=0,
        al0=0,
        v_min=11.1,
        v_max=30.5,
        e_min=-3,        
        e_max=3,
        a_min=-2.0,
        a_max=2.0,
        T=10,
        T_min=1,
        T_max=7,
        delta_T=1,
        m=743.0,
        mutation_prob=0.7,
        start_time=None,
        spawn_mode='random',
        version=None,
        **kwargs
    ):
        # VANT
        # px0   int : Posição inicial no eixo x (m)
        # py0   int : Posição inicial no eixo y (m)
        # v0    int : Velocidade Inicial (m/s)
        # al0   int : Ângulo inicial (graus)
        self.gene_decoded_0 = GeneDecoded(px0, py0, v0, al0) # GeneDecoded : objeto contendo o gene decodificado de posição 0
        self.v_min = v_min # float : Velocidade máxima (m/s)
        self.v_max = v_max # float : Velocidade mínima (m/s)
        self.e_min = e_min # int   : Velocidade angular mínima (graus/s)
        self.e_max = e_max # int   : Velocidade angular máxima (graus/s)
        self.a_min = a_min # float : Aceleração mínima (m/s**2)
        self.a_max = a_max # float : Aceleração máxima (m/s**2)
        
        # TODO9:implementar os initialize
        
        # Modelo
        self.T_min   = T_min   # int : Valor mínimo para o horizonte de planejamento
        self.T_max   = T_max   # int : Valor máximo para o horizonte de planejamento
        self.delta_T = delta_T # int : Discretização do tempo (s) Tempo que leva de um waypoint até o outro
        self.m       = m       # float : Massa do VANT (!=0) (gramas)
    
        # Parametros do indivíduo
        self.mutation_prob = mutation_prob # float : Probabilidade de ocorrer uma mutação no dna (%)
        self.fitness       = None          # float : Fitness do indivíduo
        #self.birth_time    = None          # time  : Hora que o indivíduo é criado
        self.dna           = None          # list  : Conjunto de genes formando o DNA ([Gene, ...])
        self.dna_decoded   = None          # list  : DNA decodificado ([GeneDecoded, ...])
        self.spawn_mode    = spawn_mode    # str   : Tipo de incialização do DNA {'random'}
        self.start_time    = start_time    # time  : a hora em que o genético começou a rodar

        assert version, 'Algorithm version must be informed!\nEx: Version("alpha","RC")'
        if version.major == 'alpha': # Sem otimização em T
            self.T = T
            self.mutation_choices = [
                self._mutation_creep, 
                self._mutation_change
            ]
        elif version.major == 'beta': # Com otimização em T
            self.T = random.randint(T_min, T_max) # int : Horizonte de planejamento (quantidade de waypoints)
            self.mutation_choices = [
                self._mutation_remove, 
                self._mutation_insert, 
                self._mutation_creep, 
                self._mutation_change
            ]


        self.spawn(mode=spawn_mode)
        
    
    def set_fitness(self, fitness, fitness_trace, birth_time):
        self.fitness = fitness
        self.fitness_trace = fitness_trace
        #self.birth_time = birth_time
    
    
    # ---
    
    def spawn(self, mode):
        self.dna = [self._build_gene(mode) for _ in range(self.T) ]
        
    def _build_gene(self, mode='random'):
        # Inicialização aleatória gera valores com distribuição uniforme
        if mode == 'random':
            a = random.uniform(self.a_min, self.a_max)
            e = random.uniform(self.e_min, self.e_max)
            
        return Gene(a, e)
    
    # ---
    
    def decode(self):
        #self.dna_decoded = [self._decode_gene() for i in range(len(self.dna))]
        self.dna_decoded = self._decode_gene() # TODO: Organizar, voltar como era a linha de cima. Fazer função abaixo só computar o gene
        self.birth_time = time.time() - self.start_time

    def _decode_gene(self):
        dna = self.dna
        
        # parametros
        delta_T = self.delta_T
        m = self.m
        
        dna_decoded = []
        dna_decoded.append(self.gene_decoded_0)
        
        for i in range(0, len(dna)):
            # dna
            a  = dna[i].a
            e  = dna[i].e
            
            # dna decodificado
            px = dna_decoded[i].x
            py = dna_decoded[i].y
            v  = dna_decoded[i].v
            al = dna_decoded[i].al
            
            F = self.__F(v)
        
            # Equações descritas em (Arantes 2016)
            _px = px + ( v * cos(al) * delta_T ) + ( a * cos(al) * ((delta_T**2)/2) ) 
            _py = py + ( v * sin(al) * delta_T ) + ( a * sin(al) * ((delta_T**2)/2) ) 
            _v  = v  + ( a * delta_T ) - ( (F/m) * delta_T )
            _al = al + ( e * delta_T )

            dna_decoded.append(GeneDecoded(_px, _py, _v, _al))

        return dna_decoded
    
    
    def __F(self, v):
        # Equação do Arrasto
        # Disponível em https://pt.wikipedia.org/wiki/Equa%C3%A7%C3%A3o_do_arrasto
        # Versão utilizada ((Arantes, 2016) equação 3.5)
        
        Cd  = 0.8     # float : Coeficiente de arrasto, específico para cada aeronave
                      #         (considerado Angled Cube) obtido de https://pt.wikipedia.org/wiki/Coeficiente_de_resist%C3%AAncia_aerodin%C3%A2mica
        rho = 1.225   # float : Massa específica do fuído (aka densidade) (k/m**3)
                      #         (a 15 graus Celsius) Valor de rho obtido de https://pt.m.wikipedia.org/wiki/Densidade_do_ar
        A = 1.0       # float : Área de referência # TODO: o que é isso?
        # v = v       # float : Velocidade do Vant no instante t (fornecido como parâmetro da função)
        
        F = 0.5 * Cd * rho * A * (v**2)
        
        return F
        
    
    # ---
    
    def crossover(self, parent2):
        dna = random.choice([self._OX, self._BLX_Alpha])(self.dna, parent2.dna)
        dna = self._complete(dna, self.dna, parent2.dna)
        child = self.generate(dna)
        return child
    
    
    def _complete(self, dna, dna1, dna2):
        # Adiciona os genes restantes da diferença de tamanho entre os dois DNAs
               
        if len(dna1) > len(dna2):
            bigger  = dna1
            smaller = dna2
        else:
            bigger  = dna2
            smaller = dna1
    
        for i in range(len(smaller)-1, len(bigger)-1):
            if random.random() < 0.5:
                dna.append(bigger[i])
                
        return dna
        
    
    def _OX(self, dna1, dna2):
        dna = []
        for gene1, gene2 in zip(dna1, dna2):
            dna.append(random.choice([gene1, gene2]))
        return dna
        
        
    def _BLX_Alpha(self, dna1, dna2):
        dna = []
        for gene1, gene2 in zip(dna1, dna2):
            a = self.__BLX_ALpha_select_gene(gene1.a, gene2.a)
            e = self.__BLX_ALpha_select_gene(gene1.e, gene2.e)
            if a>self.a_max:
              a=self.a_max
            elif a < self.a_min:
              a=self.a_min

            if e>self.e_max:
              e=self.e_max
            elif e < self.e_min:
              e=self.e_min            
            
            gene = Gene(a, e)
            dna.append(gene)
            
        return dna
    
    
    def __BLX_ALpha_select_gene(self, x, y):
        # x - Gene : gene do pai 1
        # y - Gene : gene do pai 2
        alpha = random.uniform(0,1)
        d = abs(x-y)
        u = random.uniform(min(x,y)-alpha*d, max(x,y)+alpha*d)
        return u
    
    
    def generate(self, dna):
        # Cria um filho com os mesmos parametros do pai, mas com um dna fornecido
        child = copy.deepcopy(self)
        child.dna = dna
        child.decode()
        return child
    
        
    # ---
    
    def mutation(self, mutation_prob=None):
        mutation_prob = self.mutation_prob if not mutation_prob else mutation_prob # 0.7
        
        # Tem uma probabilidade mutation_prob de mutar o gene ou não
        if random.random() < mutation_prob:
            # Seleciona aleatoriamente uma das formas de mutação
            new_dna = random.choice(self.mutation_choices)(self.dna)
            # [
            #     self._mutation_remove, 
            #     self._mutation_insert, 
            #     self._mutation_creep, 
            #     self._mutation_change
            # ]
            
            if new_dna:
                self.dna = new_dna
                self.decode()
            
            return True
        return False
    
    def _mutation_change(self, dna):
        # Reinicia um gene aleatoriamente
        new_dna = []
        for gene in dna:
            if random.random() < 0.5:
                new_dna.append(self._build_gene('random'))
            else:
                new_dna.append(gene)
        
        return new_dna
    
    
    def _mutation_remove(self, dna):
        # Remove UM gene aleatório do DNA
        if len(dna) > self.T_min:
            i = random.randint(0, len(dna)-1)
            dna.pop(i)
            return dna
        return None
        
        
    def _mutation_insert(self, dna):
        # Insere UM gene aleatório no DNA em uma posição aleatória
        if len(dna) < self.T_max:
            i = random.randint(0, len(dna)-1)
            gene = self._build_gene()
            dna.insert(i, gene)
            return dna
        return None
    
    
    def _mutation_creep(self, dna):
        # Muta em um pequeno valor aleatorio todos os genes
        new_dna = []
        for gene in dna:
            a = self.__mute(gene.a, self.a_min, self.a_max)
            e = self.__mute(gene.e, self.e_min, self.e_max)

            # TODO2: otimizar
            new_gene = Gene(a, e)
            new_dna.append(new_gene)

        return new_dna
        
        
    def __mute(self, val, min_val, max_val):
        mutation_rate = random.uniform(0, max_val*0.5)
        s = random.choice([1, -1])
        val = val * (1 + (mutation_rate * s))

        # Checa se não estoura os limites
        if val>max_val:
          val=max_val
        elif val<min_val:
          val=min_val
        #val = max(val, min_val)
        #val = min(val, max_val)

        return val
    
    
    # ---
    
    def get_route(self):
        return [ [gene.x, gene.y] for gene in self.dna_decoded ]

# %% [markdown]
# ## 2.2. Definição do Genético

# %%
class Genetic():
    
    def __init__(
        self, 
        Specie, 
        mapa,
        taxa_cross=1.0,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=500,
        C_cur=100,
        C_t=10,
        max_exec_time=30,
        min_precision=1.0,
        k_tournament=2,
        gps_imprecision=1,
        big_delta=1,
        version=Version('alpha','RC'),
        **kwargs
    ):
        # Modelo
        self.Specie = Specie # objeto : Definição da classe (não a instância)
        self.mapa   = mapa   # Mapa   : Mapa com as características da missão

        # Parâmetros
        self.taxa_cross      = taxa_cross      # float : Taxa de ocorrencia do crossover [0,1]
        self.population_size = population_size # int   : Quantidade máxima de indivíduos na população 
        self.C_d             = C_d             # int   : Custo associado ao fitness de destino
        self.C_obs           = C_obs           # int   : Custo associado ao fitness de obstáculos
        self.C_con           = C_con           # int   : Custo associado ao fitness de consumo de combustível
        self.C_cur           = C_cur           # int   : Custo associado ao fitness de curvatura da rota
        self.C_t             = C_t             # int   : Custo associado ao fitness do tamanho do DNA (T ou horizonte de planejamento)
        self.max_exec_time   = max_exec_time   # float : Tempo máximo de execução - Stop criteria (segundos)
        self.min_precision   = min_precision   # float : Precisão mínima de acerto ao destino (metros)
        self.k_tournament    = k_tournament    # int   : Quantidade de indivíduos disputando o torneio
        self.gps_imprecision = gps_imprecision # float : Imprecisão do GPS (metros)
        self.big_delta       = big_delta
        
        # Versionamento
        self.version = version

        # Alguns dos valores do kwargs são passados para a instanciação dos indivíduos
        self.kwargs = kwargs
        
        # Inicialização
        self.population = None 
        self.fitnesses  = None
        self.best       = None
        self.ancestry   = []
        

#         if version.minor == "RC":
#             self.__fitness_obstacles = self.__fitness_obstacles_RC
#         elif version.minor == "CC":
#             self.__fitness_obstacles = self.__fitness_obstacles_CC

        
    def run(self, max_exec_time=None, verbose=False, info=False, debug=False):
        self.max_exec_time = max_exec_time if max_exec_time else self.max_exec_time
        
        # Acompanhamento do tempo (critério de parada)
        self.start_time = time.time()
        
        # Genesis
        self.population = self._genesis(self.Specie, self.population_size)
        
        # Inicializar
        self._decode(self.population)
        
        # Avaliar
        self.fitnesses = [self._fitness(subject, self.mapa) for subject in self.population]
    
        # Escolher melhor de todos
        self.best = self.population[self.fitnesses.index(max(self.fitnesses))]
        
        
        self.trace = []
        
        while not self.stop_criteria():
            self.flag_newborn = self.population_size
            count_while = 0
            
            while not self.converge():
                self.flag_newborn = 0
                count_while += 1
                
                for i in range(ceil(self.taxa_cross * self.population_size)):
                    # Seleção por torneio
                    parent1, parent2 = self._tournament(self.population, k=self.k_tournament)
            
                    # Crossover
                    child = parent1.crossover(parent2)
                    
                    # Mutação
                    child.mutation()
                    
                    # Fitness
                    self._fitness(child, self.mapa)
                    
                    # Adicionar filho na população
                    self._insert(child, parent1, parent2)
                    
                    # Print
                    if verbose and self.flag_newbest:
                        print('  Novo melhor de todos! fit: {}'.format(self.best.fitness))
                    if debug:
                        print('\nparent1.dna', parent1.dna)
                        print('\nparent2.dna', parent2.dna)
                        print('\nchild.dna.mutation', child.dna)
                        
                        
                aux_T_dna = [len(subject.dna) for subject in self.population]
                self.trace.append({
                    'medium_fitness': sum(self.fitnesses)/self.population_size,
                    'best_fitness': self.best.fitness,
                    'newborns': self.flag_newborn,
                    'newbest': self.flag_newbest,
                    'T_medio': sum(aux_T_dna)/self.population_size,
                    'T_maior': max(aux_T_dna),
                    'T_menor': min(aux_T_dna),
                    'T_melhor': len(self.best.dna)
                })
                
                # Print
                if verbose:
                    print('Fim da geração. {} novos indivíduos'.format(self.flag_newborn))
                    print('Melhor de todos: {}'.format(self.best.fitness))
                    print('-'*20)
                        
                        
            # Reiniciar rotas
            self.population = []
            self.population = self._genesis(self.Specie, self.population_size-1)
            # Nunca matar o melhor de todos
            self.population.append(self.best)
            
            # Inicializar
            self._decode(self.population)
            
            # Avaliar
            self.fitnesses = [self._fitness(subject, self.mapa) for subject in self.population]
            
            # Print
            if verbose:
                print('Meteoro! Reiniciando rotas')
            if info:
                print('Meteoro! Melhor de todos:{} - count:{}'.format(self.best.fitness, count_while))
                
                
        return self.best
                      
    # ---
    
    def _insert(self, child, parent1, parent2):
        # Verifica se um indivíduo é digno de entrar na população e tomar o lugar de um de seus pais

        self.flag_newbest = False
        
        if child.fitness < parent1.fitness:
            self.__substitute(child, parent1)

        elif child.fitness < parent2.fitness:
            self.__substitute(child, parent2)

        if child.fitness < self.best.fitness:
            self.best = child
            self.ancestry.append(child)
            self.flag_newbest = True
    
    
    def __substitute(self, child, parent):
        i_parent = self.population.index(parent)

        self.population.remove(parent)
        self.population.append(child)

        self.fitnesses.pop(i_parent)
        self.fitnesses.append(child.fitness)
        self.flag_newborn += 1
    
    
    # ---
    
    def stop_criteria(self):
        # Para a execução depois de uma quantidade de segundos
        if (time.time() - self.start_time) >= self.max_exec_time:
            return True
        return False
    
    def converge(self):
        # Converge caso nenhum novo indivíduo seja adicinado
        if self.flag_newborn == 0:
            return True
        return False
                         
    # ---
    
    def _genesis(self, Specie, population_size):
        population = [Specie(start_time=self.start_time, version=self.version,**self.kwargs) for i in range(population_size)]
        return population 
    
    # ---
    
    def _decode(self, population):
        for subject in population:
            subject.decode()
        return True
    
    # ---
    
    def _fitness(self, subject, mapa):
        
        fit_d   = self.__fitness_destination(subject, mapa)
        fit_obs = self.__fitness_obstacles(subject, mapa)
        fit_con = self.__fitness_consumption(subject, mapa)
        fit_cur = self.__fitness_curves(subject, mapa)
        fit_t   = self.__fitness_t(subject, mapa)
        
        fitness_trace = [self.C_d   * fit_d,
                         self.C_obs * fit_obs,
                         self.C_con * fit_con,
                         self.C_cur * fit_cur,
                         self.C_t   * fit_t]
        
        fitness = sum(fitness_trace)
        
        birth_time = time.time() - self.start_time
        
        subject.set_fitness(fitness, fitness_trace, birth_time)
        
        return fitness
    
    def __fitness_destination(self, subject, mapa):
        # Prioriza rotas que acertem o destino
        
        A = subject.dna_decoded[-1] # Último waypoint da rota
        B = mapa.destination        # Waypoint de destino
        
        # Distância euclidiana entre o último ponto da rota e o ponto de destino
        d = sqrt( (B.x - A.x)**2 + (B.y - A.y)**2 )
        
        # Determina uma precisão mínima aceita
        if d < self.min_precision: # min_precision default = 1.0
            return 0
        return d

    
    # def __fitness_obstacles is an abstraction of either one of those two following functions:
    # __fitness_obstacles_RC and __fitness_obstacles_CC

#     def __fitness_obstacles_RC(self, subject, mapa):
    def __fitness_obstacles(self, subject, mapa):
        # Prioriza rotas que não ultrapassem obstáculos
        count = 0
        
        for gene_decoded_t1, gene_decoded_t2  in pairwise(subject.dna_decoded):
            # Utiliza somente as áreas infladas para cálculo
            for area_n in mapa.areas_n_inf:
                wp1 = CartesianPoint(gene_decoded_t1.x, gene_decoded_t1.y)
                wp2 = CartesianPoint(gene_decoded_t2.x, gene_decoded_t2.y)
                
                # Calcula se algum waypoint está dentro de algum obstáculo
                if point_in_polygon(wp1, area_n):
                    count += 1

                # Calcula se alguma conexão entre os waypoints intersecciona algum obstáculo
                if segment_in_polygon(wp1, wp2, area_n):
                    count += 1
            
        return count


    def __fitness_obstacles_CC(self, subject, mapa):
        # Prioriza rotas que não ultrapassem obstáculos
        count       = 0
        
        #bigger_risk = 0 #M1
        sum_risk    = 0 #M2
    
        for gene_decoded_t1  in subject.dna_decoded:
            # Utiliza somente as áreas infladas para cálculo
            for area_n in mapa.areas_n_inf:
                wp1 = CartesianPoint(gene_decoded_t1.x, gene_decoded_t1.y)
    
                # Alocação de Risco    
                wp_risk = risk_total(wp1, area_n, self.gps_imprecision) #M1 #M2
            
                # Modo 1: Considerar o maior risco
                # bigger_risk = max(wp_risk, bigger_risk) #M1

                # Modo 2: Considerar a soma individual de cada risco
                sum_risk += wp_risk #M2

        #prob = min(bigger_risk, 1) #M1
        #prob = min(self.big_delta - sum_risk, 1) #M2
        if self.big_delta-sum_risk > 0:
            prob=0
        else:
            prob=sum_risk-self.big_delta
            
        #print(sum_risk)
            
        return prob
    
    
    def __fitness_consumption(self, subject, _):
        # Prioriza rotas com menor consumo de combustível (bateria)
        consumption = [gene.a**2 for gene in subject.dna]
        return sum(consumption)
    
        
    def __fitness_curves(self, subject, _):
        # Prioriza rotas que evitem fazer curvas desnecessárias
        curves = [abs(gene.e) for gene in subject.dna]
        return (1/subject.e_max) * sum(curves)
        
        
    def __fitness_t(self, subject, _):
        # Prioriza rotas com menor quantidade de waypoints
        return len(subject.dna)
    
        
    # ---
        
    def _tournament(self, population, k=2):
        parents = []
        for i in range(2):
            
            local_best = random.choice(population)
            for j in range(k-1):
                # Seleciona k individuos
                a = random.choice(population)
                if a.fitness < local_best.fitness:
                    local_best = a
                    
            parents.append(local_best)
            
        # Retorna o resultado de duas batalhas
        return parents[0], parents[1]

# %% [markdown]
# # 3. Execução
# Essa seção contém a execução do AG. Aqui contém as definições dos mapas, e execução do planejador de rotas. Pode alterar os parâmetros a vontade para testar novos resultados

# %% [markdown]
# ## 3.1. Mapas

# %% [markdown]
# ### Mapa 1

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (20.0, 5.0), # left, bottom
    (20.0, 15.5), # left, top
    (30.0, 15.5), # right, top
    (30.0, 5.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]


mapa_1 = Mapa(wp_ori, wp_des, [verts1], inflation_rate=1)

# %%
# Visualização desse mapa
vis_mapa(mapa_1)

# %% [markdown]
# ### Mapa 2

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (15.0,  8.0), # left, bottom
    (15.0, 20.0), # left, top
    (20.0, 20.0), # right, top
    (20.0,  8.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (30.0,  0.0), # left, bottom
    (30.0, 12.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  0.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_2 = Mapa(wp_ori, wp_des, [verts1, verts2], inflation_rate=1)

# %%
# Visualização desse mapa
vis_mapa(mapa_2)

# %% [markdown]
# ### Mapa 3

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (15.0, 11.0), # left, bottom
    (15.0, 25.0), # left, top
    (35.0, 23.0), # right, top
    (35.0, 16.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (15.0,  0.0), # left, bottom
    (15.0,  9.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  6.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_3 = Mapa(wp_ori, wp_des, [verts1, verts2], inflation_rate=0.5)

# %%
# Visualização desse mapa
vis_mapa(mapa_3)

# %% [markdown]
# ### Mapa 4

# %%
wp_ori = CartesianPoint(40.0, 25.0)
wp_des = CartesianPoint(36.0, -22.0)

verts1 = [
    (19.0,-12.0), # left, bottom
    (15.0,0.0), # left, top
    (87.0,15.0), # right, top
    (90.0,3.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

# verts1 = [
#     (38.0,-9.0), # left, bottom
#     (38.0,6.0), # left, top
#     (87.0,15.0), # right, top
#     (90.0,3.0), # right, bottom
# ]
# verts1.append(verts1[0])
# verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (15.0,  0.0), # left, bottom
    (15.0,  9.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  6.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_4 = Mapa(wp_ori, wp_des, [verts1], inflation_rate=0.5)

# %%
# Visualização desse mapa
vis_mapa(mapa_4)

# %% [markdown]
# ## 3.2. Planejamento de Rota

# %%
# ===============================================================
# --------------   UTILIZE ESSE ESPAÇO --------------------------

debug = False

# Altere aqui o mapa que deseja utilizar
#mapa = mapa_1
mapa = mapa_2
#mapa = mapa_3
#mapa = mapa_4


# Inicialização do Algoritmo
ag = Genetic(Subject, mapa, 
        version = Version('beta', 'RC'),
        # Parâmetros da classe Genetic:
        taxa_cross=5,
        population_size=10,
        C_d=1000,
        C_obs=10000,
        C_con=500,
        C_cur=100,
        C_t=100,
        max_exec_time=30, # segundos
        # Parâmetros da classe Subject:
        px0=mapa.origin.x,
        py0=mapa.origin.y,
        T_min=1,
        T_max=25,
        mutation_prob=0.7
)

# ===============================================================

# Execução do AG, retorna o melhor indivíduo
best = ag.run(info=True)

# Print do DNA do melhor
print('-'*30)
for dna in best.dna:
    print(dna)
    
# Print do DNA DECODIFICADO do melhor
print('-'*30)
for dna_decoded in best.dna_decoded:
    print(dna_decoded)
    
best = ag.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)


# Visualização de alguns gráficos de fitness e quantidade de Ts
#plot_stats(ag.trace, normalize=True)
#plot_stats(ag.trace, normalize=False)
# Out:
# Meteoro! Melhor de todos:15281.311455170333 - count:19
# Meteoro! Melhor de todos:14317.629230098617 - count:10
# Meteoro! Melhor de todos:14311.441386089544 - count:10
# Meteoro! Melhor de todos:14311.441386089544 - count:9
# Meteoro! Melhor de todos:14157.466690931911 - count:22
# Meteoro! Melhor de todos:13926.267246008189 - count:16
# Meteoro! Melhor de todos:4246.115217509077 - count:91
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-af7f70d2284e> in <module>
#      34
#      35 # Execução do AG, retorna o melhor indivíduo
# ---> 36 best = ag.run(info=True)
#      37
#      38 # Print do DNA do melhor
#
# <ipython-input-8-dccfed203b93> in run(self, max_exec_time, verbose, info, debug)
#      94
#      95                     # Mutação
# ---> 96                     child.mutation()
#      97
#      98                     # Fitness
#
# <ipython-input-7-1acf4adfb448> in mutation(self, mutation_prob)
#     244         if random.random() < mutation_prob:
#     245             # Seleciona aleatoriamente uma das formas de mutação
# --> 246             new_dna = random.choice(self.mutation_choices)(self.dna)
#     247             # [
#     248             #     self._mutation_remove,
#
# <ipython-input-7-1acf4adfb448> in _mutation_creep(self, dna)
#     295         for gene in dna:
#     296             a = self.__mute(gene.a, self.a_min, self.a_max)
# --> 297             e = self.__mute(gene.e, self.e_min, self.e_max)
#     298
#     299             # TODO2: otimizar
#
# <ipython-input-7-1acf4adfb448> in __mute(self, val, min_val, max_val)
#     305
#     306     def __mute(self, val, min_val, max_val):
# --> 307         mutation_rate = random.uniform(0, max_val*0.5)
#     308         s = random.choice([1, -1])
#     309         val = val * (1 + (mutation_rate * s))
#
# KeyboardInterrupt:

# %%
import pickle
pickle.dump(ag, open( "test_ag_save.p", "wb" ) )
ag_backup = pickle.load(open( "test_ag_save.p", "rb" ) )

# %%
ag.__module__

# %%
ag_backup.best.birth_time

# %%
ag_backup

# %%
debug = True
wp_teste = GeneDecoded(x=19, y=16.5, v=7.8730500357006825, al=0.23615218818588443)

risk_total(wp_teste, mapa.areas_n_inf[0], 5)

# %%
 mapa.areas_n_inf[0]

# %% [markdown]
# #### Visualizar Detalhes do fitness

# %%
best.fitness_trace
# Destino Obstáculo Consumo Curva QtdWP

# %% [markdown]
# #### Recuperação de Erros
# Caso o AG pare no meio da execução, é possível visualizar o melhor de todos gerado até o momento mesmo assim, basta rodar a célula abaixo

# %%
best = ag.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %% [markdown]
# # 4. Execução da Implementação em ROS

# %%
mapa_file = [
{
	"id": 0,
	"name": "Mapa C2",
	"geo_home": [-47.932949, -22.002467, 0],
	"areas_bonificadoras":[],
	"areas_penalizadoras":[],
	"areas_nao_navegaveis":[
		{
			"id": "NN1",
			"name": "Campo atras dos containers",
			"geo_points":[
				[-47.932749, -22.002332, 7], 
				[-47.932794, -22.002177, 13], 
				[-47.932664, -22.002147, 13], 
				[-47.932612, -22.002306, 7]
    			]
    		},
		{
			"id": "NN2",
			"name": "Bloco de aula",
			"geo_points":[
				[-47.932099, -22.002278, 20],
				[-47.932063, -22.002396, 20],
				[-47.932772, -22.002582, 20],
				[-47.932811, -22.002465, 20]
			]
		}
    ]
}
]

# %%
mapa_file = [
{
	"id": 0,
	"name": "Mapa C2",
	"geo_home": [-47.932949, -22.002467, 0],
	"areas_bonificadoras":[],
	"areas_penalizadoras":[],
	"areas_nao_navegaveis":[
		{
			"id": "NN1",
			"name": "Bloco de Aula",
			"geo_points":[
				[-47.932754, -22.002590, 7], 
				[-47.932804, -22.002485, 13], 
				[-47.932109, -22.002287, 13], 
				[-47.932072, -22.002401, 7]
    			]
    		},
		{
			"id": "NN2",
			"name": "Containers",
			"geo_points":[
				[-47.933286, -22.002630, 20],
				[-47.933370, -22.002350, 20],
				[-47.933047, -22.002259, 20],
				[-47.932956, -22.002532, 20]
			]
		}
    ]
}
]

# %%
import argparse

#from visualization import plot_map
#from genetic_v2_3 import Subject, Genetic 
#from data_definitions import Mapa, CartesianPoint, Conversor, GeoPoint

#from file_manipulation import read_mapa, write_mavros, upload_mapa

## ENTRADA

# Parâmetros recebidos (arquivo .srv)
origin_lat       = -22.002237
origin_long      = -47.932546
origin_alt       = 13
destination_lat  = -22.002674 
destination_long = -47.932608
destination_alt  = 15

# P0
# destination_lat  = -22.002278 
# destination_long = -47.932099
# destination_alt  = 20

# P1
# destination_lat  = -22.002396 
# destination_long = -47.932063
# destination_alt  = 20


mapa_id          = 0

# Leitura do arquvio em DATA
#PATH = '/home/gustavosouza/Documents/Per/path-planning/data/mapa.json' #Ubuntu
PATH = r'../../data' #Windows
#geo_home, _, _, areas_n = read_mapa(PATH, mapa_id)
geo_home, _, _, areas_n = upload_mapa(mapa_file, mapa_id)

cart_origin      = Conversor.geo_to_cart(GeoPoint(origin_lat, origin_long, origin_alt), geo_home)
cart_destination = Conversor.geo_to_cart(GeoPoint(destination_lat, destination_long, destination_alt), geo_home)


mapa = Mapa(cart_origin, cart_destination, areas_n, inflation_rate=3)



## EXECUÇÃO DO AG
ag_teste = Genetic(Subject, mapa,
        # Genetic
        taxa_cross=0.5,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=100,
        C_cur=500,
        C_t=100,
        max_exec_time=6000,
        #Subject,
        T_min=10,
        T_max=40,
        mutation_prob=0.7,
        px0=cart_origin.x,
        py0=cart_origin.y
)


best = ag_teste.run(info=True)

# Melhor rota encontrada : WPs em cartesiano
cart_points = best.get_route()

# Melhor rota encontrada : WPs em geográfico
geo_points = [ Conversor.cart_to_geo(CartesianPoint(cart_point[0], cart_point[1]), geo_home) for cart_point in cart_points ]


# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

## SAÍDA

#output_filename = '/mnt/c/Projetos/path-planning/algorithms/ros_genetic/path_from_ga_output.wp'
#write_mavros(output_filename, geo_points)

# %%
def print_mavros(geo_points): #throws FileNotFoundException
    print('Printing mavros file...\n\n\n')
    count = 1


    current_waypoint = 1

    print('QGC WPL 120\n') # Determines the file version

    i = 0

    for geo_point in geo_points:
        print(
            str(i) + '\t'
            + str(current_waypoint) + '\t' 
            + '3\t16\t3\t0\t0\t0\t'
            + '{:10.8f}'.format(geo_point.longitude) + '\t' 
            + '{:10.8f}'.format(geo_point.latitude) + '\t'
            + '{:10.8f}'.format(geo_point.altitude) + '\t'
            + '1'
            + '\n'
        )

        current_waypoint = 0
        i+=1

    print('\n\n\nOutput print generated.')

# %%
print_mavros(geo_points)

# %%
mapa.areas_n

# %%
areas = [ area for area in itertools.chain(mapa.areas_n) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %%
import argparse

#from visualization import plot_map
#from genetic_v2_3 import Subject, Genetic 
#from data_definitions import Mapa, CartesianPoint, Conversor, GeoPoint

#from file_manipulation import read_mapa, write_mavros, upload_mapa

## ENTRADA

# Parâmetros recebidos (arquivo .srv)
origin_lat       = -22.002237
origin_long      = -47.932546
origin_alt       = 13
destination_lat  = -22.002674 
destination_long = -47.932608
destination_alt  = 15

# P0
# destination_lat  = -22.002278 
# destination_long = -47.932099
# destination_alt  = 20

# P1
# destination_lat  = -22.002396 
# destination_long = -47.932063
# destination_alt  = 20


mapa_id          = 0

# Leitura do arquvio em DATA
#PATH = '/home/gustavosouza/Documents/Per/path-planning/data/mapa.json' #Ubuntu
PATH = r'../../data' #Windows
#geo_home, _, _, areas_n = read_mapa(PATH, mapa_id)
geo_home, _, _, areas_n = upload_mapa(mapa_file, mapa_id)

cart_origin      = Conversor.geo_to_cart(GeoPoint(origin_lat, origin_long, origin_alt), geo_home)
cart_destination = Conversor.geo_to_cart(GeoPoint(destination_lat, destination_long, destination_alt), geo_home)


mapa = Mapa(cart_origin, cart_destination, areas_n, inflation_rate=0.1)



## EXECUÇÃO DO AG
ag_teste = Genetic(Subject, mapa,
        # Genetic
        taxa_cross=0.5,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=100,
        C_cur=500,
        C_t=1,
        max_exec_time=600,
        #Subject,
        T_min=10,
        T_max=40,
        mutation_prob=0.7,
        px0=cart_origin.x,
        py0=cart_origin.y
)


best = ag_teste.run(info=True)

# Melhor rota encontrada : WPs em cartesiano
cart_points = best.get_route()

# Melhor rota encontrada : WPs em geográfico
geo_points = [ Conversor.cart_to_geo(CartesianPoint(cart_point[0], cart_point[1]), geo_home) for cart_point in cart_points ]


# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

## SAÍDA

#output_filename = '/mnt/c/Projetos/path-planning/algorithms/ros_genetic/path_from_ga_output.wp'
#write_mavros(output_filename, geo_points)

# %%
best.fitness_trace
# Destino Obstáculo Consumo Curva QtdWP

# %%
best = ag_teste.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %% [markdown]
# # 5. Ray Casting Stress Test
# Testes de estresse para verificar desempenho do algoritmo Ray Casting

# %% [markdown]
# ## 5.1. Point in Polygon

# %%
qty_points = 1000


verts1 = [
    (2.5, 2.5), # left, bottom
    (2.5, 4.5), # left, top
    (4.5, 4.5), # right, top
    (4.5, 2.5), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

texts = []
wps = []
for i in range(qty_points):
    x = random.uniform(1,6)
    y = random.uniform(1,6)
    
    wp = CartesianPoint(x,y)
    wps.append(wp)
    texts.append(str(point_in_polygon(wp, verts1))[0])
    
plot_map(
    areas=[verts1], 
    labels=['n'], 
    texts=texts,
    points=wps,
    wp_style='x',
    title='Ray Casting Algorithm Stress Test, wp={}'.format(qty_points),
    stress=True
)

# %% [markdown]
# ## 5.2. Segment intersects polygon

# %%
qty_segments = 15

verts1 = [
    (2.5, 2.5), # left, bottom
    (2.5, 4.5), # left, top
    (4.5, 4.5), # right, top
    (4.5, 2.5), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

texts = []
segments = []
for i in range(qty_segments):
    x = random.uniform(1,6)
    y = random.uniform(1,6)
    wp1 = CartesianPoint(x,y)

    x = random.uniform(1,6)
    y = random.uniform(1,6)
    wp2 = CartesianPoint(x,y)

    segment = [wp1, wp2]
    segments.append(segment)
    texts.append(str(segment_in_polygon(wp1, wp2, verts1))[0])
    
plot_map(
    areas=[verts1], 
    labels=['n'], 
    texts=texts,
    segments=segments,
    wp_style='-x',
    title='Ray Casting Algorithm Stress Test, wp={}'.format(qty_segments),
    stress=True
)

# %% [markdown]
# # 6. Automated Experiments

# %% [markdown]
# ## Def

# %%
debug = False

# Altere aqui o mapa que deseja utilizar
#mapa = mapa_1
#mapa = mapa_2
#mapa = mapa_3
#mapa = mapa_4

def run_ag(mapa):

    # Inicialização do Algoritmo
    ag = Genetic(Subject, mapa, 
            version = Version('beta', 'RC'),
            # Parâmetros da classe Genetic:
            taxa_cross=5,
            population_size=10,
            C_d=1000,
            C_obs=10000,
            C_con=500,
            C_cur=100,
            C_t=100,
            max_exec_time=600, # segundos
            # Parâmetros da classe Subject:
            px0=mapa.origin.x,
            py0=mapa.origin.y,
            T=10,
            T_min=1,
            T_max=25,
            mutation_prob=0.7
    )

    # Execução do AG, retorna o melhor indivíduo
    best = ag.run(info=True)

    # Print do DNA do melhor
    print('-'*30)
    for dna in best.dna:
        print(dna)
        
    # Print do DNA DECODIFICADO do melhor
    print('-'*30)
    for dna_decoded in best.dna_decoded:
        print(dna_decoded)
        
    best = ag.best

    # Visualização do Mapa usado, com a rota do melhor de todos
    areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
    tipos = [ 'n' for _ in range(len(areas))]
    plot_map(
        areas=areas,            # Mapa usado
        labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
        origem=mapa.origin,      # waypoint de origem
        destino=mapa.destination, # waypoint de destino
        waypoints=best.get_route(), # rota do melhor de todos
    )


    # Visualização de alguns gráficos de fitness e quantidade de Ts
    #plot_stats(ag.trace, normalize=True)
    #plot_stats(ag.trace, normalize=False)

    return ag

# %% [markdown]
# ## Run

# %%
import pickle

# %%
tests = {
    'mapa1':{
        'ags': [],
        'res': []
    },
    'mapa2':{
        'ags': [],
        'res': []
    },
    'mapa3':{
        'ags': [],
        'res': []
    },
    'mapa4':{
        'ags': [],
        'res': []
    }
}

# %%
import pickle

for i in range(5):
    for selected_map, mapa in zip(['mapa3'], [mapa_3]):
        ag = run_ag(mapa)
        tests[selected_map]['ags'].append(ag)
        
        l = [[subject.fitness, subject.birth_time] for subject in ag.ancestry]   
        tests[selected_map]['res'].append(l)
        
        pickle.dump(tests, open( 'backups/{}_{}.p'.format(selected_map, str(i)), 'wb' ) )

pickle.dump(tests, open('execution_10min_C.p', 'wb'))
# Out:
# Meteoro! Melhor de todos:24747.48107977676 - count:16
# Meteoro! Melhor de todos:24747.48107977676 - count:9
# Meteoro! Melhor de todos:6065.2011383647105 - count:207
# Meteoro! Melhor de todos:5300.571260901776 - count:144
# Meteoro! Melhor de todos:5300.54948631972 - count:24
# Meteoro! Melhor de todos:5300.521139191721 - count:25
# Meteoro! Melhor de todos:5300.521139191721 - count:12
# Meteoro! Melhor de todos:5300.482430635669 - count:47
# Meteoro! Melhor de todos:5300.466552292738 - count:67
# Meteoro! Melhor de todos:5300.21293065314 - count:33
# Meteoro! Melhor de todos:5300.21293065314 - count:18
# Meteoro! Melhor de todos:5300.209366652445 - count:16
# Meteoro! Melhor de todos:5300.209366652445 - count:15
# Meteoro! Melhor de todos:5300.209366652445 - count:14
# Meteoro! Melhor de todos:5300.209366652445 - count:17
# Meteoro! Melhor de todos:5300.209366652445 - count:15
# Meteoro! Melhor de todos:5300.207173131253 - count:21
# Meteoro! Melhor de todos:5300.207173131253 - count:17
# Meteoro! Melhor de todos:5300.0225625960275 - count:21
# Meteoro! Melhor de todos:5300.0225625960275 - count:14
# Meteoro! Melhor de todos:5299.862885833377 - count:71
# Meteoro! Melhor de todos:5299.682660060859 - count:47
# Meteoro! Melhor de todos:5299.679831289175 - count:22
# Meteoro! Melhor de todos:5299.679831289175 - count:18
# Meteoro! Melhor de todos:5299.679831289175 - count:17
# Meteoro! Melhor de todos:5299.679831289175 - count:22
# Meteoro! Melhor de todos:5299.508244955447 - count:52
# Meteoro! Melhor de todos:5299.077698738438 - count:50
# Meteoro! Melhor de todos:5299.077698738438 - count:21
# Meteoro! Melhor de todos:5299.077698738438 - count:13
# Meteoro! Melhor de todos:5297.821420645538 - count:37
# Meteoro! Melhor de todos:5294.729255889346 - count:59
# Meteoro! Melhor de todos:5294.718279717835 - count:21
# Meteoro! Melhor de todos:5294.718279717835 - count:10
# Meteoro! Melhor de todos:5294.645976107508 - count:20
# Meteoro! Melhor de todos:5294.645976107508 - count:11
# Meteoro! Melhor de todos:5288.137988979262 - count:34
# Meteoro! Melhor de todos:5241.0759644727705 - count:109
# Meteoro! Melhor de todos:5159.445166368625 - count:17
# Meteoro! Melhor de todos:5156.742750281547 - count:36
# Meteoro! Melhor de todos:5156.281446030608 - count:28
# Meteoro! Melhor de todos:5156.281446030608 - count:17
# Meteoro! Melhor de todos:5156.249459260133 - count:30
# Meteoro! Melhor de todos:5156.249459260133 - count:21
# Meteoro! Melhor de todos:5156.249459260133 - count:23
# Meteoro! Melhor de todos:5156.249459260133 - count:11
# Meteoro! Melhor de todos:5155.974483265836 - count:41
# Meteoro! Melhor de todos:5155.776500293191 - count:43
# Meteoro! Melhor de todos:5155.776500293191 - count:16
# Meteoro! Melhor de todos:5155.776500293191 - count:22
# Meteoro! Melhor de todos:5154.665184298566 - count:23
# Meteoro! Melhor de todos:5154.665184298566 - count:18
# Meteoro! Melhor de todos:5039.056839440247 - count:35
# Meteoro! Melhor de todos:5039.056839440247 - count:13
# Meteoro! Melhor de todos:5039.056839440247 - count:17
# Meteoro! Melhor de todos:5039.056839440247 - count:15
# Meteoro! Melhor de todos:5038.939900359766 - count:36
# Meteoro! Melhor de todos:5038.939900359766 - count:13
# Meteoro! Melhor de todos:5038.939900359766 - count:24
# Meteoro! Melhor de todos:5038.8784467127625 - count:25
# Meteoro! Melhor de todos:5038.793244337665 - count:19
# Meteoro! Melhor de todos:5038.699907653943 - count:20
# Meteoro! Melhor de todos:5038.587126066174 - count:41
# Meteoro! Melhor de todos:5038.587126066174 - count:11
# Meteoro! Melhor de todos:5038.587126066174 - count:10
# Meteoro! Melhor de todos:5038.587126066174 - count:9
# Meteoro! Melhor de todos:5038.587126066174 - count:17
# Meteoro! Melhor de todos:5038.587126066174 - count:20
# Meteoro! Melhor de todos:5038.587126066174 - count:19
# Meteoro! Melhor de todos:5038.587126066174 - count:18
# Meteoro! Melhor de todos:5038.587126066174 - count:25
# Meteoro! Melhor de todos:5038.587126066174 - count:14
# Meteoro! Melhor de todos:5038.587126066174 - count:19
# Meteoro! Melhor de todos:5038.587126066174 - count:18
# Meteoro! Melhor de todos:5038.587126066174 - count:20
# Meteoro! Melhor de todos:5038.587126066174 - count:18
# Meteoro! Melhor de todos:5038.587126066174 - count:18
# Meteoro! Melhor de todos:5038.587126066174 - count:20
# Meteoro! Melhor de todos:5038.587126066174 - count:16
# Meteoro! Melhor de todos:5038.096807657871 - count:22
# Meteoro! Melhor de todos:5037.871589647614 - count:75
# Meteoro! Melhor de todos:5037.871589647614 - count:5
# Meteoro! Melhor de todos:5037.871589647614 - count:7
# Meteoro! Melhor de todos:5037.871589647614 - count:13
# Meteoro! Melhor de todos:5037.871589647614 - count:15
# Meteoro! Melhor de todos:5037.871589647614 - count:23
# Meteoro! Melhor de todos:5037.871589647614 - count:16
# Meteoro! Melhor de todos:5037.871589647614 - count:21
# Meteoro! Melhor de todos:5037.871589647614 - count:18
# Meteoro! Melhor de todos:5037.871589647614 - count:15
# Meteoro! Melhor de todos:5037.871589647614 - count:8
# Meteoro! Melhor de todos:5037.871589647614 - count:27
# Meteoro! Melhor de todos:5037.871589647614 - count:21
# Meteoro! Melhor de todos:4468.944170663943 - count:25
# Meteoro! Melhor de todos:4199.666712905553 - count:31
# Meteoro! Melhor de todos:4159.486462393233 - count:14
# Meteoro! Melhor de todos:4106.695809947105 - count:115
# Meteoro! Melhor de todos:4106.695809947105 - count:9
# Meteoro! Melhor de todos:4106.695809947105 - count:12
# Meteoro! Melhor de todos:4099.695150570379 - count:15
# Meteoro! Melhor de todos:4099.306060618634 - count:27
# Meteoro! Melhor de todos:4099.306060618634 - count:12
# Meteoro! Melhor de todos:3901.8416532025117 - count:16
# Meteoro! Melhor de todos:3901.8416532025117 - count:11
# Meteoro! Melhor de todos:3901.0541445188323 - count:13
# Meteoro! Melhor de todos:3716.118336713997 - count:14
# Meteoro! Melhor de todos:3584.944790563233 - count:24
# Meteoro! Melhor de todos:3584.1093758573857 - count:17
# Meteoro! Melhor de todos:3584.1093758573857 - count:9
# Meteoro! Melhor de todos:3578.8182413919585 - count:8
# Meteoro! Melhor de todos:3493.6592107937 - count:82
# Meteoro! Melhor de todos:3493.6592107937 - count:21
# Meteoro! Melhor de todos:3492.8020432011 - count:53
# Meteoro! Melhor de todos:3492.8020432011 - count:18
# Meteoro! Melhor de todos:3491.626876265075 - count:48
# Meteoro! Melhor de todos:3179.678798119752 - count:26
# Meteoro! Melhor de todos:3178.5386703306926 - count:102
# Meteoro! Melhor de todos:3093.913415797276 - count:29
# Meteoro! Melhor de todos:3093.913415797276 - count:5
# Meteoro! Melhor de todos:3092.2506204913198 - count:60
# Meteoro! Melhor de todos:3076.3268422893525 - count:78
# Meteoro! Melhor de todos:3057.9198341995134 - count:154
# Meteoro! Melhor de todos:3057.8024458672885 - count:30
# Meteoro! Melhor de todos:3038.0687651969365 - count:140
# Meteoro! Melhor de todos:3038.0687651969365 - count:6
# Meteoro! Melhor de todos:3037.1314614257726 - count:25
# Meteoro! Melhor de todos:3037.1314614257726 - count:8
# Meteoro! Melhor de todos:3037.130553303896 - count:43
# Meteoro! Melhor de todos:3037.130553303896 - count:16
# Meteoro! Melhor de todos:3037.130553303896 - count:21
# Meteoro! Melhor de todos:3037.130553303896 - count:31
# Meteoro! Melhor de todos:3037.130553303896 - count:31
# Meteoro! Melhor de todos:2993.289261795634 - count:26
# Meteoro! Melhor de todos:2993.190568274928 - count:23
# Meteoro! Melhor de todos:2990.071146497063 - count:20
# Meteoro! Melhor de todos:2960.4832011972762 - count:137
# Meteoro! Melhor de todos:2960.477334088147 - count:26
# Meteoro! Melhor de todos:2960.404270203569 - count:28
# Meteoro! Melhor de todos:2960.404270203569 - count:9
# Meteoro! Melhor de todos:2960.404270203569 - count:15
# Meteoro! Melhor de todos:2960.404270203569 - count:9
# Meteoro! Melhor de todos:2959.925636423454 - count:21
# Meteoro! Melhor de todos:2950.7229794169343 - count:79
# Meteoro! Melhor de todos:2950.7229794169343 - count:14
# Meteoro! Melhor de todos:2950.7229794169343 - count:10
# Meteoro! Melhor de todos:2941.8642396826153 - count:67
# Meteoro! Melhor de todos:2941.8642396826153 - count:18
# Meteoro! Melhor de todos:2941.8642396826153 - count:14
# Meteoro! Melhor de todos:2941.8642396826153 - count:23
# Meteoro! Melhor de todos:2939.1461151259764 - count:23
# Meteoro! Melhor de todos:2939.1461151259764 - count:9
# Meteoro! Melhor de todos:2932.7088421851813 - count:25
# Meteoro! Melhor de todos:2932.7088421851813 - count:11
# Meteoro! Melhor de todos:2929.939608255133 - count:18
# Meteoro! Melhor de todos:2928.409230015672 - count:14
# Meteoro! Melhor de todos:2926.3211141993656 - count:47
# Meteoro! Melhor de todos:2926.1768183856975 - count:26
# Meteoro! Melhor de todos:2925.063879668186 - count:44
# Meteoro! Melhor de todos:2925.063879668186 - count:32
# Meteoro! Melhor de todos:2925.063879668186 - count:13
# Meteoro! Melhor de todos:2925.063879668186 - count:20
# Meteoro! Melhor de todos:2916.758862421685 - count:100
# Meteoro! Melhor de todos:2916.758862421685 - count:12
# Meteoro! Melhor de todos:2916.2700438368447 - count:59
# Meteoro! Melhor de todos:2914.9583548950022 - count:50
# Meteoro! Melhor de todos:2914.8531003636213 - count:27
# Meteoro! Melhor de todos:2914.784804600504 - count:68
# Meteoro! Melhor de todos:2914.784804600504 - count:18
# Meteoro! Melhor de todos:2914.707182036472 - count:41
# Meteoro! Melhor de todos:2914.707182036472 - count:17
# Meteoro! Melhor de todos:2914.707182036472 - count:16
# Meteoro! Melhor de todos:2887.668623010968 - count:108
# Meteoro! Melhor de todos:2887.668623010968 - count:17
# Meteoro! Melhor de todos:2887.668623010968 - count:14
# Meteoro! Melhor de todos:2887.668623010968 - count:21
# Meteoro! Melhor de todos:2887.668623010968 - count:17
# Meteoro! Melhor de todos:2887.668623010968 - count:17
# Meteoro! Melhor de todos:2887.668623010968 - count:17
# Meteoro! Melhor de todos:2887.668623010968 - count:25
# Meteoro! Melhor de todos:2871.2900040958475 - count:40
# Meteoro! Melhor de todos:2871.08092091864 - count:88
# Meteoro! Melhor de todos:2870.847629642508 - count:94
# Meteoro! Melhor de todos:2870.847629642508 - count:23
# Meteoro! Melhor de todos:2870.8436779727417 - count:26
# Meteoro! Melhor de todos:2869.4218916814348 - count:18
# Meteoro! Melhor de todos:2868.810702123591 - count:136
# Meteoro! Melhor de todos:2868.810702123591 - count:16
# Meteoro! Melhor de todos:2868.7618288773174 - count:24
# Meteoro! Melhor de todos:2868.7618288773174 - count:19
# Meteoro! Melhor de todos:2868.1478596031457 - count:106
# Meteoro! Melhor de todos:2868.1478596031457 - count:27
# Meteoro! Melhor de todos:2868.042699990101 - count:107
# Meteoro! Melhor de todos:2868.042699990101 - count:30
# Meteoro! Melhor de todos:2868.042699990101 - count:24
# Meteoro! Melhor de todos:2868.042699990101 - count:17
# Meteoro! Melhor de todos:2868.042699990101 - count:20
# Meteoro! Melhor de todos:2867.7777030199286 - count:17
# Meteoro! Melhor de todos:2867.7777030199286 - count:14
# Meteoro! Melhor de todos:2867.7777030199286 - count:11
# Meteoro! Melhor de todos:2867.7777030199286 - count:17
# Meteoro! Melhor de todos:2867.7777030199286 - count:27
# Meteoro! Melhor de todos:2865.627272340039 - count:45
# Meteoro! Melhor de todos:2865.627272102405 - count:27
# Meteoro! Melhor de todos:2865.627272102405 - count:27
# Meteoro! Melhor de todos:2865.627272102405 - count:10
# Meteoro! Melhor de todos:2865.609754018453 - count:21
# Meteoro! Melhor de todos:2865.6085300851605 - count:44
# Meteoro! Melhor de todos:2865.6085300851605 - count:13
# Meteoro! Melhor de todos:2865.6085300851605 - count:23
# Meteoro! Melhor de todos:2865.6085300851605 - count:9
# Meteoro! Melhor de todos:2865.6085300851605 - count:27
# Meteoro! Melhor de todos:2865.6085300851605 - count:17
# Meteoro! Melhor de todos:2865.6085300851605 - count:19
# Meteoro! Melhor de todos:2865.6085300851605 - count:20
# Meteoro! Melhor de todos:2865.6085300851605 - count:21
# Meteoro! Melhor de todos:2865.6085300851605 - count:13
# Meteoro! Melhor de todos:2865.578201457218 - count:29
# Meteoro! Melhor de todos:2865.4830867541314 - count:25
# Meteoro! Melhor de todos:2865.4830867541314 - count:25
# Meteoro! Melhor de todos:2865.4830867541314 - count:15
# Meteoro! Melhor de todos:2865.4830867541314 - count:24
# Meteoro! Melhor de todos:2865.4830867541314 - count:9
# Meteoro! Melhor de todos:2865.4830867541314 - count:19
# Meteoro! Melhor de todos:2865.4830867541314 - count:14
# Meteoro! Melhor de todos:2865.4830867541314 - count:16
# Meteoro! Melhor de todos:2865.4830867541314 - count:10
# Meteoro! Melhor de todos:2865.4830867541314 - count:14
# Meteoro! Melhor de todos:2863.6687145314127 - count:133
# Meteoro! Melhor de todos:2863.6577816346703 - count:65
# Meteoro! Melhor de todos:2863.6577816346703 - count:19
# Meteoro! Melhor de todos:2863.6577816346703 - count:22
# Meteoro! Melhor de todos:2863.613413653623 - count:35
# Meteoro! Melhor de todos:2863.613413653623 - count:21
# Meteoro! Melhor de todos:2863.6133520702733 - count:29
# Meteoro! Melhor de todos:2863.6133520702733 - count:15
# Meteoro! Melhor de todos:2863.6133520702733 - count:13
# Meteoro! Melhor de todos:2863.6130229029254 - count:30
# Meteoro! Melhor de todos:2863.6130229029254 - count:17
# Meteoro! Melhor de todos:2863.6130229029254 - count:6
# Meteoro! Melhor de todos:2863.6130229029254 - count:27
# Meteoro! Melhor de todos:2863.6130229029254 - count:23
# Meteoro! Melhor de todos:2863.6130229029254 - count:8
# Meteoro! Melhor de todos:2863.583016985286 - count:32
# Meteoro! Melhor de todos:2863.51361947283 - count:24
# Meteoro! Melhor de todos:2863.51361947283 - count:17
# Meteoro! Melhor de todos:2863.51361947283 - count:11
# Meteoro! Melhor de todos:2863.3030377829677 - count:28
# Meteoro! Melhor de todos:2863.3030377829677 - count:14
# Meteoro! Melhor de todos:2863.3030377829677 - count:24
# Meteoro! Melhor de todos:2863.3030377829677 - count:20
# Meteoro! Melhor de todos:2863.3030377829677 - count:14
# Meteoro! Melhor de todos:2863.284827163877 - count:33
# Meteoro! Melhor de todos:2863.284827163877 - count:16
# Meteoro! Melhor de todos:2863.284827163877 - count:25
# Meteoro! Melhor de todos:2863.284827163877 - count:7
# Meteoro! Melhor de todos:2863.284827163877 - count:12
# Meteoro! Melhor de todos:2863.073745344429 - count:19
# Meteoro! Melhor de todos:2863.073745344429 - count:18
# Meteoro! Melhor de todos:2863.073745344429 - count:16
# Meteoro! Melhor de todos:2863.073745344429 - count:20
# Meteoro! Melhor de todos:2863.073745344429 - count:20
# Meteoro! Melhor de todos:2863.073745344429 - count:21
# Meteoro! Melhor de todos:2863.073745344429 - count:21
# Meteoro! Melhor de todos:2863.073745344429 - count:17
# Meteoro! Melhor de todos:2863.073745344429 - count:16
# Meteoro! Melhor de todos:2863.073745344429 - count:17
# Meteoro! Melhor de todos:2863.073745344429 - count:35
# Meteoro! Melhor de todos:2862.9547293971245 - count:65
# Meteoro! Melhor de todos:2862.9547293971245 - count:9
# Meteoro! Melhor de todos:2862.9547293971245 - count:18
# Meteoro! Melhor de todos:2862.9547293971245 - count:15
# Meteoro! Melhor de todos:2862.944021022823 - count:25
# Meteoro! Melhor de todos:2862.944021022823 - count:15
# Meteoro! Melhor de todos:2862.8224653968355 - count:44
# Meteoro! Melhor de todos:2862.821730218479 - count:79
# Meteoro! Melhor de todos:2862.821730218479 - count:18
# Meteoro! Melhor de todos:2862.821730218479 - count:17
# Meteoro! Melhor de todos:2862.821730218479 - count:28
# Meteoro! Melhor de todos:2862.821730218479 - count:10
# Meteoro! Melhor de todos:2862.821730218479 - count:8
# Meteoro! Melhor de todos:2862.821730218479 - count:14
# Meteoro! Melhor de todos:2862.818644766814 - count:62
# Meteoro! Melhor de todos:2862.818644766814 - count:12
# Meteoro! Melhor de todos:2862.818644766814 - count:23
# Meteoro! Melhor de todos:2862.818644766814 - count:21
# Meteoro! Melhor de todos:2862.818644766814 - count:16
# Meteoro! Melhor de todos:2862.818644766814 - count:6
# Meteoro! Melhor de todos:2862.818644766814 - count:25
# Meteoro! Melhor de todos:2862.818644766814 - count:35
# Meteoro! Melhor de todos:2862.818644766814 - count:22
# Meteoro! Melhor de todos:2862.818644766814 - count:7
# Meteoro! Melhor de todos:2862.818644766814 - count:20
# Meteoro! Melhor de todos:2862.818644766814 - count:19
# Meteoro! Melhor de todos:2862.818644766814 - count:10
# Meteoro! Melhor de todos:2862.818644766814 - count:16
# Meteoro! Melhor de todos:2862.818644766814 - count:27
# Meteoro! Melhor de todos:2862.818644766814 - count:25
# Meteoro! Melhor de todos:2862.818644766814 - count:11
# Meteoro! Melhor de todos:2862.818644766814 - count:19
# Meteoro! Melhor de todos:2862.818644766814 - count:12
# Meteoro! Melhor de todos:2862.818644766814 - count:8
# Meteoro! Melhor de todos:2862.818644766814 - count:18
# Meteoro! Melhor de todos:2862.818644766814 - count:8
# Meteoro! Melhor de todos:2862.818644766814 - count:24
# Meteoro! Melhor de todos:2862.818644766814 - count:25
# Meteoro! Melhor de todos:2862.818644766814 - count:13
# Meteoro! Melhor de todos:2862.818644766814 - count:20
# Meteoro! Melhor de todos:2862.818644766814 - count:21
# Meteoro! Melhor de todos:2861.702690847991 - count:31
# Meteoro! Melhor de todos:2861.702690847991 - count:27
# Meteoro! Melhor de todos:2861.702690847991 - count:35
# Meteoro! Melhor de todos:2861.702690847991 - count:11
# Meteoro! Melhor de todos:2861.702690847991 - count:20
# Meteoro! Melhor de todos:2861.655573445827 - count:20
# Meteoro! Melhor de todos:2861.655573445827 - count:17
# Meteoro! Melhor de todos:2861.655573445827 - count:27
# Meteoro! Melhor de todos:2861.655573445827 - count:25
# Meteoro! Melhor de todos:2861.655573445827 - count:13
# Meteoro! Melhor de todos:2861.641046113232 - count:49
# Meteoro! Melhor de todos:2861.641046113232 - count:25
# Meteoro! Melhor de todos:2861.641046113232 - count:23
# Meteoro! Melhor de todos:2861.641046113232 - count:27
# Meteoro! Melhor de todos:2861.641046113232 - count:14
# Meteoro! Melhor de todos:2861.641046113232 - count:19
# Meteoro! Melhor de todos:2861.641046113232 - count:17
# Meteoro! Melhor de todos:2861.641046113232 - count:23
# Meteoro! Melhor de todos:2861.641046113232 - count:31
# Meteoro! Melhor de todos:2861.641046113232 - count:8
# Meteoro! Melhor de todos:2861.641046113232 - count:15
# Meteoro! Melhor de todos:2861.641046113232 - count:15
# Meteoro! Melhor de todos:2861.641046113232 - count:16
# Meteoro! Melhor de todos:2861.641046113232 - count:11
# Meteoro! Melhor de todos:2861.641046113232 - count:9
# Meteoro! Melhor de todos:2861.641046113232 - count:10
# Meteoro! Melhor de todos:2861.641046113232 - count:11
# Meteoro! Melhor de todos:2861.641046113232 - count:17
# Meteoro! Melhor de todos:2861.641046113232 - count:12
# Meteoro! Melhor de todos:2861.641046113232 - count:19
# Meteoro! Melhor de todos:2861.641046113232 - count:14
# Meteoro! Melhor de todos:2861.641046113232 - count:20
# Meteoro! Melhor de todos:2861.641046113232 - count:22
# Meteoro! Melhor de todos:2861.641046113232 - count:20
# Meteoro! Melhor de todos:2861.641046113232 - count:20
# Meteoro! Melhor de todos:2861.6409410607157 - count:47
# Meteoro! Melhor de todos:2861.6409410607157 - count:21
# Meteoro! Melhor de todos:2861.640143792411 - count:35
# Meteoro! Melhor de todos:2861.640143792411 - count:27
# Meteoro! Melhor de todos:2861.640143792411 - count:18
# Meteoro! Melhor de todos:2861.640143792411 - count:17
# Meteoro! Melhor de todos:2861.640143792411 - count:16
# Meteoro! Melhor de todos:2861.640143792411 - count:26
# Meteoro! Melhor de todos:2861.640143792411 - count:27
# Meteoro! Melhor de todos:2861.640143792411 - count:16
# Meteoro! Melhor de todos:2861.639765842402 - count:22
# Meteoro! Melhor de todos:2861.639765842402 - count:29
# Meteoro! Melhor de todos:2861.639765842402 - count:22
# Meteoro! Melhor de todos:2861.639765842402 - count:34
# Meteoro! Melhor de todos:2861.639765842402 - count:26
# Meteoro! Melhor de todos:2861.639765842402 - count:29
# Meteoro! Melhor de todos:2861.639765842402 - count:16
# Meteoro! Melhor de todos:2861.639765842402 - count:31
# Meteoro! Melhor de todos:2861.639765842402 - count:26
# Meteoro! Melhor de todos:2861.639765842402 - count:21
# Meteoro! Melhor de todos:2861.639765842402 - count:12
# Meteoro! Melhor de todos:2861.639765842402 - count:13
# Meteoro! Melhor de todos:2861.639765842402 - count:22
# Meteoro! Melhor de todos:2861.639765842402 - count:20
# Meteoro! Melhor de todos:2861.639765842402 - count:17
# Meteoro! Melhor de todos:2861.639765842402 - count:11
# Meteoro! Melhor de todos:2861.639765842402 - count:26
# Meteoro! Melhor de todos:2852.245265702296 - count:33
# Meteoro! Melhor de todos:2852.245265702296 - count:19
# Meteoro! Melhor de todos:2852.222793547051 - count:42
# Meteoro! Melhor de todos:2852.222793547051 - count:20
# Meteoro! Melhor de todos:2850.9967599086767 - count:23
# Meteoro! Melhor de todos:2850.9746253059707 - count:22
# Meteoro! Melhor de todos:2850.894485681994 - count:65
# Meteoro! Melhor de todos:2850.861510656743 - count:30
# Meteoro! Melhor de todos:2850.861510656743 - count:6
# Meteoro! Melhor de todos:2850.6384538244297 - count:52
# Meteoro! Melhor de todos:2850.6384538244297 - count:17
# Meteoro! Melhor de todos:2850.5850246040136 - count:43
# Meteoro! Melhor de todos:2850.5673171676553 - count:27
# Meteoro! Melhor de todos:2850.5673171676553 - count:23
# Meteoro! Melhor de todos:2850.5673171676553 - count:19
# Meteoro! Melhor de todos:2850.5673171676553 - count:19
# Meteoro! Melhor de todos:2850.5673171676553 - count:31
# Meteoro! Melhor de todos:2850.5673171676553 - count:31
# Meteoro! Melhor de todos:2850.5673171676553 - count:22
# Meteoro! Melhor de todos:2850.5673171676553 - count:33
# Meteoro! Melhor de todos:2850.5673171676553 - count:22
# Meteoro! Melhor de todos:2850.5673171676553 - count:22
# Meteoro! Melhor de todos:2850.5673171676553 - count:13
# Meteoro! Melhor de todos:2850.5673171676553 - count:20
# Meteoro! Melhor de todos:2850.5673171676553 - count:17
# Meteoro! Melhor de todos:2850.5673171676553 - count:11
# Meteoro! Melhor de todos:2850.5673171676553 - count:19
# Meteoro! Melhor de todos:2735.121435917782 - count:16
# Meteoro! Melhor de todos:2735.121435917782 - count:11
# Meteoro! Melhor de todos:2729.4559604596084 - count:40
# Meteoro! Melhor de todos:2555.7435976230317 - count:73
# Meteoro! Melhor de todos:2555.7435976230317 - count:28
# Meteoro! Melhor de todos:2555.7435976230317 - count:31
# Meteoro! Melhor de todos:2555.7435976230317 - count:7
# Meteoro! Melhor de todos:2555.7435976230317 - count:8
# Meteoro! Melhor de todos:2555.7435976230317 - count:15
# Meteoro! Melhor de todos:2555.7435976230317 - count:12
# Meteoro! Melhor de todos:2555.7435976230317 - count:27
# Meteoro! Melhor de todos:2555.7435976230317 - count:20
# Meteoro! Melhor de todos:2555.7435976230317 - count:18
# Meteoro! Melhor de todos:2555.6803069069515 - count:38
# Meteoro! Melhor de todos:2555.6803069069515 - count:23
# Meteoro! Melhor de todos:2555.366921222947 - count:79
# Meteoro! Melhor de todos:2555.366921222947 - count:19
# Meteoro! Melhor de todos:2555.366921222947 - count:19
# Meteoro! Melhor de todos:2555.366921222947 - count:26
# Meteoro! Melhor de todos:2555.366921222947 - count:11
# Meteoro! Melhor de todos:2555.366921222947 - count:19
# Meteoro! Melhor de todos:2555.3615276255705 - count:35
# Meteoro! Melhor de todos:2555.3615276255705 - count:27
# Meteoro! Melhor de todos:2555.3615276255705 - count:17
# Meteoro! Melhor de todos:2555.3615276255705 - count:12
# Meteoro! Melhor de todos:2555.3615276255705 - count:7
# Meteoro! Melhor de todos:2555.3615276255705 - count:18
# Meteoro! Melhor de todos:2555.3615276255705 - count:27
# Meteoro! Melhor de todos:2555.3615276255705 - count:12
# Meteoro! Melhor de todos:2555.3615276255705 - count:15
# Meteoro! Melhor de todos:2555.3615276255705 - count:24
# Meteoro! Melhor de todos:2555.3615276255705 - count:14
# Meteoro! Melhor de todos:2555.3615276255705 - count:22
# Meteoro! Melhor de todos:2555.3615276255705 - count:31
# Meteoro! Melhor de todos:2555.3615276255705 - count:13
# Meteoro! Melhor de todos:2555.3615276255705 - count:25
# Meteoro! Melhor de todos:2555.3615276255705 - count:26
# Meteoro! Melhor de todos:2555.3615276255705 - count:9
# Meteoro! Melhor de todos:2555.3615276255705 - count:19
# Meteoro! Melhor de todos:2555.3615276255705 - count:20
# Meteoro! Melhor de todos:2555.3615276255705 - count:23
# Meteoro! Melhor de todos:2555.3615276255705 - count:22
# Meteoro! Melhor de todos:2555.3615276255705 - count:8
# Meteoro! Melhor de todos:2555.3615276255705 - count:7
# Meteoro! Melhor de todos:2555.3615276255705 - count:15
# Meteoro! Melhor de todos:2555.3615276255705 - count:12
# Meteoro! Melhor de todos:2555.3615276255705 - count:18
# Meteoro! Melhor de todos:2555.3283123337806 - count:29
# Meteoro! Melhor de todos:2555.3283123337806 - count:14
# Meteoro! Melhor de todos:2555.3283123337806 - count:11
# Meteoro! Melhor de todos:2555.321040570332 - count:71
# Meteoro! Melhor de todos:2555.321040570332 - count:22
# Meteoro! Melhor de todos:2555.321040570332 - count:25
# Meteoro! Melhor de todos:2555.321040570332 - count:19
# Meteoro! Melhor de todos:2555.321040570332 - count:15
# Meteoro! Melhor de todos:2555.321040570332 - count:17
# Meteoro! Melhor de todos:2555.321040570332 - count:19
# Meteoro! Melhor de todos:2555.321040570332 - count:18
# Meteoro! Melhor de todos:2555.321040570332 - count:23
# Meteoro! Melhor de todos:2555.321040570332 - count:18
# Meteoro! Melhor de todos:2555.321040570332 - count:22
# Meteoro! Melhor de todos:2555.321040570332 - count:26
# Meteoro! Melhor de todos:2555.321040570332 - count:6
# Meteoro! Melhor de todos:2555.321040570332 - count:28
# Meteoro! Melhor de todos:2555.321040570332 - count:26
# Meteoro! Melhor de todos:2555.321040570332 - count:25
# Meteoro! Melhor de todos:2555.321040570332 - count:41
# Meteoro! Melhor de todos:2555.321040570332 - count:10
# Meteoro! Melhor de todos:2555.321040570332 - count:24
# Meteoro! Melhor de todos:2555.321040570332 - count:11
# Meteoro! Melhor de todos:2555.321040570332 - count:23
# Meteoro! Melhor de todos:2555.321040570332 - count:17
# Meteoro! Melhor de todos:2555.321040570332 - count:7
# Meteoro! Melhor de todos:2555.321040570332 - count:22
# Meteoro! Melhor de todos:2555.321040570332 - count:33
# Meteoro! Melhor de todos:2555.321040570332 - count:7
# Meteoro! Melhor de todos:2555.321040570332 - count:22
# Meteoro! Melhor de todos:2555.321040570332 - count:27
# Meteoro! Melhor de todos:2555.3191872324314 - count:31
# Meteoro! Melhor de todos:2555.3191872324314 - count:32
# Meteoro! Melhor de todos:2555.3191872324314 - count:17
# Meteoro! Melhor de todos:2555.3191872324314 - count:16
# Meteoro! Melhor de todos:2555.3191872324314 - count:19
# Meteoro! Melhor de todos:2555.3191872324314 - count:12
# Meteoro! Melhor de todos:2555.3191872324314 - count:19
# Meteoro! Melhor de todos:2555.3191872324314 - count:16
# Meteoro! Melhor de todos:2555.3191872324314 - count:14
# Meteoro! Melhor de todos:2555.3191872324314 - count:28
# Meteoro! Melhor de todos:2555.3191872324314 - count:20
# Meteoro! Melhor de todos:2555.3191872324314 - count:15
# Meteoro! Melhor de todos:2555.3191872324314 - count:10
# Meteoro! Melhor de todos:2555.3191872324314 - count:11
# Meteoro! Melhor de todos:2555.3191872324314 - count:13
# Meteoro! Melhor de todos:2555.3191872324314 - count:13
# Meteoro! Melhor de todos:2555.3191872324314 - count:11
# Meteoro! Melhor de todos:2555.3191872324314 - count:27
# Meteoro! Melhor de todos:2555.3191872324314 - count:15
# Meteoro! Melhor de todos:2555.3191872324314 - count:11
# Meteoro! Melhor de todos:2555.3191872324314 - count:16
# Meteoro! Melhor de todos:2555.3191872324314 - count:46
# Meteoro! Melhor de todos:2555.3191872324314 - count:19
# Meteoro! Melhor de todos:2555.3191872324314 - count:17
# Meteoro! Melhor de todos:2555.3191872324314 - count:15
# Meteoro! Melhor de todos:2555.3191872324314 - count:20
# Meteoro! Melhor de todos:2555.3191872324314 - count:23
# Meteoro! Melhor de todos:2555.3191872324314 - count:24
# Meteoro! Melhor de todos:2555.3191872324314 - count:20
# Meteoro! Melhor de todos:2555.3191872324314 - count:28
# Meteoro! Melhor de todos:2555.3191872324314 - count:17
# Meteoro! Melhor de todos:2555.3191872324314 - count:31
# Meteoro! Melhor de todos:2554.355960580131 - count:12
# Meteoro! Melhor de todos:2554.355960580131 - count:13
# Meteoro! Melhor de todos:2554.2484309855545 - count:19
# Meteoro! Melhor de todos:2553.2534261269084 - count:31
# Meteoro! Melhor de todos:2553.2534261269084 - count:21
# Meteoro! Melhor de todos:2552.9950110073646 - count:19
# Meteoro! Melhor de todos:2552.9950110073646 - count:17
# Meteoro! Melhor de todos:2552.9950110073646 - count:24
# Meteoro! Melhor de todos:2552.7048362625105 - count:41
# Meteoro! Melhor de todos:2552.338731183596 - count:15
# Meteoro! Melhor de todos:2552.338731183596 - count:28
# Meteoro! Melhor de todos:2552.338731183596 - count:10
# Meteoro! Melhor de todos:2552.338731183596 - count:13
# Meteoro! Melhor de todos:2552.307915960033 - count:33
# Meteoro! Melhor de todos:2552.307915960033 - count:18
# Meteoro! Melhor de todos:2552.307915960033 - count:24
# Meteoro! Melhor de todos:2549.5060392905216 - count:123
# Meteoro! Melhor de todos:2549.5060392905216 - count:24
# Meteoro! Melhor de todos:2549.5060392905216 - count:15
# Meteoro! Melhor de todos:2549.5060392905216 - count:11
# Meteoro! Melhor de todos:2549.5060392905216 - count:13
# Meteoro! Melhor de todos:2549.505824221573 - count:24
# Meteoro! Melhor de todos:2549.505824221573 - count:17
# Meteoro! Melhor de todos:2549.505824221573 - count:18
# Meteoro! Melhor de todos:2549.505824221573 - count:17
# Meteoro! Melhor de todos:2549.505824221573 - count:24
# Meteoro! Melhor de todos:2548.815185658962 - count:44
# Meteoro! Melhor de todos:2548.815185658962 - count:26
# Meteoro! Melhor de todos:2548.7128977646953 - count:24
# Meteoro! Melhor de todos:2548.7128977646953 - count:24
# Meteoro! Melhor de todos:2548.7128977646953 - count:20
# Meteoro! Melhor de todos:2548.7128977646953 - count:29
# Meteoro! Melhor de todos:2548.7128977646953 - count:20
# Meteoro! Melhor de todos:2548.7128977646953 - count:20
# Meteoro! Melhor de todos:2548.7128977646953 - count:16
# Meteoro! Melhor de todos:2548.7128977646953 - count:4
# Meteoro! Melhor de todos:2548.7128977646953 - count:16
# Meteoro! Melhor de todos:2548.7128977646953 - count:14
# Meteoro! Melhor de todos:2548.7128977646953 - count:21
# Meteoro! Melhor de todos:2548.7128977646953 - count:29
# Meteoro! Melhor de todos:2548.7128977646953 - count:12
# Meteoro! Melhor de todos:2548.65261150422 - count:96
# Meteoro! Melhor de todos:2546.2064602945347 - count:28
# Meteoro! Melhor de todos:2546.2064602945347 - count:19
# Meteoro! Melhor de todos:2546.2064602945347 - count:10
# Meteoro! Melhor de todos:2546.2064602945347 - count:10
# Meteoro! Melhor de todos:2546.2064602945347 - count:18
# Meteoro! Melhor de todos:2545.7158847978326 - count:37
# Meteoro! Melhor de todos:2522.968013382255 - count:65
# Meteoro! Melhor de todos:2522.968013382255 - count:21
# Meteoro! Melhor de todos:2522.968013382255 - count:17
# Meteoro! Melhor de todos:2520.903848104723 - count:103
# Meteoro! Melhor de todos:2520.903848104723 - count:33
# Meteoro! Melhor de todos:2520.903848104723 - count:22
# Meteoro! Melhor de todos:2520.903848104723 - count:17
# Meteoro! Melhor de todos:2520.8290524697404 - count:25
# Meteoro! Melhor de todos:2520.8290524697404 - count:9
# Meteoro! Melhor de todos:2520.8290524697404 - count:19
# Meteoro! Melhor de todos:2520.8290524697404 - count:14
# Meteoro! Melhor de todos:2520.8290524697404 - count:19
# Meteoro! Melhor de todos:2520.8290524697404 - count:30
# Meteoro! Melhor de todos:2520.8290524697404 - count:16
# Meteoro! Melhor de todos:2520.8290524697404 - count:25
# Meteoro! Melhor de todos:2520.8290524697404 - count:18
# Meteoro! Melhor de todos:2520.8290524697404 - count:15
# Meteoro! Melhor de todos:2520.8127098676714 - count:25
# Meteoro! Melhor de todos:2520.8127098676714 - count:25
# Meteoro! Melhor de todos:2520.8127098676714 - count:12
# Meteoro! Melhor de todos:2520.8127098676714 - count:11
# Meteoro! Melhor de todos:2520.8127098676714 - count:24
# Meteoro! Melhor de todos:2520.8127098676714 - count:13
# Meteoro! Melhor de todos:2520.8127098676714 - count:22
# Meteoro! Melhor de todos:2520.8127098676714 - count:19
# Meteoro! Melhor de todos:2520.7616425258984 - count:43
# Meteoro! Melhor de todos:2520.7616425258984 - count:26
# Meteoro! Melhor de todos:2520.7616425258984 - count:19
# Meteoro! Melhor de todos:2520.7346876909037 - count:71
# Meteoro! Melhor de todos:2520.685506275092 - count:89
# Meteoro! Melhor de todos:2520.685506275092 - count:28
# Meteoro! Melhor de todos:2520.673298059144 - count:26
# Meteoro! Melhor de todos:2520.673298059144 - count:23
# Meteoro! Melhor de todos:2520.4479025399896 - count:34
# Meteoro! Melhor de todos:2517.1398993405983 - count:78
# Meteoro! Melhor de todos:2517.1398993405983 - count:14
# Meteoro! Melhor de todos:2517.1398993405983 - count:17
# Meteoro! Melhor de todos:2517.1398993405983 - count:14
# Meteoro! Melhor de todos:2517.1398993405983 - count:27
# Meteoro! Melhor de todos:2517.1398993405983 - count:21
# Meteoro! Melhor de todos:2517.0975793603493 - count:50
# Meteoro! Melhor de todos:2517.0975793603493 - count:9
# Meteoro! Melhor de todos:2517.004008653641 - count:31
# Meteoro! Melhor de todos:2517.004008653641 - count:18
# Meteoro! Melhor de todos:2517.004008653641 - count:15
# Meteoro! Melhor de todos:2517.004008653641 - count:19
# Meteoro! Melhor de todos:2517.004008653641 - count:22
# Meteoro! Melhor de todos:2517.004008653641 - count:10
# Meteoro! Melhor de todos:2517.004008653641 - count:19
# Meteoro! Melhor de todos:2516.933958043891 - count:47
# Meteoro! Melhor de todos:2516.933958043891 - count:18
# Meteoro! Melhor de todos:2511.6901776775835 - count:32
# Meteoro! Melhor de todos:2511.6901776775835 - count:11
# Meteoro! Melhor de todos:2511.6901776775835 - count:18
# Meteoro! Melhor de todos:2511.6901776775835 - count:16
# Meteoro! Melhor de todos:2511.6901776775835 - count:17
# Meteoro! Melhor de todos:2511.6901776775835 - count:9
# Meteoro! Melhor de todos:2511.6901776775835 - count:24
# Meteoro! Melhor de todos:2414.7118783429764 - count:73
# Meteoro! Melhor de todos:2414.7118783429764 - count:25
# Meteoro! Melhor de todos:2414.7118783429764 - count:5
# Meteoro! Melhor de todos:2414.626880709291 - count:40
# Meteoro! Melhor de todos:2414.55483979371 - count:27
# Meteoro! Melhor de todos:2414.55483979371 - count:24
# Meteoro! Melhor de todos:2414.1458971082584 - count:73
# Meteoro! Melhor de todos:2414.1458971082584 - count:20
# Meteoro! Melhor de todos:2414.1458971082584 - count:23
# Meteoro! Melhor de todos:2414.1458971082584 - count:23
# Meteoro! Melhor de todos:2414.1458971082584 - count:14
# Meteoro! Melhor de todos:2414.1458971082584 - count:17
# Meteoro! Melhor de todos:2414.1062187793077 - count:35
# Meteoro! Melhor de todos:2414.1062187793077 - count:22
# Meteoro! Melhor de todos:2414.1062187793077 - count:14
# Meteoro! Melhor de todos:2412.404009561635 - count:66
# Meteoro! Melhor de todos:2412.404009561635 - count:20
# Meteoro! Melhor de todos:2412.404009561635 - count:14
# Meteoro! Melhor de todos:2412.1907462877507 - count:37
# Meteoro! Melhor de todos:2412.1907462877507 - count:12
# Meteoro! Melhor de todos:2412.1907462877507 - count:30
# Meteoro! Melhor de todos:2412.190371949475 - count:25
# Meteoro! Melhor de todos:2412.177794546632 - count:26
# Meteoro! Melhor de todos:2412.177794546632 - count:17
# Meteoro! Melhor de todos:2412.177794546632 - count:10
# Meteoro! Melhor de todos:2412.177794546632 - count:25
# Meteoro! Melhor de todos:2412.177794546632 - count:15
# Meteoro! Melhor de todos:2412.176722086344 - count:19
# Meteoro! Melhor de todos:2412.054864298747 - count:18
# Meteoro! Melhor de todos:2412.054864298747 - count:19
# Meteoro! Melhor de todos:2412.054864298747 - count:25
# Meteoro! Melhor de todos:2412.054864298747 - count:19
# ------------------------------
# Gene(a=0.9017931454865152, e=-0.014776898182830445)
# Gene(a=0.7903658898379099, e=0.05516689629552291)
# Gene(a=0.7258500972268137, e=0.011383317796752843)
# Gene(a=0.572114448653114, e=0.03651606876745474)
# Gene(a=0.35333396992165966, e=0.14146247225170266)
# Gene(a=0.39370446236746776, e=-0.02081198334265958)
# Gene(a=0.2796500603528027, e=-0.09341962360862953)
# Gene(a=0.21406291157845078, e=-0.09595948352951506)
# Gene(a=0.24588397859580435, e=-0.5103614810886337)
# Gene(a=0.048671262704471537, e=6.251573561065665e-06)
# ------------------------------
# GeneDecoded(x=10.0, y=10.0, v=0, al=0)
# GeneDecoded(x=10.450896572743257, y=10.0, v=0.9017931454865152, al=-0.014776898182830445)
# GeneDecoded(x=11.747731064002902, y=9.980835413836976, v=1.6916227188643298, al=0.04038999811269246)
# GeneDecoded(x=13.800603214041805, y=10.063796033665959, v=2.415585631922558, al=0.051773315909445304)
# GeneDecoded(x=16.49862603427476, y=10.203606563398436, v=2.98385192925249, al=0.08828938467690003)
# GeneDecoded(x=19.646834801210208, y=10.482284454324406, v=3.3313142269742912, al=0.2297518569286027)
# GeneDecoded(x=23.082291403794876, y=11.285774646068369, v=3.7176999131713253, al=0.20893987358594313)
# GeneDecoded(x=26.855920421770016, y=12.085913835988382, v=3.9882349891422257, al=0.1155202499773136)
# GeneDecoded(x=30.923891723035705, y=12.557948524396148, v=4.191808063599515, al=0.01956076644779854)
# GeneDecoded(x=35.2378163396882, y=12.642342960337654, v=4.426104000644029, al=-0.49080071464083513)
# GeneDecoded(x=39.16290711313318, y=10.544707306021072, v=4.461855620890878, al=-0.4907944630672741)
# Meteoro! Melhor de todos:8165.326409951456 - count:95
# Meteoro! Melhor de todos:4345.019772174591 - count:156
# Meteoro! Melhor de todos:4331.089605061828 - count:111
# Meteoro! Melhor de todos:4331.089605061828 - count:18
# Meteoro! Melhor de todos:4331.089605061828 - count:19
# Meteoro! Melhor de todos:4331.089605061828 - count:17
# Meteoro! Melhor de todos:4331.089605061828 - count:18
# Meteoro! Melhor de todos:4331.089605061828 - count:12
# Meteoro! Melhor de todos:4331.089605061828 - count:21
# Meteoro! Melhor de todos:4004.435029073265 - count:148
# Meteoro! Melhor de todos:3953.2985479180093 - count:124
# Meteoro! Melhor de todos:3951.8557559817555 - count:39
# Meteoro! Melhor de todos:3951.8557559817555 - count:8
# Meteoro! Melhor de todos:3914.2404505090167 - count:52
# Meteoro! Melhor de todos:3914.2404505090167 - count:27
# Meteoro! Melhor de todos:3911.0124746878737 - count:93
# Meteoro! Melhor de todos:3878.8350389158695 - count:88
# Meteoro! Melhor de todos:3878.8350389158695 - count:17
# Meteoro! Melhor de todos:3864.961915080996 - count:82
# Meteoro! Melhor de todos:3864.961915080996 - count:11
# Meteoro! Melhor de todos:3864.961915080996 - count:19
# Meteoro! Melhor de todos:3771.631686152915 - count:38
# Meteoro! Melhor de todos:3575.4673928430007 - count:30
# Meteoro! Melhor de todos:3544.664706877108 - count:62
# Meteoro! Melhor de todos:3179.088781072302 - count:346
# Meteoro! Melhor de todos:3151.5227250883845 - count:175
# Meteoro! Melhor de todos:3099.6174434833297 - count:101
# Meteoro! Melhor de todos:3099.6174434833297 - count:20
# Meteoro! Melhor de todos:3099.5727684308686 - count:21
# Meteoro! Melhor de todos:3099.5641211078055 - count:46
# Meteoro! Melhor de todos:3099.449645673919 - count:26
# Meteoro! Melhor de todos:3096.5659504295877 - count:15
# Meteoro! Melhor de todos:3094.144019480668 - count:72
# Meteoro! Melhor de todos:3093.700059220613 - count:87
# Meteoro! Melhor de todos:3093.700059220613 - count:24
# Meteoro! Melhor de todos:3093.696705780961 - count:19
# Meteoro! Melhor de todos:3093.4429123784294 - count:37
# Meteoro! Melhor de todos:3093.4429123784294 - count:15
# Meteoro! Melhor de todos:3093.4429123784294 - count:16
# Meteoro! Melhor de todos:3062.1605211026763 - count:103
# Meteoro! Melhor de todos:3061.816954816082 - count:121
# Meteoro! Melhor de todos:3061.816954816082 - count:17
# Meteoro! Melhor de todos:3058.630396659506 - count:147
# Meteoro! Melhor de todos:3058.630396659506 - count:5
# Meteoro! Melhor de todos:3058.630396659506 - count:20
# Meteoro! Melhor de todos:3058.630396659506 - count:26
# Meteoro! Melhor de todos:3058.630396659506 - count:19
# Meteoro! Melhor de todos:3058.630396659506 - count:21
# Meteoro! Melhor de todos:3058.630396659506 - count:20
# Meteoro! Melhor de todos:3040.8238184529264 - count:114
# Meteoro! Melhor de todos:3040.6784722679095 - count:89
# Meteoro! Melhor de todos:3040.6784722679095 - count:18
# Meteoro! Melhor de todos:3039.102314071131 - count:84
# Meteoro! Melhor de todos:2965.65458074928 - count:121
# Meteoro! Melhor de todos:2963.8273589143105 - count:56
# Meteoro! Melhor de todos:2963.8273589143105 - count:22
# Meteoro! Melhor de todos:2963.8273589143105 - count:8
# Meteoro! Melhor de todos:2963.4330546825317 - count:16
# Meteoro! Melhor de todos:2963.4330546825317 - count:21
# Meteoro! Melhor de todos:2963.332546971348 - count:47
# Meteoro! Melhor de todos:2960.096048353962 - count:77
# Meteoro! Melhor de todos:2960.096048353962 - count:9
# Meteoro! Melhor de todos:2956.680683879944 - count:42
# Meteoro! Melhor de todos:2956.650818244444 - count:34
# Meteoro! Melhor de todos:2956.650818244444 - count:13
# Meteoro! Melhor de todos:2956.650818244444 - count:8
# Meteoro! Melhor de todos:2956.650818244444 - count:20
# Meteoro! Melhor de todos:2956.650818244444 - count:28
# Meteoro! Melhor de todos:2956.650818244444 - count:12
# Meteoro! Melhor de todos:2956.650818244444 - count:17
# Meteoro! Melhor de todos:2956.650818244444 - count:19
# Meteoro! Melhor de todos:2956.650818244444 - count:16
# Meteoro! Melhor de todos:2956.650818244444 - count:30
# Meteoro! Melhor de todos:2956.650818244444 - count:14
# Meteoro! Melhor de todos:2956.650818244444 - count:30
# Meteoro! Melhor de todos:2956.650818244444 - count:13
# Meteoro! Melhor de todos:2956.650818244444 - count:9
# Meteoro! Melhor de todos:2956.01389807538 - count:22
# Meteoro! Melhor de todos:2943.292246439754 - count:115
# Meteoro! Melhor de todos:2942.5838104843506 - count:124
# Meteoro! Melhor de todos:2942.5838104843506 - count:14
# Meteoro! Melhor de todos:2942.5838104843506 - count:22
# Meteoro! Melhor de todos:2942.5838104843506 - count:22
# Meteoro! Melhor de todos:2942.5838104843506 - count:26
# Meteoro! Melhor de todos:2942.5838104843506 - count:28
# Meteoro! Melhor de todos:2942.5838104843506 - count:12
# Meteoro! Melhor de todos:2940.933488729478 - count:29
# Meteoro! Melhor de todos:2909.9128437891322 - count:121
# Meteoro! Melhor de todos:2909.9128437891322 - count:27
# Meteoro! Melhor de todos:2909.593472103386 - count:66
# Meteoro! Melhor de todos:2909.593472103386 - count:17
# Meteoro! Melhor de todos:2909.593472103386 - count:14
# Meteoro! Melhor de todos:2909.593472103386 - count:20
# Meteoro! Melhor de todos:2908.548907269297 - count:84
# Meteoro! Melhor de todos:2908.548907269297 - count:7
# Meteoro! Melhor de todos:2908.548907269297 - count:17
# Meteoro! Melhor de todos:2908.548907269297 - count:20
# Meteoro! Melhor de todos:2908.548907269297 - count:31
# Meteoro! Melhor de todos:2908.548907269297 - count:20
# Meteoro! Melhor de todos:2908.122789433654 - count:35
# Meteoro! Melhor de todos:2908.122789433654 - count:18
# Meteoro! Melhor de todos:2908.122789433654 - count:17
# Meteoro! Melhor de todos:2908.122789433654 - count:18
# Meteoro! Melhor de todos:2908.122789433654 - count:15
# Meteoro! Melhor de todos:2908.122789433654 - count:31
# Meteoro! Melhor de todos:2908.1227733219284 - count:45
# Meteoro! Melhor de todos:2908.1227733219284 - count:15
# Meteoro! Melhor de todos:2905.6750103290738 - count:28
# Meteoro! Melhor de todos:2905.662334412964 - count:23
# Meteoro! Melhor de todos:2905.662334412964 - count:26
# Meteoro! Melhor de todos:2905.5930827239954 - count:59
# Meteoro! Melhor de todos:2905.5930827239954 - count:16
# Meteoro! Melhor de todos:2905.5930827239954 - count:16
# Meteoro! Melhor de todos:2905.2210490365733 - count:58
# Meteoro! Melhor de todos:2904.8528925709006 - count:40
# Meteoro! Melhor de todos:2904.8528925709006 - count:23
# Meteoro! Melhor de todos:2904.8528925709006 - count:20
# Meteoro! Melhor de todos:2904.8528925709006 - count:15
# Meteoro! Melhor de todos:2904.8528925709006 - count:20
# Meteoro! Melhor de todos:2904.8528925709006 - count:18
# Meteoro! Melhor de todos:2904.8528925709006 - count:14
# Meteoro! Melhor de todos:2904.8528925709006 - count:8
# Meteoro! Melhor de todos:2904.8528925709006 - count:17
# Meteoro! Melhor de todos:2904.8528925709006 - count:14
# Meteoro! Melhor de todos:2904.8528925709006 - count:20
# Meteoro! Melhor de todos:2904.82713855995 - count:26
# Meteoro! Melhor de todos:2904.82713855995 - count:20
# Meteoro! Melhor de todos:2904.82713855995 - count:19
# Meteoro! Melhor de todos:2904.82713855995 - count:23
# Meteoro! Melhor de todos:2904.82713855995 - count:21
# Meteoro! Melhor de todos:2904.82713855995 - count:21
# Meteoro! Melhor de todos:2904.82713855995 - count:8
# Meteoro! Melhor de todos:2904.82713855995 - count:16
# Meteoro! Melhor de todos:2892.2426437845666 - count:70
# Meteoro! Melhor de todos:2892.2426437845666 - count:20
# Meteoro! Melhor de todos:2892.2413616518506 - count:32
# Meteoro! Melhor de todos:2892.2413616518506 - count:24
# Meteoro! Melhor de todos:2892.2413616518506 - count:16
# Meteoro! Melhor de todos:2892.2413616518506 - count:20
# Meteoro! Melhor de todos:2892.2413616518506 - count:10
# Meteoro! Melhor de todos:2892.2413616518506 - count:15
# Meteoro! Melhor de todos:2892.2413616518506 - count:5
# Meteoro! Melhor de todos:2892.2413616518506 - count:24
# Meteoro! Melhor de todos:2892.2413616518506 - count:19
# Meteoro! Melhor de todos:2892.2413616518506 - count:5
# Meteoro! Melhor de todos:2892.2413616518506 - count:21
# Meteoro! Melhor de todos:2892.2413616518506 - count:19
# Meteoro! Melhor de todos:2892.1910657932012 - count:31
# Meteoro! Melhor de todos:2892.1910657932012 - count:15
# Meteoro! Melhor de todos:2892.1910657932012 - count:21
# Meteoro! Melhor de todos:2892.1910657932012 - count:15
# Meteoro! Melhor de todos:2892.1910657932012 - count:27
# Meteoro! Melhor de todos:2892.131428070208 - count:25
# Meteoro! Melhor de todos:2891.9543575197413 - count:34
# Meteoro! Melhor de todos:2874.7015668924464 - count:20
# Meteoro! Melhor de todos:2846.1737819171267 - count:123
# Meteoro! Melhor de todos:2846.1737819171267 - count:15
# Meteoro! Melhor de todos:2845.722113618558 - count:73
# Meteoro! Melhor de todos:2845.722113618558 - count:18
# Meteoro! Melhor de todos:2838.882988259767 - count:136
# Meteoro! Melhor de todos:2838.882988259767 - count:21
# Meteoro! Melhor de todos:2836.713196736808 - count:108
# Meteoro! Melhor de todos:2836.441614378269 - count:20
# Meteoro! Melhor de todos:2836.441614378269 - count:28
# Meteoro! Melhor de todos:2836.441614378269 - count:31
# Meteoro! Melhor de todos:2836.416064114198 - count:27
# Meteoro! Melhor de todos:2836.416064114198 - count:12
# Meteoro! Melhor de todos:2836.416064114198 - count:20
# Meteoro! Melhor de todos:2836.293821787465 - count:36
# Meteoro! Melhor de todos:2836.293821787465 - count:14
# Meteoro! Melhor de todos:2836.293821787465 - count:19
# Meteoro! Melhor de todos:2836.215215140116 - count:43
# Meteoro! Melhor de todos:2836.215215140116 - count:10
# Meteoro! Melhor de todos:2836.215215140116 - count:12
# Meteoro! Melhor de todos:2836.2152151341143 - count:28
# Meteoro! Melhor de todos:2836.214903697672 - count:49
# Meteoro! Melhor de todos:2835.359749113447 - count:24
# Meteoro! Melhor de todos:2835.286895463939 - count:29
# Meteoro! Melhor de todos:2835.2678803952813 - count:21
# Meteoro! Melhor de todos:2835.2678803952813 - count:23
# Meteoro! Melhor de todos:2835.14137646447 - count:26
# Meteoro! Melhor de todos:2835.14137646447 - count:7
# Meteoro! Melhor de todos:2835.14137646447 - count:8
# Meteoro! Melhor de todos:2835.14137646447 - count:12
# Meteoro! Melhor de todos:2834.6194877988933 - count:44
# Meteoro! Melhor de todos:2834.6194877988933 - count:18
# Meteoro! Melhor de todos:2834.580866541207 - count:39
# Meteoro! Melhor de todos:2834.580866541207 - count:20
# Meteoro! Melhor de todos:2834.5668353270257 - count:28
# Meteoro! Melhor de todos:2834.5668353270257 - count:18
# Meteoro! Melhor de todos:2834.5304387477263 - count:76
# Meteoro! Melhor de todos:2834.5304387477263 - count:16
# Meteoro! Melhor de todos:2834.4101268435816 - count:87
# Meteoro! Melhor de todos:2834.4101268435816 - count:25
# Meteoro! Melhor de todos:2834.4101268435816 - count:27
# Meteoro! Melhor de todos:2834.4101268435816 - count:19
# Meteoro! Melhor de todos:2834.4101268435816 - count:15
# Meteoro! Melhor de todos:2834.4101268435816 - count:12
# Meteoro! Melhor de todos:2834.4101268435816 - count:16
# Meteoro! Melhor de todos:2834.4101268435816 - count:18
# Meteoro! Melhor de todos:2834.3629579027765 - count:26
# Meteoro! Melhor de todos:2834.3629579027765 - count:25
# Meteoro! Melhor de todos:2834.3629579027765 - count:19
# Meteoro! Melhor de todos:2834.3629579027765 - count:15
# Meteoro! Melhor de todos:2834.3629579027765 - count:25
# Meteoro! Melhor de todos:2834.3629579027765 - count:15
# Meteoro! Melhor de todos:2834.3629579027765 - count:17
# Meteoro! Melhor de todos:2834.3629579027765 - count:24
# ...
# Meteoro! Melhor de todos:3878.563545349016 - count:27
# Meteoro! Melhor de todos:3878.563545349016 - count:16
# Meteoro! Melhor de todos:3878.3264492579033 - count:36
# Meteoro! Melhor de todos:3878.3264492579033 - count:8
# Meteoro! Melhor de todos:3878.3264492579033 - count:23
# Meteoro! Melhor de todos:3878.3264492579033 - count:10
# Meteoro! Melhor de todos:3877.2394036636524 - count:20
# Meteoro! Melhor de todos:3877.2394036636524 - count:20
# Meteoro! Melhor de todos:3874.0279444548337 - count:31
# Meteoro! Melhor de todos:3874.0279444548337 - count:7
# Meteoro! Melhor de todos:3873.8792966292567 - count:43
# Meteoro! Melhor de todos:3873.376252201711 - count:111
# Meteoro! Melhor de todos:3873.376252201711 - count:14
# Meteoro! Melhor de todos:3873.376252201711 - count:15
# Meteoro! Melhor de todos:3873.376252201711 - count:19
# Meteoro! Melhor de todos:3873.376252201711 - count:11
# Meteoro! Melhor de todos:3873.376252201711 - count:6
# Meteoro! Melhor de todos:3873.376252201711 - count:24
# Meteoro! Melhor de todos:3873.376252201711 - count:11
# Meteoro! Melhor de todos:3873.376252201711 - count:21
# Meteoro! Melhor de todos:3873.376252201711 - count:17
# Meteoro! Melhor de todos:3873.376252201711 - count:7
# Meteoro! Melhor de todos:3873.376252201711 - count:14
# Meteoro! Melhor de todos:3873.376252201711 - count:6
# Meteoro! Melhor de todos:3873.376252201711 - count:21
# Meteoro! Melhor de todos:3873.376252201711 - count:15
# Meteoro! Melhor de todos:3873.376252201711 - count:18
# Meteoro! Melhor de todos:3873.376252201711 - count:18
# Meteoro! Melhor de todos:3873.376252201711 - count:15
# Meteoro! Melhor de todos:3873.376252201711 - count:12
# Meteoro! Melhor de todos:3873.376252201711 - count:27
# Meteoro! Melhor de todos:3873.376252201711 - count:12
# Meteoro! Melhor de todos:3873.376252201711 - count:14
# Meteoro! Melhor de todos:3873.376252201711 - count:9
# Meteoro! Melhor de todos:3873.376252201711 - count:23
# Meteoro! Melhor de todos:3873.376252201711 - count:14
# Meteoro! Melhor de todos:3873.376252201711 - count:17
# Meteoro! Melhor de todos:3873.376252201711 - count:22
# Meteoro! Melhor de todos:3873.376252201711 - count:27
# Meteoro! Melhor de todos:3873.376252201711 - count:13
# Meteoro! Melhor de todos:3873.376252201711 - count:10
# Meteoro! Melhor de todos:3872.804634576044 - count:60
# Meteoro! Melhor de todos:3872.804634576044 - count:18
# Meteoro! Melhor de todos:3872.539202438996 - count:20
# Meteoro! Melhor de todos:3872.539202438996 - count:29
# Meteoro! Melhor de todos:3872.539202438996 - count:26
# Meteoro! Melhor de todos:3872.539202438996 - count:8
# Meteoro! Melhor de todos:3872.539202438996 - count:11
# Meteoro! Melhor de todos:3872.27696240746 - count:49
# Meteoro! Melhor de todos:3872.27696240746 - count:14
# Meteoro! Melhor de todos:3872.230363258776 - count:48
# Meteoro! Melhor de todos:3872.230363258776 - count:9
# Meteoro! Melhor de todos:3871.6958677765147 - count:60
# Meteoro! Melhor de todos:3870.8967495184943 - count:19
# Meteoro! Melhor de todos:3870.8967495184943 - count:13
# Meteoro! Melhor de todos:3870.875375205745 - count:48
# Meteoro! Melhor de todos:3870.875375205745 - count:21
# Meteoro! Melhor de todos:3870.875375205745 - count:17
# Meteoro! Melhor de todos:3870.875375205745 - count:16
# Meteoro! Melhor de todos:3870.875375205745 - count:18
# Meteoro! Melhor de todos:3870.875375205745 - count:26
# Meteoro! Melhor de todos:3870.875375205745 - count:15
# Meteoro! Melhor de todos:3870.875375205745 - count:18
# Meteoro! Melhor de todos:3870.875375205745 - count:19
# Meteoro! Melhor de todos:3870.875375205745 - count:24
# Meteoro! Melhor de todos:3870.875375205745 - count:13
# Meteoro! Melhor de todos:3870.875375205745 - count:16
# Meteoro! Melhor de todos:3870.875375205745 - count:8
# Meteoro! Melhor de todos:3870.875375205745 - count:30
# Meteoro! Melhor de todos:3870.875375205745 - count:18
# Meteoro! Melhor de todos:3870.875375205745 - count:17
# Meteoro! Melhor de todos:3870.875375205745 - count:10
# Meteoro! Melhor de todos:3870.875375205745 - count:15
# Meteoro! Melhor de todos:3870.875375205745 - count:18
# Meteoro! Melhor de todos:3870.875375205745 - count:13
# Meteoro! Melhor de todos:3870.875375205745 - count:22
# Meteoro! Melhor de todos:3870.875375205745 - count:24
# Meteoro! Melhor de todos:3870.875375205745 - count:14
# Meteoro! Melhor de todos:3870.875375205745 - count:12
# Meteoro! Melhor de todos:3870.8730785530756 - count:29
# Meteoro! Melhor de todos:3870.8730785530756 - count:15
# Meteoro! Melhor de todos:3870.8730785530756 - count:16
# Meteoro! Melhor de todos:3870.8730785530756 - count:22
# Meteoro! Melhor de todos:3870.8730785530756 - count:12
# Meteoro! Melhor de todos:3870.8730785530756 - count:18
# Meteoro! Melhor de todos:3870.8730785530756 - count:16
# Meteoro! Melhor de todos:3870.8730785530756 - count:6
# Meteoro! Melhor de todos:3870.8730785530756 - count:13
# Meteoro! Melhor de todos:3870.8730785530756 - count:16
# Meteoro! Melhor de todos:3870.8730785530756 - count:15
# Meteoro! Melhor de todos:3870.8730785530756 - count:24
# Meteoro! Melhor de todos:3870.871707981696 - count:25
# Meteoro! Melhor de todos:3870.871707981696 - count:20
# Meteoro! Melhor de todos:3870.871707981696 - count:15
# Meteoro! Melhor de todos:3870.871707981696 - count:20
# Meteoro! Melhor de todos:3870.871707981696 - count:21
# Meteoro! Melhor de todos:3870.871707981696 - count:14
# Meteoro! Melhor de todos:3870.871707981696 - count:12
# Meteoro! Melhor de todos:3870.871707981696 - count:17
# Meteoro! Melhor de todos:3870.871707981696 - count:21
# Meteoro! Melhor de todos:3870.871707981696 - count:19
# Meteoro! Melhor de todos:3870.871707981696 - count:15
# Meteoro! Melhor de todos:3870.871707981696 - count:28
# Meteoro! Melhor de todos:3870.871707981696 - count:11
# Meteoro! Melhor de todos:3870.871707981696 - count:21
# Meteoro! Melhor de todos:3870.871707981696 - count:15
# Meteoro! Melhor de todos:3870.871707981696 - count:16
# Meteoro! Melhor de todos:3870.871707981696 - count:15
# Meteoro! Melhor de todos:3870.871707981696 - count:18
# Meteoro! Melhor de todos:3870.871707981696 - count:15
# Meteoro! Melhor de todos:3870.871707981696 - count:9
# Meteoro! Melhor de todos:3870.871707981696 - count:12
# Meteoro! Melhor de todos:3870.871707981696 - count:19
# Meteoro! Melhor de todos:3870.871707981696 - count:21
# Meteoro! Melhor de todos:3870.871707981696 - count:21
# Meteoro! Melhor de todos:3870.871707981696 - count:29
# Meteoro! Melhor de todos:3870.871707981696 - count:14
# Meteoro! Melhor de todos:3870.871707981696 - count:17
# Meteoro! Melhor de todos:3870.871707981696 - count:20
# Meteoro! Melhor de todos:3870.871707981696 - count:25
# Meteoro! Melhor de todos:3870.871707981696 - count:10
# Meteoro! Melhor de todos:3870.871707981696 - count:10
# Meteoro! Melhor de todos:3870.871707981696 - count:20
# Meteoro! Melhor de todos:3870.869109160391 - count:18
# Meteoro! Melhor de todos:3870.869109160391 - count:15
# Meteoro! Melhor de todos:3870.869109160391 - count:21
# Meteoro! Melhor de todos:3870.869109160391 - count:29
# Meteoro! Melhor de todos:3870.869109160391 - count:17
# Meteoro! Melhor de todos:3870.869109160391 - count:16
# Meteoro! Melhor de todos:3870.869109160391 - count:18
# Meteoro! Melhor de todos:3870.869109160391 - count:19
# Meteoro! Melhor de todos:3870.869109160391 - count:11
# Meteoro! Melhor de todos:3870.85776840283 - count:18
# Meteoro! Melhor de todos:3870.85776840283 - count:18
# Meteoro! Melhor de todos:3870.85776840283 - count:16
# Meteoro! Melhor de todos:3870.85776840283 - count:23
# Meteoro! Melhor de todos:3870.85776840283 - count:23
# Meteoro! Melhor de todos:3870.85776840283 - count:11
# Meteoro! Melhor de todos:3870.8415868822117 - count:40
# Meteoro! Melhor de todos:3870.8415868822117 - count:13
# Meteoro! Melhor de todos:3870.8415868822117 - count:15
# Meteoro! Melhor de todos:3870.8415868822117 - count:24
# Meteoro! Melhor de todos:3870.8415868822117 - count:8
# Meteoro! Melhor de todos:3870.8415868822117 - count:22
# Meteoro! Melhor de todos:3870.8415868822117 - count:12
# Meteoro! Melhor de todos:3870.8415868822117 - count:19
# Meteoro! Melhor de todos:3870.8415868822117 - count:12
# Meteoro! Melhor de todos:3870.8415868822117 - count:21
# Meteoro! Melhor de todos:3870.8415868822117 - count:16
# Meteoro! Melhor de todos:3870.8415868822117 - count:24
# Meteoro! Melhor de todos:3870.8415868822117 - count:16
# Meteoro! Melhor de todos:3870.8415868822117 - count:22
# Meteoro! Melhor de todos:3870.8415868822117 - count:15
# Meteoro! Melhor de todos:3870.8415868822117 - count:21
# Meteoro! Melhor de todos:3870.8415868822117 - count:27
# Meteoro! Melhor de todos:3870.8415868822117 - count:16
# Meteoro! Melhor de todos:3870.8415868822117 - count:15
# Meteoro! Melhor de todos:3870.8415868822117 - count:21
# Meteoro! Melhor de todos:3870.8415868822117 - count:16
# Meteoro! Melhor de todos:3870.8415868822117 - count:22
# Meteoro! Melhor de todos:3870.8415868822117 - count:20
# Meteoro! Melhor de todos:3870.8415868822117 - count:20
# Meteoro! Melhor de todos:3870.8415868822117 - count:14
# Meteoro! Melhor de todos:3870.8415868822117 - count:17
# Meteoro! Melhor de todos:3870.8415868822117 - count:26
# Meteoro! Melhor de todos:3870.8415868822117 - count:22
# Meteoro! Melhor de todos:3870.8415868822117 - count:20
# Meteoro! Melhor de todos:3870.8415868822117 - count:6
# Meteoro! Melhor de todos:3870.8415868822117 - count:21
# Meteoro! Melhor de todos:3870.8415868822117 - count:20
# Meteoro! Melhor de todos:3870.8415868822117 - count:11
# Meteoro! Melhor de todos:3870.8415868822117 - count:25
# Meteoro! Melhor de todos:3870.8415868822117 - count:24
# Meteoro! Melhor de todos:3870.8415868822117 - count:12
# Meteoro! Melhor de todos:3870.8415868822117 - count:26
# Meteoro! Melhor de todos:3870.8415868822117 - count:18
# Meteoro! Melhor de todos:3870.8415868822117 - count:19
# Meteoro! Melhor de todos:3870.8415868822117 - count:20
# Meteoro! Melhor de todos:3870.8415868822117 - count:18
# Meteoro! Melhor de todos:3870.8415868822117 - count:13
# Meteoro! Melhor de todos:3870.8415868822117 - count:8
# Meteoro! Melhor de todos:3870.8415868822117 - count:5
# Meteoro! Melhor de todos:3870.8415868822117 - count:19
# Meteoro! Melhor de todos:3870.8415868822117 - count:17
# Meteoro! Melhor de todos:3870.8415868822117 - count:23
# Meteoro! Melhor de todos:3870.8415868822117 - count:20
# Meteoro! Melhor de todos:3870.8415868822117 - count:12
# Meteoro! Melhor de todos:3870.8415868822117 - count:12
# Meteoro! Melhor de todos:3870.8415868822117 - count:21
# Meteoro! Melhor de todos:3870.8346166921356 - count:17
# Meteoro! Melhor de todos:3870.8346166921356 - count:22
# Meteoro! Melhor de todos:3870.8346166921356 - count:21
# Meteoro! Melhor de todos:3870.8346166921356 - count:21
# Meteoro! Melhor de todos:3870.8346166921356 - count:18
# Meteoro! Melhor de todos:3870.8346166921356 - count:18
# Meteoro! Melhor de todos:3870.8346166921356 - count:27
# Meteoro! Melhor de todos:3870.834375395484 - count:40
# Meteoro! Melhor de todos:3870.834375395484 - count:17
# Meteoro! Melhor de todos:3870.834375395484 - count:13
# Meteoro! Melhor de todos:3870.834375395484 - count:21
# Meteoro! Melhor de todos:3870.834375395484 - count:16
# Meteoro! Melhor de todos:3870.834375395484 - count:17
# Meteoro! Melhor de todos:3870.834375395484 - count:15
# Meteoro! Melhor de todos:3870.834375395484 - count:15
# Meteoro! Melhor de todos:3870.834375395484 - count:16
# Meteoro! Melhor de todos:3870.834375395484 - count:19
# Meteoro! Melhor de todos:3870.773534527461 - count:27
# Meteoro! Melhor de todos:3870.773534527461 - count:15
# Meteoro! Melhor de todos:3870.773534527461 - count:19
# Meteoro! Melhor de todos:3870.773534527461 - count:5
# Meteoro! Melhor de todos:3870.773534527461 - count:12
# Meteoro! Melhor de todos:3870.773534527461 - count:27
# Meteoro! Melhor de todos:3870.773534527461 - count:17
# Meteoro! Melhor de todos:3870.773534527461 - count:25
# Meteoro! Melhor de todos:3870.764785820813 - count:48
# Meteoro! Melhor de todos:3870.764785820813 - count:11
# Meteoro! Melhor de todos:3870.764572871174 - count:17
# Meteoro! Melhor de todos:3870.764572871174 - count:19
# Meteoro! Melhor de todos:3870.764572871174 - count:16
# Meteoro! Melhor de todos:3870.724793218081 - count:30
# Meteoro! Melhor de todos:3870.724793218081 - count:27
# Meteoro! Melhor de todos:3870.724793218081 - count:13
# Meteoro! Melhor de todos:3870.724793218081 - count:15
# Meteoro! Melhor de todos:3870.724793218081 - count:17
# Meteoro! Melhor de todos:3870.724793218081 - count:10
# Meteoro! Melhor de todos:3870.724793218081 - count:18
# Meteoro! Melhor de todos:3870.724793218081 - count:14
# Meteoro! Melhor de todos:3870.724793218081 - count:18
# Meteoro! Melhor de todos:3870.724793218081 - count:16
# Meteoro! Melhor de todos:3870.724793218081 - count:16
# Meteoro! Melhor de todos:3870.724793218081 - count:17
# Meteoro! Melhor de todos:3870.724793218081 - count:15
# Meteoro! Melhor de todos:3870.724793218081 - count:23
# Meteoro! Melhor de todos:3870.724793218081 - count:27
# Meteoro! Melhor de todos:3870.724793218081 - count:7
# Meteoro! Melhor de todos:3870.724793218081 - count:24
# Meteoro! Melhor de todos:3870.724793218081 - count:16
# Meteoro! Melhor de todos:3870.724793218081 - count:5
# Meteoro! Melhor de todos:3870.724793218081 - count:7
# Meteoro! Melhor de todos:3870.724793218081 - count:26
# Meteoro! Melhor de todos:3870.724793218081 - count:20
# Meteoro! Melhor de todos:3870.724793218081 - count:17
# Meteoro! Melhor de todos:3870.724793218081 - count:10
# Meteoro! Melhor de todos:3870.724793218081 - count:22
# Meteoro! Melhor de todos:3870.724793218081 - count:11
# Meteoro! Melhor de todos:3870.724793218081 - count:20
# Meteoro! Melhor de todos:3870.724793218081 - count:15
# Meteoro! Melhor de todos:3870.724793218081 - count:11
# Meteoro! Melhor de todos:3870.724793218081 - count:23
# Meteoro! Melhor de todos:3870.724793218081 - count:12
# Meteoro! Melhor de todos:3870.724793218081 - count:22
# Meteoro! Melhor de todos:3870.724793218081 - count:12
# Meteoro! Melhor de todos:3870.724793218081 - count:16
# Meteoro! Melhor de todos:3870.724793218081 - count:7
# Meteoro! Melhor de todos:3870.724793218081 - count:17
# Meteoro! Melhor de todos:3870.724793218081 - count:17
# Meteoro! Melhor de todos:3870.724793218081 - count:12
# Meteoro! Melhor de todos:3862.082871191134 - count:49
# Meteoro! Melhor de todos:3862.082871191134 - count:26
# Meteoro! Melhor de todos:3862.082871191134 - count:6
# Meteoro! Melhor de todos:3861.9025314021055 - count:39
# Meteoro! Melhor de todos:3861.0331234379287 - count:42
# Meteoro! Melhor de todos:3860.6276515959325 - count:32
# Meteoro! Melhor de todos:3860.582681859724 - count:18
# Meteoro! Melhor de todos:3860.120635597238 - count:28
# Meteoro! Melhor de todos:3860.120635597238 - count:10
# Meteoro! Melhor de todos:3859.305486820782 - count:42
# Meteoro! Melhor de todos:3859.305486820782 - count:11
# Meteoro! Melhor de todos:3855.646474524077 - count:34
# Meteoro! Melhor de todos:3855.646474524077 - count:19
# Meteoro! Melhor de todos:3854.685537145602 - count:69
# ------------------------------
# Gene(a=-1.233145921128269, e=-2.9999297976936976)
# Gene(a=-1.1197199589008242, e=-0.0898758602201829)
# Gene(a=-1.1116206733548777, e=-0.053813608115024184)
# Gene(a=-0.995272742993215, e=0.1712345837285281)
# Gene(a=-0.7159698262874508, e=0.08839705635993002)
# Gene(a=-0.510502965205084, e=-0.12676205026304205)
# Gene(a=-0.2368621057048072, e=-0.6038781478467886)
# Gene(a=-0.06116116802782396, e=-0.0002687287101267444)
# ------------------------------
# GeneDecoded(x=10.0, y=10.0, v=0, al=0)
# GeneDecoded(x=9.383427039435865, y=10.0, v=-1.233145921128269, al=-2.9999297976936976)
# GeneDecoded(x=11.15847165977516, y=10.253153619990906, v=-2.35386873055772, al=-3.0898056579138804)
# GeneDecoded(x=14.064249875086233, y=10.403769813443196, v=-3.4691434308578755, al=-3.1436192660289044)
# GeneDecoded(x=18.031021531347847, y=10.395730693655521, v=-4.472353089746775, al=-2.972384682300376)
# GeneDecoded(x=22.792374844878164, y=11.209167750779226, v=-5.201513968063956, al=-2.883987625940446)
# GeneDecoded(x=28.06908289743323, y=12.599362453577386, v=-5.729859889264171, al=-3.010749676203488)
# GeneDecoded(x=33.86738418533024, y=13.36238874304236, v=-5.9883738579996555, al=-3.6146278240502765)
# GeneDecoded(x=39.225394811745204, y=10.620211742508083, v=-6.0731846956330715, al=-3.614896552760403)

# %%
pickle.dump(tests, open( "aasave_alpha.p", "wb" ) )

# %%
import pickle
tests = pickle.load(open( "save_alpha.p", "rb" ) )

# %% [markdown]
# ## Import

# %%
test_backup = pickle.load(open( "execution_1.p", "rb" ) )

# %% [markdown]
# ## Visualization

# %%
for i in range(5):
    np_ar = np.array(tests['mapa3']['res'][i])
    plt.plot(np_ar[:,1], np_ar[:,0])

# %%
for i in range(1):
    np_ar = np.array(test_backup['mapa2']['res'][i])
    plt.plot(np_ar[:,1], np_ar[:,0])

# %% [markdown]
# # TODO

# %%
# TODO1: Setar a semente do random para controlar o experimento
# TODO1: Printar o tempo que encontra cada melhor
# TODO1: Ter certeza na conversão de latitutde e longitude <- confiavel   (Veronica)

# %%
Monografia
- até domingo - sobrar somente resultados
- ler os abstracts dos principais artigos
- achar ref pro Ray casting (google scholar: ray casting / ray casting GA / RC path planning) 
      foco pra imagens (citar) 
    rc com ga, mesmo que em outra area
    só ler abstract (os mais novos)
    ate onde nos pudermos pesquisar nessa monografia, nos nao encontramos trabalhos

- durante a semana so sobra os resultados


- retornar no domingo (a noite) ou segunda (noite): apresentar a monografia
    a medida que concluir uma seção, enviar
