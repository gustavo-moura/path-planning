# %% [markdown]
# # Algoritmo Genético Versão Ensamble
#
# Essa versão inclui:
# - Otimização da rota (V1)
# - Otimização da quantidade de waypoints (V2)
# - Risco Inflado: Inflação das áreas não-navegáveis (V3)
# - Alocação de risco (V3.5)

# %% [markdown]
# # 1. Utils
# Essa seção contém funções auxiliares para o algoritmo. Não é necessário mexer nessa parte
# (Feche essa aba)

# %% [markdown]
# ## utils.py

# %%
import itertools
from scipy.stats import norm

# Support Functions
# _________________________________________________________________________________________________
def pairwise_circle(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ... (s<last>,s0)"
    a, b = itertools.tee(iterable)
    first_value = next(b, None)
    return itertools.zip_longest(a, b,fillvalue=first_value)

def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = itertools.tee(iterable)
    next(b, None)
    return zip(a, b)

def boundary(val, val_min, val_max):
  if val<val_min:
    return val_min
  if val>val_max:
    return val_max
  return val

# Ray Casting Algorithm
# _________________________________________________________________________________________________
epsilon = 0.00001  # Used on the Ray-Tracing Algorithm

def point_in_polygon(point, polygon):
    # Using ray_casting algorithm
    # https://rosettacode.org/wiki/Ray-casting_algorithm

    count = 0
    
    for vertex1, vertex2 in pairwise_circle(polygon):

        if vertex1.y < vertex2.y:
            A = vertex1
            B = vertex2
        else:
            A = vertex2
            B = vertex1

        if ray_intersects_segment(point, A, B):
            count += 1

    if count % 2 == 0: # Odd
        return False 
    else:
        return True # Inside the polygon
    

def ray_intersects_segment(P, A, B):
    # P : the point from which the ray starts
    # A : the end-point of the segment with the smallest y coordinate
    #     (A must be "below" B)
    # B : the end-point of the segment with the greatest y coordinate
    #     (B must be "above" A)

    # To avoid the "ray on vertex" problem, the point is moved upward of a small quantity epsilon.
    if P.y == A.y or P.y == B.y:
        P.y += epsilon

    # Point higher or lower than polygon
    if P.y < A.y or P.y > B.y:
        return False

    # Point to the right of the polygon
    elif P.x >= max(A.x, B.x):
        return False 

    else:

        if P.x < min(A.x, B.x):
            return True

        else:

            if A.x != B.x:
                m_red = (B.y - A.y)/(B.x - A.x)
            else:
                m_red = 99999999 # Infinite


            if A.x != P.x:
                m_blue = (P.y - A.y)/(P.x - A.x)
            else:
                m_blue = 99999999 # Infinite


            if m_blue >= m_red:
                return True
            else:
                return False



# Segment Intersection
# _________________________________________________________________________________________________
def segment_in_polygon(wp1, wp2, polygon):
    # count = 0
    #print('Segment: {}-{}'.format(wp1,wp2))

    for vertex1, vertex2 in pairwise_circle(polygon):
        A = vertex1
        B = vertex2
        #if vertex1.y < vertex2.y:
        #    A = vertex1
        #    B = vertex2
        #else:
        #    A = vertex2
        #    B = vertex1
        #print('Polygon edge: {}-{}'.format(A, B))

        if segment_intersects_segment(wp1, wp2, A, B):
            return True
    return False
    # if count > 1:
    #     return True 
    # else:
    #     return False 
    

def segment_intersects_segment(p1, q1, p2, q2):
    # Returns true if line segment 'p1q1' and 'p2q2' intersect. 
    # Based on the algorithm from https://www.geeksforgeeks.org/check-if-two-given-line-segments-intersect/

    
    # Two segments (p1,q1) and (p2,q2) intersect if and only if one of the following two conditions is verified:
    #
    # 1. General Case:
    # – (p1, q1, p2) and (p1, q1, q2) have different orientations and
    # – (p2, q2, p1) and (p2, q2, q1) have different orientations.
    #
    # 2. Special Case
    # – (p1, q1, p2), (p1, q1, q2), (p2, q2, p1), and (p2, q2, q1) are all collinear and
    # – the x-projections of (p1, q1) and (p2, q2) intersect
    # – the y-projections of (p1, q1) and (p2, q2) intersect
    
    
    # Find the four orientations needed for general and 
    # special cases 
    o1 = orientation(p1, q1, p2) 
    o2 = orientation(p1, q1, q2) 
    o3 = orientation(p2, q2, p1) 
    #print(p2, q2, p1, o3)
    o4 = orientation(p2, q2, q1) 
    #print(o1,o2,o3,o4)
    
    # 1. General case 
    if o1 != o2 and o3 != o4:
        return True  


    # 2. Special Cases 
    # p1, q1 and p2 are colinear and p2 lies on segment p1q1 
    if o1 == 0 and on_segment(p1, p2, q1): 
        return True 
  
    # p1, q1 and q2 are colinear and q2 lies on segment p1q1 
    if o2 == 0 and on_segment(p1, q2, q1):
        return True 
  
    # p2, q2 and p1 are colinear and p1 lies on segment p2q2 
    if o3 == 0 and on_segment(p2, p1, q2):
        return True 
  
    # p2, q2 and q1 are colinear and q1 lies on segment p2q2 
    if o4 == 0 and on_segment(p2, q1, q2):
        return True 
  
    
    # Doesn't fall in any of the above cases 
    return False 
    
    
def on_segment(p, q, r):
    # Given three colinear points p, q, r, the function checks if 
    # point q lies on line segment 'pr' 
    if (q.x <= max(p.x, r.x) and q.x >= min(p.x, r.x) 
    and q.y <= max(p.y, r.y) and q.y >= min(p.y, r.y)):
        return True
    else:
        return False
    
    
def orientation(p, q, r):
    # To find orientation of ordered triplet (p, q, r). 
    # The function returns following values 
    # 0 --> p, q and r are colinear 
    # 1 --> Clockwise 
    # 2 --> Counterclockwise 
    
    # See https://www.geeksforgeeks.org/orientation-3-ordered-points/ 
    # for details of below formula. 
      
    val =( (q.y - p.y) * (r.x - q.x) 
         - ((q.x - p.x) * (r.y - q.y)))
    #print('\n---\ndebug')
    #print((q.y - p.y), (r.x - q.x), (q.x - p.x), (r.y - q.y))
    #print(val)
    if val == 0:
        return 0         # colinear

    return (1 if val > 0 else 2)  # clock or counterclock wise



# Chance Constraint
# _________________________________________________________________________________________________

def risk_total(wp, area, imprecision):   
    distance_total = math.inf

    maior = 0 #M1
    soma = 0 #M2

    if debug:
        print('maior, soma, wp_risk, distance_total')
    for A, B in pairwise(area):
        # segmento A-B

        # plano determinado pela equação ax + by + cz + d = 0, onde (a, b, c) é o vetor normal
        x = A.x - B.x
        y = A.y - B.y
        # direction_vector = (x, y) # vector in the same direction of the line that connects A and B
        # normal_vector = [-y, x] # rotate the direction vector by 90º. (x, y) -> (-y, x) 
        normal_vector = [-y/(sqrt((y**2)+(x**2))), x/(sqrt((y**2)+(x**2)))] # dividindo pela norma, normalizando o vetor

        b = (-y) * A.x + x * A.y # Coeficiente da reta

        distance = wp.x * normal_vector[0] + wp.y * normal_vector[1] - b
        #print(distance)
        distance_total = min(distance_total, distance)
        wp_risk  = risk(distance_total, imprecision)
        # maior = max(maior, wp_risk) #M1
        # soma += wp_risk #M2
        if debug:
            print(maior, soma, wp_risk, distance_total, '--', wp, A, B)
    
    

    return wp_risk
    #return maior #M1
    #return soma #M2


def risk(distance, imprecision):
    # Survival function (also defined as 1 - cdf, but sf is sometimes more accurate).
    # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

    # mi    : média         : location
    # sigma : desvio padrão : scale

    return norm.sf(distance, loc=0, scale=imprecision)

# %% [markdown]
# ## visualization.py

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path

import plotly.graph_objects as go

from sklearn import preprocessing


cor_area_nn    = '#25283d' # Yankees Blue
cor_area_p     = '#8f3985' # Plum
cor_area_b     = '#07beb8' # Tiffany Blue
cor_waypoints  = '#aa1155' # Jazzberry Jam
cor_ori_dest   = '#880044' # Pink Raspberry


def new_shape(vertices, color='navajowhite', lw=.25):

    assert len(vertices) >= 3, 'At least 3 vertices to form a shape'

    colors = {
        'n': cor_area_nn,
        'p': cor_area_p,
        'b': cor_area_b
    }
    
    color = colors[color] if color in colors else color
    
    codes = [Path.MOVETO]
    for _ in range(1, len(vertices)-1):
        codes.append(Path.LINETO)
    codes.append(Path.CLOSEPOLY)
    
    path = Path(vertices, codes)

    patch = patches.PathPatch(path, facecolor=color, lw=lw, alpha=0.6)

    return patch


def plot_map(wp_style='-x', **kwargs):
    # Optional arguments:
    # areas, labels, origem, destino, waypoints, texts

    fig, ax = plt.subplots(figsize=(8,8)) 
    
    # Plot areas
    if 'areas' in kwargs and 'labels' in kwargs:
        areas=kwargs['areas']
        labels=kwargs['labels']
        patches = [ new_shape(vertice, color=label) for vertice, label in zip(areas, labels) ]
        for patch in patches:
            ax.add_patch(patch)
        
    # Plot origin and destination
    if 'origem' in kwargs and 'destino' in kwargs:
        origem=kwargs['origem']
        destino=kwargs['destino']
        ax.plot([origem[0], destino[0]], [origem[1], destino[1]], 'o', color=cor_ori_dest)
    
    # Plot waypoints and route
    if 'waypoints' in kwargs:
        waypoints=kwargs['waypoints']
        waypoints = list(map(list, zip(*waypoints)))
        ax.plot(waypoints[0], waypoints[1], wp_style, color=cor_waypoints, linewidth=2) #marker='x', linestyle='solid'
        if 'texts' in kwargs:
            for i, text in enumerate(kwargs['texts']):
                ax.annotate(text, (waypoints[0][i], waypoints[1][i]))
    
    if 'stress' in kwargs:
        # Plot waypoints
        if 'points' in kwargs:
            for wp, text in zip(kwargs['points'], kwargs['texts']):
                if text=='T':
                    in_color=cor_area_b
                else:
                    in_color=cor_waypoints

                ax.plot(wp[0], wp[1], wp_style, color=in_color, linewidth=2)
                ax.annotate(text, (wp[0], wp[1]))

        # Plot segments
        if 'segments' in kwargs and 'texts' in kwargs:
            i=0
            for segment, text in zip(kwargs['segments'], kwargs['texts']):
                X = [segment[0].x, segment[1].x]
                Y = [segment[0].y, segment[1].y]

                if text=='T':
                    in_color=cor_area_b
                else:
                    in_color=cor_waypoints
                ax.plot(X, Y, wp_style, color=in_color, linewidth=2)
                ax.annotate(text+str(i), (X[0], Y[0]))
                i+=1
    
    # Set size
    automin, automax = ax.get_xlim()
    plt.xlim(automin-0.5, automax+0.5)
    automin, automax = ax.get_ylim()
    plt.ylim(automin-0.5, automax+0.5)
    plt.gca().set_aspect('equal', adjustable='box')
    
    if 'title' in kwargs:
        plt.title(kwargs['title'])
    
    plt.show()
    #plt.savefig('out.png')

def plot_stats(ag_trace, normalize=True):
    dft = pd.DataFrame.from_dict(ag_trace)
    
    if normalize:
        x = dft.values #returns a numpy array
        min_max_scaler = preprocessing.MinMaxScaler()
        x_scaled = min_max_scaler.fit_transform(x)
        dft = pd.DataFrame(x_scaled, columns=dft.columns)

    fig = go.Figure()

    for column in dft.columns:
        fig.add_trace(go.Scatter(x=dft.index, y=dft[column], name=column))
    fig.show()

# %%
def vis_mapa(mapa):
    areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
    tipos = [ 'n' for _ in range(len(areas))]
    plot_map(
        areas=areas,             # Mapa usado
        labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
        origem=mapa.origin,      # waypoint de origem
        destino=mapa.destination # waypoint de destino   
    )

# %% [markdown]
# ## data_definitions.py

# %%
import collections
import math

CartesianPoint = collections.namedtuple('CartesianPoint', 'x y')
GeoPoint = collections.namedtuple('GeoPoint', 'latitude, longitude, altitude')
Version = collections.namedtuple('Version', 'major, minor')

class Mapa():
    def __init__(self, origin, destination, areas_n, inflation_rate=0.1, mode='scalar'):
        self.origin = origin           # CartesianPoint : Define o ponto de partida da rota
        self.destination = destination # CartesianPoint : Define o ponto de destino da rota
        self.areas_n = areas_n         # [area, ...]
                                       # area = [CartesianPoint(),...]      
        self.areas_n_inf = [ self._inflate_area(area, inflation_rate=inflation_rate, mode=mode) for area in areas_n ]
        
        
    def _inflate_area(self, area, inflation_rate, mode):
        if mode == 'percentage':
            # Infla uma área retangular em uma porcentagem do tamanho, alterando os valores em x% de cada vértice
            x = area[2].x - area[0].x
            y = area[1].y - area[3].y

            inc = (inflation_rate)
            dec = -(inflation_rate)

            new_area = [
                CartesianPoint(area[0].x + dec * x, area[0].y + dec * y), # left,  bottom
                CartesianPoint(area[1].x + dec * x, area[1].y + inc * y), # left,  top
                CartesianPoint(area[2].x + inc * x, area[2].y + inc * y), # right, top
                CartesianPoint(area[3].x + inc * x, area[3].y + dec * y)  # right, bottom
            ]
            new_area.append(new_area[0]) # Repetir primeiro ponto, para o ignore do shape na hora de plotar
        
        elif mode == 'scalar':
            # Infla uma área retangular em uma quantidade fixa
            inc = (inflation_rate)
            dec = -(inflation_rate)

            new_area = [
                CartesianPoint(area[0].x + dec, area[0].y + dec), # left,  bottom
                CartesianPoint(area[1].x + dec, area[1].y + inc), # left,  top
                CartesianPoint(area[2].x + inc, area[2].y + inc), # right, top
                CartesianPoint(area[3].x + inc, area[3].y + dec)  # right, bottom
            ]
            new_area.append(new_area[0]) # Repetir primeiro ponto, para o ignore do shape na hora de plotar
        
        
        return new_area



class Conversor():

    def list_geo_to_cart( l, geo_home):
        for i in l:
            yield Conversor.geo_to_cart(i, geo_home)

    def list_cart_to_geo( l, geo_home):
        for i in l:
            yield Conversor.cart_to_geo(i, geo_home)


    def geo_to_cart( geo_point, geo_home):
        
        def calc_y(lat, lat_):
            return (lat - lat_) * (10000000.0 / 90)
        def calc_x(longi, longi_, lat_):
            return (longi - longi_) * (6400000.0 * (math.cos(lat_ * math.pi / 180) * 2 * math.pi / 360))

        x = calc_x(geo_point.longitude, geo_home.longitude, geo_home.latitude)
        y = calc_y(geo_point.latitude, geo_home.latitude)

        #return CartesianPoint(x, y, geo_point.altitude)
        return CartesianPoint(x, y)


    def cart_to_geo( cartesian_point, geo_home):

        def calc_latitude_y(lat_, y):
            return ((y * 90) / 10000000.0) + lat_
        def calc_longitude_x(lat_, longi_, x):
            return ((x * 90) / (10008000 * math.cos(lat_ * math.pi / 180))) + longi_


        longitude_x = calc_longitude_x(geo_home.latitude, geo_home.longitude, cartesian_point.x)
        latitude_y = calc_latitude_y(geo_home.latitude, cartesian_point.y)

        #return GeoPoint(longitude_x, latitude_y, cartesian_point.z)
        return GeoPoint(longitude_x, latitude_y, 10)

# %% [markdown]
# ## file_manipulation.py

# %%
def upload_mapa(mapa_file, mapa_id):
    mapa = mapa_file[mapa_id]

    geo_home = GeoPoint(mapa['geo_home'][1], mapa['geo_home'][0], mapa['geo_home'][2])

    areas_bonificadoras  = [ Conversor.list_geo_to_cart(area['geo_points'], geo_home) for area in mapa['areas_bonificadoras'] ]
    areas_penalizadoras  = [ Conversor.list_geo_to_cart(area['geo_points'], geo_home) for area in mapa['areas_penalizadoras'] ]
    
    areas_nao_navegaveis = []
    for area in mapa['areas_nao_navegaveis']:
        geo_points=[]
        for geo_point in area['geo_points']:
            geo_points.append(Conversor.geo_to_cart(
                GeoPoint(geo_point[1], geo_point[0], geo_point[2]) 
                , geo_home))
        geo_points.append(geo_points[0])
        areas_nao_navegaveis.append(geo_points)



    return geo_home, areas_bonificadoras, areas_penalizadoras, areas_nao_navegaveis

# %% [markdown]
# # 2. Algoritmo Genético
# Essa seção contém a implementação do algoritmo genético, contendo a definição da classe indivíduo (Subject) e da classe do genético (Genetic).
# Aqui está a implementação, não é necessário mexer, a menos que queira mudar alguma coisa na lógica da solução. **Caso somente queira mexer nos parâmetros, pule para a próxima etapa**

# %% [markdown]
# ### Utilitários

# %%
import collections
import random
import time
import copy

from math import cos, sin, sqrt, ceil

from itertools import tee
#from utils import pairwise, point_in_polygon, segment_in_polygon

Gene           = collections.namedtuple('Gene', 'a e')
GeneDecoded    = collections.namedtuple('GeneDecoded', 'x y v al')

# %% [markdown]
# ## 2.1. Definição do Indivíduo

# %%
class Subject():
    
    # codificação - u
    # dna = [Gene, ...]
    #     Gene = [a, e]
    #         a = float: aceleração
    #         e = float: variação angular


    # decodificação - x
    # dna_decoded = [GeneDecoded, ...]
    #     GeneDecoded = (x, y, v, al)
    #         x  = : Posição do VANT no eixo x (aka px)
    #         y  = : Posição do VANT no eixo y (aka py)
    #         v  = : Velocidade do VANT na horizontal
    #         al = : ângulo (direção) do VANT na horizontal
    def __init__(
        self,
        px0=10.,
        py0=10.,
        v0=0,
        al0=0,
        v_min=11.1,
        v_max=30.5,
        e_min=-3,        
        e_max=3,
        a_min=-2.0,
        a_max=2.0,
        T=10,
        T_min=1,
        T_max=7,
        delta_T=1,
        m=743.0,
        mutation_prob=0.7,
        start_time=None,
        spawn_mode='random',
        version=None,
        **kwargs
    ):
        # VANT
        # px0   int : Posição inicial no eixo x (m)
        # py0   int : Posição inicial no eixo y (m)
        # v0    int : Velocidade Inicial (m/s)
        # al0   int : Ângulo inicial (graus)
        self.gene_decoded_0 = GeneDecoded(px0, py0, v0, al0) # GeneDecoded : objeto contendo o gene decodificado de posição 0
        self.v_min = v_min # float : Velocidade máxima (m/s)
        self.v_max = v_max # float : Velocidade mínima (m/s)
        self.e_min = e_min # int   : Velocidade angular mínima (graus/s)
        self.e_max = e_max # int   : Velocidade angular máxima (graus/s)
        self.a_min = a_min # float : Aceleração mínima (m/s**2)
        self.a_max = a_max # float : Aceleração máxima (m/s**2)
        
        # TODO9:implementar os initialize
        
        # Modelo
        self.T_min   = T_min   # int : Valor mínimo para o horizonte de planejamento
        self.T_max   = T_max   # int : Valor máximo para o horizonte de planejamento
        self.delta_T = delta_T # int : Discretização do tempo (s) Tempo que leva de um waypoint até o outro
        self.m       = m       # float : Massa do VANT (!=0) (gramas)
    
        # Parametros do indivíduo
        self.mutation_prob = mutation_prob # float : Probabilidade de ocorrer uma mutação no dna (%)
        self.fitness       = None          # float : Fitness do indivíduo
        #self.birth_time    = None          # time  : Hora que o indivíduo é criado
        self.dna           = None          # list  : Conjunto de genes formando o DNA ([Gene, ...])
        self.dna_decoded   = None          # list  : DNA decodificado ([GeneDecoded, ...])
        self.spawn_mode    = spawn_mode    # str   : Tipo de incialização do DNA {'random'}
        self.start_time    = start_time    # time  : a hora em que o genético começou a rodar

        assert version, 'Algorithm version must be informed!\nEx: Version("alpha","RC")'
        if version.major == 'alpha': # Sem otimização em T
            self.T = T
            self.mutation_choices = [
                self._mutation_creep, 
                self._mutation_change
            ]
        elif version.major == 'beta': # Com otimização em T
            self.T = random.randint(T_min, T_max) # int : Horizonte de planejamento (quantidade de waypoints)
            self.mutation_choices = [
                self._mutation_remove, 
                self._mutation_insert, 
                self._mutation_creep, 
                self._mutation_change
            ]


        self.spawn(mode=spawn_mode)
        
    
    def set_fitness(self, fitness, fitness_trace, birth_time):
        self.fitness = fitness
        self.fitness_trace = fitness_trace
        #self.birth_time = birth_time
    
    
    # ---
    
    def spawn(self, mode):
        self.dna = [self._build_gene(mode) for _ in range(self.T) ]
        
    def _build_gene(self, mode='random'):
        # Inicialização aleatória gera valores com distribuição uniforme
        if mode == 'random':
            a = random.uniform(self.a_min, self.a_max)
            e = random.uniform(self.e_min, self.e_max)
            
        return Gene(a, e)
    
    # ---
    
    def decode(self):
        #self.dna_decoded = [self._decode_gene() for i in range(len(self.dna))]
        self.dna_decoded = self._decode_gene() # TODO: Organizar, voltar como era a linha de cima. Fazer função abaixo só computar o gene
        self.birth_time = time.time() - self.start_time

    def _decode_gene(self):
        dna = self.dna
        
        # parametros
        delta_T = self.delta_T
        m = self.m
        
        dna_decoded = []
        dna_decoded.append(self.gene_decoded_0)
        
        for i in range(0, len(dna)):
            # dna
            a  = dna[i].a
            e  = dna[i].e
            
            # dna decodificado
            px = dna_decoded[i].x
            py = dna_decoded[i].y
            v  = dna_decoded[i].v
            al = dna_decoded[i].al
            
            F = self.__F(v)
        
            # Equações descritas em (Arantes 2016)
            _px = px + ( v * cos(al) * delta_T ) + ( a * cos(al) * ((delta_T**2)/2) ) 
            _py = py + ( v * sin(al) * delta_T ) + ( a * sin(al) * ((delta_T**2)/2) ) 
            _v  = v  + ( a * delta_T ) - ( (F/m) * delta_T )
            _al = al + ( e * delta_T )

            dna_decoded.append(GeneDecoded(_px, _py, _v, _al))

        return dna_decoded
    
    
    def __F(self, v):
        # Equação do Arrasto
        # Disponível em https://pt.wikipedia.org/wiki/Equa%C3%A7%C3%A3o_do_arrasto
        # Versão utilizada ((Arantes, 2016) equação 3.5)
        
        Cd  = 0.8     # float : Coeficiente de arrasto, específico para cada aeronave
                      #         (considerado Angled Cube) obtido de https://pt.wikipedia.org/wiki/Coeficiente_de_resist%C3%AAncia_aerodin%C3%A2mica
        rho = 1.225   # float : Massa específica do fuído (aka densidade) (k/m**3)
                      #         (a 15 graus Celsius) Valor de rho obtido de https://pt.m.wikipedia.org/wiki/Densidade_do_ar
        A = 1.0       # float : Área de referência # TODO: o que é isso?
        # v = v       # float : Velocidade do Vant no instante t (fornecido como parâmetro da função)
        
        F = 0.5 * Cd * rho * A * (v**2)
        
        return F
        
    
    # ---
    
    def crossover(self, parent2):
        dna = random.choice([self._OX, self._BLX_Alpha])(self.dna, parent2.dna)
        dna = self._complete(dna, self.dna, parent2.dna)
        child = self.generate(dna)
        return child
    
    
    def _complete(self, dna, dna1, dna2):
        # Adiciona os genes restantes da diferença de tamanho entre os dois DNAs
               
        if len(dna1) > len(dna2):
            bigger  = dna1
            smaller = dna2
        else:
            bigger  = dna2
            smaller = dna1
    
        for i in range(len(smaller)-1, len(bigger)-1):
            if random.random() < 0.5:
                dna.append(bigger[i])
                
        return dna
        
    
    def _OX(self, dna1, dna2):
        dna = []
        for gene1, gene2 in zip(dna1, dna2):
            dna.append(random.choice([gene1, gene2]))
        return dna
        
        
    def _BLX_Alpha(self, dna1, dna2):
        dna = []
        for gene1, gene2 in zip(dna1, dna2):
            a = self.__BLX_ALpha_select_gene(gene1.a, gene2.a)
            e = self.__BLX_ALpha_select_gene(gene1.e, gene2.e)
            if a>self.a_max:
              a=self.a_max
            elif a < self.a_min:
              a=self.a_min

            if e>self.e_max:
              e=self.e_max
            elif e < self.e_min:
              e=self.e_min            
            
            gene = Gene(a, e)
            dna.append(gene)
            
        return dna
    
    
    def __BLX_ALpha_select_gene(self, x, y):
        # x - Gene : gene do pai 1
        # y - Gene : gene do pai 2
        alpha = random.uniform(0,1)
        d = abs(x-y)
        u = random.uniform(min(x,y)-alpha*d, max(x,y)+alpha*d)
        return u
    
    
    def generate(self, dna):
        # Cria um filho com os mesmos parametros do pai, mas com um dna fornecido
        child = copy.deepcopy(self)
        child.dna = dna
        child.decode()
        return child
    
        
    # ---
    
    def mutation(self, mutation_prob=None):
        mutation_prob = self.mutation_prob if not mutation_prob else mutation_prob # 0.7
        
        # Tem uma probabilidade mutation_prob de mutar o gene ou não
        if random.random() < mutation_prob:
            # Seleciona aleatoriamente uma das formas de mutação
            new_dna = random.choice(self.mutation_choices)(self.dna)
            # [
            #     self._mutation_remove, 
            #     self._mutation_insert, 
            #     self._mutation_creep, 
            #     self._mutation_change
            # ]
            
            if new_dna:
                self.dna = new_dna
                self.decode()
            
            return True
        return False
    
    def _mutation_change(self, dna):
        # Reinicia um gene aleatoriamente
        new_dna = []
        for gene in dna:
            if random.random() < 0.5:
                new_dna.append(self._build_gene('random'))
            else:
                new_dna.append(gene)
        
        return new_dna
    
    
    def _mutation_remove(self, dna):
        # Remove UM gene aleatório do DNA
        if len(dna) > self.T_min:
            i = random.randint(0, len(dna)-1)
            dna.pop(i)
            return dna
        return None
        
        
    def _mutation_insert(self, dna):
        # Insere UM gene aleatório no DNA em uma posição aleatória
        if len(dna) < self.T_max:
            i = random.randint(0, len(dna)-1)
            gene = self._build_gene()
            dna.insert(i, gene)
            return dna
        return None
    
    
    def _mutation_creep(self, dna):
        # Muta em um pequeno valor aleatorio todos os genes
        new_dna = []
        for gene in dna:
            a = self.__mute(gene.a, self.a_min, self.a_max)
            e = self.__mute(gene.e, self.e_min, self.e_max)

            # TODO2: otimizar
            new_gene = Gene(a, e)
            new_dna.append(new_gene)

        return new_dna
        
        
    def __mute(self, val, min_val, max_val):
        mutation_rate = random.uniform(0, max_val*0.5)
        s = random.choice([1, -1])
        val = val * (1 + (mutation_rate * s))

        # Checa se não estoura os limites
        if val>max_val:
          val=max_val
        elif val<min_val:
          val=min_val
        #val = max(val, min_val)
        #val = min(val, max_val)

        return val
    
    
    # ---
    
    def get_route(self):
        return [ [gene.x, gene.y] for gene in self.dna_decoded ]

# %% [markdown]
# ## 2.2. Definição do Genético

# %%
class Genetic():
    
    def __init__(
        self, 
        Specie, 
        mapa,
        taxa_cross=1.0,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=500,
        C_cur=100,
        C_t=10,
        max_exec_time=30,
        min_precision=1.0,
        k_tournament=2,
        gps_imprecision=1,
        big_delta=1,
        version=Version('alpha','RC'),
        **kwargs
    ):
        # Modelo
        self.Specie = Specie # objeto : Definição da classe (não a instância)
        self.mapa   = mapa   # Mapa   : Mapa com as características da missão

        # Parâmetros
        self.taxa_cross      = taxa_cross      # float : Taxa de ocorrencia do crossover [0,1]
        self.population_size = population_size # int   : Quantidade máxima de indivíduos na população 
        self.C_d             = C_d             # int   : Custo associado ao fitness de destino
        self.C_obs           = C_obs           # int   : Custo associado ao fitness de obstáculos
        self.C_con           = C_con           # int   : Custo associado ao fitness de consumo de combustível
        self.C_cur           = C_cur           # int   : Custo associado ao fitness de curvatura da rota
        self.C_t             = C_t             # int   : Custo associado ao fitness do tamanho do DNA (T ou horizonte de planejamento)
        self.max_exec_time   = max_exec_time   # float : Tempo máximo de execução - Stop criteria (segundos)
        self.min_precision   = min_precision   # float : Precisão mínima de acerto ao destino (metros)
        self.k_tournament    = k_tournament    # int   : Quantidade de indivíduos disputando o torneio
        self.gps_imprecision = gps_imprecision # float : Imprecisão do GPS (metros)
        self.big_delta       = big_delta
        
        # Versionamento
        self.version = version

        # Alguns dos valores do kwargs são passados para a instanciação dos indivíduos
        self.kwargs = kwargs
        
        # Inicialização
        self.population = None 
        self.fitnesses  = None
        self.best       = None
        self.ancestry   = []
        

#         if version.minor == "RC":
#             self.__fitness_obstacles = self.__fitness_obstacles_RC
#         elif version.minor == "CC":
#             self.__fitness_obstacles = self.__fitness_obstacles_CC

        
    def run(self, max_exec_time=None, verbose=False, info=False, debug=False):
        self.max_exec_time = max_exec_time if max_exec_time else self.max_exec_time
        
        # Acompanhamento do tempo (critério de parada)
        self.start_time = time.time()
        
        # Genesis
        self.population = self._genesis(self.Specie, self.population_size)
        
        # Inicializar
        self._decode(self.population)
        
        # Avaliar
        self.fitnesses = [self._fitness(subject, self.mapa) for subject in self.population]
    
        # Escolher melhor de todos
        self.best = self.population[self.fitnesses.index(max(self.fitnesses))]
        
        
        self.trace = []
        
        while not self.stop_criteria():
            self.flag_newborn = self.population_size
            count_while = 0
            
            while not self.converge():
                self.flag_newborn = 0
                count_while += 1
                
                for i in range(ceil(self.taxa_cross * self.population_size)):
                    # Seleção por torneio
                    parent1, parent2 = self._tournament(self.population, k=self.k_tournament)
            
                    # Crossover
                    child = parent1.crossover(parent2)
                    
                    # Mutação
                    child.mutation()
                    
                    # Fitness
                    self._fitness(child, self.mapa)
                    
                    # Adicionar filho na população
                    self._insert(child, parent1, parent2)
                    
                    # Print
                    if verbose and self.flag_newbest:
                        print('  Novo melhor de todos! fit: {}'.format(self.best.fitness))
                    if debug:
                        print('\nparent1.dna', parent1.dna)
                        print('\nparent2.dna', parent2.dna)
                        print('\nchild.dna.mutation', child.dna)
                        
                        
                aux_T_dna = [len(subject.dna) for subject in self.population]
                self.trace.append({
                    'medium_fitness': sum(self.fitnesses)/self.population_size,
                    'best_fitness': self.best.fitness,
                    'newborns': self.flag_newborn,
                    'newbest': self.flag_newbest,
                    'T_medio': sum(aux_T_dna)/self.population_size,
                    'T_maior': max(aux_T_dna),
                    'T_menor': min(aux_T_dna),
                    'T_melhor': len(self.best.dna)
                })
                
                # Print
                if verbose:
                    print('Fim da geração. {} novos indivíduos'.format(self.flag_newborn))
                    print('Melhor de todos: {}'.format(self.best.fitness))
                    print('-'*20)
                        
                        
            # Reiniciar rotas
            self.population = []
            self.population = self._genesis(self.Specie, self.population_size-1)
            # Nunca matar o melhor de todos
            self.population.append(self.best)
            
            # Inicializar
            self._decode(self.population)
            
            # Avaliar
            self.fitnesses = [self._fitness(subject, self.mapa) for subject in self.population]
            
            # Print
            if verbose:
                print('Meteoro! Reiniciando rotas')
            if info:
                print('Meteoro! Melhor de todos:{} - count:{}'.format(self.best.fitness, count_while))
                
                
        return self.best
                      
    # ---
    
    def _insert(self, child, parent1, parent2):
        # Verifica se um indivíduo é digno de entrar na população e tomar o lugar de um de seus pais

        self.flag_newbest = False
        
        if child.fitness < parent1.fitness:
            self.__substitute(child, parent1)

        elif child.fitness < parent2.fitness:
            self.__substitute(child, parent2)

        if child.fitness < self.best.fitness:
            self.best = child
            self.ancestry.append(child)
            self.flag_newbest = True
    
    
    def __substitute(self, child, parent):
        i_parent = self.population.index(parent)

        self.population.remove(parent)
        self.population.append(child)

        self.fitnesses.pop(i_parent)
        self.fitnesses.append(child.fitness)
        self.flag_newborn += 1
    
    
    # ---
    
    def stop_criteria(self):
        # Para a execução depois de uma quantidade de segundos
        if (time.time() - self.start_time) >= self.max_exec_time:
            return True
        return False
    
    def converge(self):
        # Converge caso nenhum novo indivíduo seja adicinado
        if self.flag_newborn == 0:
            return True
        return False
                         
    # ---
    
    def _genesis(self, Specie, population_size):
        population = [Specie(start_time=self.start_time, version=self.version,**self.kwargs) for i in range(population_size)]
        return population 
    
    # ---
    
    def _decode(self, population):
        for subject in population:
            subject.decode()
        return True
    
    # ---
    
    def _fitness(self, subject, mapa):
        
        fit_d   = self.__fitness_destination(subject, mapa)
        fit_obs = self.__fitness_obstacles(subject, mapa)
        fit_con = self.__fitness_consumption(subject, mapa)
        fit_cur = self.__fitness_curves(subject, mapa)
        fit_t   = self.__fitness_t(subject, mapa)
        
        fitness_trace = [self.C_d   * fit_d,
                         self.C_obs * fit_obs,
                         self.C_con * fit_con,
                         self.C_cur * fit_cur,
                         self.C_t   * fit_t]
        
        fitness = sum(fitness_trace)
        
        birth_time = time.time() - self.start_time
        
        subject.set_fitness(fitness, fitness_trace, birth_time)
        
        return fitness
    
    def __fitness_destination(self, subject, mapa):
        # Prioriza rotas que acertem o destino
        
        A = subject.dna_decoded[-1] # Último waypoint da rota
        B = mapa.destination        # Waypoint de destino
        
        # Distância euclidiana entre o último ponto da rota e o ponto de destino
        d = sqrt( (B.x - A.x)**2 + (B.y - A.y)**2 )
        
        # Determina uma precisão mínima aceita
        if d < self.min_precision: # min_precision default = 1.0
            return 0
        return d

    
    # def __fitness_obstacles is an abstraction of either one of those two following functions:
    # __fitness_obstacles_RC and __fitness_obstacles_CC

#     def __fitness_obstacles_RC(self, subject, mapa):
    def __fitness_obstacles(self, subject, mapa):
        # Prioriza rotas que não ultrapassem obstáculos
        count = 0
        
        for gene_decoded_t1, gene_decoded_t2  in pairwise(subject.dna_decoded):
            # Utiliza somente as áreas infladas para cálculo
            for area_n in mapa.areas_n_inf:
                wp1 = CartesianPoint(gene_decoded_t1.x, gene_decoded_t1.y)
                wp2 = CartesianPoint(gene_decoded_t2.x, gene_decoded_t2.y)
                
                # Calcula se algum waypoint está dentro de algum obstáculo
                if point_in_polygon(wp1, area_n):
                    count += 1

                # Calcula se alguma conexão entre os waypoints intersecciona algum obstáculo
                if segment_in_polygon(wp1, wp2, area_n):
                    count += 1
            
        return count


    def __fitness_obstacles_CC(self, subject, mapa):
        # Prioriza rotas que não ultrapassem obstáculos
        count       = 0
        
        #bigger_risk = 0 #M1
        sum_risk    = 0 #M2
    
        for gene_decoded_t1  in subject.dna_decoded:
            # Utiliza somente as áreas infladas para cálculo
            for area_n in mapa.areas_n_inf:
                wp1 = CartesianPoint(gene_decoded_t1.x, gene_decoded_t1.y)
    
                # Alocação de Risco    
                wp_risk = risk_total(wp1, area_n, self.gps_imprecision) #M1 #M2
            
                # Modo 1: Considerar o maior risco
                # bigger_risk = max(wp_risk, bigger_risk) #M1

                # Modo 2: Considerar a soma individual de cada risco
                sum_risk += wp_risk #M2

        #prob = min(bigger_risk, 1) #M1
        #prob = min(self.big_delta - sum_risk, 1) #M2
        if self.big_delta-sum_risk > 0:
            prob=0
        else:
            prob=sum_risk-self.big_delta
            
        #print(sum_risk)
            
        return prob
    
    
    def __fitness_consumption(self, subject, _):
        # Prioriza rotas com menor consumo de combustível (bateria)
        consumption = [gene.a**2 for gene in subject.dna]
        return sum(consumption)
    
        
    def __fitness_curves(self, subject, _):
        # Prioriza rotas que evitem fazer curvas desnecessárias
        curves = [abs(gene.e) for gene in subject.dna]
        return (1/subject.e_max) * sum(curves)
        
        
    def __fitness_t(self, subject, _):
        # Prioriza rotas com menor quantidade de waypoints
        return len(subject.dna)
    
        
    # ---
        
    def _tournament(self, population, k=2):
        parents = []
        for i in range(2):
            
            local_best = random.choice(population)
            for j in range(k-1):
                # Seleciona k individuos
                a = random.choice(population)
                if a.fitness < local_best.fitness:
                    local_best = a
                    
            parents.append(local_best)
            
        # Retorna o resultado de duas batalhas
        return parents[0], parents[1]

# %% [markdown]
# # 3. Execução
# Essa seção contém a execução do AG. Aqui contém as definições dos mapas, e execução do planejador de rotas. Pode alterar os parâmetros a vontade para testar novos resultados

# %% [markdown]
# ## 3.1. Mapas

# %% [markdown]
# ### Mapa 1

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (20.0, 5.0), # left, bottom
    (20.0, 15.5), # left, top
    (30.0, 15.5), # right, top
    (30.0, 5.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]


mapa_1 = Mapa(wp_ori, wp_des, [verts1], inflation_rate=1)

# %%
# Visualização desse mapa
vis_mapa(mapa_1)

# %% [markdown]
# ### Mapa 2

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (15.0,  8.0), # left, bottom
    (15.0, 20.0), # left, top
    (20.0, 20.0), # right, top
    (20.0,  8.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (30.0,  0.0), # left, bottom
    (30.0, 12.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  0.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_2 = Mapa(wp_ori, wp_des, [verts1, verts2], inflation_rate=1)

# %%
# Visualização desse mapa
vis_mapa(mapa_2)

# %% [markdown]
# ### Mapa 3

# %%
wp_ori = CartesianPoint(10.0, 10.0)
wp_des = CartesianPoint(40.0, 10.0)

verts1 = [
    (15.0, 11.0), # left, bottom
    (15.0, 25.0), # left, top
    (35.0, 23.0), # right, top
    (35.0, 16.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (15.0,  0.0), # left, bottom
    (15.0,  9.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  6.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_3 = Mapa(wp_ori, wp_des, [verts1, verts2], inflation_rate=0.5)

# %%
# Visualização desse mapa
vis_mapa(mapa_3)

# %% [markdown]
# ### Mapa 4

# %%
wp_ori = CartesianPoint(40.0, 25.0)
wp_des = CartesianPoint(36.0, -22.0)

verts1 = [
    (19.0,-12.0), # left, bottom
    (15.0,0.0), # left, top
    (87.0,15.0), # right, top
    (90.0,3.0), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

# verts1 = [
#     (38.0,-9.0), # left, bottom
#     (38.0,6.0), # left, top
#     (87.0,15.0), # right, top
#     (90.0,3.0), # right, bottom
# ]
# verts1.append(verts1[0])
# verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

verts2 = [
    (15.0,  0.0), # left, bottom
    (15.0,  9.0), # left, top
    (35.0, 12.0), # right, top
    (35.0,  6.0), # right, bottom
]
verts2.append(verts2[0])
verts2 = [CartesianPoint(v[0], v[1]) for v in verts2]

mapa_4 = Mapa(wp_ori, wp_des, [verts1], inflation_rate=0.5)

# %%
# Visualização desse mapa
vis_mapa(mapa_4)

# %% [markdown]
# ## 3.2. Planejamento de Rota

# %%
# ===============================================================
# --------------   UTILIZE ESSE ESPAÇO --------------------------

debug = False

# Altere aqui o mapa que deseja utilizar
#mapa = mapa_1
mapa = mapa_2
#mapa = mapa_3
#mapa = mapa_4


# Inicialização do Algoritmo
ag = Genetic(Subject, mapa, 
        version = Version('beta', 'RC'),
        # Parâmetros da classe Genetic:
        taxa_cross=5,
        population_size=10,
        C_d=1000,
        C_obs=10000,
        C_con=500,
        C_cur=100,
        C_t=100,
        max_exec_time=30, # segundos
        # Parâmetros da classe Subject:
        px0=mapa.origin.x,
        py0=mapa.origin.y,
        T_min=1,
        T_max=25,
        mutation_prob=0.7
)

# ===============================================================

# Execução do AG, retorna o melhor indivíduo
best = ag.run(info=True)

# Print do DNA do melhor
print('-'*30)
for dna in best.dna:
    print(dna)
    
# Print do DNA DECODIFICADO do melhor
print('-'*30)
for dna_decoded in best.dna_decoded:
    print(dna_decoded)
    
best = ag.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)


# Visualização de alguns gráficos de fitness e quantidade de Ts
#plot_stats(ag.trace, normalize=True)
#plot_stats(ag.trace, normalize=False)
# Out:
# Meteoro! Melhor de todos:14688.304122598169 - count:57
# Meteoro! Melhor de todos:14688.304122598169 - count:17
# Meteoro! Melhor de todos:14685.044684747172 - count:78
# Meteoro! Melhor de todos:14663.570380566343 - count:17
# Meteoro! Melhor de todos:14663.570380566343 - count:10
# Meteoro! Melhor de todos:14146.175990296833 - count:25
# Meteoro! Melhor de todos:14120.853373872375 - count:56
# Meteoro! Melhor de todos:13737.388926068063 - count:8
# Meteoro! Melhor de todos:11509.41182638507 - count:11
# Meteoro! Melhor de todos:4325.166152446929 - count:51
# Meteoro! Melhor de todos:4296.614783147661 - count:23
# Meteoro! Melhor de todos:4296.614783147661 - count:14
# Meteoro! Melhor de todos:3987.952531836036 - count:45
# Meteoro! Melhor de todos:3860.2445807136946 - count:100
# Meteoro! Melhor de todos:3789.9630131974764 - count:15
# Meteoro! Melhor de todos:3524.843405173356 - count:142
# Meteoro! Melhor de todos:3484.529580477908 - count:51
# Meteoro! Melhor de todos:3456.887431971914 - count:72
# Meteoro! Melhor de todos:3454.1017227980806 - count:133
# ------------------------------
# Gene(a=1.5880069468376365, e=-0.8511194078637915)
# Gene(a=1.0367255455249966, e=0.13909141554427482)
# Gene(a=0.7628438797374881, e=0.21923097153422408)
# Gene(a=0.1366396891443046, e=0.5932963919121725)
# Gene(a=-0.04557579832753844, e=0.6182179098983569)
# Gene(a=0.14727316901938856, e=0.10868324809147903)
# Gene(a=0.03245462227961504, e=0.18304261061957522)
# Gene(a=0.004839798074945223, e=-0.44460146684322244)
# Gene(a=-0.0035044791886838303, e=-0.9564360418309291)
# Gene(a=-0.02506346334742919, e=-0.019033524728017406)
# Gene(a=-0.010760341285959938, e=-0.09289530907944253)
# Gene(a=-0.00589334383876572, e=-0.05538313111356922)
# ------------------------------
# GeneDecoded(x=10.0, y=10.0, v=0, al=0)
# GeneDecoded(x=10.794003473418819, y=10.0, v=1.5880069468376365, al=-0.8511194078637915)
# GeneDecoded(x=12.1823996825639, y=8.415970529920635, v=2.623069416493225, al=-0.7120279923195166)
# GeneDecoded(x=14.45691502242922, y=6.452924865864108, v=3.381375689702808, al=-0.4927970207852925)
# GeneDecoded(x=17.496141836143476, y=4.820901687720831, v=3.510474983474424, al=0.10049937112688001)
# GeneDecoded(x=20.96623070464077, y=5.17082231128931, v=3.4567720210032733, al=0.7187172810252369)
# GeneDecoded(x=23.623395974166648, y=7.4953131485062405, v=3.5961647813086057, al=0.8274005291167159)
# GeneDecoded(x=26.068232991536117, y=10.15466430773358, v=3.620090632988195, al=1.0104431397362912)
# GeneDecoded(x=27.99354446632075, y=13.223175066994413, v=3.6162877964283973, al=0.5658416728930687)
# GeneDecoded(x=31.044710040020053, y=15.161023341109258, v=3.604158830915309, al=-0.39059436893786037)
# GeneDecoded(x=34.36582628918779, y=13.793554116767945, v=3.5705286369750833, al=-0.40962789366587776)
# GeneDecoded(x=37.63602675856209, y=12.3736694464182, v=3.551360690539386, al=-0.5025232027453203)
# GeneDecoded(x=40.74575064215257, y=10.664617248454116, v=3.5371497696486536, al=-0.5579063338588894)

# %%
import pickle
pickle.dump(ag, open( "test_ag_save.p", "wb" ) )
ag_backup = pickle.load(open( "test_ag_save.p", "rb" ) )

# %%
ag.__module__
# Out:
# '__main__'

# %%
ag_backup.best.birth_time
# Out:
# 35.55169415473938

# %%
ag_backup

# %%
debug = True
wp_teste = GeneDecoded(x=19, y=16.5, v=7.8730500357006825, al=0.23615218818588443)

risk_total(wp_teste, mapa.areas_n_inf[0], 5)

# %%
 mapa.areas_n_inf[0]

# %% [markdown]
# #### Visualizar Detalhes do fitness

# %%
best.fitness_trace
# Destino Obstáculo Consumo Curva QtdWP

# %% [markdown]
# #### Recuperação de Erros
# Caso o AG pare no meio da execução, é possível visualizar o melhor de todos gerado até o momento mesmo assim, basta rodar a célula abaixo

# %%
best = ag.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %% [markdown]
# # 4. Execução da Implementação em ROS

# %%
mapa_file = [
{
	"id": 0,
	"name": "Mapa C2",
	"geo_home": [-47.932949, -22.002467, 0],
	"areas_bonificadoras":[],
	"areas_penalizadoras":[],
	"areas_nao_navegaveis":[
		{
			"id": "NN1",
			"name": "Campo atras dos containers",
			"geo_points":[
				[-47.932749, -22.002332, 7], 
				[-47.932794, -22.002177, 13], 
				[-47.932664, -22.002147, 13], 
				[-47.932612, -22.002306, 7]
    			]
    		},
		{
			"id": "NN2",
			"name": "Bloco de aula",
			"geo_points":[
				[-47.932099, -22.002278, 20],
				[-47.932063, -22.002396, 20],
				[-47.932772, -22.002582, 20],
				[-47.932811, -22.002465, 20]
			]
		}
    ]
}
]

# %%
mapa_file = [
{
	"id": 0,
	"name": "Mapa C2",
	"geo_home": [-47.932949, -22.002467, 0],
	"areas_bonificadoras":[],
	"areas_penalizadoras":[],
	"areas_nao_navegaveis":[
		{
			"id": "NN1",
			"name": "Bloco de Aula",
			"geo_points":[
				[-47.932754, -22.002590, 7], 
				[-47.932804, -22.002485, 13], 
				[-47.932109, -22.002287, 13], 
				[-47.932072, -22.002401, 7]
    			]
    		},
		{
			"id": "NN2",
			"name": "Containers",
			"geo_points":[
				[-47.933286, -22.002630, 20],
				[-47.933370, -22.002350, 20],
				[-47.933047, -22.002259, 20],
				[-47.932956, -22.002532, 20]
			]
		}
    ]
}
]

# %%
import argparse

#from visualization import plot_map
#from genetic_v2_3 import Subject, Genetic 
#from data_definitions import Mapa, CartesianPoint, Conversor, GeoPoint

#from file_manipulation import read_mapa, write_mavros, upload_mapa

## ENTRADA

# Parâmetros recebidos (arquivo .srv)
origin_lat       = -22.002237
origin_long      = -47.932546
origin_alt       = 13
destination_lat  = -22.002674 
destination_long = -47.932608
destination_alt  = 15

# P0
# destination_lat  = -22.002278 
# destination_long = -47.932099
# destination_alt  = 20

# P1
# destination_lat  = -22.002396 
# destination_long = -47.932063
# destination_alt  = 20


mapa_id          = 0

# Leitura do arquvio em DATA
#PATH = '/home/gustavosouza/Documents/Per/path-planning/data/mapa.json' #Ubuntu
PATH = r'../../data' #Windows
#geo_home, _, _, areas_n = read_mapa(PATH, mapa_id)
geo_home, _, _, areas_n = upload_mapa(mapa_file, mapa_id)

cart_origin      = Conversor.geo_to_cart(GeoPoint(origin_lat, origin_long, origin_alt), geo_home)
cart_destination = Conversor.geo_to_cart(GeoPoint(destination_lat, destination_long, destination_alt), geo_home)


mapa = Mapa(cart_origin, cart_destination, areas_n, inflation_rate=3)



## EXECUÇÃO DO AG
ag_teste = Genetic(Subject, mapa,
        # Genetic
        taxa_cross=0.5,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=100,
        C_cur=500,
        C_t=100,
        max_exec_time=6000,
        #Subject,
        T_min=10,
        T_max=40,
        mutation_prob=0.7,
        px0=cart_origin.x,
        py0=cart_origin.y
)


best = ag_teste.run(info=True)

# Melhor rota encontrada : WPs em cartesiano
cart_points = best.get_route()

# Melhor rota encontrada : WPs em geográfico
geo_points = [ Conversor.cart_to_geo(CartesianPoint(cart_point[0], cart_point[1]), geo_home) for cart_point in cart_points ]


# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

## SAÍDA

#output_filename = '/mnt/c/Projetos/path-planning/algorithms/ros_genetic/path_from_ga_output.wp'
#write_mavros(output_filename, geo_points)

# %%
def print_mavros(geo_points): #throws FileNotFoundException
    print('Printing mavros file...\n\n\n')
    count = 1


    current_waypoint = 1

    print('QGC WPL 120\n') # Determines the file version

    i = 0

    for geo_point in geo_points:
        print(
            str(i) + '\t'
            + str(current_waypoint) + '\t' 
            + '3\t16\t3\t0\t0\t0\t'
            + '{:10.8f}'.format(geo_point.longitude) + '\t' 
            + '{:10.8f}'.format(geo_point.latitude) + '\t'
            + '{:10.8f}'.format(geo_point.altitude) + '\t'
            + '1'
            + '\n'
        )

        current_waypoint = 0
        i+=1

    print('\n\n\nOutput print generated.')

# %%
print_mavros(geo_points)

# %%
mapa.areas_n

# %%
areas = [ area for area in itertools.chain(mapa.areas_n) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %%
import argparse

#from visualization import plot_map
#from genetic_v2_3 import Subject, Genetic 
#from data_definitions import Mapa, CartesianPoint, Conversor, GeoPoint

#from file_manipulation import read_mapa, write_mavros, upload_mapa

## ENTRADA

# Parâmetros recebidos (arquivo .srv)
origin_lat       = -22.002237
origin_long      = -47.932546
origin_alt       = 13
destination_lat  = -22.002674 
destination_long = -47.932608
destination_alt  = 15

# P0
# destination_lat  = -22.002278 
# destination_long = -47.932099
# destination_alt  = 20

# P1
# destination_lat  = -22.002396 
# destination_long = -47.932063
# destination_alt  = 20


mapa_id          = 0

# Leitura do arquvio em DATA
#PATH = '/home/gustavosouza/Documents/Per/path-planning/data/mapa.json' #Ubuntu
PATH = r'../../data' #Windows
#geo_home, _, _, areas_n = read_mapa(PATH, mapa_id)
geo_home, _, _, areas_n = upload_mapa(mapa_file, mapa_id)

cart_origin      = Conversor.geo_to_cart(GeoPoint(origin_lat, origin_long, origin_alt), geo_home)
cart_destination = Conversor.geo_to_cart(GeoPoint(destination_lat, destination_long, destination_alt), geo_home)


mapa = Mapa(cart_origin, cart_destination, areas_n, inflation_rate=0.1)



## EXECUÇÃO DO AG
ag_teste = Genetic(Subject, mapa,
        # Genetic
        taxa_cross=0.5,
        population_size=100,
        C_d=1000,
        C_obs=10000,
        C_con=100,
        C_cur=500,
        C_t=1,
        max_exec_time=600,
        #Subject,
        T_min=10,
        T_max=40,
        mutation_prob=0.7,
        px0=cart_origin.x,
        py0=cart_origin.y
)


best = ag_teste.run(info=True)

# Melhor rota encontrada : WPs em cartesiano
cart_points = best.get_route()

# Melhor rota encontrada : WPs em geográfico
geo_points = [ Conversor.cart_to_geo(CartesianPoint(cart_point[0], cart_point[1]), geo_home) for cart_point in cart_points ]


# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

## SAÍDA

#output_filename = '/mnt/c/Projetos/path-planning/algorithms/ros_genetic/path_from_ga_output.wp'
#write_mavros(output_filename, geo_points)

# %%
best.fitness_trace
# Destino Obstáculo Consumo Curva QtdWP

# %%
best = ag_teste.best

# Visualização do Mapa usado, com a rota do melhor de todos
areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
tipos = [ 'n' for _ in range(len(areas))]
plot_map(
    areas=areas,            # Mapa usado
    labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
    origem=mapa.origin,      # waypoint de origem
    destino=mapa.destination, # waypoint de destino
    waypoints=best.get_route(), # rota do melhor de todos
)

# %% [markdown]
# # 5. Ray Casting Stress Test
# Testes de estresse para verificar desempenho do algoritmo Ray Casting

# %% [markdown]
# ## 5.1. Point in Polygon

# %%
qty_points = 1000


verts1 = [
    (2.5, 2.5), # left, bottom
    (2.5, 4.5), # left, top
    (4.5, 4.5), # right, top
    (4.5, 2.5), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

texts = []
wps = []
for i in range(qty_points):
    x = random.uniform(1,6)
    y = random.uniform(1,6)
    
    wp = CartesianPoint(x,y)
    wps.append(wp)
    texts.append(str(point_in_polygon(wp, verts1))[0])
    
plot_map(
    areas=[verts1], 
    labels=['n'], 
    texts=texts,
    points=wps,
    wp_style='x',
    title='Ray Casting Algorithm Stress Test, wp={}'.format(qty_points),
    stress=True
)

# %% [markdown]
# ## 5.2. Segment intersects polygon

# %%
qty_segments = 15

verts1 = [
    (2.5, 2.5), # left, bottom
    (2.5, 4.5), # left, top
    (4.5, 4.5), # right, top
    (4.5, 2.5), # right, bottom
]
verts1.append(verts1[0])
verts1 = [CartesianPoint(v[0], v[1]) for v in verts1]

texts = []
segments = []
for i in range(qty_segments):
    x = random.uniform(1,6)
    y = random.uniform(1,6)
    wp1 = CartesianPoint(x,y)

    x = random.uniform(1,6)
    y = random.uniform(1,6)
    wp2 = CartesianPoint(x,y)

    segment = [wp1, wp2]
    segments.append(segment)
    texts.append(str(segment_in_polygon(wp1, wp2, verts1))[0])
    
plot_map(
    areas=[verts1], 
    labels=['n'], 
    texts=texts,
    segments=segments,
    wp_style='-x',
    title='Ray Casting Algorithm Stress Test, wp={}'.format(qty_segments),
    stress=True
)

# %% [markdown]
# # 6. Automated Experiments

# %% [markdown]
# ## Def

# %%
debug = False

# Altere aqui o mapa que deseja utilizar
#mapa = mapa_1
#mapa = mapa_2
#mapa = mapa_3
#mapa = mapa_4

def run_ag(mapa):

    # Inicialização do Algoritmo
    ag = Genetic(Subject, mapa, 
            version = Version('beta', 'RC'),
            # Parâmetros da classe Genetic:
            taxa_cross=5,
            population_size=10,
            C_d=1000,
            C_obs=10000,
            C_con=500,
            C_cur=100,
            C_t=100,
            max_exec_time=600, # segundos
            # Parâmetros da classe Subject:
            px0=mapa.origin.x,
            py0=mapa.origin.y,
            T=10,
            T_min=1,
            T_max=25,
            mutation_prob=0.7
    )

    # Execução do AG, retorna o melhor indivíduo
    best = ag.run(info=True)

    # Print do DNA do melhor
    print('-'*30)
    for dna in best.dna:
        print(dna)
        
    # Print do DNA DECODIFICADO do melhor
    print('-'*30)
    for dna_decoded in best.dna_decoded:
        print(dna_decoded)
        
    best = ag.best

    # Visualização do Mapa usado, com a rota do melhor de todos
    areas = [ area for area in itertools.chain(mapa.areas_n, mapa.areas_n_inf) ]
    tipos = [ 'n' for _ in range(len(areas))]
    plot_map(
        areas=areas,            # Mapa usado
        labels=tipos,            # Tipo do mapa {'n','p','b'} <- Não afeta o genético, só muda a visualização
        origem=mapa.origin,      # waypoint de origem
        destino=mapa.destination, # waypoint de destino
        waypoints=best.get_route(), # rota do melhor de todos
    )


    # Visualização de alguns gráficos de fitness e quantidade de Ts
    #plot_stats(ag.trace, normalize=True)
    #plot_stats(ag.trace, normalize=False)

    return ag

# %% [markdown]
# ## Run

# %%
import pickle

# %%
tests = {
    'mapa1':{
        'ags': [],
        'res': []
    },
    'mapa2':{
        'ags': [],
        'res': []
    },
    'mapa3':{
        'ags': [],
        'res': []
    },
    'mapa4':{
        'ags': [],
        'res': []
    }
}

# %%
import pickle

for i in range(5):
    for selected_map, mapa in zip(['mapa1','mapa2','mapa3','mapa4'], [mapa_1,mapa_2,mapa_3,mapa_4]):
        ag = run_ag(mapa)
        tests[selected_map]['ags'].append(ag)
        
        l = [[subject.fitness, subject.birth_time] for subject in ag.ancestry]   
        tests[selected_map]['res'].append(l)
        
        pickle.dump(tests, open( 'backups/{}_{}.p'.format(selected_map, str(i)), 'wb' ) )

pickle.dump(tests, open('execution_10min.p', 'wb'))
# Out:
# Meteoro! Melhor de todos:7775.525130509282 - count:24
# Meteoro! Melhor de todos:5545.299943705328 - count:23
# Meteoro! Melhor de todos:5444.704524181873 - count:9
# Meteoro! Melhor de todos:5444.704524181873 - count:14
# Meteoro! Melhor de todos:4966.144131486644 - count:96
# Meteoro! Melhor de todos:3212.270985492531 - count:162
# Meteoro! Melhor de todos:3212.270985492531 - count:9
# Meteoro! Melhor de todos:3198.6616549464 - count:83
# Meteoro! Melhor de todos:3189.4242415957438 - count:12
# Meteoro! Melhor de todos:3189.4242415957438 - count:12
# Meteoro! Melhor de todos:3186.671631196726 - count:70
# Meteoro! Melhor de todos:3186.671631196726 - count:6
# Meteoro! Melhor de todos:3163.667049250611 - count:24
# Meteoro! Melhor de todos:3163.667049250611 - count:19
# Meteoro! Melhor de todos:3157.875874997315 - count:18
# Meteoro! Melhor de todos:3157.875874997315 - count:8
# Meteoro! Melhor de todos:3155.756954498797 - count:79
# Meteoro! Melhor de todos:3155.3899001049595 - count:20
# Meteoro! Melhor de todos:3155.1780001661546 - count:48
# Meteoro! Melhor de todos:3154.9308737490073 - count:44
# Meteoro! Melhor de todos:3116.3050457443096 - count:26
# Meteoro! Melhor de todos:3115.8444383613923 - count:17
# Meteoro! Melhor de todos:2865.5171572190607 - count:16
# Meteoro! Melhor de todos:2857.1305207820355 - count:39
# Meteoro! Melhor de todos:2851.4054362428164 - count:32
# Meteoro! Melhor de todos:2821.931180502671 - count:129
# Meteoro! Melhor de todos:2821.0340594819463 - count:35
# Meteoro! Melhor de todos:2821.0340594819463 - count:17
# Meteoro! Melhor de todos:2819.5250507908468 - count:73
# Meteoro! Melhor de todos:2819.5250507908468 - count:10
# Meteoro! Melhor de todos:2787.186784232465 - count:14
# Meteoro! Melhor de todos:2780.4363458263842 - count:23
# Meteoro! Melhor de todos:2766.5031768304907 - count:22
# Meteoro! Melhor de todos:2753.6455277494415 - count:19
# Meteoro! Melhor de todos:2753.6455277494415 - count:8
# Meteoro! Melhor de todos:2732.642016827898 - count:68
# Meteoro! Melhor de todos:2730.598963446 - count:55
# Meteoro! Melhor de todos:2729.815394339381 - count:75
# Meteoro! Melhor de todos:2729.815394339381 - count:11
# Meteoro! Melhor de todos:2715.9251449657277 - count:132
# Meteoro! Melhor de todos:2715.9251449657277 - count:20
# Meteoro! Melhor de todos:2715.9251449657277 - count:10
# Meteoro! Melhor de todos:2694.645336506445 - count:43
# Meteoro! Melhor de todos:2633.4548740011496 - count:201
# Meteoro! Melhor de todos:2571.8180767674785 - count:101
# Meteoro! Melhor de todos:2571.1603966238563 - count:18
# Meteoro! Melhor de todos:2570.760203843058 - count:10
# Meteoro! Melhor de todos:2570.760203843058 - count:23
# Meteoro! Melhor de todos:2570.760203843058 - count:7
# Meteoro! Melhor de todos:2570.760203843058 - count:10
# Meteoro! Melhor de todos:2568.274973484979 - count:31
# Meteoro! Melhor de todos:2568.0771363581 - count:20
# Meteoro! Melhor de todos:2568.0771363581 - count:8
# Meteoro! Melhor de todos:2552.969717551339 - count:25
# Meteoro! Melhor de todos:2552.969717551339 - count:7
# Meteoro! Melhor de todos:2552.969717551339 - count:22
# Meteoro! Melhor de todos:2552.969717551339 - count:5
# Meteoro! Melhor de todos:2551.9639539571476 - count:43
# Meteoro! Melhor de todos:2551.8950695851213 - count:18
# Meteoro! Melhor de todos:2539.780875487789 - count:156
# Meteoro! Melhor de todos:2529.0650826048886 - count:84
# Meteoro! Melhor de todos:2513.545514606881 - count:147
# Meteoro! Melhor de todos:2513.545514606881 - count:17
# Meteoro! Melhor de todos:2513.545514606881 - count:19
# Meteoro! Melhor de todos:2513.4862396502494 - count:54
# Meteoro! Melhor de todos:2513.4862396502494 - count:5
# Meteoro! Melhor de todos:2513.4862396502494 - count:19
# Meteoro! Melhor de todos:2513.4862396502494 - count:11
# Meteoro! Melhor de todos:2513.4862396502494 - count:12
# Meteoro! Melhor de todos:2513.4862396502494 - count:9
# Meteoro! Melhor de todos:2513.4862396502494 - count:11
# Meteoro! Melhor de todos:2513.4862396502494 - count:18
# Meteoro! Melhor de todos:2502.6757879536044 - count:100
# Meteoro! Melhor de todos:2502.6757879536044 - count:17
# Meteoro! Melhor de todos:2502.6757879536044 - count:20
# Meteoro! Melhor de todos:2502.6757879536044 - count:15
# Meteoro! Melhor de todos:2502.3013305338272 - count:122
# Meteoro! Melhor de todos:2502.299480443354 - count:35
# Meteoro! Melhor de todos:2502.299480443354 - count:19
# Meteoro! Melhor de todos:2496.539974669883 - count:110
# Meteoro! Melhor de todos:2496.5395001908964 - count:20
# Meteoro! Melhor de todos:2496.5395001908964 - count:18
# Meteoro! Melhor de todos:2496.5395001908964 - count:18
# Meteoro! Melhor de todos:2496.5210608315942 - count:27
# Meteoro! Melhor de todos:2496.1101329657704 - count:65
# Meteoro! Melhor de todos:2495.606706760632 - count:25
# Meteoro! Melhor de todos:2495.503120031298 - count:53
# Meteoro! Melhor de todos:2495.503120031298 - count:16
# Meteoro! Melhor de todos:2495.503120031298 - count:7
# Meteoro! Melhor de todos:2495.503120031298 - count:16
# Meteoro! Melhor de todos:2495.3929802709536 - count:48
# Meteoro! Melhor de todos:2495.3929802709536 - count:21
# Meteoro! Melhor de todos:2495.3875428484716 - count:18
# Meteoro! Melhor de todos:2494.7010119616352 - count:20
# Meteoro! Melhor de todos:2494.433373154961 - count:25
# Meteoro! Melhor de todos:2494.433373154961 - count:11
# Meteoro! Melhor de todos:2494.433373154961 - count:4
# Meteoro! Melhor de todos:2494.433373154961 - count:9
# Meteoro! Melhor de todos:2494.433373154961 - count:8
# Meteoro! Melhor de todos:2494.433373154961 - count:15
# Meteoro! Melhor de todos:2493.5350401650117 - count:15
# Meteoro! Melhor de todos:2486.5717801299193 - count:129
# Meteoro! Melhor de todos:2486.5505769267356 - count:13
# Meteoro! Melhor de todos:2480.8881078867616 - count:16
# Meteoro! Melhor de todos:2480.8881078867616 - count:5
# Meteoro! Melhor de todos:2480.8881078867616 - count:17
# Meteoro! Melhor de todos:2480.8881078867616 - count:7
# Meteoro! Melhor de todos:2480.8148050012105 - count:27
# Meteoro! Melhor de todos:2480.8148050012105 - count:28
# Meteoro! Melhor de todos:2480.8148050012105 - count:13
# Meteoro! Melhor de todos:2480.8148050012105 - count:13
# Meteoro! Melhor de todos:2480.8148050012105 - count:20
# Meteoro! Melhor de todos:2480.8148050012105 - count:22
# Meteoro! Melhor de todos:2479.8750003868927 - count:71
# Meteoro! Melhor de todos:2479.7986407757567 - count:23
# Meteoro! Melhor de todos:2479.7225928990874 - count:44
# Meteoro! Melhor de todos:2479.7225928990874 - count:10
# Meteoro! Melhor de todos:2479.7225928990874 - count:11
# Meteoro! Melhor de todos:2479.7225928990874 - count:10
# Meteoro! Melhor de todos:2479.7225928990874 - count:13
# Meteoro! Melhor de todos:2479.7225928990874 - count:12
# Meteoro! Melhor de todos:2479.7225928990874 - count:14
# Meteoro! Melhor de todos:2479.7225928990874 - count:11
# Meteoro! Melhor de todos:2479.7225928990874 - count:15
# Meteoro! Melhor de todos:2479.7225928990874 - count:22
# Meteoro! Melhor de todos:2479.7225928990874 - count:8
# Meteoro! Melhor de todos:2477.9976912780494 - count:22
# Meteoro! Melhor de todos:2477.9976912780494 - count:11
# Meteoro! Melhor de todos:2477.9976912780494 - count:29
# Meteoro! Melhor de todos:2474.2914145119694 - count:28
# Meteoro! Melhor de todos:2474.2908173657834 - count:11
# Meteoro! Melhor de todos:2474.2908173657834 - count:20
# Meteoro! Melhor de todos:2474.2908173657834 - count:19
# Meteoro! Melhor de todos:2474.2908173657834 - count:13
# Meteoro! Melhor de todos:2474.2908173657834 - count:17
# Meteoro! Melhor de todos:2474.2908173657834 - count:19
# Meteoro! Melhor de todos:2474.2908173657834 - count:19
# Meteoro! Melhor de todos:2474.2908173657834 - count:7
# Meteoro! Melhor de todos:2474.112170596806 - count:41
# Meteoro! Melhor de todos:2474.112170596806 - count:23
# Meteoro! Melhor de todos:2474.112170596806 - count:12
# Meteoro! Melhor de todos:2474.112170596806 - count:15
# Meteoro! Melhor de todos:2473.7296389856897 - count:48
# Meteoro! Melhor de todos:2473.7296389856897 - count:10
# Meteoro! Melhor de todos:2473.5806269982836 - count:51
# Meteoro! Melhor de todos:2473.5806269982836 - count:19
# Meteoro! Melhor de todos:2471.266761439181 - count:19
# Meteoro! Melhor de todos:2471.266761439181 - count:23
# Meteoro! Melhor de todos:2471.266761439181 - count:6
# Meteoro! Melhor de todos:2471.266761439181 - count:12
# Meteoro! Melhor de todos:2466.97700647246 - count:56
# Meteoro! Melhor de todos:2464.989100807097 - count:20
# Meteoro! Melhor de todos:2464.781969758512 - count:18
# Meteoro! Melhor de todos:2458.820575684254 - count:143
# Meteoro! Melhor de todos:2458.820575684254 - count:14
# Meteoro! Melhor de todos:2458.820575684254 - count:18
# Meteoro! Melhor de todos:2458.820575684254 - count:22
# Meteoro! Melhor de todos:2458.820575684254 - count:9
# Meteoro! Melhor de todos:2458.820575684254 - count:15
# Meteoro! Melhor de todos:2458.820575684254 - count:19
# Meteoro! Melhor de todos:2454.7306791094097 - count:114
# Meteoro! Melhor de todos:2453.614812618693 - count:53
# Meteoro! Melhor de todos:2453.614812618693 - count:19
# Meteoro! Melhor de todos:2453.3259159437266 - count:71
# Meteoro! Melhor de todos:2453.3259159437266 - count:15
# Meteoro! Melhor de todos:2453.3259159437266 - count:15
# Meteoro! Melhor de todos:2453.3259159437266 - count:12
# Meteoro! Melhor de todos:2448.3467678330016 - count:25
# Meteoro! Melhor de todos:2448.23019785209 - count:22
# Meteoro! Melhor de todos:2448.2146790080333 - count:12
# Meteoro! Melhor de todos:2448.2146790080333 - count:15
# Meteoro! Melhor de todos:2446.414095412693 - count:107
# Meteoro! Melhor de todos:2446.414095412693 - count:12
# Meteoro! Melhor de todos:2445.2991902575195 - count:22
# Meteoro! Melhor de todos:2445.286494093128 - count:27
# Meteoro! Melhor de todos:2445.2151064503505 - count:19
# Meteoro! Melhor de todos:2445.1388153697776 - count:10
# Meteoro! Melhor de todos:2445.1388153697776 - count:15
# Meteoro! Melhor de todos:2445.1388153697776 - count:23
# Meteoro! Melhor de todos:2445.133051486483 - count:20
# Meteoro! Melhor de todos:2445.133051486483 - count:16
# Meteoro! Melhor de todos:2444.874217698877 - count:50
# Meteoro! Melhor de todos:2444.874217698877 - count:20
# Meteoro! Melhor de todos:2444.874217698877 - count:7
# Meteoro! Melhor de todos:2444.874217698877 - count:5
# Meteoro! Melhor de todos:2444.874217698877 - count:16
# Meteoro! Melhor de todos:2444.874217698877 - count:24
# Meteoro! Melhor de todos:2427.5367717328713 - count:29
# Meteoro! Melhor de todos:2418.7001259631493 - count:87
# Meteoro! Melhor de todos:2418.7001259631493 - count:20
# Meteoro! Melhor de todos:2418.5880248885387 - count:30
# Meteoro! Melhor de todos:2403.134084453347 - count:46
# Meteoro! Melhor de todos:2403.134084453347 - count:17
# Meteoro! Melhor de todos:2403.132046498795 - count:35
# Meteoro! Melhor de todos:2403.132046498795 - count:19
# Meteoro! Melhor de todos:2403.132046498795 - count:15
# Meteoro! Melhor de todos:2398.9213933118463 - count:86
# Meteoro! Melhor de todos:2398.9213933118463 - count:7
# Meteoro! Melhor de todos:2398.9213933118463 - count:22
# Meteoro! Melhor de todos:2398.80804442136 - count:46
# Meteoro! Melhor de todos:2398.4742607495505 - count:15
# Meteoro! Melhor de todos:2394.105852181189 - count:60
# Meteoro! Melhor de todos:2391.452001309746 - count:85
# Meteoro! Melhor de todos:2391.452001309746 - count:17
# Meteoro! Melhor de todos:2389.4741017433344 - count:62
# Meteoro! Melhor de todos:2388.293268502819 - count:57
# Meteoro! Melhor de todos:2388.293268502819 - count:25
# Meteoro! Melhor de todos:2385.9809272348207 - count:34
# Meteoro! Melhor de todos:2385.9809272348207 - count:15
# Meteoro! Melhor de todos:2385.9809272348207 - count:23
# Meteoro! Melhor de todos:2385.9485233837036 - count:24
# Meteoro! Melhor de todos:2385.884898745749 - count:46
# Meteoro! Melhor de todos:2385.884898745749 - count:12
# Meteoro! Melhor de todos:2385.862816130092 - count:23
# Meteoro! Melhor de todos:2365.9402847233496 - count:81
# Meteoro! Melhor de todos:2363.1256385803067 - count:23
# Meteoro! Melhor de todos:2362.2614569887965 - count:42
# Meteoro! Melhor de todos:2362.2614569887965 - count:13
# Meteoro! Melhor de todos:2355.7002343469367 - count:35
# Meteoro! Melhor de todos:2355.3860458690697 - count:28
# Meteoro! Melhor de todos:2355.3860458690697 - count:5
# Meteoro! Melhor de todos:2354.8648010874886 - count:19
# Meteoro! Melhor de todos:2354.8648010874886 - count:18
# Meteoro! Melhor de todos:2354.8648010874886 - count:19
# Meteoro! Melhor de todos:2354.8648010874886 - count:23
# Meteoro! Melhor de todos:2354.8648010874886 - count:15
# Meteoro! Melhor de todos:2354.8648010874886 - count:19
# Meteoro! Melhor de todos:2354.8648010874886 - count:20
# Meteoro! Melhor de todos:2354.8093352751143 - count:30
# Meteoro! Melhor de todos:2354.8035970635037 - count:27
# Meteoro! Melhor de todos:2354.8035970635037 - count:20
# Meteoro! Melhor de todos:2354.8035970635037 - count:22
# Meteoro! Melhor de todos:2351.9575877475127 - count:71
# Meteoro! Melhor de todos:2351.9575877475127 - count:10
# Meteoro! Melhor de todos:2351.957433600552 - count:27
# Meteoro! Melhor de todos:2351.957433600552 - count:20
# Meteoro! Melhor de todos:2351.957433600552 - count:17
# Meteoro! Melhor de todos:2351.9499182493246 - count:39
# Meteoro! Melhor de todos:2351.812033896377 - count:35
# Meteoro! Melhor de todos:2351.812033896377 - count:15
# Meteoro! Melhor de todos:2351.812033896377 - count:28
# Meteoro! Melhor de todos:2351.812033896377 - count:7
# Meteoro! Melhor de todos:2351.812033896377 - count:15
# Meteoro! Melhor de todos:2351.812033896377 - count:24
# Meteoro! Melhor de todos:2351.812033896377 - count:14
# Meteoro! Melhor de todos:2351.812033896377 - count:10
# Meteoro! Melhor de todos:2351.812033896377 - count:20
# Meteoro! Melhor de todos:2351.236391833843 - count:70
# Meteoro! Melhor de todos:2350.5714486775987 - count:57
# Meteoro! Melhor de todos:2350.5714486775987 - count:10
# Meteoro! Melhor de todos:2350.5714486775987 - count:21
# Meteoro! Melhor de todos:2350.5714486775987 - count:7
# Meteoro! Melhor de todos:2350.5711400901655 - count:32
# Meteoro! Melhor de todos:2350.5711400901655 - count:26
# Meteoro! Melhor de todos:2350.5711400901655 - count:14
# Meteoro! Melhor de todos:2350.5711400901655 - count:16
# Meteoro! Melhor de todos:2350.5711400901655 - count:18
# Meteoro! Melhor de todos:2350.5711400901655 - count:14
# Meteoro! Melhor de todos:2350.5711400901655 - count:19
# Meteoro! Melhor de todos:2350.5711400901655 - count:12
# Meteoro! Melhor de todos:2350.5711400901655 - count:25
# Meteoro! Melhor de todos:2350.5711400901655 - count:14
# Meteoro! Melhor de todos:2350.5711400901655 - count:23
# Meteoro! Melhor de todos:2350.5711400901655 - count:18
# Meteoro! Melhor de todos:2350.5711400901655 - count:14
# Meteoro! Melhor de todos:2350.5711400901655 - count:17
# Meteoro! Melhor de todos:2350.5711400901655 - count:15
# Meteoro! Melhor de todos:2350.5711400901655 - count:11
# Meteoro! Melhor de todos:2350.5711400901655 - count:18
# Meteoro! Melhor de todos:2350.5711400901655 - count:15
# Meteoro! Melhor de todos:2350.5711400901655 - count:31
# Meteoro! Melhor de todos:2350.5711400901655 - count:8
# Meteoro! Melhor de todos:2350.5711400901655 - count:19
# Meteoro! Melhor de todos:2350.5711400901655 - count:11
# Meteoro! Melhor de todos:2350.5711400901655 - count:18
# Meteoro! Melhor de todos:2350.5711400901655 - count:18
# Meteoro! Melhor de todos:2350.5711400901655 - count:20
# Meteoro! Melhor de todos:2350.5580744375766 - count:23
# Meteoro! Melhor de todos:2350.5580744375766 - count:14
# Meteoro! Melhor de todos:2350.5580744375766 - count:17
# Meteoro! Melhor de todos:2350.5580744375766 - count:11
# Meteoro! Melhor de todos:2344.9558841270837 - count:24
# Meteoro! Melhor de todos:2344.7343280949026 - count:63
# Meteoro! Melhor de todos:2344.7291072287603 - count:64
# Meteoro! Melhor de todos:2344.7291072287603 - count:14
# Meteoro! Melhor de todos:2344.7291072287603 - count:20
# Meteoro! Melhor de todos:2344.7291072287603 - count:19
# Meteoro! Melhor de todos:2344.7291072287603 - count:22
# Meteoro! Melhor de todos:2344.7291072287603 - count:11
# Meteoro! Melhor de todos:2344.7291072287603 - count:8
# Meteoro! Melhor de todos:2344.7291072287603 - count:16
# Meteoro! Melhor de todos:2344.7291072287603 - count:18
# Meteoro! Melhor de todos:2344.6971048178693 - count:56
# Meteoro! Melhor de todos:2344.6971048178693 - count:13
# Meteoro! Melhor de todos:2344.6971048178693 - count:17
# Meteoro! Melhor de todos:2344.1522013229014 - count:87
# Meteoro! Melhor de todos:2344.135867477288 - count:35
# Meteoro! Melhor de todos:2344.1341060720815 - count:18
# Meteoro! Melhor de todos:2344.1341060720815 - count:13
# Meteoro! Melhor de todos:2344.1341060720815 - count:22
# Meteoro! Melhor de todos:2343.0185887074513 - count:27
# Meteoro! Melhor de todos:2343.0185887074513 - count:13
# Meteoro! Melhor de todos:2343.0185887074513 - count:19
# Meteoro! Melhor de todos:2343.0185887074513 - count:18
# Meteoro! Melhor de todos:2340.2734389844363 - count:67
# Meteoro! Melhor de todos:2340.2734389844363 - count:17
# Meteoro! Melhor de todos:2340.2734389844363 - count:18
# Meteoro! Melhor de todos:2340.2734389844363 - count:11
# Meteoro! Melhor de todos:2340.2734389844363 - count:65
# Meteoro! Melhor de todos:2340.2734389844363 - count:17
# Meteoro! Melhor de todos:2340.2734389844363 - count:6
# Meteoro! Melhor de todos:2340.2734389844363 - count:12
# Meteoro! Melhor de todos:2340.2734389844363 - count:24
# Meteoro! Melhor de todos:2340.2734389844363 - count:5
# Meteoro! Melhor de todos:2340.2734389844363 - count:25
# Meteoro! Melhor de todos:2340.2734389844363 - count:10
# Meteoro! Melhor de todos:2340.2734389844363 - count:22
# Meteoro! Melhor de todos:2340.2734354614713 - count:23
# Meteoro! Melhor de todos:2340.2734354614713 - count:31
# Meteoro! Melhor de todos:2340.2734354614713 - count:22
# Meteoro! Melhor de todos:2340.2734354614713 - count:25
# Meteoro! Melhor de todos:2340.2734354614713 - count:13
# Meteoro! Melhor de todos:2340.2734354614713 - count:20
# Meteoro! Melhor de todos:2340.2734354614713 - count:14
# Meteoro! Melhor de todos:2340.2734354614713 - count:17
# Meteoro! Melhor de todos:2340.2734354614713 - count:16
# Meteoro! Melhor de todos:2340.2734354614713 - count:22
# Meteoro! Melhor de todos:2340.2734354614713 - count:15
# Meteoro! Melhor de todos:2340.2734354614713 - count:12
# Meteoro! Melhor de todos:2340.2734354614713 - count:16
# Meteoro! Melhor de todos:2340.2734354614713 - count:20
# Meteoro! Melhor de todos:2340.2734354614713 - count:27
# Meteoro! Melhor de todos:2340.267138082694 - count:35
# Meteoro! Melhor de todos:2340.267138082694 - count:14
# Meteoro! Melhor de todos:2338.2904395180703 - count:32
# Meteoro! Melhor de todos:2338.2904395180703 - count:12
# Meteoro! Melhor de todos:2338.2904395180703 - count:30
# Meteoro! Melhor de todos:2338.2904395180703 - count:15
# Meteoro! Melhor de todos:2338.2904395180703 - count:18
# Meteoro! Melhor de todos:2338.2904395180703 - count:10
# Meteoro! Melhor de todos:2338.2904395180703 - count:6
# Meteoro! Melhor de todos:2338.04378031539 - count:85
# Meteoro! Melhor de todos:2338.0413438973064 - count:25
# Meteoro! Melhor de todos:2338.0413438973064 - count:20
# Meteoro! Melhor de todos:2337.5101302037438 - count:72
# Meteoro! Melhor de todos:2337.5101302037438 - count:14
# Meteoro! Melhor de todos:2337.5101302037438 - count:25
# Meteoro! Melhor de todos:2337.5101302037438 - count:15
# Meteoro! Melhor de todos:2337.5073669635385 - count:25
# Meteoro! Melhor de todos:2337.5073669635385 - count:23
# Meteoro! Melhor de todos:2337.5073669635385 - count:10
# Meteoro! Melhor de todos:2337.507154418803 - count:17
# Meteoro! Melhor de todos:2337.507154418803 - count:10
# Meteoro! Melhor de todos:2337.507154418803 - count:16
# Meteoro! Melhor de todos:2337.507154418803 - count:10
# Meteoro! Melhor de todos:2337.507154418803 - count:16
# Meteoro! Melhor de todos:2337.507154418803 - count:25
# Meteoro! Melhor de todos:2337.507154418803 - count:17
# Meteoro! Melhor de todos:2337.507154418803 - count:24
# Meteoro! Melhor de todos:2337.507154418803 - count:21
# Meteoro! Melhor de todos:2337.507154418803 - count:24
# Meteoro! Melhor de todos:2337.507154418803 - count:20
# Meteoro! Melhor de todos:2337.507154418803 - count:19
# Meteoro! Melhor de todos:2337.507154418803 - count:10
# Meteoro! Melhor de todos:2337.4495154675724 - count:83
# Meteoro! Melhor de todos:2337.4495154675724 - count:27
# Meteoro! Melhor de todos:2337.4495154675724 - count:21
# Meteoro! Melhor de todos:2337.4495154675724 - count:10
# Meteoro! Melhor de todos:2337.402111867572 - count:26
# Meteoro! Melhor de todos:2337.402111867572 - count:14
# Meteoro! Melhor de todos:2337.402111867572 - count:20
# Meteoro! Melhor de todos:2337.402111867572 - count:24
# Meteoro! Melhor de todos:2337.4015241734 - count:28
# Meteoro! Melhor de todos:2337.4015241734 - count:16
# Meteoro! Melhor de todos:2337.4015241734 - count:14
# Meteoro! Melhor de todos:2337.4015241734 - count:11
# Meteoro! Melhor de todos:2337.4015241734 - count:11
# Meteoro! Melhor de todos:2337.4015241734 - count:22
# Meteoro! Melhor de todos:2337.4015241734 - count:17
# Meteoro! Melhor de todos:2337.4015241734 - count:35
# Meteoro! Melhor de todos:2337.4015241734 - count:15
# Meteoro! Melhor de todos:2337.400696478008 - count:30
# Meteoro! Melhor de todos:2337.400696478008 - count:10
# Meteoro! Melhor de todos:2337.400696478008 - count:29
# Meteoro! Melhor de todos:2337.400696478008 - count:16
# Meteoro! Melhor de todos:2337.400696478008 - count:22
# Meteoro! Melhor de todos:2337.400696478008 - count:16
# Meteoro! Melhor de todos:2337.400696478008 - count:28
# Meteoro! Melhor de todos:2337.400696478008 - count:17
# Meteoro! Melhor de todos:2337.400696478008 - count:21
# Meteoro! Melhor de todos:2337.400696478008 - count:4
# Meteoro! Melhor de todos:2337.400696478008 - count:22
# Meteoro! Melhor de todos:2337.400696478008 - count:33
# Meteoro! Melhor de todos:2337.400696478008 - count:11
# Meteoro! Melhor de todos:2337.400696478008 - count:27
# Meteoro! Melhor de todos:2337.400617494817 - count:35
# Meteoro! Melhor de todos:2337.400617494817 - count:20
# Meteoro! Melhor de todos:2337.400617494817 - count:14
# Meteoro! Melhor de todos:2337.400617494817 - count:21
# Meteoro! Melhor de todos:2337.400617494817 - count:14
# Meteoro! Melhor de todos:2337.400617494817 - count:19
# Meteoro! Melhor de todos:2337.400617494817 - count:10
# Meteoro! Melhor de todos:2337.400617494817 - count:9
# Meteoro! Melhor de todos:2337.400617494817 - count:22
# Meteoro! Melhor de todos:2337.400617494817 - count:8
# Meteoro! Melhor de todos:2337.400617494817 - count:14
# Meteoro! Melhor de todos:2337.400617494817 - count:12
# Meteoro! Melhor de todos:2337.400617494817 - count:26
# Meteoro! Melhor de todos:2337.400617494817 - count:29
# Meteoro! Melhor de todos:2337.400617494817 - count:15
# Meteoro! Melhor de todos:2337.400617494817 - count:9
# Meteoro! Melhor de todos:2337.400617494817 - count:16
# Meteoro! Melhor de todos:2337.400617494817 - count:14
# Meteoro! Melhor de todos:2337.398383545947 - count:34
# Meteoro! Melhor de todos:2337.398383545947 - count:20
# Meteoro! Melhor de todos:2337.3983446581346 - count:52
# Meteoro! Melhor de todos:2337.3983446581346 - count:9
# Meteoro! Melhor de todos:2337.3983446581346 - count:13
# Meteoro! Melhor de todos:2337.3983446581346 - count:30
# Meteoro! Melhor de todos:2337.3983446581346 - count:18
# Meteoro! Melhor de todos:2337.3983446581346 - count:11
# Meteoro! Melhor de todos:2337.3983446581346 - count:23
# Meteoro! Melhor de todos:2337.3983446581346 - count:23
# Meteoro! Melhor de todos:2337.3983446581346 - count:29
# Meteoro! Melhor de todos:2337.3983446581346 - count:12
# Meteoro! Melhor de todos:2337.3983446581346 - count:17
# Meteoro! Melhor de todos:2337.3983446581346 - count:20
# Meteoro! Melhor de todos:2337.3983446581346 - count:9
# Meteoro! Melhor de todos:2333.8637872259224 - count:94
# Meteoro! Melhor de todos:2333.7124796509634 - count:8
# Meteoro! Melhor de todos:2333.262356842127 - count:96
# Meteoro! Melhor de todos:2332.9438018319674 - count:59
# Meteoro! Melhor de todos:2332.9438018319674 - count:16
# Meteoro! Melhor de todos:2332.913267985341 - count:94
# Meteoro! Melhor de todos:2332.913267985341 - count:9
# Meteoro! Melhor de todos:2332.913267985341 - count:17
# Meteoro! Melhor de todos:2332.913267985341 - count:25
# Meteoro! Melhor de todos:2332.913267985341 - count:18
# Meteoro! Melhor de todos:2332.913267985341 - count:10
# Meteoro! Melhor de todos:2332.913267985341 - count:26
# Meteoro! Melhor de todos:2332.913267985341 - count:18
# Meteoro! Melhor de todos:2332.913058840747 - count:39
# Meteoro! Melhor de todos:2332.913058840747 - count:20
# Meteoro! Melhor de todos:2332.913058840747 - count:22
# Meteoro! Melhor de todos:2332.913058840747 - count:25
# Meteoro! Melhor de todos:2332.913058840747 - count:23
# Meteoro! Melhor de todos:2332.913058840747 - count:18
# Meteoro! Melhor de todos:2332.913058840747 - count:19
# Meteoro! Melhor de todos:2332.9115501163014 - count:19
# Meteoro! Melhor de todos:2332.9115501163014 - count:16
# Meteoro! Melhor de todos:2332.9115501163014 - count:13
# Meteoro! Melhor de todos:2332.9115501163014 - count:15
# Meteoro! Melhor de todos:2332.9115501163014 - count:10
# Meteoro! Melhor de todos:2332.9115501163014 - count:13
# Meteoro! Melhor de todos:2332.9115501163014 - count:12
# Meteoro! Melhor de todos:2332.9115501163014 - count:9
# Meteoro! Melhor de todos:2332.9108058059674 - count:20
# Meteoro! Melhor de todos:2332.9108058059674 - count:25
# Meteoro! Melhor de todos:2332.9108058059674 - count:15
# Meteoro! Melhor de todos:2332.9108058059674 - count:7
# Meteoro! Melhor de todos:2332.9108058059674 - count:10
# Meteoro! Melhor de todos:2332.901653149285 - count:22
# Meteoro! Melhor de todos:2332.901653149285 - count:14
# Meteoro! Melhor de todos:2332.8930832778233 - count:31
# Meteoro! Melhor de todos:2332.8930832778233 - count:17
# Meteoro! Melhor de todos:2332.8930832778233 - count:7
# Meteoro! Melhor de todos:2332.8930832778233 - count:29
# Meteoro! Melhor de todos:2332.8930832778233 - count:16
# Meteoro! Melhor de todos:2332.8930832778233 - count:12
# Meteoro! Melhor de todos:2332.8930832778233 - count:15
# Meteoro! Melhor de todos:2332.8930832778233 - count:23
# Meteoro! Melhor de todos:2332.8930832778233 - count:8
# Meteoro! Melhor de todos:2332.8930832778233 - count:23
# Meteoro! Melhor de todos:2332.8930832778233 - count:11
# Meteoro! Melhor de todos:2332.8930832778233 - count:23
# Meteoro! Melhor de todos:2331.924630643551 - count:51
# Meteoro! Melhor de todos:2331.811682802003 - count:17
# Meteoro! Melhor de todos:2331.811682802003 - count:13
# Meteoro! Melhor de todos:2331.811682802003 - count:18
# Meteoro! Melhor de todos:2331.811682802003 - count:25
# Meteoro! Melhor de todos:2331.811682802003 - count:10
# Meteoro! Melhor de todos:2331.811682802003 - count:24
# Meteoro! Melhor de todos:2331.7934101588726 - count:24
# Meteoro! Melhor de todos:2331.7934101588726 - count:16
# Meteoro! Melhor de todos:2331.7934101588726 - count:13
# Meteoro! Melhor de todos:2331.7934101588726 - count:20
# Meteoro! Melhor de todos:2331.7934101588726 - count:37
# Meteoro! Melhor de todos:2331.7934101588726 - count:10
# Meteoro! Melhor de todos:2331.7934101588726 - count:21
# Meteoro! Melhor de todos:2331.7934101588726 - count:12
# Meteoro! Melhor de todos:2331.7934101588726 - count:20
# Meteoro! Melhor de todos:2331.7934101588726 - count:14
# Meteoro! Melhor de todos:2331.7609753919533 - count:32
# Meteoro! Melhor de todos:2331.7609753919533 - count:19
# Meteoro! Melhor de todos:2331.7508082932436 - count:36
# Meteoro! Melhor de todos:2331.7508082932436 - count:11
# Meteoro! Melhor de todos:2331.5981692083874 - count:60
# Meteoro! Melhor de todos:2331.4923951864184 - count:33
# Meteoro! Melhor de todos:2331.4508123837913 - count:20
# Meteoro! Melhor de todos:2331.4508123837913 - count:23
# Meteoro! Melhor de todos:2331.4508123837913 - count:14
# Meteoro! Melhor de todos:2331.4508123837913 - count:23
# Meteoro! Melhor de todos:2331.4508123837913 - count:19
# Meteoro! Melhor de todos:2331.4182214034613 - count:42
# Meteoro! Melhor de todos:2331.4182214034613 - count:23
# Meteoro! Melhor de todos:2331.4182214034613 - count:10
# Meteoro! Melhor de todos:2331.3109690884626 - count:16
# Meteoro! Melhor de todos:2331.3039792973013 - count:21
# Meteoro! Melhor de todos:2331.3039792973013 - count:21
# Meteoro! Melhor de todos:2331.3039792973013 - count:27
# Meteoro! Melhor de todos:2331.3039792973013 - count:19
# Meteoro! Melhor de todos:2331.3039792973013 - count:12
# Meteoro! Melhor de todos:2331.3039792973013 - count:13
# Meteoro! Melhor de todos:2331.3039792973013 - count:17
# Meteoro! Melhor de todos:2331.3039792973013 - count:10
# Meteoro! Melhor de todos:2331.3039792973013 - count:28
# Meteoro! Melhor de todos:2331.3039792973013 - count:13
# Meteoro! Melhor de todos:2331.3039792973013 - count:13
# Meteoro! Melhor de todos:2331.3039792973013 - count:11
# Meteoro! Melhor de todos:2331.1673462952886 - count:81
# Meteoro! Melhor de todos:2331.1673462952886 - count:11
# Meteoro! Melhor de todos:2331.1673462952886 - count:20
# Meteoro! Melhor de todos:2331.1673462952886 - count:19
# Meteoro! Melhor de todos:2331.1673462952886 - count:4
# Meteoro! Melhor de todos:2331.1673462952886 - count:22
# Meteoro! Melhor de todos:2331.1673462952886 - count:18
# Meteoro! Melhor de todos:2331.1673462952886 - count:13
# Meteoro! Melhor de todos:2331.1673462952886 - count:15
# Meteoro! Melhor de todos:2331.1656237682637 - count:23
# Meteoro! Melhor de todos:2331.1656237682637 - count:14
# Meteoro! Melhor de todos:2331.1656237682637 - count:14
# Meteoro! Melhor de todos:2331.1656237682637 - count:27
# Meteoro! Melhor de todos:2331.1200228328835 - count:31
# Meteoro! Melhor de todos:2331.1200228328835 - count:15
# Meteoro! Melhor de todos:2331.1200228328835 - count:15
# Meteoro! Melhor de todos:2331.1200228328835 - count:12
# Meteoro! Melhor de todos:2331.1200228328835 - count:21
# Meteoro! Melhor de todos:2331.1200228328835 - count:11
# Meteoro! Melhor de todos:2331.1200228328835 - count:16
# Meteoro! Melhor de todos:2331.1200228328835 - count:29
# Meteoro! Melhor de todos:2331.1200228328835 - count:16
# Meteoro! Melhor de todos:2331.1200228328835 - count:15
# Meteoro! Melhor de todos:2331.1200228328835 - count:16
# Meteoro! Melhor de todos:2331.1200228328835 - count:19
# Meteoro! Melhor de todos:2331.1200228328835 - count:18
# Meteoro! Melhor de todos:2331.1200228328835 - count:20
# Meteoro! Melhor de todos:2331.1200228328835 - count:23
# Meteoro! Melhor de todos:2331.1200228328835 - count:11
# Meteoro! Melhor de todos:2331.1200228328835 - count:21
# Meteoro! Melhor de todos:2331.1200228328835 - count:8
# Meteoro! Melhor de todos:2331.1200228328835 - count:28
# Meteoro! Melhor de todos:2331.1200228328835 - count:16
# Meteoro! Melhor de todos:2331.1200228328835 - count:20
# Meteoro! Melhor de todos:2331.1200228328835 - count:9
# Meteoro! Melhor de todos:2331.1200228328835 - count:16
# Meteoro! Melhor de todos:2331.1200228328835 - count:10
# Meteoro! Melhor de todos:2331.1200228328835 - count:22
# Meteoro! Melhor de todos:2331.1200228328835 - count:17
# Meteoro! Melhor de todos:2331.1200228328835 - count:21
# Meteoro! Melhor de todos:2331.1187530175694 - count:19
# Meteoro! Melhor de todos:2331.1187530175694 - count:9
# Meteoro! Melhor de todos:2331.1187530175694 - count:13
# Meteoro! Melhor de todos:2331.1187530175694 - count:17
# Meteoro! Melhor de todos:2331.1187530175694 - count:11
# Meteoro! Melhor de todos:2331.1187530175694 - count:17
# Meteoro! Melhor de todos:2331.1187530175694 - count:21
# Meteoro! Melhor de todos:2331.1187530175694 - count:14
# Meteoro! Melhor de todos:2331.1187530175694 - count:14
# Meteoro! Melhor de todos:2331.1187530175694 - count:16
# Meteoro! Melhor de todos:2331.1187530175694 - count:17
# Meteoro! Melhor de todos:2331.1187530175694 - count:22
# Meteoro! Melhor de todos:2331.1187530175694 - count:12
# Meteoro! Melhor de todos:2331.1187530175694 - count:15
# Meteoro! Melhor de todos:2331.1187530175694 - count:13
# Meteoro! Melhor de todos:2325.506235016629 - count:103
# Meteoro! Melhor de todos:2325.506235016629 - count:19
# Meteoro! Melhor de todos:2325.506235016629 - count:19
# Meteoro! Melhor de todos:2325.506235016629 - count:40
# Meteoro! Melhor de todos:2325.506235016629 - count:26
# Meteoro! Melhor de todos:2325.506235016629 - count:24
# Meteoro! Melhor de todos:2325.506235016629 - count:19
# Meteoro! Melhor de todos:2324.8534110962455 - count:45
# Meteoro! Melhor de todos:2324.6668096556323 - count:34
# Meteoro! Melhor de todos:2324.6668096556323 - count:20
# Meteoro! Melhor de todos:2324.6668096556323 - count:14
# Meteoro! Melhor de todos:2324.6668096556323 - count:17
# Meteoro! Melhor de todos:2324.6668096556323 - count:14
# Meteoro! Melhor de todos:2324.6668096556323 - count:22
# Meteoro! Melhor de todos:2324.6668096556323 - count:21
# Meteoro! Melhor de todos:2324.6668096556323 - count:9
# Meteoro! Melhor de todos:2324.4895284742806 - count:26
# Meteoro! Melhor de todos:2324.4895284742806 - count:11
# Meteoro! Melhor de todos:2324.4832311695063 - count:19
# Meteoro! Melhor de todos:2324.4832311695063 - count:28
# Meteoro! Melhor de todos:2324.417929078807 - count:18
# Meteoro! Melhor de todos:2324.417929078807 - count:13
# Meteoro! Melhor de todos:2324.417929078807 - count:19
# Meteoro! Melhor de todos:2324.417929078807 - count:17
# Meteoro! Melhor de todos:2324.4176922866154 - count:23
# Meteoro! Melhor de todos:2324.4176922866154 - count:11
# Meteoro! Melhor de todos:2324.4113815419414 - count:19
# Meteoro! Melhor de todos:2324.4113815419414 - count:17
# Meteoro! Melhor de todos:2324.4113815419414 - count:24
# Meteoro! Melhor de todos:2324.4113815419414 - count:14
# Meteoro! Melhor de todos:2324.4113815419414 - count:13
# Meteoro! Melhor de todos:2324.4113815419414 - count:25
# Meteoro! Melhor de todos:2324.4113815419414 - count:19
# Meteoro! Melhor de todos:2324.318068526144 - count:36
# Meteoro! Melhor de todos:2324.316715625181 - count:22
# Meteoro! Melhor de todos:2324.316715625181 - count:12
# Meteoro! Melhor de todos:2324.316715625181 - count:12
# Meteoro! Melhor de todos:2324.316715625181 - count:9
# Meteoro! Melhor de todos:2324.316715625181 - count:14
# Meteoro! Melhor de todos:2324.2241744640796 - count:38
# Meteoro! Melhor de todos:2324.222250319836 - count:35
# Meteoro! Melhor de todos:2324.222250319836 - count:15
# Meteoro! Melhor de todos:2324.222250319836 - count:12
# Meteoro! Melhor de todos:2324.222250319836 - count:20
# Meteoro! Melhor de todos:2322.526730969343 - count:26
# Meteoro! Melhor de todos:2322.5265351878033 - count:20
# Meteoro! Melhor de todos:2322.5265351878033 - count:6
# Meteoro! Melhor de todos:2322.5265351878033 - count:12
# Meteoro! Melhor de todos:2322.5265351878033 - count:9
# Meteoro! Melhor de todos:2322.5265351878033 - count:9
# Meteoro! Melhor de todos:2322.433255630063 - count:17
# Meteoro! Melhor de todos:2322.433255630063 - count:117
# Meteoro! Melhor de todos:2322.433255630063 - count:14
# Meteoro! Melhor de todos:2322.2407777749795 - count:25
# Meteoro! Melhor de todos:2322.2407777749795 - count:21
# Meteoro! Melhor de todos:2322.1736338961887 - count:31
# Meteoro! Melhor de todos:2322.1736338961887 - count:10
# Meteoro! Melhor de todos:2322.1736338961887 - count:16
# Meteoro! Melhor de todos:2322.1708088059013 - count:19
# Meteoro! Melhor de todos:2322.125296690302 - count:20
# Meteoro! Melhor de todos:2322.0454082216716 - count:34
# Meteoro! Melhor de todos:2322.0454082216716 - count:17
# Meteoro! Melhor de todos:2321.990306388806 - count:65
# Meteoro! Melhor de todos:2321.990306388806 - count:19
# Meteoro! Melhor de todos:2321.990217121601 - count:46
# Meteoro! Melhor de todos:2321.990217121601 - count:27
# Meteoro! Melhor de todos:2321.990217121601 - count:7
# Meteoro! Melhor de todos:2321.990217121601 - count:15
# Meteoro! Melhor de todos:2321.990217121601 - count:13
# Meteoro! Melhor de todos:2321.990217121601 - count:25
# Meteoro! Melhor de todos:2321.94909797699 - count:16
# Meteoro! Melhor de todos:2321.94909797699 - count:23
# Meteoro! Melhor de todos:2321.94909797699 - count:11
# Meteoro! Melhor de todos:2321.94909797699 - count:13
# Meteoro! Melhor de todos:2321.94909797699 - count:10
# Meteoro! Melhor de todos:2321.94909797699 - count:12
# Meteoro! Melhor de todos:2321.810700618582 - count:19
# Meteoro! Melhor de todos:2316.8376175767926 - count:51
# Meteoro! Melhor de todos:2310.387837054717 - count:30
# Meteoro! Melhor de todos:2310.387837054717 - count:16
# Meteoro! Melhor de todos:2310.387837054717 - count:15
# Meteoro! Melhor de todos:2306.3570485201517 - count:61
# Meteoro! Melhor de todos:2303.5976271124573 - count:28
# Meteoro! Melhor de todos:2303.5976271124573 - count:13
# Meteoro! Melhor de todos:2303.28653128701 - count:14
# Meteoro! Melhor de todos:2303.273411887002 - count:22
# Meteoro! Melhor de todos:2303.273411887002 - count:17
# Meteoro! Melhor de todos:2303.273411887002 - count:20
# Meteoro! Melhor de todos:2303.273411887002 - count:5
# Meteoro! Melhor de todos:2303.273411887002 - count:19
# Meteoro! Melhor de todos:2303.0980725211166 - count:43
# Meteoro! Melhor de todos:2303.0980725211166 - count:15
# Meteoro! Melhor de todos:2303.0980725211166 - count:12
# Meteoro! Melhor de todos:2303.0980725211166 - count:12
# Meteoro! Melhor de todos:2303.0980725211166 - count:17
# Meteoro! Melhor de todos:2303.0980725211166 - count:21
# Meteoro! Melhor de todos:2303.0980725211166 - count:17
# Meteoro! Melhor de todos:2303.0980725211166 - count:15
# Meteoro! Melhor de todos:2303.0980725211166 - count:14
# Meteoro! Melhor de todos:2303.0980725211166 - count:16
# Meteoro! Melhor de todos:2303.0980725211166 - count:11
# Meteoro! Melhor de todos:2303.0980725211166 - count:25
# Meteoro! Melhor de todos:2303.0980725211166 - count:18
# Meteoro! Melhor de todos:2303.0980725211166 - count:17
# Meteoro! Melhor de todos:2303.0980725211166 - count:14
# Meteoro! Melhor de todos:2303.0980725211166 - count:20
# Meteoro! Melhor de todos:2303.0980725211166 - count:17
# Meteoro! Melhor de todos:2303.0980725211166 - count:7
# Meteoro! Melhor de todos:2302.950275685282 - count:27
# Meteoro! Melhor de todos:2302.950275685282 - count:15
# Meteoro! Melhor de todos:2302.950275685282 - count:10
# Meteoro! Melhor de todos:2302.950275685282 - count:5
# Meteoro! Melhor de todos:2302.950275685282 - count:9
# Meteoro! Melhor de todos:2302.950275685282 - count:14
# Meteoro! Melhor de todos:2302.1455458440955 - count:29
# Meteoro! Melhor de todos:2302.1455458440955 - count:13
# Meteoro! Melhor de todos:2301.7812479622007 - count:24
# Meteoro! Melhor de todos:2301.649318807224 - count:66
# Meteoro! Melhor de todos:2301.649093302365 - count:44
# Meteoro! Melhor de todos:2301.649093302365 - count:10
# Meteoro! Melhor de todos:2301.649093302365 - count:21
# Meteoro! Melhor de todos:2301.649093302365 - count:21
# Meteoro! Melhor de todos:2301.649093302365 - count:29
# Meteoro! Melhor de todos:2301.649093302365 - count:13
# Meteoro! Melhor de todos:2301.649093302365 - count:35
# Meteoro! Melhor de todos:2301.649093302365 - count:14
# Meteoro! Melhor de todos:2301.649093302365 - count:20
# Meteoro! Melhor de todos:2301.649093302365 - count:21
# Meteoro! Melhor de todos:2301.6431570580417 - count:58
# Meteoro! Melhor de todos:2301.6431570580417 - count:26
# Meteoro! Melhor de todos:2301.6431570580417 - count:13
# Meteoro! Melhor de todos:2301.6431570580417 - count:17
# Meteoro! Melhor de todos:2301.6431570580417 - count:11
# Meteoro! Melhor de todos:2301.6431570580417 - count:24
# Meteoro! Melhor de todos:2301.6431570580417 - count:19
# Meteoro! Melhor de todos:2301.5850819139264 - count:22
# Meteoro! Melhor de todos:2301.5850819139264 - count:22
# Meteoro! Melhor de todos:2301.5850819139264 - count:20
# Meteoro! Melhor de todos:2301.5850819139264 - count:22
# Meteoro! Melhor de todos:2301.5430659115127 - count:26
# Meteoro! Melhor de todos:2301.5430659115127 - count:18
# Meteoro! Melhor de todos:2301.5430659115127 - count:10
# Meteoro! Melhor de todos:2301.5430659115127 - count:18
# Meteoro! Melhor de todos:2301.5430659115127 - count:21
# Meteoro! Melhor de todos:2301.5430659115127 - count:9
# Meteoro! Melhor de todos:2301.5265673723416 - count:34
# Meteoro! Melhor de todos:2301.5265673723416 - count:9
# Meteoro! Melhor de todos:2301.5265673723416 - count:24
# Meteoro! Melhor de todos:2301.5265673723416 - count:32
# Meteoro! Melhor de todos:2301.5265673723416 - count:18
# Meteoro! Melhor de todos:2301.5265673723416 - count:9
# Meteoro! Melhor de todos:2301.5265673723416 - count:13
# Meteoro! Melhor de todos:2301.5265673723416 - count:17
# Meteoro! Melhor de todos:2301.5265673723416 - count:12
# Meteoro! Melhor de todos:2301.5265673723416 - count:14
# Meteoro! Melhor de todos:2301.5265673723416 - count:19
# Meteoro! Melhor de todos:2301.5265673723416 - count:16
# Meteoro! Melhor de todos:2301.5265673723416 - count:10
# Meteoro! Melhor de todos:2301.5265673723416 - count:13
# Meteoro! Melhor de todos:2301.5243284264216 - count:21
# Meteoro! Melhor de todos:2301.5243284264216 - count:16
# Meteoro! Melhor de todos:2301.5243284264216 - count:14
# Meteoro! Melhor de todos:2301.5243284264216 - count:21
# Meteoro! Melhor de todos:2301.5243284264216 - count:20
# Meteoro! Melhor de todos:2301.4549905184203 - count:25
# Meteoro! Melhor de todos:2301.4549905184203 - count:30
# Meteoro! Melhor de todos:2301.4531019423066 - count:19
# Meteoro! Melhor de todos:2301.4531019423066 - count:13
# Meteoro! Melhor de todos:2301.4531019423066 - count:23
# Meteoro! Melhor de todos:2301.4531019423066 - count:13
# Meteoro! Melhor de todos:2301.4531019423066 - count:19
# Meteoro! Melhor de todos:2301.4531019423066 - count:8
# Meteoro! Melhor de todos:2301.4531019423066 - count:58
# Meteoro! Melhor de todos:2301.4531019423066 - count:21
# Meteoro! Melhor de todos:2301.4531019423066 - count:14
# Meteoro! Melhor de todos:2301.4531019423066 - count:14
# Meteoro! Melhor de todos:2301.4531019423066 - count:17
# Meteoro! Melhor de todos:2301.4531019423066 - count:18
# Meteoro! Melhor de todos:2301.4531019423066 - count:8
# Meteoro! Melhor de todos:2301.4531019423066 - count:14
# Meteoro! Melhor de todos:2301.4531019423066 - count:13
# Meteoro! Melhor de todos:2301.4531019423066 - count:20
# Meteoro! Melhor de todos:2301.4531019423066 - count:15
# Meteoro! Melhor de todos:2301.4531019423066 - count:14
# Meteoro! Melhor de todos:2301.4531019423066 - count:15
# Meteoro! Melhor de todos:2301.4531019423066 - count:17
# Meteoro! Melhor de todos:2301.4531019423066 - count:14
# Meteoro! Melhor de todos:2301.4531019423066 - count:21
# Meteoro! Melhor de todos:2301.4531019423066 - count:13
# Meteoro! Melhor de todos:2301.4531019423066 - count:17
# Meteoro! Melhor de todos:2301.4531019423066 - count:26
# Meteoro! Melhor de todos:2301.4531019423066 - count:20
# Meteoro! Melhor de todos:2301.4531019423066 - count:14
# Meteoro! Melhor de todos:2301.4531019423066 - count:14
# Meteoro! Melhor de todos:2301.4531019423066 - count:18
# Meteoro! Melhor de todos:2301.4531019423066 - count:21
# Meteoro! Melhor de todos:2301.4531019423066 - count:8
# Meteoro! Melhor de todos:2301.4531019423066 - count:30
# Meteoro! Melhor de todos:2301.4531019423066 - count:10
# Meteoro! Melhor de todos:2301.4531019423066 - count:17
# Meteoro! Melhor de todos:2301.4531019423066 - count:36
# Meteoro! Melhor de todos:2301.4531019423066 - count:21
# Meteoro! Melhor de todos:2301.4531019423066 - count:20
# Meteoro! Melhor de todos:2301.4531019423066 - count:16
# Meteoro! Melhor de todos:2301.4531019423066 - count:16
# Meteoro! Melhor de todos:2301.4531019423066 - count:17
# Meteoro! Melhor de todos:2301.4531019423066 - count:10
# Meteoro! Melhor de todos:2301.4531019423066 - count:6
# Meteoro! Melhor de todos:2301.4531019423066 - count:13
# Meteoro! Melhor de todos:2301.4531019423066 - count:40
# Meteoro! Melhor de todos:2301.4531019423066 - count:17
# Meteoro! Melhor de todos:2301.4531019423066 - count:24
# Meteoro! Melhor de todos:2301.4531019423066 - count:9
# Meteoro! Melhor de todos:2301.4531019423066 - count:11
# Meteoro! Melhor de todos:2301.4531019423066 - count:17
# Meteoro! Melhor de todos:2301.4531019423066 - count:13
# Meteoro! Melhor de todos:2301.4531019423066 - count:5
# Meteoro! Melhor de todos:2301.4531019423066 - count:7
# Meteoro! Melhor de todos:2301.4523074055514 - count:40
# Meteoro! Melhor de todos:2301.4523074055514 - count:22
# Meteoro! Melhor de todos:2301.4523074055514 - count:16
# Meteoro! Melhor de todos:2301.451883276254 - count:22
# Meteoro! Melhor de todos:2301.451883276254 - count:21
# Meteoro! Melhor de todos:2301.451883276254 - count:15
# Meteoro! Melhor de todos:2301.451883276254 - count:15
# Meteoro! Melhor de todos:2301.451883276254 - count:13
# Meteoro! Melhor de todos:2301.451883276254 - count:30
# Meteoro! Melhor de todos:2301.451883276254 - count:16
# Meteoro! Melhor de todos:2301.451883276254 - count:7
# Meteoro! Melhor de todos:2301.451883276254 - count:29
# Meteoro! Melhor de todos:2301.451883276254 - count:11
# Meteoro! Melhor de todos:2301.451883276254 - count:21
# Meteoro! Melhor de todos:2301.451883276254 - count:12
# Meteoro! Melhor de todos:2301.451883276254 - count:13
# Meteoro! Melhor de todos:2301.451883276254 - count:21
# Meteoro! Melhor de todos:2301.451883276254 - count:18
# Meteoro! Melhor de todos:2301.451883276254 - count:22
# Meteoro! Melhor de todos:2301.451883276254 - count:23
# Meteoro! Melhor de todos:2301.451883276254 - count:21
# Meteoro! Melhor de todos:2301.451883276254 - count:8
# Meteoro! Melhor de todos:2301.451883276254 - count:16
# Meteoro! Melhor de todos:2301.451883276254 - count:4
# Meteoro! Melhor de todos:2301.451883276254 - count:7
# Meteoro! Melhor de todos:2301.451883276254 - count:16
# Meteoro! Melhor de todos:2301.451883276254 - count:14
# Meteoro! Melhor de todos:2301.451883276254 - count:29
# Meteoro! Melhor de todos:2301.451883276254 - count:19
# Meteoro! Melhor de todos:2301.451883276254 - count:29
# Meteoro! Melhor de todos:2301.451883276254 - count:14
# Meteoro! Melhor de todos:2301.451883276254 - count:18
# Meteoro! Melhor de todos:2301.451883276254 - count:30
# ------------------------------
# Gene(a=0.7804489910057408, e=-0.3135570351237175)
# Gene(a=0.7996605058421984, e=-0.570492879009879)
# Gene(a=0.5030787335167732, e=0.10533033461823466)
# Gene(a=0.4067824179815862, e=0.21384411906566614)
# Gene(a=0.3342611316462447, e=0.08456596715356732)
# Gene(a=0.2515710339392978, e=0.36260354327406213)
# Gene(a=0.3598338702292826, e=0.0592830316204266)
# Gene(a=0.205748297000539, e=0.03920105830404069)
# Gene(a=0.15777900776340284, e=0.5404916973356025)
# Gene(a=0.056158250304538665, e=0.04542919309960379)
# Gene(a=0.055170477340164996, e=0.03173397389545659)
# Gene(a=0.009655310983566803, e=-1.4626399523071038e-05)
# ------------------------------
# GeneDecoded(x=10.0, y=10.0, v=0, al=0)
# GeneDecoded(x=10.39022449550287, y=10.0, v=0.7804489910057408, al=-0.3135570351237175)
# GeneDecoded(x=11.512956207149301, y=9.63594973244346, v=1.579707801952239, al=-0.8840499141335965)
# GeneDecoded(x=12.674011779947993, y=8.21982256661979, v=2.0811407971078024, al=-0.7787195795153619)
# GeneDecoded(x=14.300172385138962, y=6.6152390776689, v=2.48506687318021, al=-0.5648754604496957)
# GeneDecoded(x=16.540364940526633, y=5.1954896032046545, v=2.815255295393821, al=-0.4803094932961284)
# GeneDecoded(x=19.148632757474182, y=3.836570895163871, v=3.061599445665099, al=-0.11770595002206624)
# GeneDecoded(x=22.36771994861338, y=3.455905553023394, v=3.415251671653208, al=-0.05842291840163964)
# GeneDecoded(x=25.87984337705319, y=3.25048328102064, v=3.613307731035231, al=-0.01922186009759895)
# GeneDecoded(x=29.57135853662868, y=3.179516752624413, v=3.762476460935931, al=0.5212698372380036)
# GeneDecoded(x=32.85848104715354, y=5.067144166078987, v=3.809298840085211, al=0.5666990303376074)
# GeneDecoded(x=36.09557455927747, y=7.126975476543751, v=3.854899638757803, al=0.598433004233064)
# GeneDecoded(x=39.28455610386183, y=9.301346993620717, v=3.854754784061426, al=0.5984183778335409)
# Meteoro! Melhor de todos:13604.896411819818 - count:59
# Meteoro! Melhor de todos:13604.896411819818 - count:18
# Meteoro! Melhor de todos:12640.585001356567 - count:13
# Meteoro! Melhor de todos:12640.585001356567 - count:14
# Meteoro! Melhor de todos:5584.038699302618 - count:25
# Meteoro! Melhor de todos:5584.038699302618 - count:12
# Meteoro! Melhor de todos:5513.396820157945 - count:93
# Meteoro! Melhor de todos:5073.353947027144 - count:126
# Meteoro! Melhor de todos:5050.831284004104 - count:133
# Meteoro! Melhor de todos:4977.537458778116 - count:46
# Meteoro! Melhor de todos:4975.489441463954 - count:8
# Meteoro! Melhor de todos:4956.057153929507 - count:92
# Meteoro! Melhor de todos:4955.094523124912 - count:19
# Meteoro! Melhor de todos:4955.094523124912 - count:10
# Meteoro! Melhor de todos:4940.3768577749315 - count:110
# Meteoro! Melhor de todos:4913.415022935422 - count:62
# Meteoro! Melhor de todos:4901.809894486474 - count:132
# Meteoro! Melhor de todos:4901.809894486474 - count:13
# Meteoro! Melhor de todos:4899.010442385518 - count:23
# Meteoro! Melhor de todos:4898.659359583797 - count:19
# ...
# Meteoro! Melhor de todos:2499.6503943449143 - count:13
# Meteoro! Melhor de todos:2499.5925692897213 - count:47
# Meteoro! Melhor de todos:2499.5925692897213 - count:12
# Meteoro! Melhor de todos:2499.5925692897213 - count:16
# Meteoro! Melhor de todos:2499.592550745896 - count:21
# Meteoro! Melhor de todos:2499.1825814933873 - count:52
# Meteoro! Melhor de todos:2499.1825814933873 - count:8
# Meteoro! Melhor de todos:2499.1816284041515 - count:44
# Meteoro! Melhor de todos:2499.1816284041515 - count:19
# Meteoro! Melhor de todos:2499.1816254063574 - count:16
# Meteoro! Melhor de todos:2499.0999507686774 - count:75
# Meteoro! Melhor de todos:2498.7909027281758 - count:21
# Meteoro! Melhor de todos:2498.7909027281758 - count:16
# Meteoro! Melhor de todos:2498.7909027281758 - count:7
# Meteoro! Melhor de todos:2498.7909027280475 - count:11
# Meteoro! Melhor de todos:2498.7909027280475 - count:28
# Meteoro! Melhor de todos:2498.7909027280475 - count:14
# Meteoro! Melhor de todos:2498.7783009478258 - count:23
# Meteoro! Melhor de todos:2498.7782753866113 - count:20
# Meteoro! Melhor de todos:2498.7782753866113 - count:13
# Meteoro! Melhor de todos:2498.77550737607 - count:36
# Meteoro! Melhor de todos:2498.7754865469715 - count:49
# Meteoro! Melhor de todos:2498.7754865469715 - count:11
# Meteoro! Melhor de todos:2498.7751375974613 - count:28
# Meteoro! Melhor de todos:2498.7751375974613 - count:20
# Meteoro! Melhor de todos:2498.7587740962626 - count:30
# Meteoro! Melhor de todos:2498.7587740962626 - count:25
# Meteoro! Melhor de todos:2498.4464331276135 - count:108
# Meteoro! Melhor de todos:2498.4464331276135 - count:21
# Meteoro! Melhor de todos:2498.4464331276135 - count:21
# Meteoro! Melhor de todos:2498.4419585178343 - count:20
# Meteoro! Melhor de todos:2498.4419585178343 - count:16
# Meteoro! Melhor de todos:2498.3769971503607 - count:18
# Meteoro! Melhor de todos:2498.3769971503607 - count:9
# Meteoro! Melhor de todos:2498.3769971503607 - count:29
# Meteoro! Melhor de todos:2496.956624303096 - count:62
# Meteoro! Melhor de todos:2496.956624303096 - count:7
# Meteoro! Melhor de todos:2496.956624303096 - count:27
# Meteoro! Melhor de todos:2493.129218743641 - count:50
# Meteoro! Melhor de todos:2493.129218743641 - count:9
# Meteoro! Melhor de todos:2492.8451517388776 - count:26
# Meteoro! Melhor de todos:2492.8451517388776 - count:10
# Meteoro! Melhor de todos:2492.308863378981 - count:55
# Meteoro! Melhor de todos:2492.308863378981 - count:16
# Meteoro! Melhor de todos:2492.117520537541 - count:25
# Meteoro! Melhor de todos:2492.117520537541 - count:8
# Meteoro! Melhor de todos:2492.117520537541 - count:20
# Meteoro! Melhor de todos:2491.9538877376644 - count:41
# Meteoro! Melhor de todos:2491.9039008194677 - count:19
# Meteoro! Melhor de todos:2491.899653198699 - count:32
# Meteoro! Melhor de todos:2491.899653198699 - count:20
# Meteoro! Melhor de todos:2491.899653198699 - count:24
# Meteoro! Melhor de todos:2480.5880205358117 - count:118
# Meteoro! Melhor de todos:2480.4765579292216 - count:44
# Meteoro! Melhor de todos:2480.4765579292216 - count:15
# Meteoro! Melhor de todos:2480.4765579292216 - count:10
# Meteoro! Melhor de todos:2480.4765579292216 - count:17
# Meteoro! Melhor de todos:2480.4765579292216 - count:16
# Meteoro! Melhor de todos:2480.386679189781 - count:15
# Meteoro! Melhor de todos:2480.386679189781 - count:17
# Meteoro! Melhor de todos:2480.386679189781 - count:20
# Meteoro! Melhor de todos:2480.386679189781 - count:7
# Meteoro! Melhor de todos:2480.386679189781 - count:18
# Meteoro! Melhor de todos:2480.386679189781 - count:15
# Meteoro! Melhor de todos:2480.386679189781 - count:15
# Meteoro! Melhor de todos:2480.386679189781 - count:11
# Meteoro! Melhor de todos:2480.386679189781 - count:15
# Meteoro! Melhor de todos:2480.386679189781 - count:28
# Meteoro! Melhor de todos:2480.386679189781 - count:12
# Meteoro! Melhor de todos:2480.386679189781 - count:26
# Meteoro! Melhor de todos:2480.386679189781 - count:14
# Meteoro! Melhor de todos:2480.327717469486 - count:20
# Meteoro! Melhor de todos:2479.78904947543 - count:48
# Meteoro! Melhor de todos:2479.78904947543 - count:47
# Meteoro! Melhor de todos:2479.78904947543 - count:12
# Meteoro! Melhor de todos:2479.78904947543 - count:10
# Meteoro! Melhor de todos:2479.7890253845417 - count:26
# Meteoro! Melhor de todos:2479.7890253845417 - count:9
# Meteoro! Melhor de todos:2479.7890253845417 - count:15
# Meteoro! Melhor de todos:2479.769730017423 - count:26
# Meteoro! Melhor de todos:2479.769730017423 - count:23
# Meteoro! Melhor de todos:2479.769730017423 - count:11
# Meteoro! Melhor de todos:2479.769730017423 - count:15
# Meteoro! Melhor de todos:2479.271579704977 - count:93
# Meteoro! Melhor de todos:2479.2112951662702 - count:42
# Meteoro! Melhor de todos:2477.9680813301893 - count:77
# Meteoro! Melhor de todos:2477.9680813301893 - count:27
# Meteoro! Melhor de todos:2477.9680813301893 - count:15
# Meteoro! Melhor de todos:2477.9680813301893 - count:20
# Meteoro! Melhor de todos:2477.9680813301893 - count:15
# Meteoro! Melhor de todos:2477.9680813301893 - count:9
# Meteoro! Melhor de todos:2477.9680813301893 - count:17
# Meteoro! Melhor de todos:2477.9680813301893 - count:8
# Meteoro! Melhor de todos:2477.9680813301893 - count:28
# Meteoro! Melhor de todos:2477.9680813301893 - count:19
# Meteoro! Melhor de todos:2477.474765856192 - count:70
# Meteoro! Melhor de todos:2477.474765856192 - count:28
# Meteoro! Melhor de todos:2477.19519239283 - count:94
# Meteoro! Melhor de todos:2477.104525933926 - count:62
# Meteoro! Melhor de todos:2477.104525933926 - count:15
# Meteoro! Melhor de todos:2477.104525933926 - count:18
# Meteoro! Melhor de todos:2477.104525933926 - count:9
# Meteoro! Melhor de todos:2477.104525933926 - count:17
# Meteoro! Melhor de todos:2477.104525933926 - count:22
# Meteoro! Melhor de todos:2477.104525933926 - count:8
# Meteoro! Melhor de todos:2477.104525933926 - count:34
# Meteoro! Melhor de todos:2477.104525933926 - count:6
# Meteoro! Melhor de todos:2477.104525933926 - count:13
# Meteoro! Melhor de todos:2472.1588517499176 - count:116
# Meteoro! Melhor de todos:2472.15035901148 - count:22
# Meteoro! Melhor de todos:2472.15035901148 - count:26
# Meteoro! Melhor de todos:2472.15035901148 - count:11
# Meteoro! Melhor de todos:2472.15035901148 - count:9
# Meteoro! Melhor de todos:2472.0666343011644 - count:71
# Meteoro! Melhor de todos:2472.0666343011644 - count:24
# Meteoro! Melhor de todos:2472.0666343011644 - count:24
# Meteoro! Melhor de todos:2470.7711846262628 - count:18
# Meteoro! Melhor de todos:2469.7809248003896 - count:40
# Meteoro! Melhor de todos:2469.7809248003896 - count:13
# Meteoro! Melhor de todos:2469.780867227231 - count:21
# Meteoro! Melhor de todos:2469.780867227231 - count:18
# Meteoro! Melhor de todos:2469.780867227231 - count:29
# Meteoro! Melhor de todos:2469.7282167533745 - count:71
# Meteoro! Melhor de todos:2469.6496205023805 - count:27
# Meteoro! Melhor de todos:2469.6495922981912 - count:30
# Meteoro! Melhor de todos:2469.197442938107 - count:43
# Meteoro! Melhor de todos:2469.197442938107 - count:13
# Meteoro! Melhor de todos:2469.195767489926 - count:31
# Meteoro! Melhor de todos:2469.195767489926 - count:14
# Meteoro! Melhor de todos:2469.195767489926 - count:14
# Meteoro! Melhor de todos:2469.195767489926 - count:16
# Meteoro! Melhor de todos:2469.195767489926 - count:19
# Meteoro! Melhor de todos:2469.195767489926 - count:13
# Meteoro! Melhor de todos:2469.195767489926 - count:16
# Meteoro! Melhor de todos:2469.195767489926 - count:31
# Meteoro! Melhor de todos:2469.195767489926 - count:13
# Meteoro! Melhor de todos:2469.1957507193924 - count:20
# Meteoro! Melhor de todos:2469.1957507193924 - count:18
# Meteoro! Melhor de todos:2469.1872035149654 - count:182
# Meteoro! Melhor de todos:2469.186501913181 - count:45
# Meteoro! Melhor de todos:2469.186138489557 - count:47
# Meteoro! Melhor de todos:2469.186138489557 - count:17
# Meteoro! Melhor de todos:2469.186138489557 - count:17
# Meteoro! Melhor de todos:2469.186138489557 - count:7
# Meteoro! Melhor de todos:2469.186138489557 - count:18
# Meteoro! Melhor de todos:2469.185970320136 - count:27
# Meteoro! Melhor de todos:2469.185970320136 - count:13
# Meteoro! Melhor de todos:2468.2718050200865 - count:26
# Meteoro! Melhor de todos:2468.2217653823864 - count:30
# Meteoro! Melhor de todos:2468.2217653823864 - count:11
# Meteoro! Melhor de todos:2468.2217653823864 - count:14
# Meteoro! Melhor de todos:2468.2217653823864 - count:15
# Meteoro! Melhor de todos:2468.2217653823864 - count:15
# Meteoro! Melhor de todos:2468.2217653823864 - count:15
# Meteoro! Melhor de todos:2468.2217653823864 - count:9
# Meteoro! Melhor de todos:2468.2217653823864 - count:11
# Meteoro! Melhor de todos:2468.2215752349184 - count:20
# Meteoro! Melhor de todos:2468.2215752349184 - count:7
# Meteoro! Melhor de todos:2468.2215752349184 - count:12
# Meteoro! Melhor de todos:2468.2050000934287 - count:17
# Meteoro! Melhor de todos:2468.2050000934287 - count:21
# Meteoro! Melhor de todos:2468.2050000934287 - count:15
# Meteoro! Melhor de todos:2468.2050000934287 - count:18
# Meteoro! Melhor de todos:2468.2050000934287 - count:20
# Meteoro! Melhor de todos:2467.992782376863 - count:21
# Meteoro! Melhor de todos:2467.880206883662 - count:35
# Meteoro! Melhor de todos:2466.3415159393444 - count:33
# Meteoro! Melhor de todos:2466.3415159393444 - count:16
# Meteoro! Melhor de todos:2466.337961533778 - count:25
# Meteoro! Melhor de todos:2466.337961533778 - count:16
# Meteoro! Melhor de todos:2466.337961533778 - count:19
# Meteoro! Melhor de todos:2466.337961533778 - count:10
# Meteoro! Melhor de todos:2466.3377180612615 - count:27
# Meteoro! Melhor de todos:2466.0093667008105 - count:23
# Meteoro! Melhor de todos:2466.0093667008105 - count:20
# Meteoro! Melhor de todos:2466.0082608723233 - count:26
# Meteoro! Melhor de todos:2466.0082608723233 - count:13
# Meteoro! Melhor de todos:2465.975867291889 - count:19
# Meteoro! Melhor de todos:2465.975867291889 - count:13
# Meteoro! Melhor de todos:2465.975867291889 - count:16
# Meteoro! Melhor de todos:2465.975867291889 - count:24
# Meteoro! Melhor de todos:2465.975867291889 - count:20
# Meteoro! Melhor de todos:2465.975867291889 - count:9
# Meteoro! Melhor de todos:2465.975867291889 - count:16
# Meteoro! Melhor de todos:2465.975867291889 - count:21
# Meteoro! Melhor de todos:2465.975867291889 - count:16
# Meteoro! Melhor de todos:2465.975867291889 - count:20
# Meteoro! Melhor de todos:2465.975867291889 - count:7
# Meteoro! Melhor de todos:2465.975867291889 - count:16
# Meteoro! Melhor de todos:2465.975867291889 - count:12
# Meteoro! Melhor de todos:2465.975867291889 - count:14
# Meteoro! Melhor de todos:2465.975867291889 - count:11
# Meteoro! Melhor de todos:2465.975867291889 - count:12
# Meteoro! Melhor de todos:2465.9744775708514 - count:41
# Meteoro! Melhor de todos:2465.9744775708514 - count:18
# Meteoro! Melhor de todos:2465.9744775708514 - count:17
# Meteoro! Melhor de todos:2465.9744775708514 - count:7
# Meteoro! Melhor de todos:2465.9744775708514 - count:7
# Meteoro! Melhor de todos:2465.9744775708514 - count:12
# Meteoro! Melhor de todos:2465.9744775708514 - count:16
# Meteoro! Melhor de todos:2465.9744775708514 - count:16
# Meteoro! Melhor de todos:2465.973676303121 - count:18
# Meteoro! Melhor de todos:2465.973676303121 - count:16
# Meteoro! Melhor de todos:2455.6439909749242 - count:37
# Meteoro! Melhor de todos:2454.060676797437 - count:24
# Meteoro! Melhor de todos:2453.4916529702787 - count:58
# Meteoro! Melhor de todos:2453.4916529702787 - count:16
# Meteoro! Melhor de todos:2453.4916529702787 - count:19
# Meteoro! Melhor de todos:2453.4916529702787 - count:16
# Meteoro! Melhor de todos:2453.4916529702787 - count:19
# Meteoro! Melhor de todos:2453.3585204326055 - count:32
# Meteoro! Melhor de todos:2453.3585204326055 - count:14
# Meteoro! Melhor de todos:2453.283655929301 - count:40
# Meteoro! Melhor de todos:2453.283655929301 - count:26
# Meteoro! Melhor de todos:2453.2584852068226 - count:81
# Meteoro! Melhor de todos:2453.240687897206 - count:27
# Meteoro! Melhor de todos:2453.240687897206 - count:32
# Meteoro! Melhor de todos:2453.240687897206 - count:14
# Meteoro! Melhor de todos:2453.240687897206 - count:22
# Meteoro! Melhor de todos:2453.240687897206 - count:17
# Meteoro! Melhor de todos:2453.240687897206 - count:27
# Meteoro! Melhor de todos:2453.240687897206 - count:7
# Meteoro! Melhor de todos:2453.240687897206 - count:29
# Meteoro! Melhor de todos:2453.240687897206 - count:27
# Meteoro! Melhor de todos:2453.240687897206 - count:19
# Meteoro! Melhor de todos:2453.240687897206 - count:19
# Meteoro! Melhor de todos:2453.236198831576 - count:47
# Meteoro! Melhor de todos:2453.2348588814702 - count:29
# Meteoro! Melhor de todos:2453.2348588814702 - count:35
# Meteoro! Melhor de todos:2453.231553329013 - count:22
# Meteoro! Melhor de todos:2453.2257446342055 - count:17
# Meteoro! Melhor de todos:2453.2198558269465 - count:20
# Meteoro! Melhor de todos:2453.2198558269465 - count:11
# Meteoro! Melhor de todos:2453.2198260550826 - count:23
# Meteoro! Melhor de todos:2453.219463451542 - count:31
# Meteoro! Melhor de todos:2453.219463451542 - count:5
# Meteoro! Melhor de todos:2453.219463451542 - count:17
# Meteoro! Melhor de todos:2453.174997991889 - count:52
# Meteoro! Melhor de todos:2453.1226987887185 - count:32
# Meteoro! Melhor de todos:2452.071947317543 - count:22
# Meteoro! Melhor de todos:2451.9243834452354 - count:42
# Meteoro! Melhor de todos:2451.9243834452354 - count:7
# Meteoro! Melhor de todos:2451.9243834452354 - count:22
# Meteoro! Melhor de todos:2451.7419157611985 - count:43
# Meteoro! Melhor de todos:2451.7419157611985 - count:19
# Meteoro! Melhor de todos:2451.7419157611985 - count:9
# Meteoro! Melhor de todos:2451.7419157611985 - count:15
# Meteoro! Melhor de todos:2451.7411721866924 - count:21
# Meteoro! Melhor de todos:2451.7411721866924 - count:19
# Meteoro! Melhor de todos:2451.7411721866924 - count:9
# Meteoro! Melhor de todos:2451.7411721866924 - count:26
# Meteoro! Melhor de todos:2451.7411721866924 - count:25
# Meteoro! Melhor de todos:2451.7411721866924 - count:11
# Meteoro! Melhor de todos:2451.7411721866924 - count:15
# Meteoro! Melhor de todos:2451.7411693474096 - count:18
# Meteoro! Melhor de todos:2451.7411693474096 - count:27
# Meteoro! Melhor de todos:2451.7406670044684 - count:22
# Meteoro! Melhor de todos:2451.7406670044684 - count:17
# Meteoro! Melhor de todos:2451.7406670044684 - count:23
# Meteoro! Melhor de todos:2451.7406670044684 - count:25
# Meteoro! Melhor de todos:2451.7406670044684 - count:12
# Meteoro! Melhor de todos:2451.7406670044684 - count:18
# Meteoro! Melhor de todos:2451.3409884597054 - count:17
# Meteoro! Melhor de todos:2451.3409884597054 - count:13
# Meteoro! Melhor de todos:2451.3409884597054 - count:13
# Meteoro! Melhor de todos:2451.3409884597054 - count:8
# Meteoro! Melhor de todos:2451.3409884597054 - count:17
# Meteoro! Melhor de todos:2451.3409884597054 - count:12
# Meteoro! Melhor de todos:2451.3409884597054 - count:19
# Meteoro! Melhor de todos:2451.3258890661627 - count:50
# Meteoro! Melhor de todos:2451.2576789275345 - count:120
# Meteoro! Melhor de todos:2451.2576789275345 - count:13
# Meteoro! Melhor de todos:2451.2576789275345 - count:21
# Meteoro! Melhor de todos:2451.2576789275345 - count:8
# Meteoro! Melhor de todos:2451.2576789275345 - count:19
# Meteoro! Melhor de todos:2451.2576789275345 - count:9
# Meteoro! Melhor de todos:2451.257678751752 - count:19
# Meteoro! Melhor de todos:2451.257678751752 - count:17
# Meteoro! Melhor de todos:2451.257678751752 - count:14
# Meteoro! Melhor de todos:2451.257678751752 - count:16
# Meteoro! Melhor de todos:2451.257678751752 - count:26
# Meteoro! Melhor de todos:2451.257678751752 - count:28
# Meteoro! Melhor de todos:2451.257678751752 - count:22
# Meteoro! Melhor de todos:2451.257678751752 - count:14
# Meteoro! Melhor de todos:2451.1977419418126 - count:17
# Meteoro! Melhor de todos:2451.1977419418126 - count:14
# Meteoro! Melhor de todos:2450.8798287927502 - count:39
# Meteoro! Melhor de todos:2450.8798287927502 - count:22
# Meteoro! Melhor de todos:2450.8798287927502 - count:9
# Meteoro! Melhor de todos:2449.6763833844875 - count:39
# Meteoro! Melhor de todos:2449.6763833844875 - count:16
# Meteoro! Melhor de todos:2449.6763833844875 - count:23
# Meteoro! Melhor de todos:2449.6763833844875 - count:16

# %%
pickle.dump(tests, open( "aasave_alpha.p", "wb" ) )

# %%
import pickle
tests = pickle.load(open( "save_alpha.p", "rb" ) )

# %% [markdown]
# ## Import

# %%
test_backup = pickle.load(open( "execution_1.p", "rb" ) )

# %% [markdown]
# ## Visualization

# %%
for i in range(5):
    np_ar = np.array(test_backup['mapa4']['res'][i])
    plt.plot(np_ar[:,1], np_ar[:,0])

# %%
for i in range(1):
    np_ar = np.array(test_backup['mapa2']['res'][i])
    plt.plot(np_ar[:,1], np_ar[:,0])

# %% [markdown]
# # TODO

# %%
# TODO1: Setar a semente do random para controlar o experimento
# TODO1: Printar o tempo que encontra cada melhor
# TODO1: Ter certeza na conversão de latitutde e longitude <- confiavel   (Veronica)

# %%
Monografia
- até domingo - sobrar somente resultados
- ler os abstracts dos principais artigos
- achar ref pro Ray casting (google scholar: ray casting / ray casting GA / RC path planning) 
      foco pra imagens (citar) 
    rc com ga, mesmo que em outra area
    só ler abstract (os mais novos)
    ate onde nos pudermos pesquisar nessa monografia, nos nao encontramos trabalhos

- durante a semana so sobra os resultados


- retornar no domingo (a noite) ou segunda (noite): apresentar a monografia
    a medida que concluir uma seção, enviar
