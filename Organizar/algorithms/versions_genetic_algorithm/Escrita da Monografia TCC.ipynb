# %%
- Começar escrita
- REvisar o metodo
- testar em mais mapas (3 ou 4, simples, para ter resultados)
- simular os mapas em ROS
- colocar alocação de risco na V2_3
- colocar alocação de risco na V1 (inflado)


TESTES:
4 versões rodando nos 5 mapas
5 mapas:
    1 a 3 obstaculos

ter certeza que o nucleo do AG é o mesmo. 

(QUARTA)
    
    



* mapa problema

# %% [markdown]
# Jesimar Mestrado 2016
#
#
#
#
#
#
#
# 4.
# codificação
# decodificação
# calculo de fitness
# operadores de cross e mutação
#
# 5. Experimentos, ver como foram reportados
#
#
#
# Leo
#
# 2.3 AG
# conceitos

# %% [markdown]
# 1. Introdução
# 2. Revisão Bibliográfica
# Revisao da literatura, falar o que ja existe, sobre AG Path planning
# {
# Jesimar
# 2.4
# 1,2 e 3 paragrafos (Planejamento de Rotas)
# Ler os trabalhos e incrementar o que fala sobre
# pag 47, 4-5 paragrafos
# pag 48, 1-3 paragrafos (AG e outros metodos p planning)
# }
#
# 3. Problema
# Conceito sobre Vants
# {
# Jesimar
# Seção 2.2.1 (Vant)
# Ler e resumir
# }
# Definir o problema de path-planning com obstáculos
# Entra as coisas do marcio
# {
# Marcio
# Seção 1.1 e 1.2
# }
# O problema que vou resolver é o
# {
# Marcio
# seção 4 (LER)
# não convexa (tem obstaculo)
#
# }
#
# 4. Metodologia
# AG - explicar o metodo
# explicar o que é, ver como Jesimar fez
#     Explicar o Ray casting
#
#
# Explicar o sistema ROS
#
#
# V1 com risco e sem risco (inflado) numero de waypoints determinado
# V2 com risco e sem risco (inflado) Evolui o numero de waypoints
#
#
#
#
# 5. Resultados
# Resultados do V1
# TODO1: testar a v1 com e sem risco
#
# Res de simulação focando na diferença da rota com risco e sem risco
# - V2 - V2_3
#
#
#
# 6. Conclusão
