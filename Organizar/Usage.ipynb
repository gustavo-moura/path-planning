# %%
PATH = '/home/gustavosouza/Documents/Per/path-planning/'
MAPS_PATH = PATH + 'maps/NonRegular/'

# %%
from pathlib import Path
import re
import pickle

from genetic.data_definitions import Map, CartesianPoint, Version
from genetic.visualization import vis_mapa
from genetic.genetic import Genetic, Subject

from multiprocessing import Pool

# %%
def sgl_read_areas(lines):
    """From the map file definition reads each area"""
    
    lines = iter(lines)
    next(lines)  # <number of polygons>
    next(lines)  # 20

    areas = []
    
    for line in lines:
        Xs = [float(n) for n in re.sub(r'\n', '', next(lines)).split(',')]
        Ys = [float(n) for n in re.sub(r'\n', '', next(lines)).split(',')]

        areas.append([CartesianPoint(x, y) for x, y in zip(Xs, Ys)])

        
    return areas

# %%
def run_ags_over_path(path):
    try:
        path = str(path)
        number = re.sub(r'[A-Za-z/\-_\.]','',path)
        print(f'1. Processing file: {number}')
        with open(path, 'r') as f:
            lines = f.readlines()  
            map = Map(wp_ori, wp_des, sgl_read_areas(lines), inflation_rate=0)

        print('1.1. Read')

        ag = Genetic(Subject, map, 
            version = Version('beta', 'RC'),
            # Parâmetros da classe Genetic:
            taxa_cross=5,
            population_size=10,
            max_exec_time=600,
            # Parâmetros da classe Subject:
            px0=map.origin.x,
            py0=map.origin.y,
            T_min=1,
            T_max=25,
            mutation_prob=0.7,
            gps_imprecision=1,
            **par_RC
        )

        best = ag.run(info=False)
        print(f'2. AG generated: {number}')

        name = re.sub(r'(\.sgl)', r'.png', path)
        vis_mapa(map, best.get_route(), save=name)


        name = re.sub(r'(\.sgl)', r'_ag.p', path)

        with open(name, "wb" ) as ag_file:
            pickle.dump(ag, ag_file)

        print(f'2. Saved: {number}')

        #vis_mapa(map)
        #maps.append(map)
        #print(f'File processed: {path}')
    except Exception as e:
        print(f'!!! {number} Problem occured!! {path}')
        print(e)

# %%
def run_ags_over_path_E(path):
#     try:
        path = str(path)
        number = re.sub(r'[A-Za-z/\-_\.]','',path)
        print(f'1. Processing file: {number}')
        with open(path, 'r') as f:
            lines = f.readlines()  
            map = Map(wp_ori, wp_des, sgl_read_areas(lines), inflation_rate=0)

        print('1.1. Read')

        ag = Genetic(Subject, map, 
            version = Version('beta', 'RC'),
            # Parâmetros da classe Genetic:
            taxa_cross=5,
            population_size=10,
            max_exec_time=600,
            # Parâmetros da classe Subject:
            px0=map.origin.x,
            py0=map.origin.y,
            T_min=1,
            T_max=25,
            mutation_prob=0.7,
            gps_imprecision=1,
            **par_RC
        )

        best = ag.run(info=False)
        print(f'2. AG generated: {number}')

        name = re.sub(r'(\.sgl)', r'.png', path)
        vis_mapa(map, best.get_route(), save=name)


        name = re.sub(r'(\.sgl)', r'_ag.p', path)

        with open(name, "wb" ) as ag_file:
            pickle.dump(ag, ag_file)

        print(f'2. Saved: {number}')

        #vis_mapa(map)
        #maps.append(map)
        #print(f'File processed: {path}')
#     except Exception as e:
#         print(f'!!! {number} Problem occured!! {path}')
#         print(e)

# %%
try:
    pathlist = Path(MAPS_PATH).glob('**/*.sgl')

    par_RC = {
        'C_d': 10000,
        'C_obs': 10000,
        'C_con': 500,
        'C_cur': 100,
        'C_t': 100,
    }

    wp_ori = CartesianPoint(0,0)
    wp_des = CartesianPoint(0,-10)

    # Iterate over different maps
    p = Pool(processes=10)
    p.map(run_ags_over_path, pathlist)
    
except Exception as e:
    print(e)
# Out:
# 1. Processing file: 20042
# 1. Processing file: 20007
# 1. Processing file: 20041
# 1. Processing file: 20037
# 1. Processing file: 20048
# 1. Processing file: 20008
# 1. Processing file: 20025
# 1. Processing file: 20045
# 1. Processing file: 20002
# 1. Processing file: 20016
# 1.1. Read
# 1.1. Read
# 1.1. Read
# 1.1. Read
# 1.1. Read
# 1.1. Read
# 1.1. Read
# 1.1. Read
# 1.1. Read
# 1.1. Read
# !!! 20042 Problem occured!! /home/gustavosouza/Documents/Per/path-planning/maps/NonRegular/map_W20_042.sgl
# object of type 'NoneType' has no len()
# 1. Processing file: 20029
# 1.1. Read
# !!! 20045 Problem occured!! /home/gustavosouza/Documents/Per/path-planning/maps/NonRegular/map_W20_045.sgl
# object of type 'NoneType' has no len()
# 1. Processing file: 20023
# 1.1. Read
# !!! 20008 Problem occured!! /home/gustavosouza/Documents/Per/path-planning/maps/NonRegular/map_W20_008.sgl
# object of type 'NoneType' has no len()
# 1. Processing file: 20022
# 1.1. Read
# !!! 20022 Problem occured!! /home/gustavosouza/Documents/Per/path-planning/maps/NonRegular/map_W20_022.sgl
# object of type 'NoneType' has no len()
# 1. Processing file: 20012
# 1.1. Read
# !!! 20023 Problem occured!! /home/gustavosouza/Documents/Per/path-planning/maps/NonRegular/map_W20_023.sgl
# object of type 'NoneType' has no len()
# 1. Processing file: 20033
# 1.1. Read
# !!! 20037 Problem occured!! /home/gustavosouza/Documents/Per/path-planning/maps/NonRegular/map_W20_037.sgl
# object of type 'NoneType' has no len()
# 1. Processing file: 20021
# 1.1. Read
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-6:
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 470, in run
#     self.fitnesses = [self._fitness(subject, self.map) for subject in self.population]
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 599, in __fitness_obstacles_RC
#     if point_in_polygon(wp1, area_n):
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 470, in <listcomp>
#     self.fitnesses = [self._fitness(subject, self.map) for subject in self.population]
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 603, in __fitness_obstacles_RC
#     if segment_in_polygon(wp1, wp2, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 421, in run
#     child = parent1.crossover(parent2)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 60, in point_in_polygon
#     for vertex1, vertex2 in pairwise_circle(polygon):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 187, in crossover
#     child = self.generate(dna)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 599, in __fitness_obstacles_RC
#     if point_in_polygon(wp1, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 595, in __fitness_obstacles_RC
#     wp1 = CartesianPoint(gene_decoded_t1.x, gene_decoded_t1.y)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 62, in point_in_polygon
#     if vertex1.y < vertex2.y:
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 243, in generate
#     child = copy.deepcopy(self)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 603, in __fitness_obstacles_RC
#     if segment_in_polygon(wp1, wp2, area_n):
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/data_definitions.py", line 11, in __init__
#     self.x = x
#   File "/usr/lib/python3.6/copy.py", line 180, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 141, in segment_in_polygon
#     for vertex1, vertex2 in pairwise_circle(polygon):
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 421, in run
#     child = parent1.crossover(parent2)
#   File "/usr/lib/python3.6/copy.py", line 180, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 17, in pairwise_circle
#     return itertools.zip_longest(a, b, fillvalue=first_value)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 187, in crossover
#     child = self.generate(dna)
#   File "/usr/lib/python3.6/copy.py", line 280, in _reconstruct
#     state = deepcopy(state, memo)
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 243, in generate
#     child = copy.deepcopy(self)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 603, in __fitness_obstacles_RC
#     if segment_in_polygon(wp1, wp2, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/usr/lib/python3.6/copy.py", line 150, in deepcopy
#     y = copier(x, memo)
#   File "/usr/lib/python3.6/copy.py", line 240, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 599, in __fitness_obstacles_RC
#     if point_in_polygon(wp1, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 142, in segment_in_polygon
#     if segment_intersects_segment(wp1, wp2, vertex1, vertex2):
#   File "/usr/lib/python3.6/copy.py", line 280, in _reconstruct
#     state = deepcopy(state, memo)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/usr/lib/python3.6/copy.py", line 150, in deepcopy
#     y = copier(x, memo)
#   File "/usr/lib/python3.6/copy.py", line 150, in deepcopy
#     y = copier(x, memo)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/usr/lib/python3.6/copy.py", line 215, in _deepcopy_list
#     append(deepcopy(a, memo))
#   File "/usr/lib/python3.6/copy.py", line 240, in _deepcopy_dict
#     y[deepcopy(key, memo)] = deepcopy(value, memo)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 599, in __fitness_obstacles_RC
#     if point_in_polygon(wp1, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 177, in segment_intersects_segment
#     o3 = orientation(p2, q2, p1)
#   File "/usr/lib/python3.6/copy.py", line 180, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "/usr/lib/python3.6/copy.py", line 150, in deepcopy
#     y = copier(x, memo)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 228, in orientation
#     val = (q.y - p.y) * (r.x - q.x) - ((q.x - p.x) * (r.y - q.y))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 69, in point_in_polygon
#     if ray_intersects_segment(point, A, B):
#   File "/usr/lib/python3.6/copy.py", line 274, in _reconstruct
#     y = func(*args)
#   File "/usr/lib/python3.6/copy.py", line 215, in _deepcopy_list
#     append(deepcopy(a, memo))
#   File "/usr/lib/python3.6/copyreg.py", line 88, in __newobj__
#     return cls.__new__(cls, *args)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 93, in ray_intersects_segment
#     if P.y == A.y or P.y == B.y:
#   File "/usr/lib/python3.6/copy.py", line 180, in deepcopy
#     y = _reconstruct(x, memo, *rv)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 69, in point_in_polygon
#     if ray_intersects_segment(point, A, B):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.6/copy.py", line 274, in _reconstruct
#     y = func(*args)
# KeyboardInterrupt
#   File "/usr/lib/python3.6/copy.py", line 273, in <genexpr>
#     args = (deepcopy(arg, memo) for arg in args)
#   File "/usr/lib/python3.6/copy.py", line 148, in deepcopy
#     copier = _deepcopy_dispatch.get(cls)
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 97, in ray_intersects_segment
#     if P.y < A.y or P.y > B.y:
# KeyboardInterrupt
# KeyboardInterrupt
# 1. Processing file: 20019
# 1.1. Read
# 1. Processing file: 20038
# 1.1. Read
# 1. Processing file: 20017
# 1.1. Read
# 1. Processing file: 20046
# 1.1. Read
# 1. Processing file: 20024
# 1.1. Read
# 1. Processing file: 20031
# 1. Processing file: 20030
# 1.1. Read
# 1.1. Read
# 1. Processing file: 20020
# 1.1. Read
# 1. Processing file: 20047
# 1.1. Read
# 1. Processing file: 20003
# 1.1. Read
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1fd37dc75f22> in <module>
#      15     # Iterate over different maps
#      16     p = Pool(processes=10)
# ---> 17     p.map(run_ags_over_path, pathlist)
#      18
#      19 except Exception as e:
#
# /usr/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /usr/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
# !!! 20003 Problem occured!! /home/gustavosouza/Documents/Per/path-planning/maps/NonRegular/map_W20_003.sgl
# object of type 'NoneType' has no len()
# 1. Processing file: 20014
# 1.1. Read
# !!! 20014 Problem occured!! /home/gustavosouza/Documents/Per/path-planning/maps/NonRegular/map_W20_014.sgl
# object of type 'NoneType' has no len()
# 1. Processing file: 20026
# 1.1. Read
# !!! 20047 Problem occured!! /home/gustavosouza/Documents/Per/path-planning/maps/NonRegular/map_W20_047.sgl
# object of type 'NoneType' has no len()
# 1. Processing file: 20013
# 1.1. Read
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-18:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 421, in run
#     child = parent1.crossover(parent2)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 187, in crossover
#     child = self.generate(dna)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 245, in generate
#     child.decode()
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 603, in __fitness_obstacles_RC
#     if segment_in_polygon(wp1, wp2, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 603, in __fitness_obstacles_RC
#     if segment_in_polygon(wp1, wp2, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 142, in segment_in_polygon
#     if segment_intersects_segment(wp1, wp2, vertex1, vertex2):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 142, in segment_in_polygon
#     if segment_intersects_segment(wp1, wp2, vertex1, vertex2):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 128, in decode
#     self.dna_decoded = self._decode_gene() # TODO: Organizar, voltar como era a linha de cima. Fazer função abaixo só computar o gene
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 194, in segment_intersects_segment
#     if o3 == 0 and on_segment(p2, p1, q2):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 176, in segment_intersects_segment
#     o2 = orientation(p1, q1, q2)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 599, in __fitness_obstacles_RC
#     if point_in_polygon(wp1, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 141, in _decode_gene
#     for i in range(0, len(dna)):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 69, in point_in_polygon
#     if ray_intersects_segment(point, A, B):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 603, in __fitness_obstacles_RC
#     if segment_in_polygon(wp1, wp2, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 142, in segment_in_polygon
#     if segment_intersects_segment(wp1, wp2, vertex1, vertex2):
#   File "<ipython-input-4-417d1f0eb21e>", line 28, in run_ags_over_path
#     best = ag.run(info=False)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 603, in __fitness_obstacles_RC
#     if segment_in_polygon(wp1, wp2, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 603, in __fitness_obstacles_RC
#     if segment_in_polygon(wp1, wp2, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 427, in run
#     self._fitness(child, self.map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 603, in __fitness_obstacles_RC
#     if segment_in_polygon(wp1, wp2, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 175, in segment_intersects_segment
#     o1 = orientation(p1, q1, p2)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 142, in segment_in_polygon
#     if segment_intersects_segment(wp1, wp2, vertex1, vertex2):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 142, in segment_in_polygon
#     if segment_intersects_segment(wp1, wp2, vertex1, vertex2):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 230, in orientation
#     if val == 0:
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 175, in segment_intersects_segment
#     o1 = orientation(p1, q1, p2)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 177, in segment_intersects_segment
#     o3 = orientation(p2, q2, p1)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 599, in __fitness_obstacles_RC
#     if point_in_polygon(wp1, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 60, in point_in_polygon
#     for vertex1, vertex2 in pairwise_circle(polygon):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 233, in orientation
#     return 1 if val > 0 else 2  # clock or counterclock wise
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 218, in orientation
#     def orientation(p, q, r):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 228, in orientation
#     val = (q.y - p.y) * (r.x - q.x) - ((q.x - p.x) * (r.y - q.y))
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 543, in _fitness
#     fit_obs = self.__fitness_obstacles(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 16, in pairwise_circle
#     first_value = next(b, None)
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 582, in __fitness_obstacles
#     return self.__fitness_obstacles_RC(subject, map)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 142, in segment_in_polygon
#     if segment_intersects_segment(wp1, wp2, vertex1, vertex2):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/genetic.py", line 603, in __fitness_obstacles_RC
#     if segment_in_polygon(wp1, wp2, area_n):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 176, in segment_intersects_segment
#     o2 = orientation(p1, q1, q2)
# KeyboardInterrupt
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 142, in segment_in_polygon
#     if segment_intersects_segment(wp1, wp2, vertex1, vertex2):
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 178, in segment_intersects_segment
#     o4 = orientation(p2, q2, q1)
#   File "/home/gustavosouza/Documents/Per/path-planning/genetic/utils.py", line 228, in orientation
#     val = (q.y - p.y) * (r.x - q.x) - ((q.x - p.x) * (r.y - q.y))
# KeyboardInterrupt

# %%
with open(MAPS_PATH+'map_W20_042_ag.p','rb') as ag_file:
    ag_test = pickle.load(ag_file)

# %%
pathlist = Path(MAPS_PATH).glob('**/*.sgl')
maps = []
for path in pathlist:
    with open(str(path), 'r') as f:
        lines = f.readlines()  
        maps.append(Map(wp_ori, wp_des, sgl_read_areas(lines), inflation_rate=0))
    break

# %%
vis_mapa(maps[0], route=ag_test.best.get_route())

# %%
pathlist = Path(MAPS_PATH).glob('**/*.sgl')
pathlist = [str(path) for path in pathlist]
len(pathlist)

# %%
run_ags_over_path_E(MAPS_PATH+'map_W20_023.sgl')
# Out:
# 1. Processing file: 20023
# 1.1. Read
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-2d665fa1cf43> in <module>
# ----> 1 run_ags_over_path_E(MAPS_PATH+'map_W20_023.sgl')
#
# <ipython-input-10-5d5ea8f74215> in run_ags_over_path_E(path)
#      26         )
#      27
# ---> 28         best = ag.run(info=False)
#      29         print(f'2. AG generated: {number}')
#      30
#
# ~/Documents/Per/path-planning/genetic/genetic.py in run(self, max_exec_time, verbose, info, debug)
#     422
#     423                     # Mutação
# --> 424                     child.mutation()
#     425
#     426                     # Fitness
#
# ~/Documents/Per/path-planning/genetic/genetic.py in mutation(self, mutation_prob)
#     265             self.decode()
#     266
# --> 267             return True
#     268         return False
#     269
#
# ~/Documents/Per/path-planning/genetic/genetic.py in decode(self)
#     126
#     127         return Gene(a, e)
# --> 128
#     129     # ---
#     130
#
# ~/Documents/Per/path-planning/genetic/genetic.py in _decode_gene(self)
#     139
#     140         # parametros
# --> 141         dna = self.dna
#     142         delta_T = self.delta_T
#     143         m = self.m
#
# TypeError: object of type 'NoneType' has no len()

# %%
def boundary(val, val_min, val_max):
    """Clips a value to stay within the range [val_min; val_max]."""
    return max(min(val, val_max), val_min)
